# %% [markdown]
# ## Instalações e bibliotecas necessárias

# %%
# !pip install PYSPARK &> /dev/null

# %%
# !pip install gcsfs &> /dev/null

# %%
# !pip install sqlalchemy &> /dev/null

# %%
# !pip install pymysql &> /dev/null

# %%
# !pip install mysql-connector-python &> /dev/null

# %%
# Bibliotecas Necessárias
from pyspark.sql import SparkSession
from pyspark import SparkConf
import pyspark.sql.functions as F
import os

import pandas as pd

import pymysql
from sqlalchemy import create_engine
import mysql.connector
from mysql.connector import Error
from IPython.lib import passwd

# Bibliotecas do cloud storage
from google.cloud import storage

# %% [markdown]
# ## Conectores e Funções

# %%
# Configuração de chave de segurança

serviceAccount = '/content/desafio-rox-375303-3b169fea64c6.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# %%
# Ip colab necessário para acesso ao MySQL na GCP

# !curl ipecho.net/plain
# Out:
# 34.81.120.183

# %%
# Acesso ao bucket na gcp
client = storage.Client()

# Variável para receber o nome da bucket
bucket = client.get_bucket('desafio-rox-leandro')

# Variável que vai receber o caminho dos arquivos RAW

path_Person = 'gs://desafio-rox-leandro/RAW/Person.Person.csv'
path_Product = 'gs://desafio-rox-leandro/RAW/Production.Product.csv'
path_Customer = 'gs://desafio-rox-leandro/RAW/Sales.Customer.csv'
path_SalesOrderDetail = 'gs://desafio-rox-leandro/RAW/Sales.SalesOrderDetail.csv'
path_SalesOrderHeader = 'gs://desafio-rox-leandro/RAW/Sales.SalesOrderHeader.csv'
path_SpecialOfferProduct = 'gs://desafio-rox-leandro/RAW/Sales.SpecialOfferProduct.csv'

# %%
# Executa o comando e altera o banco no mysql

def executar_sql(conexao, sql): 
  cursor = conexao.cursor(buffered=True)
  try:
    cursor.execute(sql)
    conexao.commit() 
    print('Query executada com sucesso!')
  except mysql.connector.Error as err:
    print('Erro ao executar a Query!',err)

# %%
# Executa o comando e retorna uma tupla como resultado da query

def retorno_sql(conexao, sql): 
  cursor = conexao.cursor(buffered=True)
  retorno = None
  try:
    cursor.execute(sql)
    retorno = cursor.fetchall()
    return retorno
  except mysql.connector.Error as err:
    print('Erro ao listar os dados da Query!',err)

# %% [markdown]
# ## Analises em pyspark para tratamento

# %%
# Criando a sparkSession

spark = (
    SparkSession.builder
         .master('local')
         .appName('desafio_rox')
         .config('spark.ui.port', '4050')
         .config("spark.jars", 'https://storage.googleapis.com/hadoop-lib/gcs/gcs-connector-hadoop2-latest.jar')
         .getOrCreate()
         )

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://63ffbe08d61c:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>desafio_rox</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### df_Person

# %%
# Criando o dataframe em spark

df_Person = (
    spark.read.format('csv')
              .option('delimiter', ';')
              .option('header', 'true')
              .option('inferschema', 'true')
              .load(path_Person)
)

# %%
# Analisando o esquema do dataframe

df_Person.printSchema()
# Out:
# root
#  |-- BusinessEntityID: integer (nullable = true)
#  |-- PersonType: string (nullable = true)
#  |-- NameStyle: integer (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- FirstName: string (nullable = true)
#  |-- MiddleName: string (nullable = true)
#  |-- LastName: string (nullable = true)
#  |-- Suffix: string (nullable = true)
#  |-- EmailPromotion: integer (nullable = true)
#  |-- AdditionalContactInfo: string (nullable = true)
#  |-- Demographics: string (nullable = true)
#  |-- rowguid: string (nullable = true)
#  |-- ModifiedDate: timestamp (nullable = true)

# %%
# Exibindo a tabela para início da análise

df_Person.show(3)
# Out:
# +----------------+----------+---------+-----+---------+----------+----------+------+--------------+---------------------+--------------------+--------------------+-------------------+
# |BusinessEntityID|PersonType|NameStyle|Title|FirstName|MiddleName|  LastName|Suffix|EmailPromotion|AdditionalContactInfo|        Demographics|             rowguid|       ModifiedDate|
# +----------------+----------+---------+-----+---------+----------+----------+------+--------------+---------------------+--------------------+--------------------+-------------------+
# |               1|        EM|        0| NULL|      Ken|         J|   Sánchez|  NULL|             0|                 NULL|"<IndividualSurve...|92C4279F-1207-48A...|2009-01-07 00:00:00|
# |               2|        EM|        0| NULL|    Terri|       Lee|     Duffy|  NULL|             1|                 NULL|"<IndividualSurve...|D8763459-8AA8-47C...|2008-01-24 00:00:00|
# |               3|        EM|        0| NULL|  Roberto|      NULL|Tamburello|  NULL|             0|                 NULL|"<IndividualSurve...|E1A2555E-0828-434...|2007-11-04 00:00:00|
# +----------------+----------+---------+-----+---------+----------+----------+------+--------------+---------------------+--------------------+--------------------+-------------------+
# only showing top 3 rows

# %%
# Verificando linhas repetidas no dataframe

linhas_repetidas = (df_Person.count() - df_Person.distinct().count())
print(linhas_repetidas)
# Out:
# 0

# %%
# Buscando por por erros graves como por exemplo /*@#$% em todas as colunas
# trazendo valores únicos e ordenando asc e desc eles estão no topo ou no final

colunas = df_Person.columns
for i in range(len(colunas)):
  df_Person.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=False).show(5)
  df_Person.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=True).show(5)
# Out:
# +----------------+
# |BusinessEntityID|
# +----------------+
# |           20777|
# |           20776|
# |           20775|
# |           20774|
# |           20773|
# +----------------+
# only showing top 5 rows
#
# +----------------+
# |BusinessEntityID|
# +----------------+
# |               1|
# |               2|
# |               3|
# |               4|
# |               5|
# +----------------+
# only showing top 5 rows
#
# +----------+
# |PersonType|
# +----------+
# |        VC|
# |        SP|
# |        SC|
# |        IN|
# |        GC|
# +----------+
# only showing top 5 rows
#
# +----------+
# |PersonType|
# +----------+
# |        EM|
# |        GC|
# |        IN|
# |        SC|
# |        SP|
# +----------+
# only showing top 5 rows
#
# +---------+
# |NameStyle|
# +---------+
# |        0|
# +---------+
#
# +---------+
# |NameStyle|
# +---------+
# |        0|
# +---------+
#
# +-----+
# |Title|
# +-----+
# | Sra.|
# |  Sr.|
# | NULL|
# |  Ms.|
# |   Ms|
# +-----+
# only showing top 5 rows
#
# +-----+
# |Title|
# +-----+
# |  Mr.|
# | Mrs.|
# |   Ms|
# |  Ms.|
# | NULL|
# +-----+
# only showing top 5 rows
#
# +---------+
# |FirstName|
# +---------+
# |      Zoe|
# |    Zheng|
# |   Zainal|
# |  Zachary|
# |   Yvonne|
# +---------+
# only showing top 5 rows
#
# +---------+
# |FirstName|
# +---------+
# |       A.|
# | A. Scott|
# |    Aaron|
# |     Abby|
# |      Abe|
# +---------+
# only showing top 5 rows
#
# +----------+
# |MiddleName|
# +----------+
# |         l|
# |        Z.|
# |         Z|
# |      Yuan|
# |        Y.|
# +----------+
# only showing top 5 rows
#
# +----------+
# |MiddleName|
# +----------+
# |         A|
# |        A.|
# |       Ann|
# |         B|
# |        B.|
# +----------+
# only showing top 5 rows
#
# +--------+
# |LastName|
# +--------+
# |Zwilling|
# |Zukowski|
# |Zugelder|
# |  Zubaty|
# |Zimprich|
# +--------+
# only showing top 5 rows
#
# +-----------+
# |   LastName|
# +-----------+
# |      Abbas|
# |       Abel|
# |Abercrombie|
# |   Abolrous|
# |    Acevedo|
# +-----------+
# only showing top 5 rows
#
# +------+
# |Suffix|
# +------+
# |   Sr.|
# |   PhD|
# |  NULL|
# |   Jr.|
# |    IV|
# +------+
# only showing top 5 rows
#
# +------+
# |Suffix|
# +------+
# |    II|
# |   III|
# |    IV|
# |   Jr.|
# |  NULL|
# +------+
# only showing top 5 rows
#
# +--------------+
# |EmailPromotion|
# +--------------+
# |             2|
# |             1|
# |             0|
# +--------------+
#
# +--------------+
# |EmailPromotion|
# +--------------+
# |             0|
# |             1|
# |             2|
# +--------------+
#
# +---------------------+
# |AdditionalContactInfo|
# +---------------------+
# |                 NULL|
# | "<AdditionalConta...|
# | "<AdditionalConta...|
# | "<AdditionalConta...|
# | "<AdditionalConta...|
# +---------------------+
# only showing top 5 rows
#
# +---------------------+
# |AdditionalContactInfo|
# +---------------------+
# | "<AdditionalConta...|
# | "<AdditionalConta...|
# | "<AdditionalConta...|
# | "<AdditionalConta...|
# | "<AdditionalConta...|
# +---------------------+
# only showing top 5 rows
#
# +--------------------+
# |        Demographics|
# +--------------------+
# |"<IndividualSurve...|
# |"<IndividualSurve...|
# |"<IndividualSurve...|
# |"<IndividualSurve...|
# |"<IndividualSurve...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |        Demographics|
# +--------------------+
# |"<IndividualSurve...|
# |"<IndividualSurve...|
# |"<IndividualSurve...|
# |"<IndividualSurve...|
# |"<IndividualSurve...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |FFFF4F5E-57D3-472...|
# |FFFF485E-6186-4DE...|
# |FFFD686B-6914-40B...|
# |FFF6C3FB-633E-4EC...|
# |FFF579A8-900B-4FA...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |000191EF-7424-4A5...|
# |00034881-67FA-4CC...|
# |00061FFE-1635-48C...|
# |0006B909-E986-4F5...|
# |00083CD8-D326-4A3...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |        ModifiedDate|
# +--------------------+
# |2015-04-15 16:33:...|
# |2015-04-15 16:33:...|
# |2015-04-15 16:33:...|
# |2015-04-15 16:33:...|
# |2015-04-15 16:33:...|
# +--------------------+
# only showing top 5 rows
#
# +-------------------+
# |       ModifiedDate|
# +-------------------+
# |2006-06-23 00:00:00|
# |2007-01-19 00:00:00|
# |2007-11-04 00:00:00|
# |2007-11-28 00:00:00|
# |2007-12-04 00:00:00|
# +-------------------+
# only showing top 5 rows

# %%
# COLUNA MiddleName aparenta ter um número 1
# Procurando por número dentro da coluna MiddleName
# Letra L minúscula, curiosamente sendo considerada após a letra Z no código anterior

df_Person.select(F.col('MiddleName')).filter(F.col('MiddleName') == 'l').show(50)
# Out:
# +----------+
# |MiddleName|
# +----------+
# |         l|
# |         l|
# |         l|
# |         l|
# |         l|
# +----------+

# %%
# Pré análise PersonType e Quantidade.

df_Person.groupBy('PersonType').count().show(10)
# Out:
# +----------+-----+
# |PersonType|count|
# +----------+-----+
# |        SC|  753|
# |        SP|   17|
# |        IN|18484|
# |        EM|  273|
# |        GC|  289|
# |        VC|  156|
# +----------+-----+

# %%
'''
Dataframe ok, sem alteracao
'''
# Out:
# '\nDataframe ok, sem alteracao\n'

# %% [markdown]
# ### df_Product

# %%
# Criando o dataframe em spark

df_Product = (
    spark.read.format('csv')
              .option('delimiter', ';')
              .option('header', 'true')
              .option('inferschema', 'true')
              .load(path_Product)
)

# %%
# Analisando o esquema do dataframe

df_Product.printSchema()
# Out:
# root
#  |-- ProductID: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- ProductNumber: string (nullable = true)
#  |-- MakeFlag: integer (nullable = true)
#  |-- FinishedGoodsFlag: integer (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- SafetyStockLevel: integer (nullable = true)
#  |-- ReorderPoint: integer (nullable = true)
#  |-- StandardCost: string (nullable = true)
#  |-- ListPrice: string (nullable = true)
#  |-- Size: string (nullable = true)
#  |-- SizeUnitMeasureCode: string (nullable = true)
#  |-- WeightUnitMeasureCode: string (nullable = true)
#  |-- Weight: string (nullable = true)
#  |-- DaysToManufacture: integer (nullable = true)
#  |-- ProductLine: string (nullable = true)
#  |-- Class: string (nullable = true)
#  |-- Style: string (nullable = true)
#  |-- ProductSubcategoryID: string (nullable = true)
#  |-- ProductModelID: string (nullable = true)
#  |-- SellStartDate: timestamp (nullable = true)
#  |-- SellEndDate: string (nullable = true)
#  |-- DiscontinuedDate: string (nullable = true)
#  |-- rowguid: string (nullable = true)
#  |-- ModifiedDate: timestamp (nullable = true)

# %%
# Exibindo a tabela para início da análise


df_Product.show(3)
# Out:
# +---------+---------------+-------------+--------+-----------------+-----+----------------+------------+------------+---------+----+-------------------+---------------------+------+-----------------+-----------+-----+-----+--------------------+--------------+-------------------+-----------+----------------+--------------------+--------------------+
# |ProductID|           Name|ProductNumber|MakeFlag|FinishedGoodsFlag|Color|SafetyStockLevel|ReorderPoint|StandardCost|ListPrice|Size|SizeUnitMeasureCode|WeightUnitMeasureCode|Weight|DaysToManufacture|ProductLine|Class|Style|ProductSubcategoryID|ProductModelID|      SellStartDate|SellEndDate|DiscontinuedDate|             rowguid|        ModifiedDate|
# +---------+---------------+-------------+--------+-----------------+-----+----------------+------------+------------+---------+----+-------------------+---------------------+------+-----------------+-----------+-----+-----+--------------------+--------------+-------------------+-----------+----------------+--------------------+--------------------+
# |        1|Adjustable Race|      AR-5381|       0|                0| NULL|            1000|         750|        0,00|     0,00|NULL|               NULL|                 NULL|  NULL|                0|       NULL| NULL| NULL|                NULL|          NULL|2008-04-30 00:00:00|       NULL|            NULL|694215B7-08F7-4C0...|2014-02-08 10:01:...|
# |        2|   Bearing Ball|      BA-8327|       0|                0| NULL|            1000|         750|        0,00|     0,00|NULL|               NULL|                 NULL|  NULL|                0|       NULL| NULL| NULL|                NULL|          NULL|2008-04-30 00:00:00|       NULL|            NULL|58AE3C20-4F3A-474...|2014-02-08 10:01:...|
# |        3|BB Ball Bearing|      BE-2349|       1|                0| NULL|             800|         600|        0,00|     0,00|NULL|               NULL|                 NULL|  NULL|                1|       NULL| NULL| NULL|                NULL|          NULL|2008-04-30 00:00:00|       NULL|            NULL|9C21AED2-5BFA-4F1...|2014-02-08 10:01:...|
# +---------+---------------+-------------+--------+-----------------+-----+----------------+------------+------------+---------+----+-------------------+---------------------+------+-----------------+-----------+-----+-----+--------------------+--------------+-------------------+-----------+----------------+--------------------+--------------------+
# only showing top 3 rows

# %%
# Verificando linhas repetidas no dataframe

linhas_repetidas = (df_Product.count() - df_Product.distinct().count())
print(linhas_repetidas)
# Out:
# 0

# %%
# Buscando por por erros graves como por exemplo /*@#$% em todas as colunas
# trazendo valores únicos e ordenando asc e desc eles estão no topo ou no final

colunas = df_Product.columns
for i in range(len(colunas)):
  df_Product.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=False).show(5)
  df_Product.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=True).show(5)
# Out:
# +---------+
# |ProductID|
# +---------+
# |      999|
# |      998|
# |      997|
# |      996|
# |      995|
# +---------+
# only showing top 5 rows
#
# +---------+
# |ProductID|
# +---------+
# |        1|
# |        2|
# |        3|
# |        4|
# |      316|
# +---------+
# only showing top 5 rows
#
# +--------------------+
# |                Name|
# +--------------------+
# |   Women's Tights, S|
# |   Women's Tights, M|
# |   Women's Tights, L|
# |Women's Mountain ...|
# |Women's Mountain ...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |                Name|
# +--------------------+
# |        AWC Logo Cap|
# |     Adjustable Race|
# |All-Purpose Bike ...|
# |     BB Ball Bearing|
# |        Bearing Ball|
# +--------------------+
# only showing top 5 rows
#
# +-------------+
# |ProductNumber|
# +-------------+
# |      WB-H098|
# |    VE-C304-S|
# |    VE-C304-M|
# |    VE-C304-L|
# |      TT-T092|
# +-------------+
# only showing top 5 rows
#
# +-------------+
# |ProductNumber|
# +-------------+
# |      AR-5381|
# |      BA-8327|
# |      BB-7421|
# |      BB-8107|
# |      BB-9108|
# +-------------+
# only showing top 5 rows
#
# +--------+
# |MakeFlag|
# +--------+
# |       1|
# |       0|
# +--------+
#
# +--------+
# |MakeFlag|
# +--------+
# |       0|
# |       1|
# +--------+
#
# +-----------------+
# |FinishedGoodsFlag|
# +-----------------+
# |                1|
# |                0|
# +-----------------+
#
# +-----------------+
# |FinishedGoodsFlag|
# +-----------------+
# |                0|
# |                1|
# +-----------------+
#
# +------------+
# |       Color|
# +------------+
# |      Yellow|
# |       White|
# |Silver/Black|
# |      Silver|
# |         Red|
# +------------+
# only showing top 5 rows
#
# +-----+
# |Color|
# +-----+
# |Black|
# | Blue|
# | Grey|
# |Multi|
# | NULL|
# +-----+
# only showing top 5 rows
#
# +----------------+
# |SafetyStockLevel|
# +----------------+
# |            1000|
# |             800|
# |             500|
# |             100|
# |              60|
# +----------------+
# only showing top 5 rows
#
# +----------------+
# |SafetyStockLevel|
# +----------------+
# |               4|
# |              60|
# |             100|
# |             500|
# |             800|
# +----------------+
# only showing top 5 rows
#
# +------------+
# |ReorderPoint|
# +------------+
# |         750|
# |         600|
# |         375|
# |          75|
# |          45|
# +------------+
# only showing top 5 rows
#
# +------------+
# |ReorderPoint|
# +------------+
# |           3|
# |          45|
# |          75|
# |         375|
# |         600|
# +------------+
# only showing top 5 rows
#
# +------------+
# |StandardCost|
# +------------+
# |       98,77|
# |     96,7964|
# |     92,8071|
# |      9,3463|
# |      9,1593|
# +------------+
# only showing top 5 rows
#
# +------------+
# |StandardCost|
# +------------+
# |        0,00|
# |      0,8565|
# |      1,4923|
# |      1,8663|
# |     10,3084|
# +------------+
# only showing top 5 rows
#
# +---------+
# |ListPrice|
# +---------+
# |    91,57|
# |    91,49|
# |     9,99|
# |     9,50|
# |    89,99|
# +---------+
# only showing top 5 rows
#
# +---------+
# |ListPrice|
# +---------+
# |     0,00|
# |  1003,91|
# |   101,24|
# |   102,29|
# |   106,50|
# +---------+
# only showing top 5 rows
#
# +----+
# |Size|
# +----+
# |  XL|
# |   S|
# |NULL|
# |   M|
# |   L|
# +----+
# only showing top 5 rows
#
# +----+
# |Size|
# +----+
# |  38|
# |  40|
# |  42|
# |  44|
# |  46|
# +----+
# only showing top 5 rows
#
# +-------------------+
# |SizeUnitMeasureCode|
# +-------------------+
# |               NULL|
# |                CM |
# +-------------------+
#
# +-------------------+
# |SizeUnitMeasureCode|
# +-------------------+
# |                CM |
# |               NULL|
# +-------------------+
#
# +---------------------+
# |WeightUnitMeasureCode|
# +---------------------+
# |                 NULL|
# |                  LB |
# |                  G  |
# +---------------------+
#
# +---------------------+
# |WeightUnitMeasureCode|
# +---------------------+
# |                  G  |
# |                  LB |
# |                 NULL|
# +---------------------+
#
# +------+
# |Weight|
# +------+
# |  NULL|
# |900.00|
# |890.00|
# | 88.00|
# |850.00|
# +------+
# only showing top 5 rows
#
# +-------+
# | Weight|
# +-------+
# |1000.00|
# |1050.00|
# |  13.77|
# |  14.13|
# |  14.42|
# +-------+
# only showing top 5 rows
#
# +-----------------+
# |DaysToManufacture|
# +-----------------+
# |                4|
# |                2|
# |                1|
# |                0|
# +-----------------+
#
# +-----------------+
# |DaysToManufacture|
# +-----------------+
# |                0|
# |                1|
# |                2|
# |                4|
# +-----------------+
#
# +-----------+
# |ProductLine|
# +-----------+
# |         T |
# |         S |
# |         R |
# |       NULL|
# |         M |
# +-----------+
#
# +-----------+
# |ProductLine|
# +-----------+
# |         M |
# |       NULL|
# |         R |
# |         S |
# |         T |
# +-----------+
#
# +-----+
# |Class|
# +-----+
# | NULL|
# |   M |
# |   L |
# |   H |
# +-----+
#
# +-----+
# |Class|
# +-----+
# |   H |
# |   L |
# |   M |
# | NULL|
# +-----+
#
# +-----+
# |Style|
# +-----+
# |   W |
# |   U |
# | NULL|
# |   M |
# +-----+
#
# +-----+
# |Style|
# +-----+
# |   M |
# | NULL|
# |   U |
# |   W |
# +-----+
#
# +--------------------+
# |ProductSubcategoryID|
# +--------------------+
# |                NULL|
# |                   9|
# |                   8|
# |                   7|
# |                   6|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |ProductSubcategoryID|
# +--------------------+
# |                   1|
# |                  10|
# |                  11|
# |                  12|
# |                  13|
# +--------------------+
# only showing top 5 rows
#
# +--------------+
# |ProductModelID|
# +--------------+
# |          NULL|
# |            99|
# |            98|
# |            97|
# |            96|
# +--------------+
# only showing top 5 rows
#
# +--------------+
# |ProductModelID|
# +--------------+
# |             1|
# |            10|
# |           100|
# |           101|
# |           102|
# +--------------+
# only showing top 5 rows
#
# +-------------------+
# |      SellStartDate|
# +-------------------+
# |2013-05-30 00:00:00|
# |2012-05-30 00:00:00|
# |2011-05-31 00:00:00|
# |2008-04-30 00:00:00|
# +-------------------+
#
# +-------------------+
# |      SellStartDate|
# +-------------------+
# |2008-04-30 00:00:00|
# |2011-05-31 00:00:00|
# |2012-05-30 00:00:00|
# |2013-05-30 00:00:00|
# +-------------------+
#
# +--------------------+
# |         SellEndDate|
# +--------------------+
# |                NULL|
# |2013-05-29 00:00:...|
# |2012-05-29 00:00:...|
# +--------------------+
#
# +--------------------+
# |         SellEndDate|
# +--------------------+
# |2012-05-29 00:00:...|
# |2013-05-29 00:00:...|
# |                NULL|
# +--------------------+
#
# +----------------+
# |DiscontinuedDate|
# +----------------+
# |            NULL|
# +----------------+
#
# +----------------+
# |DiscontinuedDate|
# +----------------+
# |            NULL|
# +----------------+
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |FE0678ED-AEF2-4C5...|
# |FD7C0858-4179-48C...|
# |FD449C82-A259-4FA...|
# |FCFEA68F-310E-4E6...|
# |FCFC0A4F-4563-4E0...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |01A8C3FC-ED52-458...|
# |01C901E3-4323-48E...|
# |02935111-A546-4C6...|
# |02C48826-21AD-41F...|
# |040A4B7D-4060-450...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |        ModifiedDate|
# +--------------------+
# |2014-02-08 10:03:...|
# |2014-02-08 10:01:...|
# +--------------------+
#
# +--------------------+
# |        ModifiedDate|
# +--------------------+
# |2014-02-08 10:01:...|
# |2014-02-08 10:03:...|
# +--------------------+

# %%
# COLUNA DiscontinuedDate aparenta ter um único valor no caso NULL
# Decidi nao dropar

df_Product.select(F.col('DiscontinuedDate')).filter(F.col('DiscontinuedDate') != 'NULL').show(50)
# Out:
# +----------------+
# |DiscontinuedDate|
# +----------------+
# +----------------+

# %%
# Pré análise DaysToManufacture e Quantidade.

df_Product.groupBy('DaysToManufacture').count().show(10)
# Out:
# +-----------------+-----+
# |DaysToManufacture|count|
# +-----------------+-----+
# |                1|  154|
# |                4|   97|
# |                2|    7|
# |                0|  246|
# +-----------------+-----+

# %%
'''
Dataframe ok, 
alterar , para . em (StandardCost, ListPrice)
'''
# Out:
# '\nDataframe ok, \nalterar , para . em (StandardCost, ListPrice)\n'

# %% [markdown]
# ### df_Customer

# %%
# Criando o dataframe em spark

df_Customer = (
    spark.read.format('csv')
              .option('delimiter', ';')
              .option('header', 'true')
              .option('inferschema', 'true')
              .load(path_Customer)
)

# %%
# Analisando o esquema do dataframe

df_Customer.printSchema()
# Out:
# root
#  |-- CustomerID: integer (nullable = true)
#  |-- PersonID: string (nullable = true)
#  |-- StoreID: string (nullable = true)
#  |-- TerritoryID: integer (nullable = true)
#  |-- AccountNumber: string (nullable = true)
#  |-- rowguid: string (nullable = true)
#  |-- ModifiedDate: timestamp (nullable = true)

# %%
# Exibindo a tabela para início da análise

df_Customer.show(3)
# Out:
# +----------+--------+-------+-----------+-------------+--------------------+--------------------+
# |CustomerID|PersonID|StoreID|TerritoryID|AccountNumber|             rowguid|        ModifiedDate|
# +----------+--------+-------+-----------+-------------+--------------------+--------------------+
# |         1|    NULL|    934|          1|   AW00000001|3F5AE95E-B87D-4AE...|2014-09-12 11:15:...|
# |         2|    NULL|   1028|          1|   AW00000002|E552F657-A9AF-4A7...|2014-09-12 11:15:...|
# |         3|    NULL|    642|          4|   AW00000003|130774B1-DB21-4EF...|2014-09-12 11:15:...|
# +----------+--------+-------+-----------+-------------+--------------------+--------------------+
# only showing top 3 rows

# %%
# Verificando linhas repetidas no dataframe

linhas_repetidas = (df_Customer.count() - df_Customer.distinct().count())
print(linhas_repetidas)
# Out:
# 0

# %%
# Buscando por por erros graves como por exemplo /*@#$% em todas as colunas
# trazendo valores únicos e ordenando asc e desc eles estão no topo ou no final

colunas = df_Customer.columns
for i in range(len(colunas)):
  df_Customer.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=False).show(5)
  df_Customer.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=True).show(5)
# Out:
# +----------+
# |CustomerID|
# +----------+
# |     30118|
# |     30117|
# |     30116|
# |     30115|
# |     30114|
# +----------+
# only showing top 5 rows
#
# +----------+
# |CustomerID|
# +----------+
# |         1|
# |         2|
# |         3|
# |         4|
# |         5|
# +----------+
# only showing top 5 rows
#
# +--------+
# |PersonID|
# +--------+
# |    NULL|
# |    9999|
# |    9998|
# |    9997|
# |    9996|
# +--------+
# only showing top 5 rows
#
# +--------+
# |PersonID|
# +--------+
# |   10000|
# |   10001|
# |   10002|
# |   10003|
# |   10004|
# +--------+
# only showing top 5 rows
#
# +-------+
# |StoreID|
# +-------+
# |   NULL|
# |    998|
# |    996|
# |    994|
# |    992|
# +-------+
# only showing top 5 rows
#
# +-------+
# |StoreID|
# +-------+
# |   1000|
# |   1002|
# |   1004|
# |   1006|
# |   1008|
# +-------+
# only showing top 5 rows
#
# +-----------+
# |TerritoryID|
# +-----------+
# |         10|
# |          9|
# |          8|
# |          7|
# |          6|
# +-----------+
# only showing top 5 rows
#
# +-----------+
# |TerritoryID|
# +-----------+
# |          1|
# |          2|
# |          3|
# |          4|
# |          5|
# +-----------+
# only showing top 5 rows
#
# +-------------+
# |AccountNumber|
# +-------------+
# |   AW00030118|
# |   AW00030117|
# |   AW00030116|
# |   AW00030115|
# |   AW00030114|
# +-------------+
# only showing top 5 rows
#
# +-------------+
# |AccountNumber|
# +-------------+
# |   AW00000001|
# |   AW00000002|
# |   AW00000003|
# |   AW00000004|
# |   AW00000005|
# +-------------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |FFFFF252-5BFC-482...|
# |FFFD9639-491F-4B9...|
# |FFFB81C8-BF8F-48F...|
# |FFF9BB54-2701-434...|
# |FFF9A40A-CB5C-433...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |0006E071-D04E-426...|
# |000DC1BD-8B01-41B...|
# |000F058F-7B32-427...|
# |00156471-294F-446...|
# |00172C37-91A8-4A7...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |        ModifiedDate|
# +--------------------+
# |2014-09-12 11:15:...|
# +--------------------+
#
# +--------------------+
# |        ModifiedDate|
# +--------------------+
# |2014-09-12 11:15:...|
# +--------------------+

# %%
# COLUNA ModifiedDate aparenta ter um único valor no caso uma data específica
# Decidi nao dropar

df_Customer.select(F.col('ModifiedDate')).distinct().show(5)
# Out:
# +--------------------+
# |        ModifiedDate|
# +--------------------+
# |2014-09-12 11:15:...|
# +--------------------+

# %%
'''
Dataframe ok, sem alteracao
'''
# Out:
# '\nDataframe ok, sem alteracao\n'

# %% [markdown]
# ### df_SalesOrderDetail

# %%
# Criando o dataframe em spark

df_SalesOrderDetail = (
    spark.read.format('csv')
              .option('delimiter', ';')
              .option('header', 'true')
              .option('inferschema', 'true')
              .load(path_SalesOrderDetail)
)

# %%
# Analisando o esquema do dataframe

df_SalesOrderDetail.printSchema()
# Out:
# root
#  |-- SalesOrderID: integer (nullable = true)
#  |-- SalesOrderDetailID: integer (nullable = true)
#  |-- CarrierTrackingNumber: string (nullable = true)
#  |-- OrderQty: integer (nullable = true)
#  |-- ProductID: integer (nullable = true)
#  |-- SpecialOfferID: integer (nullable = true)
#  |-- UnitPrice: string (nullable = true)
#  |-- UnitPriceDiscount: string (nullable = true)
#  |-- LineTotal: double (nullable = true)
#  |-- rowguid: string (nullable = true)
#  |-- ModifiedDate: timestamp (nullable = true)

# %%
# Exibindo a tabela para início da análise

df_SalesOrderDetail.show(3)
# Out:
# +------------+------------------+---------------------+--------+---------+--------------+---------+-----------------+---------+--------------------+-------------------+
# |SalesOrderID|SalesOrderDetailID|CarrierTrackingNumber|OrderQty|ProductID|SpecialOfferID|UnitPrice|UnitPriceDiscount|LineTotal|             rowguid|       ModifiedDate|
# +------------+------------------+---------------------+--------+---------+--------------+---------+-----------------+---------+--------------------+-------------------+
# |       43659|                 1|         4911-403C-98|       1|      776|             1| 2024,994|             0,00| 2024.994|B207C96D-D9E6-402...|2011-05-31 00:00:00|
# |       43659|                 2|         4911-403C-98|       3|      777|             1| 2024,994|             0,00| 6074.982|7ABB600D-1E77-41B...|2011-05-31 00:00:00|
# |       43659|                 3|         4911-403C-98|       1|      778|             1| 2024,994|             0,00| 2024.994|475CF8C6-49F6-486...|2011-05-31 00:00:00|
# +------------+------------------+---------------------+--------+---------+--------------+---------+-----------------+---------+--------------------+-------------------+
# only showing top 3 rows

# %%
# Verificando linhas repetidas no dataframe

linhas_repetidas = (df_SalesOrderDetail.count() - df_SalesOrderDetail.distinct().count())
print(linhas_repetidas)
# Out:
# 0

# %%
# Buscando por por erros graves como por exemplo /*@#$% em todas as colunas
# trazendo valores únicos e ordenando asc e desc eles estão no topo ou no final

colunas = df_SalesOrderDetail.columns
for i in range(len(colunas)):
  df_SalesOrderDetail.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=False).show(5)
  df_SalesOrderDetail.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=True).show(5)
# Out:
# +------------+
# |SalesOrderID|
# +------------+
# |       75123|
# |       75122|
# |       75121|
# |       75120|
# |       75119|
# +------------+
# only showing top 5 rows
#
# +------------+
# |SalesOrderID|
# +------------+
# |       43659|
# |       43660|
# |       43661|
# |       43662|
# |       43663|
# +------------+
# only showing top 5 rows
#
# +------------------+
# |SalesOrderDetailID|
# +------------------+
# |            121317|
# |            121316|
# |            121315|
# |            121314|
# |            121313|
# +------------------+
# only showing top 5 rows
#
# +------------------+
# |SalesOrderDetailID|
# +------------------+
# |                 1|
# |                 2|
# |                 3|
# |                 4|
# |                 5|
# +------------------+
# only showing top 5 rows
#
# +---------------------+
# |CarrierTrackingNumber|
# +---------------------+
# |                 NULL|
# |         FFF9-4C3E-A9|
# |         FFE9-4F36-B2|
# |         FFE3-4820-88|
# |         FFD2-4B06-B4|
# +---------------------+
# only showing top 5 rows
#
# +---------------------+
# |CarrierTrackingNumber|
# +---------------------+
# |         000A-434D-BC|
# |         0031-4C10-84|
# |         0083-444C-8D|
# |         0097-43FD-B7|
# |         00A2-4AD1-88|
# +---------------------+
# only showing top 5 rows
#
# +--------+
# |OrderQty|
# +--------+
# |      44|
# |      41|
# |      40|
# |      39|
# |      38|
# +--------+
# only showing top 5 rows
#
# +--------+
# |OrderQty|
# +--------+
# |       1|
# |       2|
# |       3|
# |       4|
# |       5|
# +--------+
# only showing top 5 rows
#
# +---------+
# |ProductID|
# +---------+
# |      999|
# |      998|
# |      997|
# |      996|
# |      994|
# +---------+
# only showing top 5 rows
#
# +---------+
# |ProductID|
# +---------+
# |      707|
# |      708|
# |      709|
# |      710|
# |      711|
# +---------+
# only showing top 5 rows
#
# +--------------+
# |SpecialOfferID|
# +--------------+
# |            16|
# |            14|
# |            13|
# |            11|
# |             9|
# +--------------+
# only showing top 5 rows
#
# +--------------+
# |SpecialOfferID|
# +--------------+
# |             1|
# |             2|
# |             3|
# |             4|
# |             5|
# +--------------+
# only showing top 5 rows
#
# +---------+
# |UnitPrice|
# +---------+
# | 986,5742|
# |  953,628|
# | 935,5445|
# |     9,99|
# |   88,932|
# +---------+
# only showing top 5 rows
#
# +---------+
# |UnitPrice|
# +---------+
# |   1,3282|
# |    1,374|
# |1000,4375|
# | 1020,594|
# |  105,294|
# +---------+
# only showing top 5 rows
#
# +-----------------+
# |UnitPriceDiscount|
# +-----------------+
# |             0,40|
# |             0,35|
# |             0,30|
# |             0,20|
# |             0,15|
# +-----------------+
# only showing top 5 rows
#
# +-----------------+
# |UnitPriceDiscount|
# +-----------------+
# |             0,00|
# |             0,02|
# |             0,05|
# |             0,10|
# |             0,15|
# +-----------------+
# only showing top 5 rows
#
# +------------+
# |   LineTotal|
# +------------+
# |   27893.619|
# |27055.760424|
# |26159.208075|
# |24938.476108|
# |23667.854925|
# +------------+
# only showing top 5 rows
#
# +---------+
# |LineTotal|
# +---------+
# |    1.374|
# |     2.29|
# |    2.748|
# |    2.994|
# |     3.99|
# +---------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |FFFF365B-8BAC-4A2...|
# |FFFE4F5E-86BF-470...|
# |FFFE1322-D5D9-423...|
# |FFFD5250-01E2-4B9...|
# |FFFC2A25-0A75-404...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |0000C99C-2B71-488...|
# |00010EA0-5D0F-4F0...|
# |00015BA1-153F-490...|
# |00016F2D-8CB1-4A1...|
# |0001AE0A-7ABE-48B...|
# +--------------------+
# only showing top 5 rows
#
# +-------------------+
# |       ModifiedDate|
# +-------------------+
# |2014-06-30 00:00:00|
# |2014-06-29 00:00:00|
# |2014-06-28 00:00:00|
# |2014-06-27 00:00:00|
# |2014-06-26 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+
# |       ModifiedDate|
# +-------------------+
# |2011-05-31 00:00:00|
# |2011-06-01 00:00:00|
# |2011-06-02 00:00:00|
# |2011-06-03 00:00:00|
# |2011-06-04 00:00:00|
# +-------------------+
# only showing top 5 rows

# %%
# Pré análise Ordens Produto e Total.

df_SalesOrderDetail.groupBy('ProductID').agg(F.round(F.sum('LineTotal'), 2).alias('Somatorio_total'), 
                                             F.max('OrderQty').alias('Maximo_ordens')).show(10)
# Out:
# +---------+---------------+-------------+
# |ProductID|Somatorio_total|Maximo_ordens|
# +---------+---------------+-------------+
# |      833|       68167.51|            6|
# |      858|       36490.55|           15|
# |      897|         800.21|            3|
# |      808|       22008.27|           16|
# |      883|       98472.72|           21|
# |      879|        39591.0|            1|
# |      799|      932039.59|            9|
# |      804|       61034.61|           14|
# |      970|      438867.48|           11|
# |      898|        3000.78|            3|
# +---------+---------------+-------------+
# only showing top 10 rows

# %%
'''
Dataframe ok, 
Alterar , pra . em (UnitPrice UnitPriceDiscount)
'''
# Out:
# '\nDataframe ok, \nAlterar , pra . em (UnitPrice UnitPriceDiscount)\n'

# %% [markdown]
# ### df_SalesOrderHeader

# %%
# Criando o dataframe em spark

df_SalesOrderHeader = (
    spark.read.format('csv')
              .option('delimiter', ';')
              .option('header', 'true')
              .option('inferschema', 'true')
              .load(path_SalesOrderHeader)
)

# %%
# Analisando o esquema do dataframe

df_SalesOrderHeader.printSchema()
# Out:
# root
#  |-- SalesOrderID: integer (nullable = true)
#  |-- RevisionNumber: integer (nullable = true)
#  |-- OrderDate: timestamp (nullable = true)
#  |-- DueDate: timestamp (nullable = true)
#  |-- ShipDate: timestamp (nullable = true)
#  |-- Status: integer (nullable = true)
#  |-- OnlineOrderFlag: integer (nullable = true)
#  |-- SalesOrderNumber: string (nullable = true)
#  |-- PurchaseOrderNumber: string (nullable = true)
#  |-- AccountNumber: string (nullable = true)
#  |-- CustomerID: integer (nullable = true)
#  |-- SalesPersonID: string (nullable = true)
#  |-- TerritoryID: integer (nullable = true)
#  |-- BillToAddressID: integer (nullable = true)
#  |-- ShipToAddressID: integer (nullable = true)
#  |-- ShipMethodID: integer (nullable = true)
#  |-- CreditCardID: string (nullable = true)
#  |-- CreditCardApprovalCode: string (nullable = true)
#  |-- CurrencyRateID: string (nullable = true)
#  |-- SubTotal: string (nullable = true)
#  |-- TaxAmt: string (nullable = true)
#  |-- Freight: string (nullable = true)
#  |-- TotalDue: string (nullable = true)
#  |-- Comment: string (nullable = true)
#  |-- rowguid: string (nullable = true)
#  |-- ModifiedDate: timestamp (nullable = true)

# %%
# Exibindo a tabela para início da análise

df_SalesOrderHeader.show(3)
# Out:
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+-------------+-----------+---------------+---------------+------------+------------+----------------------+--------------+----------+---------+--------+----------+-------+--------------------+-------------------+
# |SalesOrderID|RevisionNumber|          OrderDate|            DueDate|           ShipDate|Status|OnlineOrderFlag|SalesOrderNumber|PurchaseOrderNumber| AccountNumber|CustomerID|SalesPersonID|TerritoryID|BillToAddressID|ShipToAddressID|ShipMethodID|CreditCardID|CreditCardApprovalCode|CurrencyRateID|  SubTotal|   TaxAmt| Freight|  TotalDue|Comment|             rowguid|       ModifiedDate|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+-------------+-----------+---------------+---------------+------------+------------+----------------------+--------------+----------+---------+--------+----------+-------+--------------------+-------------------+
# |       43659|             8|2011-05-31 00:00:00|2011-06-12 00:00:00|2011-06-07 00:00:00|     5|              0|         SO43659|        PO522145787|10-4020-000676|     29825|          279|          5|            985|            985|           5|       16281|         105041Vi84182|          NULL|20565,6206|1971,5149|616,0984|23153,2339|   NULL|79B65321-39CA-411...|2011-06-07 00:00:00|
# |       43660|             8|2011-05-31 00:00:00|2011-06-12 00:00:00|2011-06-07 00:00:00|     5|              0|         SO43660|      PO18850127500|10-4020-000117|     29672|          279|          5|            921|            921|           5|        5618|         115213Vi29411|          NULL| 1294,2529| 124,2483| 38,8276| 1457,3288|   NULL|738DC42D-D03B-48A...|2011-06-07 00:00:00|
# |       43661|             8|2011-05-31 00:00:00|2011-06-12 00:00:00|2011-06-07 00:00:00|     5|              0|         SO43661|      PO18473189620|10-4020-000442|     29734|          282|          6|            517|            517|           5|        1346|           85274Vi6854|             4|32726,4786|3153,7696| 985,553|36865,8012|   NULL|D91B9131-18A4-4A1...|2011-06-07 00:00:00|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+-------------+-----------+---------------+---------------+------------+------------+----------------------+--------------+----------+---------+--------+----------+-------+--------------------+-------------------+
# only showing top 3 rows

# %%
# Verificando linhas repetidas no dataframe

linhas_repetidas = (df_SalesOrderHeader.count() - df_SalesOrderHeader.distinct().count())
print(linhas_repetidas)
# Out:
# 0

# %%
# Buscando por por erros graves como por exemplo /*@#$% em todas as colunas
# trazendo valores únicos e ordenando asc e desc eles estão no topo ou no final

colunas = df_SalesOrderHeader.columns
for i in range(len(colunas)):
  df_SalesOrderHeader.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=False).show(5)
  df_SalesOrderHeader.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=True).show(5)
# Out:
# +------------+
# |SalesOrderID|
# +------------+
# |       75123|
# |       75122|
# |       75121|
# |       75120|
# |       75119|
# +------------+
# only showing top 5 rows
#
# +------------+
# |SalesOrderID|
# +------------+
# |       43659|
# |       43660|
# |       43661|
# |       43662|
# |       43663|
# +------------+
# only showing top 5 rows
#
# +--------------+
# |RevisionNumber|
# +--------------+
# |             9|
# |             8|
# +--------------+
#
# +--------------+
# |RevisionNumber|
# +--------------+
# |             8|
# |             9|
# +--------------+
#
# +-------------------+
# |          OrderDate|
# +-------------------+
# |2014-06-30 00:00:00|
# |2014-06-29 00:00:00|
# |2014-06-28 00:00:00|
# |2014-06-27 00:00:00|
# |2014-06-26 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+
# |          OrderDate|
# +-------------------+
# |2011-05-31 00:00:00|
# |2011-06-01 00:00:00|
# |2011-06-02 00:00:00|
# |2011-06-03 00:00:00|
# |2011-06-04 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+
# |            DueDate|
# +-------------------+
# |2014-07-12 00:00:00|
# |2014-07-11 00:00:00|
# |2014-07-10 00:00:00|
# |2014-07-09 00:00:00|
# |2014-07-08 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+
# |            DueDate|
# +-------------------+
# |2011-06-12 00:00:00|
# |2011-06-13 00:00:00|
# |2011-06-14 00:00:00|
# |2011-06-15 00:00:00|
# |2011-06-16 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+
# |           ShipDate|
# +-------------------+
# |2014-07-07 00:00:00|
# |2014-07-06 00:00:00|
# |2014-07-05 00:00:00|
# |2014-07-04 00:00:00|
# |2014-07-03 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+
# |           ShipDate|
# +-------------------+
# |2011-06-07 00:00:00|
# |2011-06-08 00:00:00|
# |2011-06-09 00:00:00|
# |2011-06-10 00:00:00|
# |2011-06-11 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +------+
# |Status|
# +------+
# |     5|
# +------+
#
# +------+
# |Status|
# +------+
# |     5|
# +------+
#
# +---------------+
# |OnlineOrderFlag|
# +---------------+
# |              1|
# |              0|
# +---------------+
#
# +---------------+
# |OnlineOrderFlag|
# +---------------+
# |              0|
# |              1|
# +---------------+
#
# +----------------+
# |SalesOrderNumber|
# +----------------+
# |         SO75123|
# |         SO75122|
# |         SO75121|
# |         SO75120|
# |         SO75119|
# +----------------+
# only showing top 5 rows
#
# +----------------+
# |SalesOrderNumber|
# +----------------+
# |         SO43659|
# |         SO43660|
# |         SO43661|
# |         SO43662|
# |         SO43663|
# +----------------+
# only showing top 5 rows
#
# +-------------------+
# |PurchaseOrderNumber|
# +-------------------+
# |       PO9976195169|
# |       PO9976183547|
# |       PO9976177161|
# |       PO9976170932|
# |       PO9976143255|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+
# |PurchaseOrderNumber|
# +-------------------+
# |               NULL|
# |      PO10005144378|
# |      PO10005156366|
# |      PO10034131333|
# |      PO10034135364|
# +-------------------+
# only showing top 5 rows
#
# +--------------+
# | AccountNumber|
# +--------------+
# |10-4030-029483|
# |10-4030-029482|
# |10-4030-029481|
# |10-4030-029480|
# |10-4030-029479|
# +--------------+
# only showing top 5 rows
#
# +--------------+
# | AccountNumber|
# +--------------+
# |10-4020-000001|
# |10-4020-000002|
# |10-4020-000003|
# |10-4020-000004|
# |10-4020-000005|
# +--------------+
# only showing top 5 rows
#
# +----------+
# |CustomerID|
# +----------+
# |     30118|
# |     30117|
# |     30116|
# |     30115|
# |     30114|
# +----------+
# only showing top 5 rows
#
# +----------+
# |CustomerID|
# +----------+
# |     11000|
# |     11001|
# |     11002|
# |     11003|
# |     11004|
# +----------+
# only showing top 5 rows
#
# +-------------+
# |SalesPersonID|
# +-------------+
# |         NULL|
# |          290|
# |          289|
# |          288|
# |          287|
# +-------------+
# only showing top 5 rows
#
# +-------------+
# |SalesPersonID|
# +-------------+
# |          274|
# |          275|
# |          276|
# |          277|
# |          278|
# +-------------+
# only showing top 5 rows
#
# +-----------+
# |TerritoryID|
# +-----------+
# |         10|
# |          9|
# |          8|
# |          7|
# |          6|
# +-----------+
# only showing top 5 rows
#
# +-----------+
# |TerritoryID|
# +-----------+
# |          1|
# |          2|
# |          3|
# |          4|
# |          5|
# +-----------+
# only showing top 5 rows
#
# +---------------+
# |BillToAddressID|
# +---------------+
# |          29883|
# |          29882|
# |          29881|
# |          29880|
# |          29879|
# +---------------+
# only showing top 5 rows
#
# +---------------+
# |BillToAddressID|
# +---------------+
# |            405|
# |            406|
# |            407|
# |            408|
# |            409|
# +---------------+
# only showing top 5 rows
#
# +---------------+
# |ShipToAddressID|
# +---------------+
# |          29883|
# |          29882|
# |          29881|
# |          29880|
# |          29879|
# +---------------+
# only showing top 5 rows
#
# +---------------+
# |ShipToAddressID|
# +---------------+
# |              9|
# |             11|
# |             12|
# |             13|
# |             15|
# +---------------+
# only showing top 5 rows
#
# +------------+
# |ShipMethodID|
# +------------+
# |           5|
# |           1|
# +------------+
#
# +------------+
# |ShipMethodID|
# +------------+
# |           1|
# |           5|
# +------------+
#
# +------------+
# |CreditCardID|
# +------------+
# |        NULL|
# |        9999|
# |        9998|
# |        9997|
# |        9996|
# +------------+
# only showing top 5 rows
#
# +------------+
# |CreditCardID|
# +------------+
# |           1|
# |          10|
# |         100|
# |        1000|
# |       10000|
# +------------+
# only showing top 5 rows
#
# +----------------------+
# |CreditCardApprovalCode|
# +----------------------+
# |                  NULL|
# |           98795Vi7192|
# |          98794Vi14256|
# |           98792Vi7192|
# |           98791Vi7192|
# +----------------------+
# only showing top 5 rows
#
# +----------------------+
# |CreditCardApprovalCode|
# +----------------------+
# |        1016006Vi91301|
# |        1016019Vi13445|
# |        1016029Vi87083|
# |        1016033Vi21159|
# |         1016050Vi6608|
# +----------------------+
# only showing top 5 rows
#
# +--------------+
# |CurrencyRateID|
# +--------------+
# |          NULL|
# |          9997|
# |          9995|
# |          9989|
# |          9986|
# +--------------+
# only showing top 5 rows
#
# +--------------+
# |CurrencyRateID|
# +--------------+
# |         10000|
# |         10006|
# |         10008|
# |         10011|
# |         10017|
# +--------------+
# only showing top 5 rows
#
# +----------+
# |  SubTotal|
# +----------+
# |99514,5024|
# |99502,0328|
# |99262,9841|
# |   9913,52|
# |  9903,456|
# +----------+
# only showing top 5 rows
#
# +--------+
# |SubTotal|
# +--------+
# |   1,374|
# |   10,24|
# |  10,788|
# |  100,09|
# |  100,46|
# +--------+
# only showing top 5 rows
#
# +---------+
# |   TaxAmt|
# +---------+
# |9979,0212|
# | 997,3847|
# | 996,4857|
# |9956,7327|
# | 995,0057|
# +---------+
# only showing top 5 rows
#
# +------+
# |TaxAmt|
# +------+
# |0,1099|
# |0,1832|
# |0,2198|
# |0,3192|
# |0,3992|
# +------+
# only showing top 5 rows
#
# +--------+
# | Freight|
# +--------+
# | 995,912|
# |994,8671|
# |994,6826|
# |994,6333|
# | 993,094|
# +--------+
# only showing top 5 rows
#
# +-------+
# |Freight|
# +-------+
# | 0,0344|
# | 0,0573|
# | 0,0687|
# | 0,0998|
# | 0,1248|
# +-------+
# only showing top 5 rows
#
# +---------+
# | TotalDue|
# +---------+
# |99952,438|
# |9994,9128|
# |9983,2209|
# | 997,7929|
# | 997,2183|
# +---------+
# only showing top 5 rows
#
# +--------+
# |TotalDue|
# +--------+
# |  1,5183|
# |100,0909|
# |100,2242|
# |100,4487|
# |100,4998|
# +--------+
# only showing top 5 rows
#
# +-------+
# |Comment|
# +-------+
# |   NULL|
# +-------+
#
# +-------+
# |Comment|
# +-------+
# |   NULL|
# +-------+
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |FFFE293D-6CC6-445...|
# |FFF7A467-C224-44B...|
# |FFF740B2-7BDD-4E9...|
# |FFF51A9B-776A-491...|
# |FFF489DD-9865-4C4...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |0000DE87-AB3F-492...|
# |00032DF7-5D34-4EC...|
# |0004E1D8-4756-4CB...|
# |0007D2E3-1BC0-4DB...|
# |0008C5D1-3847-4F4...|
# +--------------------+
# only showing top 5 rows
#
# +-------------------+
# |       ModifiedDate|
# +-------------------+
# |2014-07-07 00:00:00|
# |2014-07-06 00:00:00|
# |2014-07-05 00:00:00|
# |2014-07-04 00:00:00|
# |2014-07-03 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+
# |       ModifiedDate|
# +-------------------+
# |2011-06-07 00:00:00|
# |2011-06-08 00:00:00|
# |2011-06-09 00:00:00|
# |2011-06-10 00:00:00|
# |2011-06-11 00:00:00|
# +-------------------+
# only showing top 5 rows

# %%
# COLUNA Comment e Status aparenta ter um único valor 
# Decidi nao dropar

df_SalesOrderHeader.select(F.col('Comment')).distinct().show(5)
df_SalesOrderHeader.select(F.col('Status')).distinct().show(5)
# Out:
# +-------+
# |Comment|
# +-------+
# |   NULL|
# +-------+
#
# +------+
# |Status|
# +------+
# |     5|
# +------+

# %%
# Pré análise TerritoryID e Quantidade.

df_SalesOrderHeader.groupBy('TerritoryID').count().show(10)
# Out:
# +-----------+-----+
# |TerritoryID|count|
# +-----------+-----+
# |          1| 4594|
# |          6| 4067|
# |          3|  385|
# |          5|  486|
# |          9| 6843|
# |          4| 6224|
# |          8| 2623|
# |          7| 2672|
# |         10| 3219|
# |          2|  352|
# +-----------+-----+

# %%
'''
Dataframe ok, 
Alterar , para . em  (SubTotal TaxAmt Freight TotalDue)
'''
# Out:
# '\nDataframe ok, \nAlterar , para . em  (SubTotal TaxAmt Freight TotalDue)\n'

# %% [markdown]
# ### df_SpecialOfferProduct

# %%
# Criando o dataframe em spark

df_SpecialOfferProduct = (
    spark.read.format('csv')
              .option('delimiter', ';')
              .option('header', 'true')
              .option('inferschema', 'true')
              .load(path_SpecialOfferProduct)
)

# %%
# Analisando o esquema do dataframe

df_SpecialOfferProduct.printSchema()
# Out:
# root
#  |-- SpecialOfferID: integer (nullable = true)
#  |-- ProductID: integer (nullable = true)
#  |-- rowguid: string (nullable = true)
#  |-- ModifiedDate: timestamp (nullable = true)

# %%
# Exibindo a tabela para início da análise
# SpecialOfferID com valores iguais.

df_SpecialOfferProduct.show(3)
# Out:
# +--------------+---------+--------------------+-------------------+
# |SpecialOfferID|ProductID|             rowguid|       ModifiedDate|
# +--------------+---------+--------------------+-------------------+
# |             1|      680|BB30B868-D86C-455...|2011-04-01 00:00:00|
# |             1|      706|B3C9A4B1-2AE6-4CB...|2011-04-01 00:00:00|
# |             1|      707|27B711FE-0B77-4EA...|2011-04-01 00:00:00|
# +--------------+---------+--------------------+-------------------+
# only showing top 3 rows

# %%
# Verificando linhas repetidas no dataframe

linhas_repetidas = (df_SpecialOfferProduct.count() - df_SpecialOfferProduct.distinct().count())
print(linhas_repetidas)
# Out:
# 0

# %%
# Buscando por por erros graves como por exemplo /*@#$% em todas as colunas
# trazendo valores únicos e ordenando asc e desc eles estão no topo ou no final

colunas = df_SpecialOfferProduct.columns
for i in range(len(colunas)):
  df_SpecialOfferProduct.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=False).show(5)
  df_SpecialOfferProduct.select(F.col(colunas[i])).distinct().orderBy(colunas[i], ascending=True).show(5)
# Out:
# +--------------+
# |SpecialOfferID|
# +--------------+
# |            16|
# |            15|
# |            14|
# |            13|
# |            12|
# +--------------+
# only showing top 5 rows
#
# +--------------+
# |SpecialOfferID|
# +--------------+
# |             1|
# |             2|
# |             3|
# |             4|
# |             5|
# +--------------+
# only showing top 5 rows
#
# +---------+
# |ProductID|
# +---------+
# |      999|
# |      998|
# |      997|
# |      996|
# |      995|
# +---------+
# only showing top 5 rows
#
# +---------+
# |ProductID|
# +---------+
# |      680|
# |      706|
# |      707|
# |      708|
# |      709|
# +---------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |FFE24AE4-9E46-433...|
# |FFC1F8D0-F9C4-452...|
# |FF93AC1F-49DC-4A6...|
# |FE9976C4-2B12-4F7...|
# |FE70F9BC-B3F6-44B...|
# +--------------------+
# only showing top 5 rows
#
# +--------------------+
# |             rowguid|
# +--------------------+
# |0020931C-087C-42F...|
# |00365938-3422-494...|
# |005D8818-0E25-477...|
# |00C21E7C-FD29-44D...|
# |01096D18-0E95-494...|
# +--------------------+
# only showing top 5 rows
#
# +-------------------+
# |       ModifiedDate|
# +-------------------+
# |2014-03-01 00:00:00|
# |2013-06-14 00:00:00|
# |2013-04-30 00:00:00|
# |2013-04-14 00:00:00|
# |2012-04-30 00:00:00|
# +-------------------+
# only showing top 5 rows
#
# +-------------------+
# |       ModifiedDate|
# +-------------------+
# |2011-04-01 00:00:00|
# |2011-05-01 00:00:00|
# |2012-03-14 00:00:00|
# |2012-04-30 00:00:00|
# |2013-04-14 00:00:00|
# +-------------------+
# only showing top 5 rows

# %%
# COLUNA SpecialOfferID aparenta ter somente alguns numeros e estao se repetindo - nao vai servir como pk
# Procurando por número dentro da coluna SpecialOfferID
# muitos id`s se repetem

df_SpecialOfferProduct.select(F.col('SpecialOfferID')).distinct().show(40)
# Out:
# +--------------+
# |SpecialOfferID|
# +--------------+
# |            12|
# |             1|
# |            13|
# |            16|
# |             3|
# |             5|
# |            15|
# |             9|
# |             4|
# |             8|
# |             7|
# |            10|
# |            11|
# |            14|
# |             2|
# +--------------+

# %%
'''
Dataframe sem SpecialOfferID correto.
'''
# Out:
# '\nDataframe sem SpecialOfferID correto.\n'

# %% [markdown]
# ## Tratamento em pandas e Exportacao dos arquivos do bucket para mysql

# %% [markdown]
# ### Person.Person

# %%
#Escolhendo o arquivo dentro do bucket

bucket.blob('Person.Person.csv')
# Out:
# <Blob: desafio-rox-leandro, Person.Person.csv, None>

# %%
# Criando o df em pandas para enviar para o mysql

df_Person = pd.read_csv(path_Person,sep=';')

# %%
# Codigo repetido em todos os passos, colab dando erro, foi preciso sempre redefinir o conector.
# Conector host:ip_banco, user:usuario, passwd: senha, db:banco criado

con = mysql.connector.connect(host='34.95.218.222',user='desafio-username',passwd='1234',db='bicicletas')
cur = con.cursor()
engine = create_engine('mysql+pymysql://desafio-username:1234@34.95.218.222/bicicletas')

# %%
# Enviando a tabela Person.Person para o MySql 

dfsql_Person = df_Person.to_sql('PersonPerson',con=engine,if_exists='replace',index=False)

# %%
# Verificando o conteúdo enviado

cur.execute('select * from PersonPerson')
cur.fetchall()
# Out:
# [(1,
#   'EM',
#   0,
#   None,
#   'Ken',
#   'J',
#   'Sánchez',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '92C4279F-1207-48A3-8448-4636514EB7E2',
#   '2009-01-07 00:00:00.000'),
#  (2,
#   'EM',
#   0,
#   None,
#   'Terri',
#   'Lee',
#   'Duffy',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'D8763459-8AA8-47CC-AFF7-C9079AF79033',
#   '2008-01-24 00:00:00.000'),
#  (3,
#   'EM',
#   0,
#   None,
#   'Roberto',
#   None,
#   'Tamburello',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'E1A2555E-0828-434B-A33B-6F38136A37DE',
#   '2007-11-04 00:00:00.000'),
#  (4,
#   'EM',
#   0,
#   None,
#   'Rob',
#   None,
#   'Walters',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F2D7CE06-38B3-4357-805B-F4B6B71C01FF',
#   '2007-11-28 00:00:00.000'),
#  (5,
#   'EM',
#   0,
#   'Ms.',
#   'Gail',
#   'A',
#   'Erickson',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F3A3F6B4-AE3B-430C-A754-9F2231BA6FEF',
#   '2007-12-30 00:00:00.000'),
#  (6,
#   'EM',
#   0,
#   'Mr.',
#   'Jossef',
#   'H',
#   'Goldberg',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '0DEA28FD-EFFE-482A-AFD3-B7E8F199D56F',
#   '2013-12-16 00:00:00.000'),
#  (7,
#   'EM',
#   0,
#   None,
#   'Dylan',
#   'A',
#   'Miller',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'C45E8AB8-01BE-4B76-B215-820C8368181A',
#   '2009-02-01 00:00:00.000'),
#  (8,
#   'EM',
#   0,
#   None,
#   'Diane',
#   'L',
#   'Margheim',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'A948E590-4A56-45A9-BC9A-160A1CC9D990',
#   '2008-12-22 00:00:00.000'),
#  (9,
#   'EM',
#   0,
#   None,
#   'Gigi',
#   'N',
#   'Matthew',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '5FC28C0E-6D36-4252-9846-05CAA0B1F6C5',
#   '2009-01-09 00:00:00.000'),
#  (10,
#   'EM',
#   0,
#   None,
#   'Michael',
#   None,
#   'Raheem',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'CA2C740E-75B2-420C-9D4B-E3CBC6609604',
#   '2009-04-26 00:00:00.000'),
#  (11,
#   'EM',
#   0,
#   None,
#   'Ovidiu',
#   'V',
#   'Cracium',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'D2CC2577-EF6B-4408-BD8C-747337FE5645',
#   '2010-11-28 00:00:00.000'),
#  (12,
#   'EM',
#   0,
#   None,
#   'Thierry',
#   'B',
#   "D'Hers",
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'FA263C7F-600D-4E89-8DCD-0978F3530F5F',
#   '2007-12-04 00:00:00.000'),
#  (13,
#   'EM',
#   0,
#   'Ms.',
#   'Janice',
#   'M',
#   'Galvin',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '34EB99E0-7042-4DC1-A2FD-BDA290FF0E07',
#   '2010-12-16 00:00:00.000'),
#  (14,
#   'EM',
#   0,
#   None,
#   'Michael',
#   'I',
#   'Sullivan',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9A7501DE-5CAF-4700-AB07-CC81102BB696',
#   '2010-12-23 00:00:00.000'),
#  (15,
#   'EM',
#   0,
#   None,
#   'Sharon',
#   'B',
#   'Salavaria',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'BEBA63CB-13F1-4B76-A3DE-FE9AC283A94C',
#   '2011-01-11 00:00:00.000'),
#  (16,
#   'EM',
#   0,
#   None,
#   'David',
#   'M',
#   'Bradley',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '2CC8BA72-5DBB-497F-B941-775517993638',
#   '2007-12-13 00:00:00.000'),
#  (17,
#   'EM',
#   0,
#   None,
#   'Kevin',
#   'F',
#   'Brown',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9EE4713E-B3D8-4409-BC5E-DEC62497F43A',
#   '2007-01-19 00:00:00.000'),
#  (18,
#   'EM',
#   0,
#   None,
#   'John',
#   'L',
#   'Wood',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'FE21BDA7-9327-4D13-89CC-8CA5CEE8F21E',
#   '2011-01-31 00:00:00.000'),
#  (19,
#   'EM',
#   0,
#   None,
#   'Mary',
#   'A',
#   'Dempsey',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '36F04305-6769-4E61-9143-048B2B7AFA20',
#   '2011-02-07 00:00:00.000'),
#  (20,
#   'EM',
#   0,
#   None,
#   'Wanida',
#   'M',
#   'Benshoof',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '1E7E56F4-A583-4E3F-A3FE-BA8A71096D10',
#   '2010-12-31 00:00:00.000'),
#  (21,
#   'EM',
#   0,
#   None,
#   'Terry',
#   'J',
#   'Eminhizer',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '6A288FE0-D9CB-4DA2-BEEA-51370220490C',
#   '2009-02-23 00:00:00.000'),
#  (22,
#   'EM',
#   0,
#   None,
#   'Sariya',
#   'E',
#   'Harnpadoungsataya',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '276E0EB5-0CE7-443F-987F-B7EF293C0930',
#   '2008-12-05 00:00:00.000'),
#  (23,
#   'EM',
#   0,
#   None,
#   'Mary',
#   'E',
#   'Gibson',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'B10CF8EB-5589-4A81-B1BD-051C5759CE06',
#   '2009-01-05 00:00:00.000'),
#  (24,
#   'EM',
#   0,
#   'Ms.',
#   'Jill',
#   'A',
#   'Williams',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '3F605060-96AD-4201-9BE2-BFE7A3C4E468',
#   '2009-01-11 00:00:00.000'),
#  (25,
#   'EM',
#   0,
#   None,
#   'James',
#   'R',
#   'Hamilton',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '423FE59B-7975-4A7E-B8D2-87105C286D4C',
#   '2009-01-27 00:00:00.000'),
#  (26,
#   'EM',
#   0,
#   None,
#   'Peter',
#   'J',
#   'Krebs',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '6F32F507-290E-4A96-A045-F445EAE4337F',
#   '2008-11-24 00:00:00.000'),
#  (27,
#   'EM',
#   0,
#   None,
#   'Jo',
#   'A',
#   'Brown',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'EDD8ADD6-F7FD-4086-BFDC-B4FD3E6AD8D7',
#   '2008-02-20 00:00:00.000'),
#  (28,
#   'EM',
#   0,
#   None,
#   'Guy',
#   'R',
#   'Gilbert',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'D366A33A-8EDE-42BD-BF79-3E7FB9713FE1',
#   '2006-06-23 00:00:00.000'),
#  (29,
#   'EM',
#   0,
#   None,
#   'Mark',
#   'K',
#   'McArthur',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '667FA3BA-B877-4BCC-A752-E461040E2DDD',
#   '2009-01-16 00:00:00.000'),
#  (30,
#   'EM',
#   0,
#   None,
#   'Britta',
#   'L',
#   'Simon',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '5090C9A8-E39E-4A4D-9133-14E7CF07998B',
#   '2009-01-22 00:00:00.000'),
#  (31,
#   'EM',
#   0,
#   None,
#   'Margie',
#   'W',
#   'Shoop',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '5EA8A3DA-7BEA-4ADC-85F5-C934E2033825',
#   '2008-12-28 00:00:00.000'),
#  (32,
#   'EM',
#   0,
#   None,
#   'Rebecca',
#   'A',
#   'Laszlo',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '686BD5AF-6F30-4633-944B-3C1916CB4CA2',
#   '2008-12-22 00:00:00.000'),
#  (33,
#   'EM',
#   0,
#   None,
#   'Annik',
#   'O',
#   'Stahl',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'BFA2BDC8-208A-447B-8A4E-72A215E9E134',
#   '2008-12-10 00:00:00.000'),
#  (34,
#   'EM',
#   0,
#   None,
#   'Suchitra',
#   'O',
#   'Mohan',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '7E239D8B-00BF-42D6-AC6B-4EA718DBC2B3',
#   '2009-02-09 00:00:00.000'),
#  (35,
#   'EM',
#   0,
#   None,
#   'Brandon',
#   'G',
#   'Heidepriem',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '4CC8EDC2-5502-4550-8089-9B3CC6006490',
#   '2009-02-01 00:00:00.000'),
#  (36,
#   'EM',
#   0,
#   None,
#   'Jose',
#   'R',
#   'Lugo',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '54655E98-B81A-4041-8FA4-9349C018521F',
#   '2009-02-03 00:00:00.000'),
#  (37,
#   'EM',
#   0,
#   None,
#   'Chris',
#   'O',
#   'Okelberry',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '5B16CA18-703B-48E8-AB3E-CA158C854808',
#   '2009-02-28 00:00:00.000'),
#  (38,
#   'EM',
#   0,
#   None,
#   'Kim',
#   'B',
#   'Abercrombie',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9A2163B3-2F4D-4F9A-91BD-07D326140F9C',
#   '2010-01-09 00:00:00.000'),
#  (39,
#   'EM',
#   0,
#   None,
#   'Ed',
#   'R',
#   'Dudenhoefer',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '83C88383-9C3E-42C5-AE09-965B5F9EF5B1',
#   '2010-01-29 00:00:00.000'),
#  (40,
#   'EM',
#   0,
#   None,
#   'JoLynn',
#   'M',
#   'Dobney',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'E8E5C9DA-F808-4439-BF5C-B28236BB8467',
#   '2007-12-19 00:00:00.000'),
#  (41,
#   'EM',
#   0,
#   None,
#   'Bryan',
#   None,
#   'Baker',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'A32E8274-08DC-4596-AB1F-BA6263CBC676',
#   '2009-01-14 00:00:00.000'),
#  (42,
#   'EM',
#   0,
#   None,
#   'James',
#   'D',
#   'Kramer',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F4F040E0-02A0-4905-B964-2E894D0F0B94',
#   '2008-12-20 00:00:00.000'),
#  (43,
#   'EM',
#   0,
#   None,
#   'Nancy',
#   'A',
#   'Anderson',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '0681C8F9-D2EC-47D9-9BD4-751B14EAED50',
#   '2008-12-26 00:00:00.000'),
#  (44,
#   'EM',
#   0,
#   None,
#   'Simon',
#   'D',
#   'Rapier',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'FF8EDBFC-A9A3-4C5D-8AFF-DF4D6F18DAFF',
#   '2008-12-01 00:00:00.000'),
#  (45,
#   'EM',
#   0,
#   None,
#   'Thomas',
#   'R',
#   'Michaels',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '2CAF9ADC-7A33-48CF-B4B7-3C57D9DE39C4',
#   '2009-02-19 00:00:00.000'),
#  (46,
#   'EM',
#   0,
#   None,
#   'Eugene',
#   'O',
#   'Kogan',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'FB0068EA-49D4-4E82-9895-2680CF59385E',
#   '2009-02-01 00:00:00.000'),
#  (47,
#   'EM',
#   0,
#   None,
#   'Andrew',
#   'R',
#   'Hill',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'B6439F4F-E57D-4293-B0C8-8919591055A3',
#   '2009-02-15 00:00:00.000'),
#  (48,
#   'EM',
#   0,
#   None,
#   'Ruth',
#   'Ann',
#   'Ellerbrock',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9BE35B50-2024-4785-9393-7C7AB8D9634D',
#   '2007-12-30 00:00:00.000'),
#  (49,
#   'EM',
#   0,
#   None,
#   'Barry',
#   'K',
#   'Johnson',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'CB28BE2E-DE93-4409-BACE-DF6042D04815',
#   '2013-11-29 00:00:00.000'),
#  (50,
#   'EM',
#   0,
#   None,
#   'Sidney',
#   'M',
#   'Higa',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'A20BB9F5-3BBB-4AB6-9BFA-6AED32C30204',
#   '2008-01-26 00:00:00.000'),
#  (51,
#   'EM',
#   0,
#   None,
#   'Jeffrey',
#   'L',
#   'Ford',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '293DF609-2FA3-4C00-A891-ACE08661FE70',
#   '2008-02-13 00:00:00.000'),
#  (52,
#   'EM',
#   0,
#   None,
#   'Doris',
#   'M',
#   'Hartwig',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '075AB67F-BFBD-4433-B33E-C65B2C045B6B',
#   '2014-01-31 00:00:00.000'),
#  (53,
#   'EM',
#   0,
#   None,
#   'Diane',
#   'R',
#   'Glimp',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9EA27F41-36BB-4456-A506-2B87C416FB0C',
#   '2008-03-21 00:00:00.000'),
#  (54,
#   'EM',
#   0,
#   None,
#   'Bonnie',
#   'N',
#   'Kearney',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'AB066D28-404A-436E-A17A-789D7F2638D3',
#   '2009-12-25 00:00:00.000'),
#  (55,
#   'EM',
#   0,
#   None,
#   'Taylor',
#   'R',
#   'Maxwell',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9F81714B-0C9C-43C3-8DF5-180CB0A42D40',
#   '2013-12-31 00:00:00.000'),
#  (56,
#   'EM',
#   0,
#   None,
#   'Denise',
#   'H',
#   'Smith',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '77F4AC33-E165-49D7-BC6A-F3C2DC069C9B',
#   '2009-01-29 00:00:00.000'),
#  (57,
#   'EM',
#   0,
#   None,
#   'Frank',
#   'T',
#   'Miller',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '05516FB2-586E-43F5-A87C-5E236F8DB8AD',
#   '2009-02-16 00:00:00.000'),
#  (58,
#   'EM',
#   0,
#   None,
#   'Kendall',
#   'C',
#   'Keil',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'CA8D648A-166B-4D61-9AE0-A0B1FFECFB1B',
#   '2008-11-28 00:00:00.000'),
#  (59,
#   'EM',
#   0,
#   None,
#   'Bob',
#   'N',
#   'Hohman',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '6384295C-C932-47C0-8E97-71D94F83CD31',
#   '2008-12-17 00:00:00.000'),
#  (60,
#   'EM',
#   0,
#   None,
#   'Pete',
#   'C',
#   'Male',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '0AEB5713-8BB0-4B8D-BF81-777158E5FF09',
#   '2009-01-04 00:00:00.000'),
#  (61,
#   'EM',
#   0,
#   None,
#   'Diane',
#   'H',
#   'Tibbott',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'E054FFC1-258C-4DA4-B2C1-40E155F4C88B',
#   '2009-01-11 00:00:00.000'),
#  (62,
#   'EM',
#   0,
#   None,
#   'John',
#   'T',
#   'Campbell',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F5A4CC1B-AEFA-46CA-8888-2CA1C6D4034B',
#   '2014-02-07 00:00:00.000'),
#  (63,
#   'EM',
#   0,
#   None,
#   'Maciej',
#   'W',
#   'Dusza',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '611D56EB-C29D-4F90-A5C6-1B3B2D44E5F8',
#   '2010-01-22 00:00:00.000'),
#  (64,
#   'EM',
#   0,
#   None,
#   'Michael',
#   'J',
#   'Zwilling',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'DCC5AA7B-C09A-47A5-86A2-90D88191EBE6',
#   '2010-02-16 00:00:00.000'),
#  (65,
#   'EM',
#   0,
#   None,
#   'Randy',
#   'T',
#   'Reeves',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'D988D8E0-C335-4F4C-9ED9-199FEB7FD4A7',
#   '2010-02-16 00:00:00.000'),
#  (66,
#   'EM',
#   0,
#   None,
#   'Karan',
#   'R',
#   'Khanna',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '58C97993-7491-49EE-BFDD-CD80CE2C922A',
#   '2009-12-15 00:00:00.000'),
#  (67,
#   'EM',
#   0,
#   None,
#   'Jay',
#   'G',
#   'Adams',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '2FE289A7-CE57-49E5-BE61-3E6580D22EA6',
#   '2009-02-26 00:00:00.000'),
#  (68,
#   'EM',
#   0,
#   None,
#   'Charles',
#   'B',
#   'Fitzgerald',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '1E7CD457-A854-4D68-ACFB-3D752EEBD231',
#   '2009-11-26 00:00:00.000'),
#  (69,
#   'EM',
#   0,
#   None,
#   'Steve',
#   'F',
#   'Masters',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '85F55758-54C4-4048-ACBE-BD9515669122',
#   '2009-02-08 00:00:00.000'),
#  (70,
#   'EM',
#   0,
#   None,
#   'David',
#   'J',
#   'Ortiz',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '60245B9F-EABD-48CF-9FA9-C5DD48BCB3DF',
#   '2008-12-08 00:00:00.000'),
#  (71,
#   'EM',
#   0,
#   None,
#   'Michael',
#   'Sean',
#   'Ray',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'CA42A0B4-C068-4C75-A8A3-DE8953760927',
#   '2009-02-08 00:00:00.000'),
#  (72,
#   'EM',
#   0,
#   None,
#   'Steven',
#   'T',
#   'Selikoff',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '7455FEFF-9238-4C29-819F-A4DF6508C0F8',
#   '2008-11-24 00:00:00.000'),
#  (73,
#   'EM',
#   0,
#   None,
#   'Carole',
#   'M',
#   'Poland',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '4EE4FAF4-9C85-4022-B07F-956F1C5595D5',
#   '2008-12-12 00:00:00.000'),
#  (74,
#   'EM',
#   0,
#   None,
#   'Bjorn',
#   'M',
#   'Rettig',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '056617D9-E65F-41C7-98AF-9C14C4569652',
#   '2008-12-31 00:00:00.000'),
#  (75,
#   'EM',
#   0,
#   None,
#   'Michiko',
#   'F',
#   'Osada',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '670CE5A5-2B86-4AD7-AEF5-DF2AAAC4A6AB',
#   '2009-01-19 00:00:00.000'),
#  (76,
#   'EM',
#   0,
#   None,
#   'Carol',
#   'M',
#   'Philips',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '7AC771B3-347A-49FA-9298-487B02FA359D',
#   '2009-02-05 00:00:00.000'),
#  (77,
#   'EM',
#   0,
#   None,
#   'Merav',
#   'A',
#   'Netz',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F9427582-FD1B-45DE-922D-2C2C58CEA0F7',
#   '2009-02-24 00:00:00.000'),
#  (78,
#   'EM',
#   0,
#   None,
#   'Reuben',
#   'H',
#   "D'sa",
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'AEBEAA5B-D861-4703-A959-6D0F6F4CDF74',
#   '2008-12-08 00:00:00.000'),
#  (79,
#   'EM',
#   0,
#   None,
#   'Eric',
#   'L',
#   'Brown',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'D0EFAF3A-04DC-442F-9AA1-926C38105241',
#   '2010-01-17 00:00:00.000'),
#  (80,
#   'EM',
#   0,
#   None,
#   'Sandeep',
#   'P',
#   'Kaliyath',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '7E5B79F9-5B7A-41DC-850F-23B4764B5161',
#   '2010-01-10 00:00:00.000'),
#  (81,
#   'EM',
#   0,
#   None,
#   'Mihail',
#   'U',
#   'Frintu',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '1062CA88-998C-472C-8BD5-9F3D4BC4D2FB',
#   '2009-12-22 00:00:00.000'),
#  (82,
#   'EM',
#   0,
#   None,
#   'Jack',
#   'T',
#   'Creasey',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'ED8B39AF-5DA5-405F-8C38-A6C3AC25CA1B',
#   '2010-02-24 00:00:00.000'),
#  (83,
#   'EM',
#   0,
#   None,
#   'Patrick',
#   'M',
#   'Cook',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F03E1512-0DC2-4329-8F21-6C5DBB9996F3',
#   '2010-02-05 00:00:00.000'),
#  (84,
#   'EM',
#   0,
#   None,
#   'Frank',
#   'R',
#   'Martinez',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'B66AB99E-691C-4CAC-B62D-579816800BFA',
#   '2010-01-29 00:00:00.000'),
#  (85,
#   'EM',
#   0,
#   None,
#   'Brian',
#   'Richard',
#   'Goldstein',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '61CE0232-4144-48AE-BA3B-1D509505F106',
#   '2009-12-04 00:00:00.000'),
#  (86,
#   'EM',
#   0,
#   None,
#   'Ryan',
#   'L',
#   'Cornelsen',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '0E3F7512-87A6-4C0D-9E02-30919A75BF60',
#   '2008-12-29 00:00:00.000'),
#  (87,
#   'EM',
#   0,
#   None,
#   'Cristian',
#   'K',
#   'Petculescu',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '45FE0378-ED23-4D24-A5F5-11B10B402980',
#   '2008-12-15 00:00:00.000'),
#  (88,
#   'EM',
#   0,
#   None,
#   'Betsy',
#   'A',
#   'Stadick',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'C214AB1E-A07E-4A62-9033-19DDE0DE1937',
#   '2009-12-11 00:00:00.000'),
#  (89,
#   'EM',
#   0,
#   None,
#   'Patrick',
#   'C',
#   'Wedge',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'CD334AC3-EE11-4999-BBA1-7F33DE161124',
#   '2010-01-25 00:00:00.000'),
#  (90,
#   'EM',
#   0,
#   None,
#   'Danielle',
#   'C',
#   'Tiedt',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '852A07EE-1D24-4810-8121-365DAB884C8D',
#   '2010-02-13 00:00:00.000'),
#  (91,
#   'EM',
#   0,
#   None,
#   'Kimberly',
#   'B',
#   'Zimmerman',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '67647D8C-C685-4704-81B7-AE1087CC2C6D',
#   '2010-01-05 00:00:00.000'),
#  (92,
#   'EM',
#   0,
#   None,
#   'Tom',
#   'M',
#   'Vande Velde',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'A36DA26B-29BA-4627-9731-134D65A53143',
#   '2010-03-03 00:00:00.000'),
#  (93,
#   'EM',
#   0,
#   None,
#   'Kok-Ho',
#   'T',
#   'Loh',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '3E4AE757-8C3E-47CC-BC20-528CCF271E3D',
#   '2008-12-20 00:00:00.000'),
#  (94,
#   'EM',
#   0,
#   None,
#   'Russell',
#   None,
#   'Hunter',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '288EF549-203C-439C-A6B2-32FD822327FF',
#   '2008-12-05 00:00:00.000'),
#  (95,
#   'EM',
#   0,
#   None,
#   'Jim',
#   'H',
#   'Scardelis',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'A45F89BB-9748-41F8-9FAA-A5D76DF4B029',
#   '2008-12-12 00:00:00.000'),
#  (96,
#   'EM',
#   0,
#   None,
#   'Elizabeth',
#   'I',
#   'Keyser',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'CB9A2A0C-68E5-475B-9D6D-EBD548FE5B9C',
#   '2009-02-23 00:00:00.000'),
#  (97,
#   'EM',
#   0,
#   None,
#   'Mandar',
#   'H',
#   'Samant',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '907AE318-9FF7-4B56-B52B-5FDCA7BF8A62',
#   '2009-02-03 00:00:00.000'),
#  (98,
#   'EM',
#   0,
#   None,
#   'Sameer',
#   'A',
#   'Tejani',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F19BE575-4A2E-413D-9BE9-0AF4B75C6FCD',
#   '2009-02-04 00:00:00.000'),
#  (99,
#   'EM',
#   0,
#   None,
#   'Nuan',
#   None,
#   'Yu',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '938FCD64-E06D-453C-9E70-BFE41753557B',
#   '2008-12-30 00:00:00.000'),
#  (100,
#   'EM',
#   0,
#   None,
#   'Lolan',
#   'B',
#   'Song',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'DCD41870-A67B-4D7F-B874-92C6854E1D0D',
#   '2009-01-05 00:00:00.000'),
#  (101,
#   'EM',
#   0,
#   None,
#   'Houman',
#   'N',
#   'Pournasseh',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '14E39720-994D-42C0-A26D-7877BB264FF5',
#   '2009-01-18 00:00:00.000'),
#  (102,
#   'EM',
#   0,
#   None,
#   'Zheng',
#   'W',
#   'Mu',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '17D15AE1-FB50-4303-A509-24C6C553C17D',
#   '2008-11-26 00:00:00.000'),
#  (103,
#   'EM',
#   0,
#   None,
#   'Ebru',
#   'N',
#   'Ersan',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '64A9674E-9625-4EF2-8F4D-357390735C08',
#   '2009-11-29 00:00:00.000'),
#  (104,
#   'EM',
#   0,
#   None,
#   'Mary',
#   'R',
#   'Baker',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9E450675-B7F1-47C1-BB64-95E998B57ED4',
#   '2009-12-18 00:00:00.000'),
#  (105,
#   'EM',
#   0,
#   None,
#   'Kevin',
#   'M',
#   'Homer',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '1D1C9D2A-EA15-409C-8E32-8F5C6F8F286A',
#   '2009-12-18 00:00:00.000'),
#  (106,
#   'EM',
#   0,
#   None,
#   'John',
#   'T',
#   'Kane',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '4C117C8F-07C6-4B4E-A7D0-B8AD58EED8AE',
#   '2010-02-20 00:00:00.000'),
#  (107,
#   'EM',
#   0,
#   None,
#   'Christopher',
#   'E',
#   'Hill',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'A066751C-B57F-4186-8219-6652AE1189B1',
#   '2010-02-01 00:00:00.000'),
#  (108,
#   'EM',
#   0,
#   None,
#   'Jinghao',
#   'K',
#   'Liu',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'DD35EB13-6D4F-4C82-B33C-D693090722B6',
#   '2008-12-01 00:00:00.000'),
#  (109,
#   'EM',
#   0,
#   None,
#   'Alice',
#   'O',
#   'Ciccu',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'B5836E66-4251-4D4D-8F49-8E6D9E3C9D64',
#   '2008-11-30 00:00:00.000'),
#  (110,
#   'EM',
#   0,
#   None,
#   'Jun',
#   'T',
#   'Cao',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '20BDFF3B-3561-482B-B02D-DA9B6183B6D9',
#   '2008-12-07 00:00:00.000'),
#  (111,
#   'EM',
#   0,
#   None,
#   'Suroor',
#   'R',
#   'Fatima',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '62C97C5B-5CAB-42C6-813D-C0C75BBBFD7B',
#   '2008-12-10 00:00:00.000'),
#  (112,
#   'EM',
#   0,
#   None,
#   'John',
#   'P',
#   'Evans',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'FCFA001C-D5BC-455F-9124-21290B4A5304',
#   '2008-12-25 00:00:00.000'),
#  (113,
#   'EM',
#   0,
#   None,
#   'Linda',
#   'K',
#   'Moschell',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '1552D700-1E1C-4725-8074-D8D7D9A49B0E',
#   '2008-12-18 00:00:00.000'),
#  (114,
#   'EM',
#   0,
#   None,
#   'Mindaugas',
#   'J',
#   'Krapauskas',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '7C623D80-0A62-42DE-A355-24715A7160C6',
#   '2009-01-06 00:00:00.000'),
#  (115,
#   'EM',
#   0,
#   None,
#   'Angela',
#   'W',
#   'Barbariol',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '8E6ADFD0-2FE0-4EB9-93F2-A04FD877F6DC',
#   '2009-01-13 00:00:00.000'),
#  (116,
#   'EM',
#   0,
#   None,
#   'Michael',
#   'W',
#   'Patten',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'C31D89BE-1DB6-495B-8699-4669E5FA4B9D',
#   '2009-01-24 00:00:00.000'),
#  (117,
#   'EM',
#   0,
#   None,
#   'Chad',
#   'W',
#   'Niswonger',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '1CAC3A75-34AB-45C1-B9F1-7CAA44C76A75',
#   '2009-02-11 00:00:00.000'),
#  (118,
#   'EM',
#   0,
#   None,
#   'Don',
#   'L',
#   'Hall',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F369194E-2FF0-4E61-97A7-B821F8B2BAED',
#   '2009-02-06 00:00:00.000'),
#  (119,
#   'EM',
#   0,
#   None,
#   'Michael',
#   'T',
#   'Entin',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '7533C47D-8E8F-40AC-8383-CF3DF57E3D84',
#   '2009-02-18 00:00:00.000'),
#  (120,
#   'EM',
#   0,
#   None,
#   'Kitti',
#   'H',
#   'Lertpiriyasuwat',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'BFADC42C-0D0E-4BDA-94B7-B14E89F5FC69',
#   '2009-02-25 00:00:00.000'),
#  (121,
#   'EM',
#   0,
#   None,
#   'Pilar',
#   'G',
#   'Ackerman',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '81F50324-D0B5-4EA5-8B20-F99D46572C76',
#   '2008-12-26 00:00:00.000'),
#  (122,
#   'EM',
#   0,
#   None,
#   'Susan',
#   'W',
#   'Eaton',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '84C723AC-F07F-4299-89B1-FAABB9CA47FC',
#   '2008-11-30 00:00:00.000'),
#  (123,
#   'EM',
#   0,
#   None,
#   'Vamsi',
#   'N',
#   'Kuppa',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '37154EFE-002F-4D85-A84B-A8B1FF714BC6',
#   '2008-11-30 00:00:00.000'),
#  (124,
#   'EM',
#   0,
#   None,
#   'Kim',
#   'T',
#   'Ralls',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '7AB39816-FF5A-4F3D-A3DC-88D906EC054F',
#   '2008-12-19 00:00:00.000'),
#  (125,
#   'EM',
#   0,
#   None,
#   'Matthias',
#   'T',
#   'Berndt',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '318BF718-6CCC-4F26-AC81-00EAF17B1BFE',
#   '2009-01-13 00:00:00.000'),
#  (126,
#   'EM',
#   0,
#   None,
#   'Jimmy',
#   'T',
#   'Bischoff',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '52182904-CFAF-4B2D-8D77-268DE7AB5DA4',
#   '2009-02-19 00:00:00.000'),
#  (127,
#   'EM',
#   0,
#   None,
#   'David',
#   'P',
#   'Hamilton',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'D6532F6D-A832-4266-B0F0-2F874F5A85BA',
#   '2008-12-27 00:00:00.000'),
#  (128,
#   'EM',
#   0,
#   None,
#   'Paul',
#   'B',
#   'Komosinski',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'E4145F40-88D2-43F4-A018-9BFB38D6D9FF',
#   '2008-11-27 00:00:00.000'),
#  (129,
#   'EM',
#   0,
#   None,
#   'Gary',
#   'W',
#   'Yukish',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '09EA8640-ED99-4205-9433-078F1D81D221',
#   '2008-12-15 00:00:00.000'),
#  (130,
#   'EM',
#   0,
#   None,
#   'Rob',
#   'T',
#   'Caron',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '909F01EF-2F6D-44DD-AF8D-1553BED7EACF',
#   '2009-02-06 00:00:00.000'),
#  (131,
#   'EM',
#   0,
#   None,
#   'Baris',
#   'F',
#   'Cetinok',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'BA03C1A4-0577-44F5-BFBC-FC701C007F13',
#   '2009-02-08 00:00:00.000'),
#  (132,
#   'EM',
#   0,
#   None,
#   'Nicole',
#   'B',
#   'Holliday',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F101C5EE-17B1-4FB0-9CAE-4A88694CEEAA',
#   '2009-02-15 00:00:00.000'),
#  (133,
#   'EM',
#   0,
#   None,
#   'Michael',
#   'L',
#   'Rothkugel',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'EE04F4CB-977A-48D0-ACB4-D89172FD5AE2',
#   '2009-01-03 00:00:00.000'),
#  (134,
#   'EM',
#   0,
#   None,
#   'Eric',
#   None,
#   'Gubbels',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '4A9AC912-9E22-47B7-B126-5F3B576A430E',
#   '2009-01-07 00:00:00.000'),
#  (135,
#   'EM',
#   0,
#   None,
#   'Ivo',
#   'William',
#   'Salmre',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'DFA4B008-D83F-4828-AAC6-449E683909F5',
#   '2008-11-27 00:00:00.000'),
#  (136,
#   'EM',
#   0,
#   None,
#   'Sylvester',
#   'A',
#   'Valdez',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '6152BEC3-BB11-43AA-B691-9881CE6DD3F3',
#   '2009-12-04 00:00:00.000'),
#  (137,
#   'EM',
#   0,
#   None,
#   'Anibal',
#   'T',
#   'Sousa',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9B75A538-958C-4C91-987A-B9BCCE683E8A',
#   '2009-02-16 00:00:00.000'),
#  (138,
#   'EM',
#   0,
#   None,
#   'Samantha',
#   'H',
#   'Smith',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '11EF6F0A-29B6-4541-82F0-2E7A35179E48',
#   '2009-01-28 00:00:00.000'),
#  (139,
#   'EM',
#   0,
#   'Mr.',
#   'Hung-Fu',
#   'T',
#   'Ting',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '739C7553-13E5-4F36-86F6-4775645547AE',
#   '2009-12-30 00:00:00.000'),
#  (140,
#   'EM',
#   0,
#   None,
#   'Prasanna',
#   'E',
#   'Samarawickrama',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'E8673E92-31F6-42F4-A65C-A595D3F899F6',
#   '2010-01-15 00:00:00.000'),
#  (141,
#   'EM',
#   0,
#   None,
#   'Min',
#   'G',
#   'Su',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '3BB0243E-11E3-4E5C-8DB5-6B927C71432E',
#   '2010-01-17 00:00:00.000'),
#  (142,
#   'EM',
#   0,
#   None,
#   'Olinda',
#   'C',
#   'Turner',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'BF741CEC-34E0-4B44-99C2-E0382FCD9E8E',
#   '2010-02-25 00:00:00.000'),
#  (143,
#   'EM',
#   0,
#   None,
#   'Krishna',
#   None,
#   'Sunkammurali',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '442C8270-1E84-47C5-A621-AF10CF1B3546',
#   '2010-02-06 00:00:00.000'),
#  (144,
#   'EM',
#   0,
#   None,
#   'Paul',
#   'R',
#   'Singh',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'BA4C0109-A2A4-4595-A357-38A64B643E3C',
#   '2009-01-10 00:00:00.000'),
#  (145,
#   'EM',
#   0,
#   None,
#   'Cynthia',
#   'S',
#   'Randall',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'F0C15AD6-4CFF-4931-A216-49B635596043',
#   '2009-01-20 00:00:00.000'),
#  (146,
#   'EM',
#   0,
#   None,
#   'Jian Shuo',
#   None,
#   'Wang',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '009EBB72-9173-4AA9-920E-B578F3C927DE',
#   '2008-11-30 00:00:00.000'),
#  (147,
#   'EM',
#   0,
#   None,
#   'Sandra',
#   None,
#   'Reátegui Alayo',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'B07FA8A6-A056-48AB-91F8-318C6C87B502',
#   '2008-12-19 00:00:00.000'),
#  (148,
#   'EM',
#   0,
#   None,
#   'Jason',
#   'M',
#   'Watters',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '00D61032-0D0E-41E3-8F37-B5987C8D5087',
#   '2009-01-07 00:00:00.000'),
#  (149,
#   'EM',
#   0,
#   None,
#   'Andy',
#   'M',
#   'Ruth',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9CFDF60A-083A-44DC-AFE2-D578C76FD55A',
#   '2009-01-24 00:00:00.000'),
#  (150,
#   'EM',
#   0,
#   None,
#   'Michael',
#   'T',
#   'Vanderhyde',
#   None,
#   2,
#   None,
# ...
#   '2011-12-23 00:00:00.000'),
#  (1629,
#   'VC',
#   0,
#   None,
#   'Alma',
#   'B.',
#   'Poorbaugh',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9D8FAF5F-8B8D-4DA0-948A-3E802D42F16E',
#   '2012-02-02 00:00:00.000'),
#  (1631,
#   'VC',
#   0,
#   'Ms.',
#   'Ethel',
#   'J.',
#   'Porter',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '1E28BDD0-5C2B-4DCB-8B21-826D61C8853A',
#   '2012-02-02 00:00:00.000'),
#  (1633,
#   'VC',
#   0,
#   'Ms.',
#   'Constance',
#   'J.',
#   'Posner',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '6E2624C6-8C4D-4A3E-A7C3-44685104F00B',
#   '2011-05-09 00:00:00.000'),
#  (1635,
#   'VC',
#   0,
#   'Mr.',
#   'Josh',
#   None,
#   'Pollock',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '58BCA248-2FA8-49A8-A159-EF1E0B80DBDA',
#   '2012-01-17 00:00:00.000'),
#  (1637,
#   'VC',
#   0,
#   'Ms.',
#   'Betty',
#   'J.',
#   'Potts',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '2CEDCB06-6574-4192-9AEF-B2A7614A5CA0',
#   '2012-01-25 00:00:00.000'),
#  (1639,
#   'VC',
#   0,
#   'Mr.',
#   'Fred',
#   None,
#   'Preston',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'AD8DC1B2-D487-496D-974E-B9134719A209',
#   '2012-02-02 00:00:00.000'),
#  (1641,
#   'VC',
#   0,
#   'Mr.',
#   'Jeff',
#   None,
#   'Price',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'DA26B021-97BB-4057-8FA8-98EBBAC63387',
#   '2012-02-02 00:00:00.000'),
#  (1643,
#   'VC',
#   0,
#   'Mr.',
#   'Milton',
#   'M.',
#   'Pugh',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '6C3A8F48-0E60-4A5D-BAD6-AC7E918BB67D',
#   '2012-01-25 00:00:00.000'),
#  (1645,
#   'VC',
#   0,
#   'Mr.',
#   'Sean',
#   None,
#   'Purcell',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'D060FE0A-41FF-414D-A861-5E11A982E27D',
#   '2012-01-17 00:00:00.000'),
#  (1647,
#   'VC',
#   0,
#   'Ms.',
#   'Monica',
#   'L.',
#   'Quintana',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '21DE8320-AB5A-4953-B865-5E07C37E6B8F',
#   '2012-01-17 00:00:00.000'),
#  (1649,
#   'VC',
#   0,
#   'Ms.',
#   'Mary Lou',
#   'M.',
#   'Quintana',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '4D5173FB-4356-47D9-B0CB-195ABC60F3FA',
#   '2011-04-25 00:00:00.000'),
#  (1651,
#   'VC',
#   0,
#   'Ms.',
#   'Kim',
#   None,
#   'Ralls',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'EF5AE74D-A030-4A80-B6D1-987B5EB5C102',
#   '2012-02-18 00:00:00.000'),
#  (1653,
#   'VC',
#   0,
#   'Ms.',
#   'Susan',
#   'J.',
#   'Ramos',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'C8606945-354C-49FE-8152-2733276CD554',
#   '2011-05-09 00:00:00.000'),
#  (1655,
#   'VC',
#   0,
#   'Ms.',
#   'Cynthia',
#   None,
#   'Randall',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '2A6B008C-6D3A-465C-A2A5-6A57C6A50E9F',
#   '2012-02-02 00:00:00.000'),
#  (1657,
#   'VC',
#   0,
#   'Mr.',
#   'Arvind',
#   'B.',
#   'Rao',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'ECC9CB33-8355-4602-BF7C-E0EA5F2E5867',
#   '2011-12-24 00:00:00.000'),
#  (1659,
#   'VC',
#   0,
#   'Mr.',
#   'Simon',
#   None,
#   'Rapier',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'C373DAE2-8BF2-4CA6-9AE9-37763692A0E2',
#   '2012-01-25 00:00:00.000'),
#  (1661,
#   'VC',
#   0,
#   'Mr.',
#   'Michael',
#   'S',
#   'Ray',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '181F0FB6-6B52-44DF-A11F-24ABEE092248',
#   '2012-02-02 00:00:00.000'),
#  (1663,
#   'VC',
#   0,
#   'Ms.',
#   'Suzann',
#   'K.',
#   'Reams',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'D47E35E9-FCFE-4BF6-A6C0-8061A65A751F',
#   '2011-05-09 00:00:00.000'),
#  (1665,
#   'VC',
#   0,
#   'Ms.',
#   'Michelle',
#   'B.',
#   'Rector',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '589F7370-661E-4E6E-9493-47D50E468679',
#   '2012-01-29 00:00:00.000'),
#  (1667,
#   'VC',
#   0,
#   'Ms.',
#   'Jamie',
#   None,
#   'Reding',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'C116CFB9-724F-4223-BF0A-685015A7CCDD',
#   '2012-02-03 00:00:00.000'),
#  (1669,
#   'VC',
#   0,
#   'Mr.',
#   'Russell',
#   'A.',
#   'Reed',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '3A35179A-0DC4-4A42-919E-BC162F72F1FE',
#   '2012-02-03 00:00:00.000'),
#  (1671,
#   'VC',
#   0,
#   'Ms.',
#   'Celine',
#   'J.',
#   'Reed',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '7EC9892F-DD0C-4E1D-98AA-0BF3EF7B41AF',
#   '2012-01-25 00:00:00.000'),
#  (1673,
#   'VC',
#   0,
#   'Mr.',
#   'Randy',
#   None,
#   'Reeves',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '4DA9BF5D-10CB-468F-991C-03F2A823E19E',
#   '2012-02-18 00:00:00.000'),
#  (1675,
#   'VC',
#   0,
#   'Mr.',
#   'Enoch',
#   'T',
#   'Remick',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'E4F14635-F2E9-4688-A41E-DC8F1EAD6D76',
#   '2012-02-03 00:00:00.000'),
#  (1677,
#   'VC',
#   0,
#   'Mr.',
#   'Eric',
#   'E.',
#   'Rhodes',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'B4DA7B01-A4DF-40AE-AE97-2BF09B1DDE27',
#   '2011-05-09 00:00:00.000'),
#  (1679,
#   'VC',
#   0,
#   'Mr.',
#   'Adam',
#   'J.',
#   'Reynolds',
#   'Jr.',
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'BC4E0302-33E6-4897-995E-9994BEBFAEB6',
#   '2012-01-25 00:00:00.000'),
#  (1681,
#   'VC',
#   0,
#   'Ms.',
#   'Constance',
#   'J.',
#   'Remmington',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9666C77B-66C6-42D2-9CFF-00ACDE4C2D84',
#   '2012-02-02 00:00:00.000'),
#  (1683,
#   'VC',
#   0,
#   'Mr.',
#   'Albert',
#   'A.',
#   'Rhodes',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'EDF54CFC-7B97-49CF-8EE9-1059524C533F',
#   '2012-02-02 00:00:00.000'),
#  (1685,
#   'VC',
#   0,
#   'Mr.',
#   'Dave',
#   None,
#   'Richards',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '01BEC60C-8E17-4C63-A787-2245E92A8845',
#   '2012-02-02 00:00:00.000'),
#  (1687,
#   'VC',
#   0,
#   'Mr.',
#   'Jack',
#   'S.',
#   'Richins',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '0D3B502B-EF37-465F-BEC4-08A6B443AD19',
#   '2012-02-18 00:00:00.000'),
#  (1689,
#   'VC',
#   0,
#   'Ms.',
#   'Marie',
#   'M.',
#   'Richmeier',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   'FBC9DAAF-4436-4281-AE9C-AC782002A175',
#   '2011-12-23 00:00:00.000'),
#  (1691,
#   'VC',
#   0,
#   'Mr.',
#   'William',
#   'J.',
#   'Richter',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '5F7E4156-1989-4E99-8574-C5F05A887DCF',
#   '2011-12-24 00:00:00.000'),
#  (1693,
#   'VC',
#   0,
#   'Mr.',
#   'Thomas',
#   'M.',
#   'Richards',
#   'Jr.',
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '9DFD05F3-6BFB-45C1-942F-1D3EC141D39F',
#   '2011-12-24 00:00:00.000'),
#  (1695,
#   'VC',
#   0,
#   'Ms.',
#   'Stacy',
#   'K.',
#   'Rizzi',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '2130ED19-EFF9-4006-B4C0-CAF5BA579D0A',
#   '2011-12-24 00:00:00.000'),
#  (1697,
#   'VC',
#   0,
#   'Ms.',
#   'Leota',
#   'J.',
#   'Roberts',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>0</TotalPurchaseYTD></IndividualSurvey>',
#   '071BA803-57A8-439F-9DAE-5695052649B6',
#   '2011-12-23 00:00:00.000'),
#  (1699,
#   'IN',
#   0,
#   'Mr.',
#   'David',
#   'R.',
#   'Robinett',
#   None,
#   1,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>-16.01</TotalPurchaseYTD><DateFirstPurchase>2003-09-01Z</DateFirstPurchase><BirthDate>1961-02-23Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>25001-50000</YearlyIncome><Gender>M</Gender><TotalChildren>4</TotalChildren><NumberChildrenAtHome>0</NumberChildrenAtHome><Education>Graduate Degree</Education><Occupation>Clerical</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>0</NumberCarsOwned><CommuteDistance>0-1 Miles</CommuteDistance></IndividualSurvey>',
#   '7893C62D-9940-4DB8-90D4-EA0CCD9F6731',
#   '2013-07-31 00:00:00.000'),
#  (1700,
#   'IN',
#   0,
#   'Ms.',
#   'Rebecca',
#   'A.',
#   'Robinson',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>-4</TotalPurchaseYTD><DateFirstPurchase>2004-06-05Z</DateFirstPurchase><BirthDate>1965-06-11Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>50001-75000</YearlyIncome><Gender>F</Gender><TotalChildren>3</TotalChildren><NumberChildrenAtHome>3</NumberChildrenAtHome><Education>Bachelors </Education><Occupation>Professional</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>1</NumberCarsOwned><CommuteDistance>5-10 Miles</CommuteDistance></IndividualSurvey>',
#   '1B81EF06-05C2-4D27-960F-4455938CB255',
#   '2014-05-05 00:00:00.000'),
#  (1701,
#   'IN',
#   0,
#   'Ms.',
#   'Dorothy',
#   'B.',
#   'Robinson',
#   None,
#   2,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>4730.04</TotalPurchaseYTD><DateFirstPurchase>2002-04-07Z</DateFirstPurchase><BirthDate>1954-09-23Z</BirthDate><MaritalStatus>S</MaritalStatus><YearlyIncome>75001-100000</YearlyIncome><Gender>M</Gender><TotalChildren>2</TotalChildren><NumberChildrenAtHome>0</NumberChildrenAtHome><Education>Partial College</Education><Occupation>Skilled Manual</Occupation><HomeOwnerFlag>0</HomeOwnerFlag><NumberCarsOwned>2</NumberCarsOwned><CommuteDistance>1-2 Miles</CommuteDistance></IndividualSurvey>',
#   'FED4A110-8137-4AA5-8B27-A15B4147D7C4',
#   '2012-03-06 00:00:00.000'),
#  (1702,
#   'IN',
#   0,
#   'Ms.',
#   'Carol Ann',
#   'F.',
#   'Rockne',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>2435.4018</TotalPurchaseYTD><DateFirstPurchase>2001-10-27Z</DateFirstPurchase><BirthDate>1943-07-15Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>25001-50000</YearlyIncome><Gender>M</Gender><TotalChildren>1</TotalChildren><NumberChildrenAtHome>0</NumberChildrenAtHome><Education>Bachelors </Education><Occupation>Clerical</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>0</NumberCarsOwned><CommuteDistance>0-1 Miles</CommuteDistance></IndividualSurvey>',
#   '1DCFABA9-41F7-4C95-8CF4-7C9FBA398C6B',
#   '2011-09-26 00:00:00.000'),
#  (1703,
#   'IN',
#   0,
#   'Mr.',
#   'Scott',
#   'M.',
#   'Rodgers',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>1647</TotalPurchaseYTD><DateFirstPurchase>2002-04-18Z</DateFirstPurchase><BirthDate>1968-05-15Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>50001-75000</YearlyIncome><Gender>M</Gender><TotalChildren>2</TotalChildren><NumberChildrenAtHome>2</NumberChildrenAtHome><Education>Bachelors </Education><Occupation>Professional</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>1</NumberCarsOwned><CommuteDistance>2-5 Miles</CommuteDistance></IndividualSurvey>',
#   '77C57B30-2394-4548-8246-3BEC69366142',
#   '2012-03-17 00:00:00.000'),
#  (1704,
#   'IN',
#   0,
#   'Mr.',
#   'Jim',
#   None,
#   'Rodman',
#   None,
#   0,
#   None,
#   '<IndividualSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey"><TotalPurchaseYTD>-699.0964</TotalPurchaseYTD><DateFirstPurchase>2002-02-14Z</DateFirstPurchase><BirthDate>1955-09-13Z</BirthDate><MaritalStatus>M</MaritalStatus><YearlyIncome>greater than 100000</YearlyIncome><Gender>F</Gender><TotalChildren>3</TotalChildren><NumberChildrenAtHome>4</NumberChildrenAtHome><Education>Partial College</Education><Occupation>Professional</Occupation><HomeOwnerFlag>1</HomeOwnerFlag><NumberCarsOwned>3</NumberCarsOwned><CommuteDistance>5-10 Miles</CommuteDistance></IndividualSurvey>',
#   '9F34A44B-148D-4A90-8E3D-824F786F995F',
#   '2012-01-14 00:00:00.000'),
#  ...]

# %% [markdown]
# ### Production.Product

# %%
#Escolhendo o arquivo dentro do bucket

bucket.blob('Production.Product.csv')
# Out:
# <Blob: desafio-rox-leandro, Production.Product.csv, None>

# %%
# Criando o df em pandas para enviar para o mysql e ajustando colunas se necessário com o pandas
# alterar , para . em (StandardCost, ListPrice)

df_Product = pd.read_csv(path_Product,sep=';')

# Alteração das "," por "." nas colunas abaixo
df_Product["StandardCost"] = df_Product["StandardCost"].replace(",", ".", regex=True)
df_Product["ListPrice"] = df_Product["ListPrice"].replace(",", ".", regex=True)

# %%
# Codigo repetido em todos os passos, colab dando erro, foi preciso sempre redefinir o conector.
# Conector host:ip_banco, user:usuario, passwd: senha, db:banco criado

con = mysql.connector.connect(host='34.95.218.222',user='desafio-username',passwd='1234',db='bicicletas')
cur = con.cursor()
engine = create_engine('mysql+pymysql://desafio-username:1234@34.95.218.222/bicicletas')

# %%
# Enviando a tabela Production.Product para o MySql  

dfsql_Product = df_Product.to_sql('ProductionProduct',con=engine,if_exists='replace',index=False)

# %%
# Verificando o conteúdo enviado

cur.execute('select * from ProductionProduct')
cur.fetchall()
# Out:
# [(1,
#   'Adjustable Race',
#   'AR-5381',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '694215B7-08F7-4C0D-ACB1-D734BA44C0C8',
#   '2014-02-08 10:01:36.827'),
#  (2,
#   'Bearing Ball',
#   'BA-8327',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '58AE3C20-4F3A-4749-A7D4-D568806CC537',
#   '2014-02-08 10:01:36.827'),
#  (3,
#   'BB Ball Bearing',
#   'BE-2349',
#   1,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E',
#   '2014-02-08 10:01:36.827'),
#  (4,
#   'Headset Ball Bearings',
#   'BE-2908',
#   0,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B',
#   '2014-02-08 10:01:36.827'),
#  (316,
#   'Blade',
#   'BL-2036',
#   1,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'E73E9750-603B-4131-89F5-3DD15ED5FF80',
#   '2014-02-08 10:01:36.827'),
#  (317,
#   'LL Crankarm',
#   'CA-5965',
#   0,
#   0,
#   'Black',
#   500,
#   375,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   'L ',
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '3C9D10B7-A6B2-4774-9963-C19DCEE72FEA',
#   '2014-02-08 10:01:36.827'),
#  (318,
#   'ML Crankarm',
#   'CA-6738',
#   0,
#   0,
#   'Black',
#   500,
#   375,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   'M ',
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'EABB9A92-FA07-4EAB-8955-F0517B4A4CA7',
#   '2014-02-08 10:01:36.827'),
#  (319,
#   'HL Crankarm',
#   'CA-7457',
#   0,
#   0,
#   'Black',
#   500,
#   375,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '7D3FD384-4F29-484B-86FA-4206E276FE58',
#   '2014-02-08 10:01:36.827'),
#  (320,
#   'Chainring Bolts',
#   'CB-2903',
#   0,
#   0,
#   'Silver',
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '7BE38E48-B7D6-4486-888E-F53C26735101',
#   '2014-02-08 10:01:36.827'),
#  (321,
#   'Chainring Nut',
#   'CN-6137',
#   0,
#   0,
#   'Silver',
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '3314B1D7-EF69-4431-B6DD-DC75268BD5DF',
#   '2014-02-08 10:01:36.827'),
#  (322,
#   'Chainring',
#   'CR-7833',
#   0,
#   0,
#   'Black',
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'F0AC2C4D-1A1F-4E3C-B4D9-68AEA0EC1CE4',
#   '2014-02-08 10:01:36.827'),
#  (323,
#   'Crown Race',
#   'CR-9981',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '51A32CA6-65A1-4C31-AF2B-D9E4F5D631D4',
#   '2014-02-08 10:01:36.827'),
#  (324,
#   'Chain Stays',
#   'CS-2812',
#   1,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'FE0678ED-AEF2-4C58-A450-8151CC24DDD8',
#   '2014-02-08 10:01:36.827'),
#  (325,
#   'Decal 1',
#   'DC-8732',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '05CE123C-A402-478E-AE9B-75D7727AEAAD',
#   '2014-02-08 10:01:36.827'),
#  (326,
#   'Decal 2',
#   'DC-9824',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A56851F9-1CD7-4E2F-8779-2E773E1B5209',
#   '2014-02-08 10:01:36.827'),
#  (327,
#   'Down Tube',
#   'DT-2377',
#   1,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '1DAD47DD-E259-42B8-B8B4-15A0B7D21B2F',
#   '2014-02-08 10:01:36.827'),
#  (328,
#   'Mountain End Caps',
#   'EC-M092',
#   1,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '6070B1EA-59B7-4F8B-950F-2BE07D00449D',
#   '2014-02-08 10:01:36.827'),
#  (329,
#   'Road End Caps',
#   'EC-R098',
#   1,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '88399D13-719E-4545-81D6-F0650F372FA2',
#   '2014-02-08 10:01:36.827'),
#  (330,
#   'Touring End Caps',
#   'EC-T209',
#   1,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '6903CE24-D0CE-4191-9198-4231DE37A929',
#   '2014-02-08 10:01:36.827'),
#  (331,
#   'Fork End',
#   'FE-3760',
#   1,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'C91D602E-DA52-43D2-BD7E-EB110A9392B9',
#   '2014-02-08 10:01:36.827'),
#  (332,
#   'Freewheel',
#   'FH-2981',
#   0,
#   0,
#   'Silver',
#   500,
#   375,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'D864879A-E8B1-4F7B-BAFA-1F136089C2C8',
#   '2014-02-08 10:01:36.827'),
#  (341,
#   'Flat Washer 1',
#   'FW-1000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A3F2FA3A-22E1-43D8-A131-A9B89C32D8EA',
#   '2014-02-08 10:01:36.827'),
#  (342,
#   'Flat Washer 6',
#   'FW-1200',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '331ADDEC-E9B9-4A7E-9324-42069C2DCDC4',
#   '2014-02-08 10:01:36.827'),
#  (343,
#   'Flat Washer 2',
#   'FW-1400',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '84A3473E-AE26-4A21-81B9-60BB418A79B2',
#   '2014-02-08 10:01:36.827'),
#  (344,
#   'Flat Washer 9',
#   'FW-3400',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '0AE4CE60-5242-48F5-ADA1-3013FF45F969',
#   '2014-02-08 10:01:36.827'),
#  (345,
#   'Flat Washer 4',
#   'FW-3800',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '2C1C58B4-234C-4B3A-8C8E-84524AC05EEA',
#   '2014-02-08 10:01:36.827'),
#  (346,
#   'Flat Washer 3',
#   'FW-5160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '590C2C3F-A8B6-42B5-9412-D655E37F0EAE',
#   '2014-02-08 10:01:36.827'),
#  (347,
#   'Flat Washer 8',
#   'FW-5800',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '1B73F5FE-AB85-49FC-99AD-0500CEBDA91D',
#   '2014-02-08 10:01:36.827'),
#  (348,
#   'Flat Washer 5',
#   'FW-7160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'D182CF18-4DDF-429B-A0DF-DE1CFC92622D',
#   '2014-02-08 10:01:36.827'),
#  (349,
#   'Flat Washer 7',
#   'FW-9160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '7E55F64D-EA3C-45FF-BE72-F7F7B9D61A79',
#   '2014-02-08 10:01:36.827'),
#  (350,
#   'Fork Crown',
#   'FC-3654',
#   1,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '1CBFA85B-5C9B-4B58-9C17-95238215D926',
#   '2014-02-08 10:01:36.827'),
#  (351,
#   'Front Derailleur Cage',
#   'FC-3982',
#   0,
#   0,
#   'Silver',
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '01C901E3-4323-48ED-AB9E-9BFDA28BDEF6',
#   '2014-02-08 10:01:36.827'),
#  (352,
#   'Front Derailleur Linkage',
#   'FL-2301',
#   0,
#   0,
#   'Silver',
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '88ED2E08-E775-4915-B506-831600B773FD',
#   '2014-02-08 10:01:36.827'),
#  (355,
#   'Guide Pulley',
#   'GP-0982',
#   0,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '6A89205B-90C3-4997-8C63-BC6A5EBC752D',
#   '2014-02-08 10:01:36.827'),
#  (356,
#   'LL Grip Tape',
#   'GT-0820',
#   0,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   'L ',
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '32C82181-1969-4660-AE04-A02D51994EC1',
#   '2014-02-08 10:01:36.827'),
#  (357,
#   'ML Grip Tape',
#   'GT-1209',
#   0,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   'M ',
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '09343E22-2494-4279-9F32-5D961A0FBFEA',
#   '2014-02-08 10:01:36.827'),
#  (358,
#   'HL Grip Tape',
#   'GT-2908',
#   0,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '8E5B2BF7-81DD-4454-B75E-D9AE2A6FBD26',
#   '2014-02-08 10:01:36.827'),
#  (359,
#   'Thin-Jam Hex Nut 9',
#   'HJ-1213',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A63AFF3C-4143-4016-BC99-D3F80EC1ADE5',
#   '2014-02-08 10:01:36.827'),
#  (360,
#   'Thin-Jam Hex Nut 10',
#   'HJ-1220',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A1AE0C6D-92A5-4FDA-B33B-1301E83EFE5B',
#   '2014-02-08 10:01:36.827'),
#  (361,
#   'Thin-Jam Hex Nut 1',
#   'HJ-1420',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'E33E8C4C-282A-4D1F-91E7-E9969CF7134F',
#   '2014-02-08 10:01:36.827'),
#  (362,
#   'Thin-Jam Hex Nut 2',
#   'HJ-1428',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A992684F-4642-4856-A817-2C0740AE8C55',
#   '2014-02-08 10:01:36.827'),
#  (363,
#   'Thin-Jam Hex Nut 15',
#   'HJ-3410',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'B9D9A30D-CB07-422D-A312-F0535575337E',
#   '2014-02-08 10:01:36.827'),
#  (364,
#   'Thin-Jam Hex Nut 16',
#   'HJ-3416',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '0EC8F653-24C9-41B6-86F5-39C1789DB580',
#   '2014-02-08 10:01:36.827'),
#  (365,
#   'Thin-Jam Hex Nut 5',
#   'HJ-3816',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '94506C9D-5991-46A7-82EA-00E05D8D9B9C',
#   '2014-02-08 10:01:36.827'),
#  (366,
#   'Thin-Jam Hex Nut 6',
#   'HJ-3824',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '71E984C6-1D11-4CF2-BAEE-6C8DF494BDAD',
#   '2014-02-08 10:01:36.827'),
#  (367,
#   'Thin-Jam Hex Nut 3',
#   'HJ-5161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'EFC09CDB-ECD5-4DB5-9E27-277DDA6D7F50',
#   '2014-02-08 10:01:36.827'),
#  (368,
#   'Thin-Jam Hex Nut 4',
#   'HJ-5162',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '0A0C93AA-D06C-48AA-99EB-20F2C8A6D6C4',
#   '2014-02-08 10:01:36.827'),
#  (369,
#   'Thin-Jam Hex Nut 13',
#   'HJ-5811',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A2728648-9517-4DEC-8606-D7D98ECD1E91',
#   '2014-02-08 10:01:36.827'),
#  (370,
#   'Thin-Jam Hex Nut 14',
#   'HJ-5818',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '0A7AD37C-3696-4844-8633-9FDDCD5FCEFC',
#   '2014-02-08 10:01:36.827'),
#  (371,
#   'Thin-Jam Hex Nut 7',
#   'HJ-7161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'ACBB1DE1-680C-4034-A8C5-3C6B01E57AA7',
#   '2014-02-08 10:01:36.827'),
#  (372,
#   'Thin-Jam Hex Nut 8',
#   'HJ-7162',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A0DA8F8F-45FB-4E62-AB14-AA229087DE1E',
#   '2014-02-08 10:01:36.827'),
#  (373,
#   'Thin-Jam Hex Nut 12',
#   'HJ-9080',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'DB99CBCD-F18D-4979-8DCF-1012F3B1CB15',
#   '2014-02-08 10:01:36.827'),
#  (374,
#   'Thin-Jam Hex Nut 11',
#   'HJ-9161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'EC2E54F5-9D07-4C26-B969-40F835395BE3',
#   '2014-02-08 10:01:36.827'),
#  (375,
#   'Hex Nut 5',
#   'HN-1024',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'F2F3A14C-DF15-4957-966D-55E5FCAD1161',
#   '2014-02-08 10:01:36.827'),
#  (376,
#   'Hex Nut 6',
#   'HN-1032',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'E73E44DD-F0B7-45D4-9066-E49F1B1FE7D0',
#   '2014-02-08 10:01:36.827'),
#  (377,
#   'Hex Nut 16',
#   'HN-1213',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '2B2A5641-BFFE-4079-B9F0-8BF355BC3996',
#   '2014-02-08 10:01:36.827'),
#  (378,
#   'Hex Nut 17',
#   'HN-1220',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'F70BBECD-5BE7-4EE9-A9E7-15786E622BA9',
#   '2014-02-08 10:01:36.827'),
#  (379,
#   'Hex Nut 7',
#   'HN-1224',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'BA3631D1-33D6-4A2F-8413-758BFDA6F9C2',
#   '2014-02-08 10:01:36.827'),
#  (380,
#   'Hex Nut 8',
#   'HN-1420',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'B478B33A-1FD5-4DB6-B99A-EB3B2A7C1623',
#   '2014-02-08 10:01:36.827'),
#  (381,
#   'Hex Nut 9',
#   'HN-1428',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'DA46D979-59DF-456D-B5AE-E7E89FC589DF',
#   '2014-02-08 10:01:36.827'),
#  (382,
#   'Hex Nut 22',
#   'HN-3410',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '2F457404-197D-4DDF-9868-A3AAD1B32D6B',
#   '2014-02-08 10:01:36.827'),
#  (383,
#   'Hex Nut 23',
#   'HN-3416',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '5F02449E-96E5-4FC8-ADE0-8A9A7F533624',
#   '2014-02-08 10:01:36.827'),
#  (384,
#   'Hex Nut 12',
#   'HN-3816',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '32C97696-7C3D-4793-A54B-3D73200BADBC',
#   '2014-02-08 10:01:36.827'),
#  (385,
#   'Hex Nut 13',
#   'HN-3824',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '8F0902D0-274D-4A4B-8FDE-E37F53B2AB29',
#   '2014-02-08 10:01:36.827'),
#  (386,
#   'Hex Nut 1',
#   'HN-4402',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '57456F8C-CB78-45EC-B9B8-21A9BE5C12F5',
#   '2014-02-08 10:01:36.827'),
#  (387,
#   'Hex Nut 10',
#   'HN-5161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '955811B4-2F17-48F0-A8B4-0C96CBA4AA6D',
#   '2014-02-08 10:01:36.827'),
#  (388,
#   'Hex Nut 11',
#   'HN-5162',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '7D4BAD17-374F-4281-9AE5-49ABC3FE585D',
#   '2014-02-08 10:01:36.827'),
#  (389,
#   'Hex Nut 2',
#   'HN-5400',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '17C4B7BA-8574-4EC7-BD3B-7A51ABA61F69',
#   '2014-02-08 10:01:36.827'),
#  (390,
#   'Hex Nut 20',
#   'HN-5811',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'B4E990B7-B3F7-4F97-8F98-CE373833ADB4',
#   '2014-02-08 10:01:36.827'),
#  (391,
#   'Hex Nut 21',
#   'HN-5818',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '433EE702-E028-4630-895C-8CDBD0F1FD89',
#   '2014-02-08 10:01:36.827'),
#  (392,
#   'Hex Nut 3',
#   'HN-6320',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'EE76FAE0-161E-409C-A6F5-837B5B8B344D',
#   '2014-02-08 10:01:36.827'),
#  (393,
#   'Hex Nut 14',
#   'HN-7161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'EB10B88C-5351-4C06-AF51-116BAA48A2C8',
#   '2014-02-08 10:01:36.827'),
#  (394,
#   'Hex Nut 15',
#   'HN-7162',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '35E28755-E8F0-47BE-A8BE-A20836DBE28D',
#   '2014-02-08 10:01:36.827'),
#  (395,
#   'Hex Nut 4',
#   'HN-8320',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '69AB8D5E-6101-4203-81B1-794E923782EA',
#   '2014-02-08 10:01:36.827'),
#  (396,
#   'Hex Nut 18',
#   'HN-9161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '39D42384-66F6-4CCD-B471-0589FC3FC576',
#   '2014-02-08 10:01:36.827'),
#  (397,
#   'Hex Nut 19',
#   'HN-9168',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'B63F827E-9055-4678-9E90-4FFD8D06D4D4',
#   '2014-02-08 10:01:36.827'),
#  (398,
#   'Handlebar Tube',
#   'HT-2981',
#   1,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '9F88C58E-5CFA-46C9-8994-DA4F3FFE92ED',
#   '2014-02-08 10:01:36.827'),
#  (399,
#   'Head Tube',
#   'HT-8019',
#   1,
#   0,
#   None,
#   800,
#   600,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'B047C048-B4FB-4F80-94BC-C5FC00A6F77F',
#   '2014-02-08 10:01:36.827'),
#  (400,
#   'LL Hub',
#   'HU-6280',
#   1,
#   0,
#   None,
#   500,
#   375,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   'L ',
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'AB332DDA-DDA5-44AD-8C50-34FFACEFFA8E',
#   '2014-02-08 10:01:36.827'),
#  (401,
#   'HL Hub',
#   'HU-8998',
#   1,
#   0,
#   None,
#   500,
#   375,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'D59403A3-D19E-4803-BDA2-B436A6416FDA',
#   '2014-02-08 10:01:36.827'),
#  (402,
#   'Keyed Washer',
#   'KW-4091',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '43024784-2741-4CAB-A6DC-8050CE507F2E',
#   '2014-02-08 10:01:36.827'),
#  (403,
#   'External Lock Washer 3',
#   'LE-1000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '763412F0-6D53-43E2-B371-DCBED69F5E98',
#   '2014-02-08 10:01:36.827'),
#  (404,
#   'External Lock Washer 4',
#   'LE-1200',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '89B6E84F-5C08-4CD9-B803-01F2CE24E417',
#   '2014-02-08 10:01:36.827'),
#  (405,
#   'External Lock Washer 9',
#   'LE-1201',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '3330A721-E8CB-4E67-8D27-300DB68C2395',
#   '2014-02-08 10:01:36.827'),
#  (406,
#   'External Lock Washer 5',
#   'LE-1400',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '39314098-768B-49F9-A777-AF2E3BB06B17',
#   '2014-02-08 10:01:36.827'),
#  (407,
#   'External Lock Washer 7',
#   'LE-3800',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '93F7BC73-BD22-45A0-9F2E-A11932342E6B',
#   '2014-02-08 10:01:36.827'),
#  (408,
#   'External Lock Washer 6',
#   'LE-5160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'DC5F4CB0-A599-42CD-A96F-E9F01BC1DACC',
#   '2014-02-08 10:01:36.827'),
#  (409,
#   'External Lock Washer 1',
#   'LE-6000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '802B7687-BC74-43F8-98AE-2112166FACA7',
#   '2014-02-08 10:01:36.827'),
#  (410,
#   'External Lock Washer 8',
#   'LE-7160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '02C48826-21AD-41F3-85A6-BC9A85A4DCE4',
#   '2014-02-08 10:01:36.827'),
#  (411,
#   'External Lock Washer 2',
#   'LE-8000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '502A2A3D-CD72-43AD-8FB6-77505187EDF4',
#   '2014-02-08 10:01:36.827'),
#  (412,
#   'Internal Lock Washer 3',
#   'LI-1000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'F1168C45-E4D2-4C37-ADAD-B76EAF402B71',
#   '2014-02-08 10:01:36.827'),
#  (413,
#   'Internal Lock Washer 4',
#   'LI-1200',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '7F7413BB-BAD2-47E4-9BC4-D98B194BE35D',
#   '2014-02-08 10:01:36.827'),
#  (414,
#   'Internal Lock Washer 9',
#   'LI-1201',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '4F040109-8332-4FCF-8084-57E6D8C49283',
#   '2014-02-08 10:01:36.827'),
#  (415,
#   'Internal Lock Washer 5',
#   'LI-1400',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '0C02F2CC-BDB4-4794-A4F9-0EB33F7545C2',
#   '2014-02-08 10:01:36.827'),
#  (416,
#   'Internal Lock Washer 7',
#   'LI-3800',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '3C2AC5BC-3F49-4FA4-8340-BC4CDA983F46',
#   '2014-02-08 10:01:36.827'),
#  (417,
#   'Internal Lock Washer 6',
#   'LI-5160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '7F175DFE-1669-4EE9-8EEB-7B55FCE9961C',
#   '2014-02-08 10:01:36.827'),
#  (418,
#   'Internal Lock Washer 10',
#   'LI-5800',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'C8323EEC-BDB2-4933-B3C6-24287638AD56',
#   '2014-02-08 10:01:36.827'),
#  (419,
#   'Internal Lock Washer 1',
#   'LI-6000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '71F8232D-2B59-41AC-99A1-F5EA197671B5',
#   '2014-02-08 10:01:36.827'),
#  (420,
#   'Internal Lock Washer 8',
#   'LI-7160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'E2F03586-02E8-4CD9-A342-1A8D65D393BD',
#   '2014-02-08 10:01:36.827'),
#  (421,
#   'Internal Lock Washer 2',
#   'LI-8000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '97741A88-92A1-4E72-B0AA-BCB198A1C378',
#   '2014-02-08 10:01:36.827'),
#  (422,
#   'Thin-Jam Lock Nut 9',
#   'LJ-1213',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '7DA2613B-3347-4072-A1DC-943ADA161D7F',
#   '2014-02-08 10:01:36.827'),
#  (423,
#   'Thin-Jam Lock Nut 10',
#   'LJ-1220',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A88F15BE-2719-4741-93A4-2D96EF3712EB',
#   '2014-02-08 10:01:36.827'),
#  (424,
#   'Thin-Jam Lock Nut 1',
#   'LJ-1420',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '48461E5D-D58A-47E5-8BA3-CE4430FCA611',
#   '2014-02-08 10:01:36.827'),
#  (425,
#   'Thin-Jam Lock Nut 2',
#   'LJ-1428',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '36187EB6-AD84-47B7-A55E-2941D3435FE2',
#   '2014-02-08 10:01:36.827'),
#  (426,
#   'Thin-Jam Lock Nut 15',
#   'LJ-3410',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '99215648-AFE8-4556-BC80-B6C62AE74FC8',
#   '2014-02-08 10:01:36.827'),
#  (427,
#   'Thin-Jam Lock Nut 16',
#   'LJ-3416',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'B4FC4C32-049C-417F-BBB0-F19CDFD64252',
#   '2014-02-08 10:01:36.827'),
#  (428,
#   'Thin-Jam Lock Nut 5',
#   'LJ-3816',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A57B7915-2E65-49DE-87BA-ACD007C55ADB',
#   '2014-02-08 10:01:36.827'),
#  (429,
#   'Thin-Jam Lock Nut 6',
#   'LJ-3824',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '5ABD940C-D61F-4108-8312-0EA97E469613',
#   '2014-02-08 10:01:36.827'),
#  (430,
#   'Thin-Jam Lock Nut 3',
#   'LJ-5161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '9883496F-4785-4BFC-8AF3-C357347B9F89',
#   '2014-02-08 10:01:36.827'),
#  (431,
#   'Thin-Jam Lock Nut 4',
#   'LJ-5162',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '8C5EE683-D93C-4F25-9454-22FAA4C31365',
#   '2014-02-08 10:01:36.827'),
#  (432,
#   'Thin-Jam Lock Nut 13',
#   'LJ-5811',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '38E4A447-3D3C-4087-ABAD-97F006525B52',
#   '2014-02-08 10:01:36.827'),
#  (433,
#   'Thin-Jam Lock Nut 14',
#   'LJ-5818',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'DCE24B6C-76D8-4934-A4F6-C934364943EA',
#   '2014-02-08 10:01:36.827'),
#  (434,
#   'Thin-Jam Lock Nut 7',
#   'LJ-7161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '344AD07C-CCA5-4374-A3F3-8A7E0A1D9916',
#   '2014-02-08 10:01:36.827'),
#  (435,
#   'Thin-Jam Lock Nut 8',
#   'LJ-7162',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'B2508CF2-C64F-493D-9DB4-0D6601AF1F73',
#   '2014-02-08 10:01:36.827'),
#  (436,
#   'Thin-Jam Lock Nut 12',
#   'LJ-9080',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '5D3E589F-4584-406B-B9CC-3C8C060CB9A5',
#   '2014-02-08 10:01:36.827'),
#  (437,
#   'Thin-Jam Lock Nut 11',
#   'LJ-9161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '64169A28-161C-4737-B724-F42FFD99DE80',
#   '2014-02-08 10:01:36.827'),
#  (438,
#   'Lock Nut 5',
#   'LN-1024',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'EB4C1D34-4816-4130-BB30-07B4DE4072B6',
#   '2014-02-08 10:01:36.827'),
#  (439,
#   'Lock Nut 6',
#   'LN-1032',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '98CCBB38-4683-486E-BBFE-CBBE4EA63C03',
#   '2014-02-08 10:01:36.827'),
#  (440,
#   'Lock Nut 16',
#   'LN-1213',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'BBFD88F8-28C5-44EE-B625-52E882393DFC',
#   '2014-02-08 10:01:36.827'),
#  (441,
#   'Lock Nut 17',
#   'LN-1220',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '92DC4BA8-A052-45DF-83EC-226F050F876B',
#   '2014-02-08 10:01:36.827'),
#  (442,
#   'Lock Nut 7',
#   'LN-1224',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'D583D825-C707-4529-B6F2-ABFFA21B81EC',
#   '2014-02-08 10:01:36.827'),
#  (443,
#   'Lock Nut 8',
#   'LN-1420',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'E91C3DC2-C99B-4D01-8108-5DDE3C87830A',
#   '2014-02-08 10:01:36.827'),
#  (444,
#   'Lock Nut 9',
#   'LN-1428',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '06534A20-4C00-4824-8BBA-B4E3A5724D93',
#   '2014-02-08 10:01:36.827'),
#  (445,
#   'Lock Nut 22',
#   'LN-3410',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '1E4FA4EC-367E-4D8D-88B4-6CD34D1CFB89',
#   '2014-02-08 10:01:36.827'),
#  (446,
#   'Lock Nut 23',
#   'LN-3416',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'AFA814C8-8EC8-49DB-9FEE-A291197A8FE9',
#   '2014-02-08 10:01:36.827'),
#  (447,
#   'Lock Nut 12',
#   'LN-3816',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '9A751F85-7130-4562-9F22-DB9CAB6E5BBC',
#   '2014-02-08 10:01:36.827'),
#  (448,
#   'Lock Nut 13',
#   'LN-3824',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '06BE8347-45C1-4C40-AFCB-6AB34AD135FB',
#   '2014-02-08 10:01:36.827'),
#  (449,
#   'Lock Nut 1',
#   'LN-4400',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '1DC29704-E0E0-4EF5-B581-4A524730C448',
#   '2014-02-08 10:01:36.827'),
#  (450,
#   'Lock Nut 10',
#   'LN-5161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '612C26C7-6018-4050-B628-8B2D2E6841FA',
#   '2014-02-08 10:01:36.827'),
#  (451,
#   'Lock Nut 11',
#   'LN-5162',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '5BCC4558-6C16-48F1-92F0-FD2EEFB17306',
#   '2014-02-08 10:01:36.827'),
#  (452,
#   'Lock Nut 2',
#   'LN-5400',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '53AD147D-C16D-4A8C-B086-625A31405574',
#   '2014-02-08 10:01:36.827'),
#  (453,
#   'Lock Nut 20',
#   'LN-5811',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '2749030E-49B7-4B24-8D47-FBCF194ABA38',
#   '2014-02-08 10:01:36.827'),
#  (454,
#   'Lock Nut 21',
#   'LN-5818',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'E10A7B34-87F5-42CD-88B3-27A3D8E16B18',
#   '2014-02-08 10:01:36.827'),
#  (455,
#   'Lock Nut 3',
#   'LN-6320',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'AA5071EB-2145-4D08-9D33-B9D2BA9E1493',
#   '2014-02-08 10:01:36.827'),
#  (456,
#   'Lock Nut 14',
#   'LN-7161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '1E96B03D-DC07-4A98-BC24-BF5B24C393E5',
#   '2014-02-08 10:01:36.827'),
#  (457,
#   'Lock Nut 15',
#   'LN-7162',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'CE04DE2B-4ECA-4203-A108-B7D92FF0E96E',
#   '2014-02-08 10:01:36.827'),
#  (458,
#   'Lock Nut 4',
#   'LN-8320',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '41BD9389-8B22-4A35-9A2C-233D39ADA7EA',
#   '2014-02-08 10:01:36.827'),
#  (459,
#   'Lock Nut 19',
#   'LN-9080',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '5986504B-22A0-4E74-A137-C7CF99A8216F',
#   '2014-02-08 10:01:36.827'),
#  (460,
#   'Lock Nut 18',
#   'LN-9161',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A420963F-92FD-4CD4-8531-6926E4162C41',
#   '2014-02-08 10:01:36.827'),
#  (461,
#   'Lock Ring',
#   'LR-2398',
#   0,
#   0,
#   'Silver',
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'AECA59DA-B61C-4976-8316-97E14CD4EFF1',
#   '2014-02-08 10:01:36.827'),
#  (462,
#   'Lower Head Race',
#   'LR-8520',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'DBB962BF-0603-4095-959B-5BA9C74FBD32',
#   '2014-02-08 10:01:36.827'),
#  (463,
#   'Lock Washer 4',
#   'LW-1000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A3EE3BC5-73C5-45F3-A952-9991D038DD9C',
#   '2014-02-08 10:01:36.827'),
#  (464,
#   'Lock Washer 5',
#   'LW-1200',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'ECAED08D-2CF5-4D81-A4ED-8369E25AF227',
#   '2014-02-08 10:01:36.827'),
#  (465,
#   'Lock Washer 10',
#   'LW-1201',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A2212BAB-AF58-41A5-A659-A6141C8967CA',
#   '2014-02-08 10:01:36.827'),
#  (466,
#   'Lock Washer 6',
#   'LW-1400',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '9092F2E1-3637-4669-8565-55404A55750E',
#   '2014-02-08 10:01:36.827'),
#  (467,
#   'Lock Washer 13',
#   'LW-3400',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '3CB31F4A-C61C-408C-BE1E-48BEE412E511',
#   '2014-02-08 10:01:36.827'),
#  (468,
#   'Lock Washer 8',
#   'LW-3800',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '900D26E6-21A0-427D-B43C-173F6DCB2045',
#   '2014-02-08 10:01:36.827'),
#  (469,
#   'Lock Washer 1',
#   'LW-4000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '5402EA37-29DF-47FF-9FC7-867D60594C48',
#   '2014-02-08 10:01:36.827'),
#  (470,
#   'Lock Washer 7',
#   'LW-5160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '99357255-E66B-458C-AB2E-6F68EF5452D2',
#   '2014-02-08 10:01:36.827'),
#  (471,
#   'Lock Washer 12',
#   'LW-5800',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '7BC9D58E-3E62-481F-8343-BEB0883B3ECF',
#   '2014-02-08 10:01:36.827'),
#  (472,
#   'Lock Washer 2',
#   'LW-6000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '5F201424-9E6A-4F8D-9C2C-30777E27D64F',
#   '2014-02-08 10:01:36.827'),
#  (473,
#   'Lock Washer 9',
#   'LW-7160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'F9426FB2-1E68-464E-BF32-615026E0249E',
#   '2014-02-08 10:01:36.827'),
#  (474,
#   'Lock Washer 3',
#   'LW-8000',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'AC007B7F-73B7-4623-8150-02444C5EC023',
#   '2014-02-08 10:01:36.827'),
#  (475,
#   'Lock Washer 11',
#   'LW-9160',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '639D8448-B427-47B1-9E5B-0E5090A27632',
#   '2014-02-08 10:01:36.827'),
#  (476,
#   'Metal Angle',
#   'MA-7075',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'E876E239-7EC2-45C8-BA4B-B9CEACB379A6',
#   '2014-02-08 10:01:36.827'),
#  (477,
#   'Metal Bar 1',
#   'MB-2024',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '8B5429CE-7876-44B3-9332-BAF78A238B36',
#   '2014-02-08 10:01:36.827'),
#  (478,
#   'Metal Bar 2',
#   'MB-6061',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '2A14F60E-3827-49BA-AF13-466DBC30C5BA',
#   '2014-02-08 10:01:36.827'),
#  (479,
#   'Metal Plate 2',
#   'MP-2066',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '0773A2C9-F47F-429E-814A-25B2E08C128A',
#   '2014-02-08 10:01:36.827'),
#  (480,
#   'Metal Plate 1',
#   'MP-2503',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '242389BE-DDE0-42A1-85D9-F99FDC981336',
#   '2014-02-08 10:01:36.827'),
#  (481,
#   'Metal Plate 3',
#   'MP-4960',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '8B7E90E5-7785-455E-BC7C-E962F18C6848',
#   '2014-02-08 10:01:36.827'),
#  (482,
#   'Metal Sheet 2',
#   'MS-0253',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '8BB96DFB-23AA-4877-9C5E-866BB18FACC7',
#   '2014-02-08 10:01:36.827'),
#  (483,
#   'Metal Sheet 3',
#   'MS-1256',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '9074E00D-005B-450E-9C92-6667782E8108',
#   '2014-02-08 10:01:36.827'),
#  (484,
#   'Metal Sheet 7',
#   'MS-1981',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   'A9539885-0CEE-4AA0-9072-8DB1D34A16DB',
#   '2014-02-08 10:01:36.827'),
#  (485,
#   'Metal Sheet 4',
#   'MS-2259',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '3CB3CF7D-AB8E-44A3-B7E9-73149F5EC29F',
#   '2014-02-08 10:01:36.827'),
#  (486,
#   'Metal Sheet 5',
#   'MS-2341',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '2A2C555D-328D-4299-BD83-591D0762DF62',
#   '2014-02-08 10:01:36.827'),
#  (487,
#   'Metal Sheet 6',
#   'MS-2348',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '64844011-A1C3-4F8F-9CAA-9C8D214ECC12',
#   '2014-02-08 10:01:36.827'),
#  (488,
#   'Metal Sheet 1',
#   'MS-6061',
#   0,
#   0,
#   None,
#   1000,
#   750,
#   '0.00',
#   '0.00',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2008-04-30 00:00:00.000',
#   None,
#   None,
#   '3B2FEBC6-C76C-4A56-9CF7-8AF5B76E24EE',
#   '2014-02-08 10:01:36.827'),
#  (489,
#   'Metal Tread Plate',
# ...
#   4.0,
#   48.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'CB524E92-4FA8-4F6C-9993-60796856C654',
#   '2014-02-08 10:01:36.827'),
#  (948,
#   'Front Brakes',
#   'FB-9873',
#   0,
#   1,
#   'Silver',
#   500,
#   375,
#   '47.286',
#   '106.50',
#   None,
#   None,
#   'G  ',
#   317.0,
#   1,
#   None,
#   None,
#   None,
#   6.0,
#   102.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'C1813164-1B4B-42D1-9007-4E5F9AEE0E19',
#   '2014-02-08 10:01:36.827'),
#  (949,
#   'LL Crankset',
#   'CS-4759',
#   1,
#   1,
#   'Black',
#   500,
#   375,
#   '77.9176',
#   '175.49',
#   None,
#   None,
#   'G  ',
#   600.0,
#   1,
#   None,
#   'L ',
#   None,
#   8.0,
#   99.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '41D47371-4374-46D3-8D61-B07616EC54F0',
#   '2014-02-08 10:01:36.827'),
#  (950,
#   'ML Crankset',
#   'CS-6583',
#   1,
#   1,
#   'Black',
#   500,
#   375,
#   '113.8816',
#   '256.49',
#   None,
#   None,
#   'G  ',
#   635.0,
#   1,
#   None,
#   'M ',
#   None,
#   8.0,
#   100.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'D3A7A02C-A3D5-4A04-9454-0C4E43772B78',
#   '2014-02-08 10:01:36.827'),
#  (951,
#   'HL Crankset',
#   'CS-9183',
#   1,
#   1,
#   'Black',
#   500,
#   375,
#   '179.8156',
#   '404.99',
#   None,
#   None,
#   'G  ',
#   575.0,
#   1,
#   None,
#   'H ',
#   None,
#   8.0,
#   101.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '2C4A8956-7B72-48FE-B028-699E117B1DAA',
#   '2014-02-08 10:01:36.827'),
#  (952,
#   'Chain',
#   'CH-0234',
#   0,
#   1,
#   'Silver',
#   500,
#   375,
#   '8.9866',
#   '20.24',
#   None,
#   None,
#   None,
#   None,
#   1,
#   None,
#   None,
#   None,
#   7.0,
#   98.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '5D27E2A5-27EC-4CCB-BA2C-FC980FFE6708',
#   '2014-02-08 10:01:36.827'),
#  (953,
#   'Touring-2000 Blue, 60',
#   'BK-T44U-60',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '755.1508',
#   '1214.85',
#   '60',
#   'CM ',
#   'LB ',
#   27.9,
#   4,
#   'T ',
#   'M ',
#   'U ',
#   3.0,
#   35.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'F1BB3957-8D27-47F3-91EC-C71822D11436',
#   '2014-02-08 10:01:36.827'),
#  (954,
#   'Touring-1000 Yellow, 46',
#   'BK-T79Y-46',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '1481.9379',
#   '2384.07',
#   '46',
#   'CM ',
#   'LB ',
#   25.13,
#   4,
#   'T ',
#   'H ',
#   'U ',
#   3.0,
#   34.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '83B77413-8C8A-4AF1-93E4-136EDB7FF15F',
#   '2014-02-08 10:01:36.827'),
#  (955,
#   'Touring-1000 Yellow, 50',
#   'BK-T79Y-50',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '1481.9379',
#   '2384.07',
#   '50',
#   'CM ',
#   'LB ',
#   25.42,
#   4,
#   'T ',
#   'H ',
#   'U ',
#   3.0,
#   34.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '5EC991AD-8761-4A61-A318-312DF3A78604',
#   '2014-02-08 10:01:36.827'),
#  (956,
#   'Touring-1000 Yellow, 54',
#   'BK-T79Y-54',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '1481.9379',
#   '2384.07',
#   '54',
#   'CM ',
#   'LB ',
#   25.68,
#   4,
#   'T ',
#   'H ',
#   'U ',
#   3.0,
#   34.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '1220B0F0-064D-46B7-8507-1FA758B77B9C',
#   '2014-02-08 10:01:36.827'),
#  (957,
#   'Touring-1000 Yellow, 60',
#   'BK-T79Y-60',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '1481.9379',
#   '2384.07',
#   '60',
#   'CM ',
#   'LB ',
#   25.9,
#   4,
#   'T ',
#   'H ',
#   'U ',
#   3.0,
#   34.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'BCD1A5A9-6140-4DC9-9620-689DC7E4C155',
#   '2014-02-08 10:01:36.827'),
#  (958,
#   'Touring-3000 Blue, 54',
#   'BK-T18U-54',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '54',
#   'CM ',
#   'LB ',
#   29.68,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'A3EE6897-52FE-42E4-92EC-7A91E7BB905A',
#   '2014-02-08 10:01:36.827'),
#  (959,
#   'Touring-3000 Blue, 58',
#   'BK-T18U-58',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '58',
#   'CM ',
#   'LB ',
#   29.9,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '23D89CEE-9F44-4F3E-B289-63DE6BA2B737',
#   '2014-02-08 10:01:36.827'),
#  (960,
#   'Touring-3000 Blue, 62',
#   'BK-T18U-62',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '62',
#   'CM ',
#   'LB ',
#   30.0,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '060192C9-BCD9-4260-B729-D6BCFADFB08E',
#   '2014-02-08 10:01:36.827'),
#  (961,
#   'Touring-3000 Yellow, 44',
#   'BK-T18Y-44',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '44',
#   'CM ',
#   'LB ',
#   28.77,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '5646C15A-68AD-4234-B328-254706CBCCC5',
#   '2014-02-08 10:01:36.827'),
#  (962,
#   'Touring-3000 Yellow, 50',
#   'BK-T18Y-50',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '50',
#   'CM ',
#   'LB ',
#   29.13,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'DF85E805-AF87-4FAB-A668-C80F2A5B8A69',
#   '2014-02-08 10:01:36.827'),
#  (963,
#   'Touring-3000 Yellow, 54',
#   'BK-T18Y-54',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '54',
#   'CM ',
#   'LB ',
#   29.42,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '192BECD1-F465-4194-88A2-EE57FED3A3C5',
#   '2014-02-08 10:01:36.827'),
#  (964,
#   'Touring-3000 Yellow, 58',
#   'BK-T18Y-58',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '58',
#   'CM ',
#   'LB ',
#   29.79,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'BED79F64-A53D-44A3-ACE8-2BAA425A5A54',
#   '2014-02-08 10:01:36.827'),
#  (965,
#   'Touring-3000 Yellow, 62',
#   'BK-T18Y-62',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '62',
#   'CM ',
#   'LB ',
#   30.0,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'D28B3872-5173-40A4-B12F-655524386CC7',
#   '2014-02-08 10:01:36.827'),
#  (966,
#   'Touring-1000 Blue, 46',
#   'BK-T79U-46',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '1481.9379',
#   '2384.07',
#   '46',
#   'CM ',
#   'LB ',
#   25.13,
#   4,
#   'T ',
#   'H ',
#   'U ',
#   3.0,
#   34.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '86990D54-6EFB-4C53-9974-6C3B0297E222',
#   '2014-02-08 10:01:36.827'),
#  (967,
#   'Touring-1000 Blue, 50',
#   'BK-T79U-50',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '1481.9379',
#   '2384.07',
#   '50',
#   'CM ',
#   'LB ',
#   25.42,
#   4,
#   'T ',
#   'H ',
#   'U ',
#   3.0,
#   34.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '68C0A818-2985-46EB-8255-0FB70919FA24',
#   '2014-02-08 10:01:36.827'),
#  (968,
#   'Touring-1000 Blue, 54',
#   'BK-T79U-54',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '1481.9379',
#   '2384.07',
#   '54',
#   'CM ',
#   'LB ',
#   25.68,
#   4,
#   'T ',
#   'H ',
#   'U ',
#   3.0,
#   34.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '12280A8C-7578-4367-BA71-214BCC1E4792',
#   '2014-02-08 10:01:36.827'),
#  (969,
#   'Touring-1000 Blue, 60',
#   'BK-T79U-60',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '1481.9379',
#   '2384.07',
#   '60',
#   'CM ',
#   'LB ',
#   25.9,
#   4,
#   'T ',
#   'H ',
#   'U ',
#   3.0,
#   34.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'DD70CF36-449A-43FD-839D-A84EE14C849A',
#   '2014-02-08 10:01:36.827'),
#  (970,
#   'Touring-2000 Blue, 46',
#   'BK-T44U-46',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '755.1508',
#   '1214.85',
#   '46',
#   'CM ',
#   'LB ',
#   27.13,
#   4,
#   'T ',
#   'M ',
#   'U ',
#   3.0,
#   35.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'C0009006-715F-4B76-A05A-1A0D3ADFB49A',
#   '2014-02-08 10:01:36.827'),
#  (971,
#   'Touring-2000 Blue, 50',
#   'BK-T44U-50',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '755.1508',
#   '1214.85',
#   '50',
#   'CM ',
#   'LB ',
#   27.42,
#   4,
#   'T ',
#   'M ',
#   'U ',
#   3.0,
#   35.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '84ABDA8F-0007-4BCA-9A61-B2DEA58866C3',
#   '2014-02-08 10:01:36.827'),
#  (972,
#   'Touring-2000 Blue, 54',
#   'BK-T44U-54',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '755.1508',
#   '1214.85',
#   '54',
#   'CM ',
#   'LB ',
#   27.68,
#   4,
#   'T ',
#   'M ',
#   'U ',
#   3.0,
#   35.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '6DCFE2A3-3555-44E4-9116-6F6DBE448B8B',
#   '2014-02-08 10:01:36.827'),
#  (973,
#   'Road-350-W Yellow, 40',
#   'BK-R79Y-40',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '1082.51',
#   '1700.99',
#   '40',
#   'CM ',
#   'LB ',
#   15.35,
#   4,
#   'R ',
#   'M ',
#   'W ',
#   2.0,
#   27.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '237B16D9-53F2-4FD4-BEFE-48209E57AEC3',
#   '2014-02-08 10:01:36.827'),
#  (974,
#   'Road-350-W Yellow, 42',
#   'BK-R79Y-42',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '1082.51',
#   '1700.99',
#   '42',
#   'CM ',
#   'LB ',
#   15.77,
#   4,
#   'R ',
#   'M ',
#   'W ',
#   2.0,
#   27.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '80BD3F8B-42C7-43D8-91F5-9FB6175287AF',
#   '2014-02-08 10:01:36.827'),
#  (975,
#   'Road-350-W Yellow, 44',
#   'BK-R79Y-44',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '1082.51',
#   '1700.99',
#   '44',
#   'CM ',
#   'LB ',
#   16.13,
#   4,
#   'R ',
#   'M ',
#   'W ',
#   2.0,
#   27.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '0C61E8AF-003D-4E4B-B5B7-02F01A26BE26',
#   '2014-02-08 10:01:36.827'),
#  (976,
#   'Road-350-W Yellow, 48',
#   'BK-R79Y-48',
#   1,
#   1,
#   'Yellow',
#   100,
#   75,
#   '1082.51',
#   '1700.99',
#   '48',
#   'CM ',
#   'LB ',
#   16.42,
#   4,
#   'R ',
#   'M ',
#   'W ',
#   2.0,
#   27.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'EC4284DC-85FA-44A8-89EC-77FC9B71720A',
#   '2014-02-08 10:01:36.827'),
#  (977,
#   'Road-750 Black, 58',
#   'BK-R19B-58',
#   1,
#   1,
#   'Black',
#   100,
#   75,
#   '343.6496',
#   '539.99',
#   '58',
#   'CM ',
#   'LB ',
#   20.79,
#   4,
#   'R ',
#   'L ',
#   'U ',
#   2.0,
#   31.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '87B81A1A-A5B5-43D2-A20D-0230800490B9',
#   '2014-02-08 10:01:36.827'),
#  (978,
#   'Touring-3000 Blue, 44',
#   'BK-T18U-44',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '44',
#   'CM ',
#   'LB ',
#   28.77,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '4F638E15-2ED0-4193-90CE-47DA580E01DD',
#   '2014-02-08 10:01:36.827'),
#  (979,
#   'Touring-3000 Blue, 50',
#   'BK-T18U-50',
#   1,
#   1,
#   'Blue',
#   100,
#   75,
#   '461.4448',
#   '742.35',
#   '50',
#   'CM ',
#   'LB ',
#   29.13,
#   4,
#   'T ',
#   'L ',
#   'U ',
#   3.0,
#   36.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'DE305B62-88FC-465B-B23D-D8C0F7E6D361',
#   '2014-02-08 10:01:36.827'),
#  (980,
#   'Mountain-400-W Silver, 38',
#   'BK-M38S-38',
#   1,
#   1,
#   'Silver',
#   100,
#   75,
#   '419.7784',
#   '769.49',
#   '38',
#   'CM ',
#   'LB ',
#   26.35,
#   4,
#   'M ',
#   'M ',
#   'W ',
#   1.0,
#   22.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '7A927632-99A4-4F24-ADCE-0062D2D113D9',
#   '2014-02-08 10:01:36.827'),
#  (981,
#   'Mountain-400-W Silver, 40',
#   'BK-M38S-40',
#   1,
#   1,
#   'Silver',
#   100,
#   75,
#   '419.7784',
#   '769.49',
#   '40',
#   'CM ',
#   'LB ',
#   26.77,
#   4,
#   'M ',
#   'M ',
#   'W ',
#   1.0,
#   22.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '0A72791C-A984-4733-AE4E-2B4373CFD7CD',
#   '2014-02-08 10:01:36.827'),
#  (982,
#   'Mountain-400-W Silver, 42',
#   'BK-M38S-42',
#   1,
#   1,
#   'Silver',
#   100,
#   75,
#   '419.7784',
#   '769.49',
#   '42',
#   'CM ',
#   'LB ',
#   27.13,
#   4,
#   'M ',
#   'M ',
#   'W ',
#   1.0,
#   22.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '4EA4FE06-AAEA-42D4-A9D9-69F6A9A4A042',
#   '2014-02-08 10:01:36.827'),
#  (983,
#   'Mountain-400-W Silver, 46',
#   'BK-M38S-46',
#   1,
#   1,
#   'Silver',
#   100,
#   75,
#   '419.7784',
#   '769.49',
#   '46',
#   'CM ',
#   'LB ',
#   27.42,
#   4,
#   'M ',
#   'M ',
#   'W ',
#   1.0,
#   22.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '0B0C8EE4-FF2D-438E-9CAC-464783B86191',
#   '2014-02-08 10:01:36.827'),
#  (984,
#   'Mountain-500 Silver, 40',
#   'BK-M18S-40',
#   1,
#   1,
#   'Silver',
#   100,
#   75,
#   '308.2179',
#   '564.99',
#   '40',
#   'CM ',
#   'LB ',
#   27.35,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'B96C057B-6416-4851-8D59-BCB37C8E6E51',
#   '2014-02-08 10:01:36.827'),
#  (985,
#   'Mountain-500 Silver, 42',
#   'BK-M18S-42',
#   1,
#   1,
#   'Silver',
#   100,
#   75,
#   '308.2179',
#   '564.99',
#   '42',
#   'CM ',
#   'LB ',
#   27.77,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'B8D1B5D9-8A39-4097-A04A-56E95559B534',
#   '2014-02-08 10:01:36.827'),
#  (986,
#   'Mountain-500 Silver, 44',
#   'BK-M18S-44',
#   1,
#   1,
#   'Silver',
#   100,
#   75,
#   '308.2179',
#   '564.99',
#   '44',
#   'CM ',
#   'LB ',
#   28.13,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'E8CEC794-E8E2-4312-96A7-4832E573D3FC',
#   '2014-02-08 10:01:36.827'),
#  (987,
#   'Mountain-500 Silver, 48',
#   'BK-M18S-48',
#   1,
#   1,
#   'Silver',
#   100,
#   75,
#   '308.2179',
#   '564.99',
#   '48',
#   'CM ',
#   'LB ',
#   28.42,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '77EF419F-481F-40B9-BDB9-7E6678E550E3',
#   '2014-02-08 10:01:36.827'),
#  (988,
#   'Mountain-500 Silver, 52',
#   'BK-M18S-52',
#   1,
#   1,
#   'Silver',
#   100,
#   75,
#   '308.2179',
#   '564.99',
#   '52',
#   'CM ',
#   'LB ',
#   28.68,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'CAD60945-183E-4AB3-A70C-3F5BAC6BF134',
#   '2014-02-08 10:01:36.827'),
#  (989,
#   'Mountain-500 Black, 40',
#   'BK-M18B-40',
#   1,
#   1,
#   'Black',
#   100,
#   75,
#   '294.5797',
#   '539.99',
#   '40',
#   'CM ',
#   'LB ',
#   27.35,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '28287157-3F06-487B-8531-BEE8A37329E4',
#   '2014-02-08 10:01:36.827'),
#  (990,
#   'Mountain-500 Black, 42',
#   'BK-M18B-42',
#   1,
#   1,
#   'Black',
#   100,
#   75,
#   '294.5797',
#   '539.99',
#   '42',
#   'CM ',
#   'LB ',
#   27.77,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'F5752C9C-56BA-41A7-83FD-139DA28C15FA',
#   '2014-02-08 10:01:36.827'),
#  (991,
#   'Mountain-500 Black, 44',
#   'BK-M18B-44',
#   1,
#   1,
#   'Black',
#   100,
#   75,
#   '294.5797',
#   '539.99',
#   '44',
#   'CM ',
#   'LB ',
#   28.13,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'C7852127-2FB8-4959-B5A3-DE5A8D6445E4',
#   '2014-02-08 10:01:36.827'),
#  (992,
#   'Mountain-500 Black, 48',
#   'BK-M18B-48',
#   1,
#   1,
#   'Black',
#   100,
#   75,
#   '294.5797',
#   '539.99',
#   '48',
#   'CM ',
#   'LB ',
#   28.42,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '75752E26-A3B6-4264-9B06-F23A4FBDC5A7',
#   '2014-02-08 10:01:36.827'),
#  (993,
#   'Mountain-500 Black, 52',
#   'BK-M18B-52',
#   1,
#   1,
#   'Black',
#   100,
#   75,
#   '294.5797',
#   '539.99',
#   '52',
#   'CM ',
#   'LB ',
#   28.68,
#   4,
#   'M ',
#   'L ',
#   'U ',
#   1.0,
#   23.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '69EE3B55-E142-4E4F-AED8-AF02978FBE87',
#   '2014-02-08 10:01:36.827'),
#  (994,
#   'LL Bottom Bracket',
#   'BB-7421',
#   1,
#   1,
#   None,
#   500,
#   375,
#   '23.9716',
#   '53.99',
#   None,
#   None,
#   'G  ',
#   223.0,
#   1,
#   None,
#   'L ',
#   None,
#   5.0,
#   95.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'FA3C65CD-0A22-47E3-BDF6-53F1DC138C43',
#   '2014-02-08 10:01:36.827'),
#  (995,
#   'ML Bottom Bracket',
#   'BB-8107',
#   1,
#   1,
#   None,
#   500,
#   375,
#   '44.9506',
#   '101.24',
#   None,
#   None,
#   'G  ',
#   168.0,
#   1,
#   None,
#   'M ',
#   None,
#   5.0,
#   96.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '71AB847F-D091-42D6-B735-7B0C2D82FC84',
#   '2014-02-08 10:01:36.827'),
#  (996,
#   'HL Bottom Bracket',
#   'BB-9108',
#   1,
#   1,
#   None,
#   500,
#   375,
#   '53.9416',
#   '121.49',
#   None,
#   None,
#   'G  ',
#   170.0,
#   1,
#   None,
#   'H ',
#   None,
#   5.0,
#   97.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '230C47C5-08B2-4CE3-B706-69C0BDD62965',
#   '2014-02-08 10:01:36.827'),
#  (997,
#   'Road-750 Black, 44',
#   'BK-R19B-44',
#   1,
#   1,
#   'Black',
#   100,
#   75,
#   '343.6496',
#   '539.99',
#   '44',
#   'CM ',
#   'LB ',
#   19.77,
#   4,
#   'R ',
#   'L ',
#   'U ',
#   2.0,
#   31.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '44CE4802-409F-43AB-9B27-CA53421805BE',
#   '2014-02-08 10:01:36.827'),
#  (998,
#   'Road-750 Black, 48',
#   'BK-R19B-48',
#   1,
#   1,
#   'Black',
#   100,
#   75,
#   '343.6496',
#   '539.99',
#   '48',
#   'CM ',
#   'LB ',
#   20.13,
#   4,
#   'R ',
#   'L ',
#   'U ',
#   2.0,
#   31.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   '3DE9A212-1D49-40B6-B10A-F564D981DBDE',
#   '2014-02-08 10:01:36.827'),
#  (999,
#   'Road-750 Black, 52',
#   'BK-R19B-52',
#   1,
#   1,
#   'Black',
#   100,
#   75,
#   '343.6496',
#   '539.99',
#   '52',
#   'CM ',
#   'LB ',
#   20.42,
#   4,
#   'R ',
#   'L ',
#   'U ',
#   2.0,
#   31.0,
#   '2013-05-30 00:00:00.000',
#   None,
#   None,
#   'AE638923-2B67-4679-B90E-ABBAB17DCA31',
#   '2014-02-08 10:01:36.827')]

# %% [markdown]
# ### Sales.Customer

# %%
#Escolhendo o arquivo dentro do bucket

bucket.blob('Sales.Customer.csv')
# Out:
# <Blob: desafio-rox-leandro, Sales.Customer.csv, None>

# %%
# Criando o df em pandas para enviar para o mysql

df_Customer = pd.read_csv(path_Customer,sep=';')

# %%
# Codigo repetido em todos os passos, colab dando erro, foi preciso sempre redefinir o conector.
# Conector host:ip_banco, user:usuario, passwd: senha, db:banco criado

con = mysql.connector.connect(host='34.95.218.222',user='desafio-username',passwd='1234',db='bicicletas')
cur = con.cursor()
engine = create_engine('mysql+pymysql://desafio-username:1234@34.95.218.222/bicicletas')

# %%
# Enviando a tabela SalesCustomer para o MySql 

dfsql_Customer = df_Customer.to_sql('SalesCustomer',con=engine,if_exists='replace',index=False)

# %%
# Verificando o conteúdo enviado

cur.execute('select * from SalesCustomer')
cur.fetchall()
# Out:
# [(1,
#   None,
#   934.0,
#   1,
#   'AW00000001',
#   '3F5AE95E-B87D-4AED-95B4-C3797AFCB74F',
#   '2014-09-12 11:15:07.263'),
#  (2,
#   None,
#   1028.0,
#   1,
#   'AW00000002',
#   'E552F657-A9AF-4A7D-A645-C429D6E02491',
#   '2014-09-12 11:15:07.263'),
#  (3,
#   None,
#   642.0,
#   4,
#   'AW00000003',
#   '130774B1-DB21-4EF3-98C8-C104BCD6ED6D',
#   '2014-09-12 11:15:07.263'),
#  (4,
#   None,
#   932.0,
#   4,
#   'AW00000004',
#   'FF862851-1DAA-4044-BE7C-3E85583C054D',
#   '2014-09-12 11:15:07.263'),
#  (5,
#   None,
#   1026.0,
#   4,
#   'AW00000005',
#   '83905BDC-6F5E-4F71-B162-C98DA069F38A',
#   '2014-09-12 11:15:07.263'),
#  (6,
#   None,
#   644.0,
#   4,
#   'AW00000006',
#   '1A92DF88-BFA2-467D-BD54-FCB9E647FDD7',
#   '2014-09-12 11:15:07.263'),
#  (7,
#   None,
#   930.0,
#   1,
#   'AW00000007',
#   '03E9273E-B193-448E-9823-FE0C44AEED78',
#   '2014-09-12 11:15:07.263'),
#  (8,
#   None,
#   1024.0,
#   5,
#   'AW00000008',
#   '801368B1-4323-4BFA-8BEA-5B5B1E4BD4A0',
#   '2014-09-12 11:15:07.263'),
#  (9,
#   None,
#   620.0,
#   5,
#   'AW00000009',
#   'B900BB7F-23C3-481D-80DA-C49A5BD6F772',
#   '2014-09-12 11:15:07.263'),
#  (10,
#   None,
#   928.0,
#   6,
#   'AW00000010',
#   'CDB6698D-2FF1-4FBA-8F22-60AD1D11DABD',
#   '2014-09-12 11:15:07.263'),
#  (11,
#   None,
#   1022.0,
#   6,
#   'AW00000011',
#   '750F3495-59C4-48A0-80E1-E37EC60E77D9',
#   '2014-09-12 11:15:07.263'),
#  (12,
#   None,
#   622.0,
#   6,
#   'AW00000012',
#   '947BCAF1-1F32-44F3-B9C3-0011F95FBE54',
#   '2014-09-12 11:15:07.263'),
#  (13,
#   None,
#   434.0,
#   7,
#   'AW00000013',
#   'B0FA5854-2511-439B-A7AC-50C9C460B175',
#   '2014-09-12 11:15:07.263'),
#  (14,
#   None,
#   1020.0,
#   8,
#   'AW00000014',
#   '2F96BEDC-723D-468F-834B-B2B8AE79C849',
#   '2014-09-12 11:15:07.263'),
#  (15,
#   None,
#   624.0,
#   9,
#   'AW00000015',
#   '0340737B-D4FA-4795-93AA-CAEB8371BCF9',
#   '2014-09-12 11:15:07.263'),
#  (16,
#   None,
#   432.0,
#   10,
#   'AW00000016',
#   'C9381589-D31C-4EFE-8978-8D3449EB1F0F',
#   '2014-09-12 11:15:07.263'),
#  (17,
#   None,
#   1018.0,
#   5,
#   'AW00000017',
#   '34DB417F-1E0B-4408-9FF6-987E59D0D73C',
#   '2014-09-12 11:15:07.263'),
#  (18,
#   None,
#   1332.0,
#   3,
#   'AW00000018',
#   'C04D6B4D-94C6-4C5C-A44C-B449C0AC1B45',
#   '2014-09-12 11:15:07.263'),
#  (19,
#   None,
#   430.0,
#   1,
#   'AW00000019',
#   '69AE5D43-31BE-4B76-BFBB-5A23C4788BBC',
#   '2014-09-12 11:15:07.263'),
#  (20,
#   None,
#   1016.0,
#   1,
#   'AW00000020',
#   'E010C10A-F1C3-4BBA-81CA-A7E083350400',
#   '2014-09-12 11:15:07.263'),
#  (21,
#   None,
#   1334.0,
#   4,
#   'AW00000021',
#   '564E0B42-4609-43DE-9881-914DA433D82D',
#   '2014-09-12 11:15:07.263'),
#  (22,
#   None,
#   494.0,
#   3,
#   'AW00000022',
#   '9774AED6-D673-412D-B481-2573E470B478',
#   '2014-09-12 11:15:07.263'),
#  (23,
#   None,
#   1014.0,
#   4,
#   'AW00000023',
#   '733F8250-3251-4C2A-8C85-C285BB76B7B4',
#   '2014-09-12 11:15:07.263'),
#  (24,
#   None,
#   1336.0,
#   4,
#   'AW00000024',
#   'C111E51D-178D-4DBD-A6FF-F1CCBF4B1AAD',
#   '2014-09-12 11:15:07.263'),
#  (25,
#   None,
#   492.0,
#   4,
#   'AW00000025',
#   '31D03546-FB2A-4488-890E-4709A659E3F0',
#   '2014-09-12 11:15:07.263'),
#  (26,
#   None,
#   1012.0,
#   5,
#   'AW00000026',
#   'FD4898DE-D128-4719-8C74-9F77605AAC4A',
#   '2014-09-12 11:15:07.263'),
#  (27,
#   None,
#   1338.0,
#   5,
#   'AW00000027',
#   'CACA5149-D799-473B-847F-83F3613D3D1F',
#   '2014-09-12 11:15:07.263'),
#  (28,
#   None,
#   490.0,
#   6,
#   'AW00000028',
#   '9B8A04A4-D909-4F49-B1C5-3DE317D69B2A',
#   '2014-09-12 11:15:07.263'),
#  (29,
#   None,
#   1010.0,
#   6,
#   'AW00000029',
#   'ECA7C8FA-490B-4B97-9C32-043C90F789E8',
#   '2014-09-12 11:15:07.263'),
#  (30,
#   None,
#   1340.0,
#   6,
#   'AW00000030',
#   '2B15DFB1-831E-49E7-B337-395798B129E7',
#   '2014-09-12 11:15:07.263'),
#  (31,
#   None,
#   942.0,
#   7,
#   'AW00000031',
#   'EFFA209A-A110-4F94-887D-E50E44FB06EA',
#   '2014-09-12 11:15:07.263'),
#  (32,
#   None,
#   1008.0,
#   8,
#   'AW00000032',
#   'B9A28813-542A-4FBF-AE79-BAD64A5E133B',
#   '2014-09-12 11:15:07.263'),
#  (33,
#   None,
#   1342.0,
#   9,
#   'AW00000033',
#   'E6D92B96-FA82-41C0-8945-66A8A5EC017B',
#   '2014-09-12 11:15:07.263'),
#  (34,
#   None,
#   940.0,
#   10,
#   'AW00000034',
#   '9EDDA794-7862-4FF4-B8E2-528847CAB2BD',
#   '2014-09-12 11:15:07.263'),
#  (35,
#   None,
#   1006.0,
#   2,
#   'AW00000035',
#   '8D74B6B9-6C96-44A5-BEC4-0E9736D191BE',
#   '2014-09-12 11:15:07.263'),
#  (36,
#   None,
#   1344.0,
#   2,
#   'AW00000036',
#   '53C0491D-8AE8-4B16-A830-2078FDDF46AD',
#   '2014-09-12 11:15:07.263'),
#  (37,
#   None,
#   938.0,
#   1,
#   'AW00000037',
#   'C6EBB29A-CC67-459C-90E3-339E0F912906',
#   '2014-09-12 11:15:07.263'),
#  (38,
#   None,
#   1004.0,
#   1,
#   'AW00000038',
#   'E5EDA3F3-4EF1-4806-BD36-E61F3CB2E044',
#   '2014-09-12 11:15:07.263'),
#  (39,
#   None,
#   1346.0,
#   3,
#   'AW00000039',
#   '6808B1ED-3C9A-401D-B284-9AC31166D9EB',
#   '2014-09-12 11:15:07.263'),
#  (40,
#   None,
#   936.0,
#   4,
#   'AW00000040',
#   'AA5E28F6-16C8-4D80-894E-17531F2CF972',
#   '2014-09-12 11:15:07.263'),
#  (41,
#   None,
#   1002.0,
#   4,
#   'AW00000041',
#   'E1BA20ED-DA19-4392-A8A8-C2E670438FFB',
#   '2014-09-12 11:15:07.263'),
#  (42,
#   None,
#   1348.0,
#   4,
#   'AW00000042',
#   '64ACD300-337D-4D39-A2C4-FD5972611934',
#   '2014-09-12 11:15:07.263'),
#  (43,
#   None,
#   1290.0,
#   1,
#   'AW00000043',
#   '9E449D3E-5D79-4F65-A4F1-10DD3B0E0766',
#   '2014-09-12 11:15:07.263'),
#  (44,
#   None,
#   1000.0,
#   5,
#   'AW00000044',
#   'FB4B073C-6B38-4233-83FE-4236558F4754',
#   '2014-09-12 11:15:07.263'),
#  (45,
#   None,
#   1350.0,
#   5,
#   'AW00000045',
#   'B50043ED-C66B-4130-BEBC-07D413043991',
#   '2014-09-12 11:15:07.263'),
#  (46,
#   None,
#   1288.0,
#   6,
#   'AW00000046',
#   '21849ECF-88C2-4574-89D5-397B84DF1D0F',
#   '2014-09-12 11:15:07.263'),
#  (47,
#   None,
#   998.0,
#   6,
#   'AW00000047',
#   '0D9ABE85-D952-432D-831A-8BEB7F4E49D0',
#   '2014-09-12 11:15:07.263'),
#  (48,
#   None,
#   1352.0,
#   6,
#   'AW00000048',
#   'E656589A-198F-454F-B02F-9CE324457BDF',
#   '2014-09-12 11:15:07.263'),
#  (49,
#   None,
#   1286.0,
#   7,
#   'AW00000049',
#   'F3DFA401-85C6-4118-B5C5-6554310A1192',
#   '2014-09-12 11:15:07.263'),
#  (50,
#   None,
#   996.0,
#   8,
#   'AW00000050',
#   '0A3E846A-2DCC-4B6E-8AB3-968B5AB859F4',
#   '2014-09-12 11:15:07.263'),
#  (51,
#   None,
#   1354.0,
#   9,
#   'AW00000051',
#   'E4C69E3E-BE4B-4DCD-B2F0-1237B391BC44',
#   '2014-09-12 11:15:07.263'),
#  (52,
#   None,
#   1284.0,
#   10,
#   'AW00000052',
#   '8FB34B30-B19D-4AEC-B02E-F1BE942800E5',
#   '2014-09-12 11:15:07.263'),
#  (53,
#   None,
#   994.0,
#   2,
#   'AW00000053',
#   '81D3B740-DCF1-4F23-A5E3-D81353280016',
#   '2014-09-12 11:15:07.263'),
#  (54,
#   None,
#   1356.0,
#   2,
#   'AW00000054',
#   '123B3EBF-4EB0-442A-8482-A4E001CCCF89',
#   '2014-09-12 11:15:07.263'),
#  (55,
#   None,
#   1282.0,
#   1,
#   'AW00000055',
#   'F5D3997B-AD06-46A0-94AF-A4460F4BE471',
#   '2014-09-12 11:15:07.263'),
#  (56,
#   None,
#   992.0,
#   1,
#   'AW00000056',
#   '570B1682-9BB1-4359-984D-8F728E3D6973',
#   '2014-09-12 11:15:07.263'),
#  (57,
#   None,
#   1358.0,
#   3,
#   'AW00000057',
#   '7FF17923-E670-4F42-87A3-A6D1AF18EA05',
#   '2014-09-12 11:15:07.263'),
#  (58,
#   None,
#   1280.0,
#   3,
#   'AW00000058',
#   'E324FEE8-1EE7-4B96-854E-CFDA7B0CBBC8',
#   '2014-09-12 11:15:07.263'),
#  (59,
#   None,
#   990.0,
#   4,
#   'AW00000059',
#   '60708606-604C-44BE-90E1-3A0925B8060E',
#   '2014-09-12 11:15:07.263'),
#  (60,
#   None,
#   1360.0,
#   4,
#   'AW00000060',
#   'A029F31E-433B-4FA4-B442-B291D16A1B9F',
#   '2014-09-12 11:15:07.263'),
#  (61,
#   None,
#   1278.0,
#   4,
#   'AW00000061',
#   'CCC53B43-66A6-47F6-A38E-5DD7CFAFEAA6',
#   '2014-09-12 11:15:07.263'),
#  (62,
#   None,
#   988.0,
#   5,
#   'AW00000062',
#   '359BB644-407D-4C24-AB98-E637AEE7C81E',
#   '2014-09-12 11:15:07.263'),
#  (63,
#   None,
#   1362.0,
#   5,
#   'AW00000063',
#   '76E2E4C3-B1BA-4CB2-B410-A4D48BA886E5',
#   '2014-09-12 11:15:07.263'),
#  (64,
#   None,
#   1276.0,
#   6,
#   'AW00000064',
#   'E6B6F92D-4AC6-4BC7-BF6B-2F3C67498DE7',
#   '2014-09-12 11:15:07.263'),
#  (65,
#   None,
#   986.0,
#   6,
#   'AW00000065',
#   '7E082443-8AF6-4BB6-A0F5-1586271D1F2C',
#   '2014-09-12 11:15:07.263'),
#  (66,
#   None,
#   782.0,
#   6,
#   'AW00000066',
#   'E91E0048-9A25-489B-96C1-D726DA68FB7C',
#   '2014-09-12 11:15:07.263'),
#  (67,
#   None,
#   1274.0,
#   7,
#   'AW00000067',
#   '51CE3843-FC98-453E-8CF1-7EA145235D0F',
#   '2014-09-12 11:15:07.263'),
#  (68,
#   None,
#   532.0,
#   8,
#   'AW00000068',
#   '2138DEF5-80EB-4D95-B340-706BCD60ADDA',
#   '2014-09-12 11:15:07.263'),
#  (69,
#   None,
#   784.0,
#   9,
#   'AW00000069',
#   '64841B37-3A25-416A-A129-E9AAA2EFF4CD',
#   '2014-09-12 11:15:07.263'),
#  (70,
#   None,
#   1272.0,
#   10,
#   'AW00000070',
#   '89E10B04-064E-4313-8203-91FA98A01B11',
#   '2014-09-12 11:15:07.263'),
#  (71,
#   None,
#   530.0,
#   2,
#   'AW00000071',
#   '91CC8AC7-27E5-437C-B940-DB47692754D3',
#   '2014-09-12 11:15:07.263'),
#  (72,
#   None,
#   786.0,
#   2,
#   'AW00000072',
#   '0DA3081D-FDC7-4005-B77D-E5AFD8C15DE6',
#   '2014-09-12 11:15:07.263'),
#  (73,
#   None,
#   1270.0,
#   1,
#   'AW00000073',
#   '9D5C135E-BD60-46E0-B371-843391637827',
#   '2014-09-12 11:15:07.263'),
#  (74,
#   None,
#   528.0,
#   1,
#   'AW00000074',
#   '73485E57-076D-4B10-BB48-6043DD873582',
#   '2014-09-12 11:15:07.263'),
#  (75,
#   None,
#   788.0,
#   4,
#   'AW00000075',
#   '55CFED0E-1A7B-409C-9AFF-297065965870',
#   '2014-09-12 11:15:07.263'),
#  (76,
#   None,
#   1268.0,
#   3,
#   'AW00000076',
#   '5227D299-B05E-4D6C-A1C9-DA63154869BA',
#   '2014-09-12 11:15:07.263'),
#  (77,
#   None,
#   556.0,
#   4,
#   'AW00000077',
#   'B3F9113C-8FCE-47E1-9F04-38A0C68917C6',
#   '2014-09-12 11:15:07.263'),
#  (78,
#   None,
#   790.0,
#   4,
#   'AW00000078',
#   '8C8083AB-7943-44FA-B1AD-8E3ABD5D66EE',
#   '2014-09-12 11:15:07.263'),
#  (79,
#   None,
#   1266.0,
#   3,
#   'AW00000079',
#   '010D8AA6-CEBA-4097-9E67-3B2A9674FD5F',
#   '2014-09-12 11:15:07.263'),
#  (80,
#   None,
#   554.0,
#   5,
#   'AW00000080',
#   '98DCB8C4-E7C0-43E7-B429-2CB4D8A8D90D',
#   '2014-09-12 11:15:07.263'),
#  (81,
#   None,
#   792.0,
#   5,
#   'AW00000081',
#   'E25E3769-CADC-4DA6-9120-09C3B2205475',
#   '2014-09-12 11:15:07.263'),
#  (82,
#   None,
#   1264.0,
#   6,
#   'AW00000082',
#   '92618ECE-2254-4852-B3B3-46ED2E0E3E1A',
#   '2014-09-12 11:15:07.263'),
#  (83,
#   None,
#   552.0,
#   6,
#   'AW00000083',
#   '8E01F170-64D3-4B74-82E1-D1691AE9F37C',
#   '2014-09-12 11:15:07.263'),
#  (84,
#   None,
#   794.0,
#   6,
#   'AW00000084',
#   '45A614CE-3137-4A12-8296-24048C18F320',
#   '2014-09-12 11:15:07.263'),
#  (85,
#   None,
#   1262.0,
#   7,
#   'AW00000085',
#   'B44000F5-901B-4134-979D-F9A9BEA5A598',
#   '2014-09-12 11:15:07.263'),
#  (86,
#   None,
#   636.0,
#   8,
#   'AW00000086',
#   '2A8B2702-4644-4002-90E4-99A8ADBA5261',
#   '2014-09-12 11:15:07.263'),
#  (87,
#   None,
#   796.0,
#   9,
#   'AW00000087',
#   '07FB8B21-FB06-49F8-8CD5-9956273CD78A',
#   '2014-09-12 11:15:07.263'),
#  (88,
#   None,
#   1260.0,
#   10,
#   'AW00000088',
#   '11FEDA31-15B6-4F08-9357-355371D4D928',
#   '2014-09-12 11:15:07.263'),
#  (89,
#   None,
#   634.0,
#   2,
#   'AW00000089',
#   'A34FE994-1098-439F-A042-EE670BF2FA33',
#   '2014-09-12 11:15:07.263'),
#  (90,
#   None,
#   798.0,
#   5,
#   'AW00000090',
#   '6FC7D1F9-11E6-4574-90B3-7AA6FFC1EBD9',
#   '2014-09-12 11:15:07.263'),
#  (91,
#   None,
#   1258.0,
#   1,
#   'AW00000091',
#   '9F314FC3-9644-4412-A90A-5483F75F665B',
#   '2014-09-12 11:15:07.263'),
#  (92,
#   None,
#   632.0,
#   1,
#   'AW00000092',
#   '672412C3-5D5D-488B-B176-E3DAFAD05D70',
#   '2014-09-12 11:15:07.263'),
#  (93,
#   None,
#   800.0,
#   4,
#   'AW00000093',
#   '249B42C2-8EAE-49F1-A560-A90837748654',
#   '2014-09-12 11:15:07.263'),
#  (94,
#   None,
#   1256.0,
#   4,
#   'AW00000094',
#   '65BE08DA-DFB7-4BC8-AA5C-FAD98B82524E',
#   '2014-09-12 11:15:07.263'),
#  (95,
#   None,
#   630.0,
#   4,
#   'AW00000095',
#   'EA0BC621-9466-4F04-BBFF-3B361C6F9057',
#   '2014-09-12 11:15:07.263'),
#  (96,
#   None,
#   1308.0,
#   4,
#   'AW00000096',
#   'BAC5B4DA-00B0-4BF1-816A-1E39F676BF9B',
#   '2014-09-12 11:15:07.263'),
#  (97,
#   None,
#   1254.0,
#   4,
#   'AW00000097',
#   '355EB5D8-6B4C-4FFF-B12B-40F89CA4E31D',
#   '2014-09-12 11:15:07.263'),
#  (98,
#   None,
#   734.0,
#   5,
#   'AW00000098',
#   '7D37485D-A4CF-4C08-8D3C-364DEEC7C841',
#   '2014-09-12 11:15:07.263'),
#  (99,
#   None,
#   1310.0,
#   5,
#   'AW00000099',
#   '8583A63E-3459-44C7-8736-A92E0A7135F2',
#   '2014-09-12 11:15:07.263'),
#  (100,
#   None,
#   1252.0,
#   6,
#   'AW00000100',
#   'E789F6DD-3159-4DDC-81A8-8571C571656E',
#   '2014-09-12 11:15:07.263'),
#  (101,
#   None,
#   732.0,
#   6,
#   'AW00000101',
#   '67AD4F37-2467-4438-A749-D947BEEC3A92',
#   '2014-09-12 11:15:07.263'),
#  (102,
#   None,
#   1312.0,
#   6,
#   'AW00000102',
#   '959CF74B-1004-43F5-9AB7-4CDD482C847D',
#   '2014-09-12 11:15:07.263'),
#  (103,
#   None,
#   1894.0,
#   7,
#   'AW00000103',
#   '22390E6F-AC5F-4DED-8EE5-91C1302C7FA2',
#   '2014-09-12 11:15:07.263'),
#  (104,
#   None,
#   730.0,
#   8,
#   'AW00000104',
#   'FFBE0510-53BE-46D9-9406-63AFEE95DE3A',
#   '2014-09-12 11:15:07.263'),
#  (105,
#   None,
#   1314.0,
#   9,
#   'AW00000105',
#   'F9387EA3-EF35-49B2-B535-E02368D2C0FD',
#   '2014-09-12 11:15:07.263'),
#  (106,
#   None,
#   1892.0,
#   10,
#   'AW00000106',
#   'AAFBF7D5-8759-4962-9DEB-77C6E22875F4',
#   '2014-09-12 11:15:07.263'),
#  (107,
#   None,
#   728.0,
#   2,
#   'AW00000107',
#   '9522CA57-0246-496A-AE49-D9821CD67817',
#   '2014-09-12 11:15:07.263'),
#  (108,
#   None,
#   1316.0,
#   2,
#   'AW00000108',
#   'D1E756E0-A0D1-43D6-A7CB-AC5C5EF404E7',
#   '2014-09-12 11:15:07.263'),
#  (109,
#   None,
#   1890.0,
#   1,
#   'AW00000109',
#   '7585790B-6034-4520-A383-9FA1E8B3E76E',
#   '2014-09-12 11:15:07.263'),
#  (110,
#   None,
#   1888.0,
#   1,
#   'AW00000110',
#   '82C2F3F0-63B8-46CC-AEDC-3A856956EF04',
#   '2014-09-12 11:15:07.263'),
#  (111,
#   None,
#   726.0,
#   3,
#   'AW00000111',
#   '0122151A-9140-4663-A3EB-A442D88BC1BB',
#   '2014-09-12 11:15:07.263'),
#  (112,
#   None,
#   1318.0,
#   4,
#   'AW00000112',
#   '5035E4D6-3758-4FA6-A462-2E2ECF52E6F0',
#   '2014-09-12 11:15:07.263'),
#  (113,
#   None,
#   1886.0,
#   4,
#   'AW00000113',
#   '8A84966C-5D38-41CA-990F-AD107558A6B8',
#   '2014-09-12 11:15:07.263'),
#  (114,
#   None,
#   724.0,
#   4,
#   'AW00000114',
#   'BCC5AE61-8214-44A1-A43C-FBD65C3745AE',
#   '2014-09-12 11:15:07.263'),
#  (115,
#   None,
#   1320.0,
#   1,
#   'AW00000115',
#   '080F7047-8396-4CEC-AB43-56CF41DE4E00',
#   '2014-09-12 11:15:07.263'),
#  (116,
#   None,
#   1884.0,
#   5,
#   'AW00000116',
#   '061C4697-F808-4C31-823E-5E8E60EFE0AA',
#   '2014-09-12 11:15:07.263'),
#  (117,
#   None,
#   722.0,
#   5,
#   'AW00000117',
#   '18406109-F4AC-4F30-A96F-4E056996DE56',
#   '2014-09-12 11:15:07.263'),
#  (118,
#   None,
#   1322.0,
#   6,
#   'AW00000118',
#   '5FEAFBD2-4A43-4641-8E94-B3059B2A882E',
#   '2014-09-12 11:15:07.263'),
#  (119,
#   None,
#   1882.0,
#   6,
#   'AW00000119',
#   'D13245EF-8267-4CB4-87C9-C23155D33E93',
#   '2014-09-12 11:15:07.263'),
#  (120,
#   None,
#   720.0,
#   6,
#   'AW00000120',
#   '25863C18-4C9A-4BC9-BE0D-95F4CF67BF7D',
#   '2014-09-12 11:15:07.263'),
#  (121,
#   None,
#   1324.0,
#   7,
#   'AW00000121',
#   '7472FF87-0FBC-4D1F-B599-D47B51B41CF0',
#   '2014-09-12 11:15:07.263'),
#  (122,
#   None,
#   1880.0,
#   8,
#   'AW00000122',
#   '094EB96D-D265-474D-869E-D9BACE4745A7',
#   '2014-09-12 11:15:07.263'),
#  (123,
#   None,
#   718.0,
#   9,
#   'AW00000123',
#   'BC0A8115-7E8F-4FAA-947F-FD315C30250D',
#   '2014-09-12 11:15:07.263'),
#  (124,
#   None,
#   1326.0,
#   10,
#   'AW00000124',
#   '2F614C31-ABAE-42D0-820B-193F0DDC811E',
#   '2014-09-12 11:15:07.263'),
#  (125,
#   None,
#   1878.0,
#   2,
#   'AW00000125',
#   '69AF6E37-EAD1-4FBD-82F0-61CE3B35F943',
#   '2014-09-12 11:15:07.263'),
#  (126,
#   None,
#   716.0,
#   2,
#   'AW00000126',
#   'B03EFE01-3333-4805-9913-99323C143526',
#   '2014-09-12 11:15:07.263'),
#  (127,
#   None,
#   1328.0,
#   1,
#   'AW00000127',
#   'EF55103F-ACC7-4BFD-89B1-20A04845E706',
#   '2014-09-12 11:15:07.263'),
#  (128,
#   None,
#   1876.0,
#   1,
#   'AW00000128',
#   '03F73E74-8DE5-421E-B5AF-04B259268DD6',
#   '2014-09-12 11:15:07.263'),
#  (129,
#   None,
#   714.0,
#   3,
#   'AW00000129',
#   'E03DB34C-BF17-407D-9423-FA22DBFDD292',
#   '2014-09-12 11:15:07.263'),
#  (130,
#   None,
#   1330.0,
#   4,
#   'AW00000130',
#   '606ECDC2-6443-4E4B-897F-32D4C17AB894',
#   '2014-09-12 11:15:07.263'),
#  (131,
#   None,
#   1874.0,
#   4,
#   'AW00000131',
#   'ED0DF7CC-6234-4D60-8B81-315C019F5356',
#   '2014-09-12 11:15:07.263'),
#  (132,
#   None,
#   712.0,
#   3,
#   'AW00000132',
#   '7649E8AF-3DAB-43AA-B7DF-9776F84DFB71',
#   '2014-09-12 11:15:07.263'),
#  (133,
#   None,
#   978.0,
#   4,
#   'AW00000133',
#   '4F61574B-8353-42EC-825C-87896E6E16A4',
#   '2014-09-12 11:15:07.263'),
#  (134,
#   None,
#   1872.0,
#   5,
#   'AW00000134',
#   'FD0D8467-48D9-42B8-A4E6-DABC96F58925',
#   '2014-09-12 11:15:07.263'),
#  (135,
#   None,
#   710.0,
#   5,
#   'AW00000135',
#   'DFFD552F-30E0-488A-AC07-83C9A7B075C7',
#   '2014-09-12 11:15:07.263'),
#  (136,
#   None,
#   980.0,
#   6,
#   'AW00000136',
#   '84CD4767-F142-4D9D-9033-AD3ADE34BF74',
#   '2014-09-12 11:15:07.263'),
#  (137,
#   None,
#   418.0,
#   6,
#   'AW00000137',
#   'D6A1AEE7-25EF-4417-AB10-65BC21661864',
#   '2014-09-12 11:15:07.263'),
#  (138,
#   None,
#   708.0,
#   6,
#   'AW00000138',
#   '91B9EF4B-2FA8-4936-AC71-1FA1B3624D12',
#   '2014-09-12 11:15:07.263'),
#  (139,
#   None,
#   982.0,
#   7,
#   'AW00000139',
#   '23A1A3E2-16F0-40AA-87D4-F4AE97D12581',
#   '2014-09-12 11:15:07.263'),
#  (140,
#   None,
#   416.0,
#   8,
#   'AW00000140',
#   '01CD7E33-EDD0-46A9-8505-F3E85D9F21F4',
#   '2014-09-12 11:15:07.263'),
#  (141,
#   None,
#   706.0,
#   9,
#   'AW00000141',
#   'E0B29CC8-066D-4F7F-98C3-0F5136BB85D9',
#   '2014-09-12 11:15:07.263'),
#  (142,
#   None,
#   984.0,
#   10,
#   'AW00000142',
#   'B821D13F-E9DB-4A3B-87D0-7E867A161575',
#   '2014-09-12 11:15:07.263'),
#  (143,
#   None,
#   520.0,
#   2,
#   'AW00000143',
#   '95E93EFE-78E9-470C-B4A7-4DD6A5D0F14B',
#   '2014-09-12 11:15:07.263'),
#  (144,
#   None,
#   704.0,
#   2,
#   'AW00000144',
#   '53C1A4AC-2DE2-4AB5-808F-523BE758AD29',
#   '2014-09-12 11:15:07.263'),
#  (145,
#   None,
#   522.0,
#   1,
#   'AW00000145',
#   'FEC5609D-042B-4480-B1BA-55F2D4107327',
#   '2014-09-12 11:15:07.263'),
#  (146,
#   None,
#   518.0,
#   1,
#   'AW00000146',
#   '5475E9DD-98CA-4989-B7A2-3FC929BEEA12',
#   '2014-09-12 11:15:07.263'),
#  (147,
#   None,
#   702.0,
#   3,
#   'AW00000147',
#   '03836A0B-7AD8-4115-8D23-6EFA0D8DEEA1',
#   '2014-09-12 11:15:07.263'),
#  (148,
#   None,
#   524.0,
#   3,
#   'AW00000148',
#   '79355855-A002-4393-BB6E-36F90913FA4D',
#   '2014-09-12 11:15:07.263'),
#  (149,
#   None,
#   516.0,
#   3,
#   'AW00000149',
#   'BAA99D94-2FC2-4A1C-8B67-2C3210EB90C3',
#   '2014-09-12 11:15:07.263'),
#  (150,
#   None,
#   700.0,
#   4,
#   'AW00000150',
#   '285C5DD7-75D6-460D-97BA-AA86D86637C0',
#   '2014-09-12 11:15:07.263'),
#  (151,
#   None,
#   526.0,
#   4,
#   'AW00000151',
#   '7F2891F7-DD88-470B-95AE-CC9A7D732B1F',
#   '2014-09-12 11:15:07.263'),
#  (152,
#   None,
#   650.0,
#   5,
#   'AW00000152',
#   'E07B697E-74C1-4F52-818F-32531696F7AB',
#   '2014-09-12 11:15:07.263'),
#  (153,
#   None,
#   514.0,
#   5,
#   'AW00000153',
#   '10C2DA66-32A2-4C63-998F-9B18CDD6E3B0',
#   '2014-09-12 11:15:07.263'),
#  (154,
#   None,
#   626.0,
#   6,
#   'AW00000154',
#   '4F60F75E-B20A-4056-874C-B7F3BD33BF3F',
#   '2014-09-12 11:15:07.263'),
#  (155,
#   None,
#   648.0,
#   6,
#   'AW00000155',
#   '3B56CD66-5DDF-430C-AB41-3FF6A1836868',
#   '2014-09-12 11:15:07.263'),
#  (156,
#   None,
#   512.0,
#   6,
#   'AW00000156',
#   'CFFFAAFB-98DC-4392-84F9-FB3229F35265',
#   '2014-09-12 11:15:07.263'),
#  (157,
#   None,
#   628.0,
#   7,
#   'AW00000157',
#   'DA4968B5-6BA0-4478-BBDC-3A00E9A1B59E',
#   '2014-09-12 11:15:07.263'),
#  (158,
#   None,
#   646.0,
#   8,
#   'AW00000158',
#   'C48CFB9B-45A2-4DC2-B932-BA8C2572E833',
#   '2014-09-12 11:15:07.263'),
#  (159,
#   None,
#   456.0,
#   9,
#   'AW00000159',
#   'EB0F31C8-C2CF-46CD-8F92-C4059190A9C6',
#   '2014-09-12 11:15:07.263'),
#  (160,
#   None,
#   658.0,
#   10,
#   'AW00000160',
#   'B42D510D-3AE4-4911-88CF-8D90D6BD0922',
#   '2014-09-12 11:15:07.263'),
#  (161,
#   None,
#   820.0,
#   2,
#   'AW00000161',
#   '5A1817B3-6C90-4C17-ADF8-B30A06F92141',
#   '2014-09-12 11:15:07.263'),
#  (162,
#   None,
#   454.0,
#   2,
#   'AW00000162',
#   'F4D0EE10-E276-4A3D-8D3B-E1904195F1B8',
#   '2014-09-12 11:15:07.263'),
#  (163,
#   None,
#   660.0,
#   1,
#   'AW00000163',
#   '989F9F3A-7CB8-4083-8CDA-291C682BE73C',
#   '2014-09-12 11:15:07.263'),
#  (164,
#   None,
#   818.0,
#   1,
#   'AW00000164',
#   '5A323ACA-74A2-4CA0-AA3B-E1AE299AAD08',
#   '2014-09-12 11:15:07.263'),
#  (165,
#   None,
#   506.0,
#   4,
#   'AW00000165',
#   '3CDBD3EA-DA78-4F9A-8EEC-8DA4C050C817',
#   '2014-09-12 11:15:07.263'),
#  (166,
#   None,
#   662.0,
#   4,
#   'AW00000166',
#   'F644D9DC-4CED-49E8-8587-CE859E466DFA',
#   '2014-09-12 11:15:07.263'),
#  (167,
#   None,
#   816.0,
#   4,
#   'AW00000167',
#   '515D4A13-4E60-4D0C-8F22-BB89A9D312AD',
#   '2014-09-12 11:15:07.263'),
#  (168,
#   None,
#   504.0,
#   4,
#   'AW00000168',
#   'FCE18386-F492-4D4A-A6D2-FB7EF20C57FC',
#   '2014-09-12 11:15:07.263'),
#  (169,
#   None,
#   804.0,
#   1,
#   'AW00000169',
#   '2D6BBC35-BC19-4CB4-A61B-46899D3A4237',
#   '2014-09-12 11:15:07.263'),
#  (170,
#   None,
#   814.0,
#   5,
#   'AW00000170',
#   '1F8334E8-3DDC-4530-A1D2-E0BAB826476E',
#   '2014-09-12 11:15:07.263'),
#  (171,
#   None,
#   502.0,
#   5,
#   'AW00000171',
#   '3C40E926-090D-4A7A-9E9D-D9222AE910C5',
#   '2014-09-12 11:15:07.263'),
#  (172,
#   None,
#   806.0,
#   6,
#   'AW00000172',
#   '324C671D-DD10-4EE2-857A-767917ACC2A3',
#   '2014-09-12 11:15:07.263'),
#  (173,
#   None,
#   812.0,
#   6,
#   'AW00000173',
#   'FDC12E98-898B-4C22-972F-F0EBFBFCB7B0',
#   '2014-09-12 11:15:07.263'),
#  (174,
#   None,
#   500.0,
#   6,
#   'AW00000174',
#   '9C4DDEFA-AABD-4A51-AB90-998985FB7D2F',
#   '2014-09-12 11:15:07.263'),
#  (175,
#   None,
#   808.0,
#   7,
#   'AW00000175',
#   '66F2342A-7CC4-4F5F-A218-8791B21A9173',
#   '2014-09-12 11:15:07.263'),
#  (176,
#   None,
#   446.0,
#   8,
#   'AW00000176',
#   '10219F9C-BEF1-4CAC-A435-D75342C43153',
#   '2014-09-12 11:15:07.263'),
#  (177,
#   None,
#   688.0,
#   9,
#   'AW00000177',
#   '6ABC1437-87FF-49FE-8B91-9EEEEB4143D4',
#   '2014-09-12 11:15:07.263'),
#  (178,
#   None,
#   810.0,
#   10,
#   'AW00000178',
#   '05B8FB77-FC67-4279-AEBD-4162D21B9A11',
#   '2014-09-12 11:15:07.263'),
#  (179,
#   None,
#   444.0,
#   2,
#   'AW00000179',
#   'F7F8B200-1294-4419-9DAC-8194231AC9B7',
#   '2014-09-12 11:15:07.263'),
#  (180,
#   None,
#   686.0,
#   3,
#   'AW00000180',
#   'F7CFF29E-F164-424E-B005-BF8CF317AF27',
#   '2014-09-12 11:15:07.263'),
#  (181,
#   None,
#   1292.0,
#   1,
#   'AW00000181',
#   '3D3D4CD0-7F5D-4BD9-A589-08881095BC5A',
#   '2014-09-12 11:15:07.263'),
#  (182,
#   None,
#   442.0,
#   1,
#   'AW00000182',
#   'D3DA2FF4-51C0-4FCB-A936-1B910458D752',
#   '2014-09-12 11:15:07.263'),
#  (183,
#   None,
#   684.0,
#   3,
#   'AW00000183',
#   'B2051957-B411-44E1-BCA5-63FECB5368F2',
#   '2014-09-12 11:15:07.263'),
#  (184,
#   None,
#   1294.0,
#   4,
#   'AW00000184',
#   'A65C523A-498D-4314-A727-D17A8B2779F6',
#   '2014-09-12 11:15:07.263'),
#  (185,
#   None,
#   1196.0,
#   4,
#   'AW00000185',
#   '5014E91D-7B0E-495A-B429-FF915BE9D2FD',
#   '2014-09-12 11:15:07.263'),
#  (186,
#   None,
#   682.0,
#   4,
#   'AW00000186',
#   '48D3E26E-C051-4B24-A37F-A88F5294F25F',
#   '2014-09-12 11:15:07.263'),
#  (187,
#   None,
#   1296.0,
#   4,
#   'AW00000187',
#   '3329CE97-BB9F-4C36-9197-A6EEE803BD94',
#   '2014-09-12 11:15:07.263'),
#  (188,
#   None,
#   1194.0,
#   5,
#   'AW00000188',
#   '2AF36044-25F9-476C-961D-A8EFD29E2C4F',
#   '2014-09-12 11:15:07.263'),
#  (189,
#   None,
#   680.0,
#   5,
#   'AW00000189',
#   '3ED50D2B-A57B-4238-BB31-2F96996DB362',
#   '2014-09-12 11:15:07.263'),
#  (190,
#   None,
#   1298.0,
#   6,
#   'AW00000190',
#   '91154406-0118-4A11-BB1B-366EDFB5C97A',
#   '2014-09-12 11:15:07.263'),
#  (191,
#   None,
#   1192.0,
#   6,
#   'AW00000191',
#   'A2F63E12-1C66-41C2-AAC0-57D87F1861D9',
#   '2014-09-12 11:15:07.263'),
#  (192,
#   None,
#   678.0,
#   6,
#   'AW00000192',
#   '84401968-8977-4380-9B4E-D5149C8126C0',
#   '2014-09-12 11:15:07.263'),
#  (193,
#   None,
#   1300.0,
#   7,
#   'AW00000193',
#   '74CB0417-1626-4586-A8C8-6F0331B08C50',
#   '2014-09-12 11:15:07.263'),
#  (194,
#   None,
#   1190.0,
#   8,
#   'AW00000194',
#   '3941081B-24ED-44F1-8009-CD17693423A0',
#   '2014-09-12 11:15:07.263'),
#  (195,
#   None,
#   676.0,
#   9,
#   'AW00000195',
#   'CD4CC2C3-9FB4-4DAB-95CC-A054B1171786',
#   '2014-09-12 11:15:07.263'),
#  (196,
#   None,
#   1302.0,
#   10,
#   'AW00000196',
#   '5F0EB2D3-4691-4F71-8E9B-A3EACFA4A1D5',
#   '2014-09-12 11:15:07.263'),
#  (197,
#   None,
#   1188.0,
#   3,
#   'AW00000197',
#   '47B64828-BC4C-4940-AA23-92006BF0D7F1',
#   '2014-09-12 11:15:07.263'),
#  (198,
#   None,
#   452.0,
#   3,
#   'AW00000198',
#   'B17DE285-DF9A-487B-8773-75844A101CD0',
#   '2014-09-12 11:15:07.263'),
#  (199,
#   None,
#   1304.0,
#   1,
#   'AW00000199',
#   'F0CD52D1-B838-451E-B015-5414AB7D9154',
#   '2014-09-12 11:15:07.263'),
#  (200,
#   None,
#   1186.0,
#   1,
#   'AW00000200',
#   '7C96C878-A038-4B2F-825F-016C922D6407',
#   '2014-09-12 11:15:07.263'),
#  (201,
#   None,
#   450.0,
#   4,
#   'AW00000201',
#   'FF8EB66D-37D8-46FB-B6E2-30A1FAC37947',
#   '2014-09-12 11:15:07.263'),
#  (202,
#   None,
#   1306.0,
#   4,
#   'AW00000202',
#   'E50D76BB-E3F7-419F-A6D2-20061538FCEA',
#   '2014-09-12 11:15:07.263'),
#  (203,
#   None,
#   1184.0,
#   4,
#   'AW00000203',
#   'B05AAA08-ABC9-41E1-B113-65347A2EE406',
#   '2014-09-12 11:15:07.263'),
#  (204,
#   None,
#   448.0,
#   4,
#   'AW00000204',
#   'C807870F-FA5D-44CB-B373-47ECAC52C1D8',
#   '2014-09-12 11:15:07.263'),
#  (205,
#   None,
#   1404.0,
#   4,
#   'AW00000205',
#   '9DB0BD27-5CE6-4F6D-8C90-A85422B86060',
#   '2014-09-12 11:15:07.263'),
#  (206,
#   None,
#   1182.0,
#   5,
#   'AW00000206',
#   'F0B3A736-DD1D-4412-AF94-083990D01965',
#   '2014-09-12 11:15:07.263'),
#  (207,
#   None,
#   414.0,
#   5,
#   'AW00000207',
#   'CA07B43C-6FB2-4160-B1AC-FAAEA2A1CCF1',
#   '2014-09-12 11:15:07.263'),
#  (208,
#   None,
#   1406.0,
#   6,
#   'AW00000208',
#   '6005E7A8-0101-4BE2-B8C1-F4AD936E496F',
#   '2014-09-12 11:15:07.263'),
#  (209,
#   None,
#   1180.0,
#   6,
#   'AW00000209',
#   'E5A50573-0D83-4200-A80C-9F690AF69FCC',
#   '2014-09-12 11:15:07.263'),
#  (210,
#   None,
#   412.0,
#   6,
#   'AW00000210',
#   'FF748558-EA94-4C67-A764-D1480B0F8548',
#   '2014-09-12 11:15:07.263'),
#  (211,
#   None,
#   1408.0,
#   7,
#   'AW00000211',
#   '98158631-9D58-4222-BCBD-CB0B90CBCE17',
#   '2014-09-12 11:15:07.263'),
#  (212,
#   None,
#   1178.0,
#   8,
#   'AW00000212',
#   '4DB27C1B-60CE-4060-B84D-2F83F7A04C4A',
#   '2014-09-12 11:15:07.263'),
#  (213,
#   None,
#   410.0,
#   9,
#   'AW00000213',
#   '374EACA4-B406-4D8E-B122-184EFC4122FA',
#   '2014-09-12 11:15:07.263'),
#  (214,
#   None,
#   1410.0,
#   10,
#   'AW00000214',
#   '402E4D5F-27C3-4197-87E8-32AA42E41BB6',
#   '2014-09-12 11:15:07.263'),
#  (215,
#   None,
#   1176.0,
#   2,
#   'AW00000215',
#   '3C8FDA7C-6E91-4779-A45E-234774092C78',
#   '2014-09-12 11:15:07.263'),
#  (216,
#   None,
#   544.0,
#   2,
#   'AW00000216',
#   '4F58A074-EA37-49F8-B0C1-FDC3E0A08677',
#   '2014-09-12 11:15:07.263'),
#  (217,
#   None,
#   1412.0,
#   1,
#   'AW00000217',
#   '5CFC3A75-DDC6-4C65-B4C3-15BF96C92983',
#   '2014-09-12 11:15:07.263'),
#  (218,
#   None,
#   1174.0,
#   1,
#   'AW00000218',
#   '3C098480-0D9B-409C-8156-C7610415AC5B',
#   '2014-09-12 11:15:07.263'),
#  (219,
#   None,
#   1172.0,
#   3,
#   'AW00000219',
#   'D39CCCE3-C4A6-441D-8A3C-96507627746D',
#   '2014-09-12 11:15:07.263'),
#  (220,
#   None,
#   542.0,
#   3,
#   'AW00000220',
#   '81305A48-9F6E-4415-B7AA-488BA04A8F7E',
#   '2014-09-12 11:15:07.263'),
#  (221,
#   None,
#   1414.0,
#   4,
#   'AW00000221',
#   '98EA497E-45D0-4C54-821A-4FDD9A751095',
#   '2014-09-12 11:15:07.263'),
#  (222,
#   None,
#   1170.0,
#   3,
#   'AW00000222',
#   '3DB84B19-4063-4EC2-B1B4-317DEE133A25',
#   '2014-09-12 11:15:07.263'),
#  (223,
#   None,
#   1158.0,
#   3,
#   'AW00000223',
#   '994837FE-10A8-47DF-B7B8-86C4E6932FD0',
#   '2014-09-12 11:15:07.263'),
#  (224,
#   None,
#   1416.0,
#   5,
#   'AW00000224',
#   '8B943679-47D7-48F4-BBB9-1020A2F634CD',
#   '2014-09-12 11:15:07.263'),
#  (225,
#   None,
#   1168.0,
#   5,
#   'AW00000225',
#   'AD085784-02A0-4A02-B79C-446A9F8F7EBF',
#   '2014-09-12 11:15:07.263'),
#  (226,
#   None,
#   1156.0,
#   6,
#   'AW00000226',
#   'CF860E9B-816A-406E-A64A-7965772D5487',
#   '2014-09-12 11:15:07.263'),
#  (227,
#   None,
#   1418.0,
#   6,
#   'AW00000227',
#   '1FFA0236-84EE-415A-BE61-94CE863715EA',
#   '2014-09-12 11:15:07.263'),
#  (228,
#   None,
#   1166.0,
#   6,
#   'AW00000228',
#   'C751DD7E-51D9-4D2D-AEED-C818EEE56CEB',
#   '2014-09-12 11:15:07.263'),
#  (229,
#   None,
#   1154.0,
#   7,
#   'AW00000229',
#   '25B9F9FC-40B0-463F-B6B9-B345E7B46874',
#   '2014-09-12 11:15:07.263'),
#  (230,
#   None,
#   1420.0,
#   8,
#   'AW00000230',
#   '6AC62AD2-FF1F-4151-B2A2-969847A7BAF1',
#   '2014-09-12 11:15:07.263'),
#  (231,
#   None,
#   550.0,
#   9,
#   'AW00000231',
#   '0AC6FEF1-C8D5-46F7-8E4C-FE522A0E4917',
#   '2014-09-12 11:15:07.263'),
#  (232,
#   None,
#   1152.0,
#   10,
#   'AW00000232',
#   'AA451BD5-FFC2-436C-A295-81B350A5B899',
#   '2014-09-12 11:15:07.263'),
#  (233,
#   None,
#   1422.0,
#   2,
#   'AW00000233',
#   '4E10867D-98DA-4CCC-ADF2-92A3EDB6E7C1',
#   '2014-09-12 11:15:07.263'),
#  (234,
#   None,
#   548.0,
#   2,
#   'AW00000234',
#   '60552ADB-643C-461A-9DFD-57029760B59A',
#   '2014-09-12 11:15:07.263'),
#  (235,
#   None,
#   1150.0,
#   1,
#   'AW00000235',
#   'A4DF6D50-5068-4FA9-B4CA-A3195EB29BB6',
#   '2014-09-12 11:15:07.263'),
#  (236,
#   None,
#   1424.0,
#   1,
#   'AW00000236',
#   '21801FB2-6EA6-4FE5-9444-7E09E8BA907C',
#   '2014-09-12 11:15:07.263'),
#  (237,
#   None,
#   546.0,
#   3,
#   'AW00000237',
#   'B8F7D9D3-E498-40C2-8C7E-FB1C98C43756',
#   '2014-09-12 11:15:07.263'),
#  (238,
#   None,
#   1148.0,
#   3,
#   'AW00000238',
#   '3ECD14CB-463C-4375-B81B-D6E60A48B83D',
#   '2014-09-12 11:15:07.263'),
#  (239,
#   None,
#   1426.0,
#   4,
#   'AW00000239',
#   '48AA4A1E-F209-4B29-A276-113EC94AA6DD',
#   '2014-09-12 11:15:07.263'),
#  (240,
#   None,
#   1956.0,
#   4,
#   'AW00000240',
#   'C581A495-5772-4EB1-943A-9E94E2387814',
#   '2014-09-12 11:15:07.263'),
#  (241,
#   None,
#   1146.0,
#   4,
#   'AW00000241',
#   'FF342E5E-445C-4900-AA71-F15656A7D24D',
#   '2014-09-12 11:15:07.263'),
#  (242,
#   None,
#   1428.0,
#   5,
#   'AW00000242',
#   '01D8CEF9-298D-49A8-AFC4-FFA9F5B6D1F0',
#   '2014-09-12 11:15:07.263'),
#  (243,
#   None,
#   1954.0,
#   5,
#   'AW00000243',
#   '62F14FDC-02DA-47EC-A1AF-5B95E963A14B',
#   '2014-09-12 11:15:07.263'),
#  (244,
#   None,
#   1144.0,
#   6,
#   'AW00000244',
#   '8FF82BED-93D5-4248-99E2-47F53055EC2D',
#   '2014-09-12 11:15:07.263'),
#  (245,
#   None,
#   1430.0,
#   6,
#   'AW00000245',
#   '4A122BDD-4393-42BC-AD49-37E43A0414F6',
#   '2014-09-12 11:15:07.263'),
#  (246,
#   None,
#   1952.0,
#   6,
#   'AW00000246',
#   'CEE9F2DF-2BE7-48B9-8E41-343ADC82F8C4',
#   '2014-09-12 11:15:07.263'),
#  (247,
#   None,
#   1142.0,
#   7,
#   'AW00000247',
#   '0764E4DB-C9D4-4C8B-964D-F7FAD1C567FB',
#   '2014-09-12 11:15:07.263'),
#  (248,
#   None,
#   1432.0,
#   8,
#   'AW00000248',
#   'CF89A228-A4D7-4C95-ABDC-181F2716892E',
#   '2014-09-12 11:15:07.263'),
#  (249,
#   None,
#   1950.0,
#   9,
#   'AW00000249',
#   'C2C4F287-0FBE-436C-8FB8-0E95125DFE61',
#   '2014-09-12 11:15:07.263'),
#  (250,
#   None,
#   1140.0,
#   10,
#   'AW00000250',
#   'CB1ED6CB-18A1-4F7C-8079-DC400B6E506F',
#   '2014-09-12 11:15:07.263'),
#  (251,
#   None,
#   1434.0,
#   2,
#   'AW00000251',
#   '50FC67E2-4FEA-4191-A01B-E850214B3B3E',
#   '2014-09-12 11:15:07.263'),
#  (252,
#   None,
#   1948.0,
#   2,
#   'AW00000252',
#   '3CEA9DD6-E7D0-4892-87D1-4BBA655BCC7A',
#   '2014-09-12 11:15:07.263'),
#  (253,
#   None,
#   1138.0,
#   1,
#   'AW00000253',
#   'E09AB347-7FB1-453F-A4BD-377E68EC8C33',
#   '2014-09-12 11:15:07.263'),
#  (254,
#   None,
#   472.0,
#   1,
#   'AW00000254',
#   '2F89E8DD-A3C3-4ED4-A604-4B3D45DD1BEA',
#   '2014-09-12 11:15:07.263'),
#  (255,
#   None,
#   1946.0,
#   4,
#   'AW00000255',
#   '0A21109F-02B0-4601-B4F7-2ED62C342385',
#   '2014-09-12 11:15:07.263'),
#  (256,
#   None,
#   1136.0,
#   4,
#   'AW00000256',
#   '0B6DB35B-B8B4-4B51-9154-C33E12B38C75',
#   '2014-09-12 11:15:07.263'),
#  (257,
#   None,
#   474.0,
#   4,
#   'AW00000257',
#   'A24F5A79-DD85-4EB2-A6A2-6E7026763FF8',
#   '2014-09-12 11:15:07.263'),
#  (258,
#   None,
#   1944.0,
#   4,
#   'AW00000258',
#   '5549DF48-409F-4C2A-B97B-900EB598843C',
#   '2014-09-12 11:15:07.263'),
#  (259,
#   None,
#   1134.0,
#   4,
#   'AW00000259',
#   '2C3F7A56-819C-4E83-B791-3CE02366D3CF',
#   '2014-09-12 11:15:07.263'),
#  (260,
#   None,
#   476.0,
#   5,
#   'AW00000260',
#   '0446B06C-94D3-44DF-96D3-0BAF8124E5D4',
#   '2014-09-12 11:15:07.263'),
#  (261,
#   None,
#   1942.0,
#   5,
#   'AW00000261',
#   'F6B51FEA-D82E-440F-BC5E-508D33BA7D0F',
#   '2014-09-12 11:15:07.263'),
#  (262,
#   None,
#   1132.0,
#   6,
#   'AW00000262',
#   '1C783210-2B1E-46E2-A2C8-23E610FEEB3C',
#   '2014-09-12 11:15:07.263'),
#  (263,
#   None,
#   580.0,
#   6,
#   'AW00000263',
#   'F665A873-61A2-4B21-B9FF-B5903BEAF759',
#   '2014-09-12 11:15:07.263'),
#  (264,
#   None,
#   1940.0,
#   6,
#   'AW00000264',
#   'A5CE11CE-239C-4849-9683-14F37025A2C1',
#   '2014-09-12 11:15:07.263'),
#  (265,
#   None,
#   590.0,
#   7,
#   'AW00000265',
#   '1CD5E09A-9C62-4AD1-9C86-0E17A4512D6E',
#   '2014-09-12 11:15:07.263'),
#  (266,
#   None,
#   582.0,
#   8,
#   'AW00000266',
#   '4AF6204A-8C86-435D-85D7-B4FA11C5AE93',
#   '2014-09-12 11:15:07.263'),
#  (267,
#   None,
#   1938.0,
#   9,
#   'AW00000267',
#   'E4659480-CA31-4FCD-AC59-79DDC831839F',
#   '2014-09-12 11:15:07.263'),
#  (268,
#   None,
#   588.0,
#   10,
#   'AW00000268',
#   '0C316F6F-5D54-41FD-86A3-6ECAF31A01DD',
#   '2014-09-12 11:15:07.263'),
#  (269,
#   None,
#   584.0,
#   2,
#   'AW00000269',
#   'C8D788BB-BDBE-48A7-B0BF-B1B0488D9B9F',
#   '2014-09-12 11:15:07.263'),
#  (270,
#   None,
#   1936.0,
#   2,
#   'AW00000270',
#   'EF6CE6F1-71B7-4A5D-9EEE-55283BD5AD5C',
#   '2014-09-12 11:15:07.263'),
#  (271,
#   None,
#   586.0,
#   1,
#   'AW00000271',
#   'F2765E86-8DEA-468B-849E-9E83AE57C381',
#   '2014-09-12 11:15:07.263'),
#  (272,
#   None,
#   612.0,
#   1,
#   'AW00000272',
#   'B80F890D-A6A1-4DFC-B763-ECD7743C3C2A',
#   '2014-09-12 11:15:07.263'),
#  (273,
#   None,
#   1934.0,
#   4,
#   'AW00000273',
#   '736DA014-1371-40B2-A401-5BD3267A1E8B',
#   '2014-09-12 11:15:07.263'),
#  (274,
#   None,
#   952.0,
#   3,
#   'AW00000274',
#   '02788A66-2628-4B91-B211-1D8F7E73C500',
#   '2014-09-12 11:15:07.263'),
#  (275,
#   None,
#   614.0,
#   4,
#   'AW00000275',
#   '68DC7932-128E-47CC-80CB-CF2B1A352F3C',
#   '2014-09-12 11:15:07.263'),
#  (276,
#   None,
#   1932.0,
#   4,
#   'AW00000276',
#   '09E2CB2A-B0CA-4376-ABE7-E9240EAD2C16',
#   '2014-09-12 11:15:07.263'),
#  (277,
#   None,
#   950.0,
#   4,
#   'AW00000277',
#   '37156292-0D92-4F6B-9014-CCB0B29E9F9A',
#   '2014-09-12 11:15:07.263'),
#  (278,
#   None,
#   616.0,
#   5,
#   'AW00000278',
#   'E8544BB9-7D68-4D07-96D2-7772D3A000CE',
#   '2014-09-12 11:15:07.263'),
#  (279,
#   None,
#   1930.0,
#   5,
#   'AW00000279',
#   '27670FE7-9BEB-496C-A0B4-A097ACEFECD0',
#   '2014-09-12 11:15:07.263'),
#  (280,
#   None,
#   948.0,
#   6,
#   'AW00000280',
#   '73B26C19-1113-427F-BBAB-BEB6FCDA33C3',
#   '2014-09-12 11:15:07.263'),
#  (281,
#   None,
#   618.0,
#   6,
#   'AW00000281',
#   'B3B07166-1798-41B4-A7C2-0579292008C4',
#   '2014-09-12 11:15:07.263'),
#  (282,
#   None,
#   1928.0,
#   6,
#   'AW00000282',
#   'CF04F255-D817-4EC9-9D99-4580B1ED0CE2',
#   '2014-09-12 11:15:07.263'),
#  (283,
#   None,
#   946.0,
#   7,
#   'AW00000283',
#   '7502406D-DB42-4F26-9C7C-384116A6882D',
#   '2014-09-12 11:15:07.263'),
#  (284,
#   None,
#   758.0,
#   8,
#   'AW00000284',
#   'FF1E806E-2F9D-4494-AE4D-1F7061744DB8',
#   '2014-09-12 11:15:07.263'),
#  (285,
#   None,
#   408.0,
#   9,
#   'AW00000285',
#   '055BC119-564E-47A0-8086-995FBBE8C739',
#   '2014-09-12 11:15:07.263'),
#  (286,
#   None,
#   944.0,
#   10,
#   'AW00000286',
#   '6266CCC4-1AF0-42E0-BCA4-B33EA6838EEE',
#   '2014-09-12 11:15:07.263'),
#  (287,
#   None,
#   760.0,
#   3,
#   'AW00000287',
#   '448CBBFE-EDDC-443D-B7C8-57AEAA463BE5',
#   '2014-09-12 11:15:07.263'),
#  (288,
#   None,
#   406.0,
#   3,
#   'AW00000288',
#   '44EDC8AC-BB0E-418E-BDD3-4F7691381633',
#   '2014-09-12 11:15:07.263'),
#  (289,
#   None,
#   498.0,
#   1,
#   'AW00000289',
#   'A42D0F51-C2BC-433D-B2BD-61C516296669',
#   '2014-09-12 11:15:07.263'),
#  (290,
#   None,
#   762.0,
#   1,
#   'AW00000290',
#   'D0DCDE2D-8C38-48FC-9D83-5EBE8A8577AE',
#   '2014-09-12 11:15:07.263'),
#  (291,
#   None,
#   398.0,
#   4,
#   'AW00000291',
#   'A5AA95AD-8C82-4E50-944F-39F6BDD0A8A8',
#   '2014-09-12 11:15:07.263'),
#  (292,
#   None,
#   496.0,
#   4,
#   'AW00000292',
#   'E1E960B9-5A86-475D-80FE-B64191AEB1DA',
#   '2014-09-12 11:15:07.263'),
#  (293,
#   None,
#   764.0,
#   1,
#   'AW00000293',
#   'B37A0D83-7ED6-4C58-A476-F59B7AE4FC85',
#   '2014-09-12 11:15:07.263'),
#  (294,
#   None,
#   396.0,
#   4,
#   'AW00000294',
#   '592B130D-BFF6-4744-B0B6-02F706504993',
#   '2014-09-12 11:15:07.263'),
#  (295,
#   None,
#   1490.0,
#   4,
#   'AW00000295',
#   'BB5324B1-9ACE-4AAE-8711-41090EDCE4E0',
#   '2014-09-12 11:15:07.263'),
#  (296,
#   None,
#   766.0,
#   5,
#   'AW00000296',
#   '6D8059C6-BF5D-4871-8CA8-CC1703668B87',
#   '2014-09-12 11:15:07.263'),
#  (297,
#   None,
#   394.0,
#   5,
#   'AW00000297',
#   '39BD90D4-A3F8-4F16-A960-B76014B1A913',
#   '2014-09-12 11:15:07.263'),
#  (298,
#   None,
#   1488.0,
#   6,
#   'AW00000298',
#   '16101465-48B9-4147-9C53-6610FEADF778',
#   '2014-09-12 11:15:07.263'),
#  (299,
#   None,
#   768.0,
#   6,
#   'AW00000299',
#   '1CEA8D76-4A20-4D76-9DA2-A3777FD7E693',
#   '2014-09-12 11:15:07.263'),
#  (300,
#   None,
#   386.0,
#   6,
#   'AW00000300',
#   '7256F9B7-5253-4384-B8DE-60B6F0ADF5A6',
#   '2014-09-12 11:15:07.263'),
#  (301,
#   None,
#   1486.0,
#   7,
#   'AW00000301',
#   'D4795F2C-072A-490C-8F6A-F1557DEB3A48',
#   '2014-09-12 11:15:07.263'),
#  (302,
#   None,
#   770.0,
#   8,
#   'AW00000302',
#   '10F18596-1B27-464B-BB18-5E37B29BCE6A',
#   '2014-09-12 11:15:07.263'),
#  (303,
#   None,
#   384.0,
#   9,
#   'AW00000303',
#   '31392045-13D2-46CB-9031-67BD7C6F1300',
#   '2014-09-12 11:15:07.263'),
#  (304,
#   None,
#   1484.0,
#   10,
#   'AW00000304',
#   'C332C909-EE43-4312-A9D8-B2365A0160EA',
#   '2014-09-12 11:15:07.263'),
#  (305,
#   None,
#   772.0,
#   2,
#   'AW00000305',
#   '7B7DC9C9-DF06-43B1-995D-AAC5D58F2862',
#   '2014-09-12 11:15:07.263'),
#  (306,
#   None,
#   382.0,
#   3,
#   'AW00000306',
#   'F8F2835D-F5F0-4070-8465-46BFC815153B',
#   '2014-09-12 11:15:07.263'),
#  (307,
#   None,
#   1482.0,
#   1,
#   'AW00000307',
#   'D11D9DAE-D5D1-440B-BE3F-48D307E942A6',
#   '2014-09-12 11:15:07.263'),
#  (308,
#   None,
#   774.0,
#   1,
#   'AW00000308',
#   'D2B47DAD-E684-449B-992C-15DE391C0FCC',
#   '2014-09-12 11:15:07.263'),
#  (309,
#   None,
#   372.0,
#   4,
#   'AW00000309',
#   'A80B5E25-5EF4-4910-B70B-B2D1F5B207C2',
#   '2014-09-12 11:15:07.263'),
#  (310,
#   None,
#   1480.0,
#   3,
#   'AW00000310',
#   '0D9A0E94-F5E9-4021-8E81-F7F2F18144B1',
#   '2014-09-12 11:15:07.263'),
#  (311,
#   None,
#   776.0,
#   4,
#   'AW00000311',
#   'F070050E-2B33-41A2-A995-D9DF09EB3AE3',
#   '2014-09-12 11:15:07.263'),
#  (312,
#   None,
#   370.0,
#   4,
#   'AW00000312',
#   '067BB7DA-557D-4145-910C-EE0C82CAA0E4',
#   '2014-09-12 11:15:07.263'),
#  (313,
#   None,
#   1478.0,
#   4,
#   'AW00000313',
#   '2157D9A9-A284-4001-973A-27196613681A',
#   '2014-09-12 11:15:07.263'),
#  (314,
#   None,
#   778.0,
#   5,
#   'AW00000314',
#   '1D3E8A19-1AD4-4524-BE77-5A5998107204',
#   '2014-09-12 11:15:07.263'),
#  (315,
#   None,
#   440.0,
#   5,
#   'AW00000315',
#   '527D2334-C39D-49A8-901E-B1057F41BD73',
#   '2014-09-12 11:15:07.263'),
#  (316,
#   None,
#   1476.0,
#   6,
#   'AW00000316',
#   '8C95E9D8-88D0-4E6A-8149-B4C6C79E65BD',
#   '2014-09-12 11:15:07.263'),
#  (317,
#   None,
#   780.0,
#   6,
#   'AW00000317',
#   '5EEF4DAA-8514-43A3-B96A-D99E19E3C2E8',
#   '2014-09-12 11:15:07.263'),
#  (318,
#   None,
#   438.0,
#   6,
#   'AW00000318',
#   'D241D8F1-5A7A-41B3-8723-1E2B1A9FDBF6',
#   '2014-09-12 11:15:07.263'),
#  (319,
#   None,
#   1474.0,
#   7,
#   'AW00000319',
#   'B933A9DC-EF58-4BB6-83A1-BCE83A1468DB',
#   '2014-09-12 11:15:07.263'),
#  (320,
#   None,
#   538.0,
#   8,
#   'AW00000320',
#   'FD0864B5-E700-4407-8683-92B710034073',
#   '2014-09-12 11:15:07.263'),
#  (321,
#   None,
#   436.0,
#   9,
#   'AW00000321',
#   'FFE78B87-222B-4AB6-8D46-AFBA06C1B19E',
#   '2014-09-12 11:15:07.263'),
#  (322,
#   None,
#   1472.0,
#   10,
#   'AW00000322',
#   '1C56E02D-69F4-4C0D-965B-2B7F54AA0A34',
#   '2014-09-12 11:15:07.263'),
#  (323,
#   None,
#   540.0,
#   3,
#   'AW00000323',
#   '0DA4F03E-47E9-4BED-B149-9C18CEE9EB30',
#   '2014-09-12 11:15:07.263'),
#  (324,
#   None,
#   2051.0,
#   2,
#   'AW00000324',
#   '815EEA58-33C8-4717-8A9B-A86856090A06',
#   '2014-09-12 11:15:07.263'),
#  (325,
#   None,
#   1470.0,
#   1,
#   'AW00000325',
#   '6340AC77-4FBD-4EEC-9D60-5009D428674A',
#   '2014-09-12 11:15:07.263'),
#  (326,
#   None,
#   964.0,
#   1,
#   'AW00000326',
#   '81C81C0D-73EB-442D-BEB0-D03AD4AF5048',
#   '2014-09-12 11:15:07.263'),
#  (327,
#   None,
#   1994.0,
#   3,
#   'AW00000327',
#   'CDD7480F-7284-453A-A7CA-910535D40583',
#   '2014-09-12 11:15:07.263'),
#  (328,
#   None,
#   1992.0,
#   4,
#   'AW00000328',
#   '84A86A42-C9F8-4B4A-A1A6-28E4E448FB8C',
#   '2014-09-12 11:15:07.263'),
#  (329,
#   None,
#   470.0,
#   4,
#   'AW00000329',
#   '35DE20D0-B72D-440B-8C55-6E8AD6643335',
#   '2014-09-12 11:15:07.263'),
#  (330,
#   None,
#   966.0,
#   4,
#   'AW00000330',
#   '09480748-3F10-4C0F-9BF1-EBEFAD6540CF',
#   '2014-09-12 11:15:07.263'),
#  (331,
#   None,
#   1990.0,
#   4,
#   'AW00000331',
#   '9B6D55BD-1BFD-489B-A09D-CA2DE42C7C16',
#   '2014-09-12 11:15:07.263'),
#  (332,
#   None,
#   468.0,
#   5,
#   'AW00000332',
#   'B2E4CF6B-9C83-4025-99B4-166640C15510',
#   '2014-09-12 11:15:07.263'),
#  (333,
#   None,
#   968.0,
#   5,
#   'AW00000333',
#   '0412C1A5-E4BA-4F83-9BB3-86175B894A55',
#   '2014-09-12 11:15:07.263'),
#  (334,
#   None,
#   1988.0,
#   6,
#   'AW00000334',
#   '777D62E5-3C77-4CEF-8AF6-8A4648F49EB9',
#   '2014-09-12 11:15:07.263'),
#  (335,
#   None,
#   466.0,
#   6,
#   'AW00000335',
#   'F8BF1985-3C65-400F-BD46-92F88008F003',
#   '2014-09-12 11:15:07.263'),
#  (336,
#   None,
#   970.0,
#   6,
#   'AW00000336',
#   '0341CA02-F44F-4604-8E20-A749B90FD976',
#   '2014-09-12 11:15:07.263'),
#  (337,
#   None,
#   1986.0,
#   7,
#   'AW00000337',
#   'FB5A02EB-5589-4499-A19E-492457426B90',
#   '2014-09-12 11:15:07.263'),
#  (338,
#   None,
#   578.0,
#   8,
#   'AW00000338',
#   '2E85A0AE-4725-45D3-A21C-F1EE94FDE748',
#   '2014-09-12 11:15:07.263'),
#  (339,
#   None,
#   972.0,
#   9,
#   'AW00000339',
#   'ECBD14F2-F495-4AC9-B3F4-6A53D15856D3',
#   '2014-09-12 11:15:07.263'),
#  (340,
#   None,
#   1984.0,
#   10,
#   'AW00000340',
#   '191FE023-2354-4FBB-88D7-B57ADC3428D8',
#   '2014-09-12 11:15:07.263'),
#  (341,
#   None,
#   576.0,
#   2,
#   'AW00000341',
#   '8347E7AF-A66A-410A-A035-65CF88E500B3',
#   '2014-09-12 11:15:07.263'),
#  (342,
#   None,
#   974.0,
#   2,
#   'AW00000342',
#   'DFBE95B2-BFB7-4CB3-BBFC-045F35BB48CF',
#   '2014-09-12 11:15:07.263'),
#  (343,
#   None,
#   1982.0,
#   1,
#   'AW00000343',
#   'DAE8EF10-88DA-4F94-B6A7-A9745F250DB2',
#   '2014-09-12 11:15:07.263'),
#  (344,
#   None,
#   574.0,
#   1,
#   'AW00000344',
#   'AA3B69DF-40CF-45B8-9250-F69EF6DB1C15',
#   '2014-09-12 11:15:07.263'),
#  (345,
#   None,
#   976.0,
#   4,
#   'AW00000345',
#   '131056AB-E899-43BF-91E6-D92F44456655',
#   '2014-09-12 11:15:07.263'),
#  (346,
#   None,
#   1980.0,
#   3,
#   'AW00000346',
#   'B3E143FD-F617-401E-AAD9-C50BC280ED18',
#   '2014-09-12 11:15:07.263'),
#  (347,
#   None,
#   572.0,
#   4,
#   'AW00000347',
#   '2DE20D49-86F7-40C0-950D-12C93EA94B35',
#   '2014-09-12 11:15:07.263'),
#  (348,
#   None,
#   348.0,
#   3,
#   'AW00000348',
#   'BA20E529-555E-4D2C-83F0-DCBA833230AF',
#   '2014-09-12 11:15:07.263'),
#  (349,
#   None,
#   1978.0,
#   4,
#   'AW00000349',
#   'B23474BF-01CC-4A5E-902C-D6A4EB5ED777',
#   '2014-09-12 11:15:07.263'),
#  (350,
#   None,
#   610.0,
#   5,
#   'AW00000350',
#   '51AF3285-9533-4172-A4B9-7E654169FB33',
#   '2014-09-12 11:15:07.263'),
#  (351,
#   None,
#   354.0,
#   5,
#   'AW00000351',
#   '4267E129-15F9-41DE-B426-F38CB86CC417',
#   '2014-09-12 11:15:07.263'),
#  (352,
#   None,
#   1236.0,
#   6,
#   'AW00000352',
#   '5617D4F8-C3A1-4408-8895-AE3F7E0EFA05',
#   '2014-09-12 11:15:07.263'),
#  (353,
#   None,
#   608.0,
#   6,
#   'AW00000353',
#   '3B2E5C36-0827-4A31-B112-F347AD588822',
#   '2014-09-12 11:15:07.263'),
#  (354,
#   None,
#   356.0,
#   6,
#   'AW00000354',
#   'B65DFD89-49C5-4530-B819-B6E84F3531A6',
#   '2014-09-12 11:15:07.263'),
#  (355,
#   None,
#   1234.0,
#   7,
#   'AW00000355',
#   'E6250B8A-8DCB-4192-8A0B-9598AE0E3F05',
#   '2014-09-12 11:15:07.263'),
#  (356,
#   None,
#   606.0,
#   8,
#   'AW00000356',
#   'C5ADD2B4-2679-46D0-B6BC-649592C7DA61',
#   '2014-09-12 11:15:07.263'),
#  (357,
#   None,
#   358.0,
#   9,
#   'AW00000357',
#   'CDD731FA-45B9-405C-9265-42C039CFB509',
#   '2014-09-12 11:15:07.263'),
#  (358,
#   None,
#   1232.0,
#   10,
#   'AW00000358',
#   '3ED88E2F-3F29-4E30-93D4-CE38474DED23',
#   '2014-09-12 11:15:07.263'),
#  (359,
#   None,
#   604.0,
#   2,
#   'AW00000359',
#   '68E332E9-2929-4149-8086-FA8D7E4BC859',
#   '2014-09-12 11:15:07.263'),
#  (360,
#   None,
#   360.0,
#   3,
#   'AW00000360',
#   '8BE04D7D-1192-4A27-ACA3-926E5F530ABB',
#   '2014-09-12 11:15:07.263'),
#  (361,
#   None,
#   1230.0,
#   1,
#   'AW00000361',
#   '6F69F454-5199-4B15-B370-D926F8ED104C',
#   '2014-09-12 11:15:07.263'),
#  (362,
#   None,
#   756.0,
#   1,
#   'AW00000362',
#   'D9B640A6-0988-4548-8231-69CA927D49AB',
#   '2014-09-12 11:15:07.263'),
#  (363,
#   None,
#   374.0,
#   3,
#   'AW00000363',
#   '3543B21B-0DFA-40DE-998E-A9C3F2FCDA98',
#   '2014-09-12 11:15:07.263'),
#  (364,
#   None,
#   1228.0,
#   3,
#   'AW00000364',
#   '9D91F4ED-58B5-4A59-9894-8FD17EBDFC9B',
#   '2014-09-12 11:15:07.263'),
#  (365,
#   None,
#   754.0,
#   4,
#   'AW00000365',
#   'AB87B283-4B2B-48AD-9D10-6B9F2D4D0BAA',
#   '2014-09-12 11:15:07.263'),
#  (366,
#   None,
#   376.0,
#   4,
#   'AW00000366',
#   '76DA51E9-D61B-488C-A4E7-C7B87FDA2917',
#   '2014-09-12 11:15:07.263'),
#  (367,
#   None,
#   1226.0,
#   4,
#   'AW00000367',
#   'A65D6B08-0B08-453C-B244-CB324A3DFC0C',
#   '2014-09-12 11:15:07.263'),
#  (368,
#   None,
#   752.0,
#   5,
#   'AW00000368',
#   '992E96CC-BE7C-49AA-A6E5-6534990F1774',
#   '2014-09-12 11:15:07.263'),
#  (369,
#   None,
#   362.0,
#   5,
#   'AW00000369',
#   '3D4C073C-758C-4AE7-A00B-72DADA062AF2',
#   '2014-09-12 11:15:07.263'),
#  (370,
#   None,
#   1224.0,
#   6,
#   'AW00000370',
#   '7059E0F6-846D-4A52-8A97-0734CD064892',
#   '2014-09-12 11:15:07.263'),
#  (371,
#   None,
#   750.0,
#   6,
#   'AW00000371',
#   '05CF6683-BC27-4062-A60D-995706BBFAB5',
#   '2014-09-12 11:15:07.263'),
#  (372,
#   None,
#   1852.0,
#   6,
#   'AW00000372',
#   'F377F21A-9A29-49AF-9158-4E3FA8586FF7',
#   '2014-09-12 11:15:07.263'),
#  (373,
#   None,
#   1222.0,
#   7,
#   'AW00000373',
#   '6C49B96D-2DFE-4E55-A102-416FE3B64DC4',
#   '2014-09-12 11:15:07.263'),
#  (374,
#   None,
#   748.0,
#   8,
#   'AW00000374',
#   'B50E974F-2703-4508-81F9-84AA2FB27615',
#   '2014-09-12 11:15:07.263'),
#  (375,
#   None,
#   1854.0,
#   9,
#   'AW00000375',
#   '150DCA03-DAE1-461C-85C8-54660461356C',
#   '2014-09-12 11:15:07.263'),
#  (376,
#   None,
#   1220.0,
#   10,
#   'AW00000376',
#   'D733948F-DB34-47FF-A618-06123A32E515',
#   '2014-09-12 11:15:07.263'),
#  (377,
#   None,
#   746.0,
#   3,
#   'AW00000377',
#   'F728AB05-7868-493D-BEBA-F4E7DFAFFF31',
#   '2014-09-12 11:15:07.263'),
#  (378,
#   None,
#   1856.0,
#   2,
#   'AW00000378',
#   '95828950-E407-4293-A824-B2525F135503',
#   '2014-09-12 11:15:07.263'),
#  (379,
#   None,
#   1218.0,
#   1,
#   'AW00000379',
#   '083C2D9F-7CBB-4CD4-9BBF-30E80C376EE5',
#   '2014-09-12 11:15:07.263'),
#  (380,
#   None,
#   744.0,
#   1,
#   'AW00000380',
#   '5E469335-ACDD-41C8-89FE-0856ED944340',
#   '2014-09-12 11:15:07.263'),
#  (381,
#   None,
#   1858.0,
#   3,
#   'AW00000381',
#   '5AA5C79E-3C99-4FD2-87E7-B0E67603D5AB',
#   '2014-09-12 11:15:07.263'),
#  (382,
#   None,
#   1216.0,
#   4,
#   'AW00000382',
#   '7EE0371D-CEFE-4A15-9347-34C232D82AB0',
#   '2014-09-12 11:15:07.263'),
#  (383,
#   None,
#   742.0,
#   4,
#   'AW00000383',
#   '94DA916C-8E0D-405C-AD3C-CFE9C1DB699A',
#   '2014-09-12 11:15:07.263'),
#  (384,
#   None,
#   1860.0,
#   4,
#   'AW00000384',
#   '7BC25C4C-F0E3-4471-8D8B-E0595061AF6A',
#   '2014-09-12 11:15:07.263'),
#  (385,
#   None,
#   1214.0,
#   4,
#   'AW00000385',
#   '6EDE3BE1-137D-4984-9ECB-EB871AE9059D',
#   '2014-09-12 11:15:07.263'),
#  (386,
#   None,
#   740.0,
#   5,
#   'AW00000386',
#   'BC5C4272-DB96-464C-8F74-09A8343E5877',
#   '2014-09-12 11:15:07.263'),
#  (387,
#   None,
#   1862.0,
#   5,
#   'AW00000387',
#   '3F8DE0ED-D0F6-498C-AB91-2C35815E297E',
#   '2014-09-12 11:15:07.263'),
#  (388,
#   None,
#   1212.0,
#   6,
#   'AW00000388',
#   'C0C5EE7E-DD39-401D-9BF5-7EC01D57E57F',
#   '2014-09-12 11:15:07.263'),
#  (389,
#   None,
#   738.0,
#   6,
#   'AW00000389',
#   '0FC568B5-2A6B-4C9D-87BC-9B8C6313C9DA',
#   '2014-09-12 11:15:07.263'),
#  (390,
#   None,
#   1864.0,
#   6,
#   'AW00000390',
#   'D6AB0687-0DB2-460B-A4D2-34AAD4EC9F3D',
#   '2014-09-12 11:15:07.263'),
#  (391,
#   None,
#   1210.0,
#   7,
#   'AW00000391',
#   '030F5458-D836-4142-B2A7-321C34EA66D7',
#   '2014-09-12 11:15:07.263'),
#  (392,
#   None,
#   736.0,
#   8,
#   'AW00000392',
#   '8D04B130-E705-4B91-8159-8DA619A2B9DE',
#   '2014-09-12 11:15:07.263'),
#  (393,
#   None,
#   1866.0,
#   9,
#   'AW00000393',
#   '65923376-FAE9-430E-9712-42235694F8BD',
#   '2014-09-12 11:15:07.263'),
#  (394,
#   None,
#   1208.0,
#   10,
#   'AW00000394',
#   'F53F2CA8-F244-46B8-A64F-A09F657DB9DC',
#   '2014-09-12 11:15:07.263'),
#  (395,
#   None,
#   560.0,
#   3,
#   'AW00000395',
#   '8DA056FC-494F-4FE1-8397-0B0736603201',
#   '2014-09-12 11:15:07.263'),
#  (396,
#   None,
#   1868.0,
#   2,
#   'AW00000396',
#   '8ADBCD9A-4D47-4FD5-A04A-DFFCC2BF47DE',
#   '2014-09-12 11:15:07.263'),
#  (397,
#   None,
#   1206.0,
#   1,
#   'AW00000397',
#   'B711F333-3277-4885-AB55-5790CF41F27D',
#   '2014-09-12 11:15:07.263'),
#  (398,
#   None,
#   558.0,
#   1,
#   'AW00000398',
#   'E47537DD-645F-458C-A410-A520D38DD7B9',
#   '2014-09-12 11:15:07.263'),
#  (399,
#   None,
#   1870.0,
#   4,
#   'AW00000399',
#   'BC98B78E-3068-475A-8EAD-FBA537DDE9B9',
#   '2014-09-12 11:15:07.263'),
#  (400,
#   None,
#   1110.0,
#   3,
#   'AW00000400',
#   '40984282-13F9-4B14-90B3-E7A17180195D',
#   '2014-09-12 11:15:07.263'),
#  (401,
#   None,
#   368.0,
#   1,
#   'AW00000401',
#   'CC76F684-79AD-4A66-A30E-1B7FB5C917C5',
#   '2014-09-12 11:15:07.263'),
#  (402,
#   None,
#   460.0,
#   4,
#   'AW00000402',
#   '48941CAA-5B39-497E-AD56-EFD9172D372E',
#   '2014-09-12 11:15:07.263'),
#  (403,
#   None,
#   1108.0,
#   4,
#   'AW00000403',
#   '0484601B-6A04-41BF-9554-3EB22D5B4DC1',
#   '2014-09-12 11:15:07.263'),
#  (404,
#   None,
#   366.0,
#   5,
#   'AW00000404',
#   '8EF6E3C7-A53A-4CE4-819F-E67871C2F7ED',
#   '2014-09-12 11:15:07.263'),
#  (405,
#   None,
#   462.0,
#   5,
#   'AW00000405',
#   '2EF9B843-4B9A-4220-8503-2DBDB2878C41',
#   '2014-09-12 11:15:07.263'),
#  (406,
#   None,
#   1106.0,
#   6,
#   'AW00000406',
#   '04C17472-C4DA-40B1-82FA-B08D3828B863',
#   '2014-09-12 11:15:07.263'),
#  (407,
#   None,
#   380.0,
#   6,
#   'AW00000407',
#   '5A2338D1-158F-4386-8C30-EFF2BF990669',
#   '2014-09-12 11:15:07.263'),
#  (408,
#   None,
#   464.0,
#   6,
#   'AW00000408',
#   'A845D318-D6C0-4E69-B509-83686BD409A6',
#   '2014-09-12 11:15:07.263'),
#  (409,
#   None,
#   1104.0,
#   7,
#   'AW00000409',
#   '102DF3EB-C1A7-494A-A2FF-E0C5F2018559',
#   '2014-09-12 11:15:07.263'),
#  (410,
#   None,
#   378.0,
#   8,
# ...
#   'CA7E2C72-5F99-4D6D-A491-2A7FD760995B',
#   '2014-09-12 11:15:07.263'),
#  (11167,
#   19844.0,
#   None,
#   1,
#   'AW00011167',
#   '20EFA56F-E8B7-4700-ACBE-B84E5C4B42B5',
#   '2014-09-12 11:15:07.263'),
#  (11168,
#   18143.0,
#   None,
#   4,
#   'AW00011168',
#   '5E96EA47-3895-49F4-BBDD-1170DC3D9311',
#   '2014-09-12 11:15:07.263'),
#  (11169,
#   14713.0,
#   None,
#   4,
#   'AW00011169',
#   '45FEA86E-BC73-4CAF-A9DE-D6B1C74C764D',
#   '2014-09-12 11:15:07.263'),
#  (11170,
#   3164.0,
#   None,
#   1,
#   'AW00011170',
#   '22913E1D-E16C-4FC5-A435-D6DCE946AA6A',
#   '2014-09-12 11:15:07.263'),
#  (11171,
#   16623.0,
#   None,
#   4,
#   'AW00011171',
#   'CB3E5B8B-2A5D-4F3E-B438-A52863394471',
#   '2014-09-12 11:15:07.263'),
#  (11172,
#   10282.0,
#   None,
#   1,
#   'AW00011172',
#   'E78EA518-D4A9-4A51-9223-204103F7B4E1',
#   '2014-09-12 11:15:07.263'),
#  (11173,
#   12474.0,
#   None,
#   1,
#   'AW00011173',
#   '618B8371-A706-4E2F-B591-92A94374E3F0',
#   '2014-09-12 11:15:07.263'),
#  (11174,
#   19012.0,
#   None,
#   4,
#   'AW00011174',
#   '61E5207C-20CE-4ACC-A296-51B952F0CB18',
#   '2014-09-12 11:15:07.263'),
#  (11175,
#   5468.0,
#   None,
#   4,
#   'AW00011175',
#   '836EFA07-4C07-418A-A99C-18F78DCF6D06',
#   '2014-09-12 11:15:07.263'),
#  (11176,
#   15994.0,
#   None,
#   6,
#   'AW00011176',
#   '3464757C-E9D8-42B0-888B-5C316C8633F3',
#   '2014-09-12 11:15:07.263'),
#  (11177,
#   5651.0,
#   None,
#   4,
#   'AW00011177',
#   '04D9AD85-7194-4E5F-89C3-1BD801761603',
#   '2014-09-12 11:15:07.263'),
#  (11178,
#   17696.0,
#   None,
#   4,
#   'AW00011178',
#   '0BCE9AD6-6BD5-4ED5-83F2-500B0C789E33',
#   '2014-09-12 11:15:07.263'),
#  (11179,
#   16169.0,
#   None,
#   4,
#   'AW00011179',
#   '5AF35A8D-2F4E-4F49-8395-CCD31A7BB229',
#   '2014-09-12 11:15:07.263'),
#  (11180,
#   20564.0,
#   None,
#   4,
#   'AW00011180',
#   '52A330E9-7561-4485-A79B-CBFFA2097C4A',
#   '2014-09-12 11:15:07.263'),
#  (11181,
#   4935.0,
#   None,
#   4,
#   'AW00011181',
#   '318CDA27-DF61-4E21-A4C2-C2B7DA0D987C',
#   '2014-09-12 11:15:07.263'),
#  (11182,
#   3087.0,
#   None,
#   1,
#   'AW00011182',
#   'C8417277-861E-45EB-8C8B-940753CA9D90',
#   '2014-09-12 11:15:07.263'),
#  (11183,
#   11425.0,
#   None,
#   4,
#   'AW00011183',
#   'D100E1D7-5829-4C0A-828A-B04FCD399219',
#   '2014-09-12 11:15:07.263'),
#  (11184,
#   18783.0,
#   None,
#   4,
#   'AW00011184',
#   '0FF55283-CE4B-4666-A64E-071EF84744EC',
#   '2014-09-12 11:15:07.263'),
#  (11185,
#   12569.0,
#   None,
#   6,
#   'AW00011185',
#   '9722C311-829B-4DF5-8FD3-D2742C097B6D',
#   '2014-09-12 11:15:07.263'),
#  (11186,
#   12608.0,
#   None,
#   4,
#   'AW00011186',
#   'B51032E3-2623-4FDD-8F81-5A8680A2D9B0',
#   '2014-09-12 11:15:07.263'),
#  (11187,
#   20457.0,
#   None,
#   1,
#   'AW00011187',
#   'A52B436A-1532-4385-986F-66BE0836AD54',
#   '2014-09-12 11:15:07.263'),
#  (11188,
#   9002.0,
#   None,
#   4,
#   'AW00011188',
#   '8AF7C9C8-B802-419F-B073-171BDB5374DC',
#   '2014-09-12 11:15:07.263'),
#  (11189,
#   14459.0,
#   None,
#   1,
#   'AW00011189',
#   '579DFF3E-C102-4A2B-AB47-705060610E3F',
#   '2014-09-12 11:15:07.263'),
#  (11190,
#   13265.0,
#   None,
#   4,
#   'AW00011190',
#   'F8A4570B-9143-431D-B3F1-ABAD5089FD30',
#   '2014-09-12 11:15:07.263'),
#  (11191,
#   10722.0,
#   None,
#   4,
#   'AW00011191',
#   '728D9425-2D92-4313-955D-BC776625AA24',
#   '2014-09-12 11:15:07.263'),
#  (11192,
#   17599.0,
#   None,
#   1,
#   'AW00011192',
#   'FB0EAF09-5121-42C5-B0C6-3568C3BCFEF2',
#   '2014-09-12 11:15:07.263'),
#  (11193,
#   14519.0,
#   None,
#   1,
#   'AW00011193',
#   '46248244-5B58-4497-8A5C-EA5D5D90DB5D',
#   '2014-09-12 11:15:07.263'),
#  (11194,
#   7727.0,
#   None,
#   4,
#   'AW00011194',
#   '03835401-C9D0-4C6C-A089-C9930CBC6445',
#   '2014-09-12 11:15:07.263'),
#  (11195,
#   19140.0,
#   None,
#   1,
#   'AW00011195',
#   '9B68FE70-68C7-477E-BA88-5EF7D3A817E2',
#   '2014-09-12 11:15:07.263'),
#  (11196,
#   2800.0,
#   None,
#   1,
#   'AW00011196',
#   '2E6EAB45-4534-4FEC-8703-73D1205A7EFB',
#   '2014-09-12 11:15:07.263'),
#  (11197,
#   9000.0,
#   None,
#   1,
#   'AW00011197',
#   '89196BC4-980C-4FA3-BA48-E5BB97647647',
#   '2014-09-12 11:15:07.263'),
#  (11198,
#   8052.0,
#   None,
#   4,
#   'AW00011198',
#   '3E5E07F3-6806-4B01-A7C4-F98B34AF8634',
#   '2014-09-12 11:15:07.263'),
#  (11199,
#   7729.0,
#   None,
#   4,
#   'AW00011199',
#   '1D735C67-E7AD-492A-A63A-9FC04293BF07',
#   '2014-09-12 11:15:07.263'),
#  (11200,
#   5409.0,
#   None,
#   6,
#   'AW00011200',
#   'A6E1B02A-306C-4E4A-B028-50EA7A90B2ED',
#   '2014-09-12 11:15:07.263'),
#  (11201,
#   3054.0,
#   None,
#   4,
#   'AW00011201',
#   'AAD968E6-E34A-4DE4-A8AD-C37D16E2B250',
#   '2014-09-12 11:15:07.263'),
#  (11202,
#   7092.0,
#   None,
#   4,
#   'AW00011202',
#   'B816C3E3-3FFC-4ED3-BF18-698A59F44C31',
#   '2014-09-12 11:15:07.263'),
#  (11203,
#   5463.0,
#   None,
#   6,
#   'AW00011203',
#   'F2312406-601B-4223-BFAA-BABA69550635',
#   '2014-09-12 11:15:07.263'),
#  (11204,
#   20019.0,
#   None,
#   1,
#   'AW00011204',
#   '37CBB06B-A879-46F1-8EEF-B29AE040EA48',
#   '2014-09-12 11:15:07.263'),
#  (11205,
#   18028.0,
#   None,
#   1,
#   'AW00011205',
#   'A00D9DD1-D961-405A-AEBB-AC9EA5BE7C15',
#   '2014-09-12 11:15:07.263'),
#  (11206,
#   13604.0,
#   None,
#   1,
#   'AW00011206',
#   '4EB6A1AB-0D6F-4095-A00C-545396BC1993',
#   '2014-09-12 11:15:07.263'),
#  (11207,
#   8512.0,
#   None,
#   1,
#   'AW00011207',
#   '0F5C719C-E5E5-48AA-9526-117A697914B0',
#   '2014-09-12 11:15:07.263'),
#  (11208,
#   3225.0,
#   None,
#   4,
#   'AW00011208',
#   'C32FEA35-579D-4F13-B8C4-9BDD98A49652',
#   '2014-09-12 11:15:07.263'),
#  (11209,
#   9318.0,
#   None,
#   4,
#   'AW00011209',
#   '2B3AC9B1-0B86-4EFA-B433-BF6DC68E13D0',
#   '2014-09-12 11:15:07.263'),
#  (11210,
#   13628.0,
#   None,
#   4,
#   'AW00011210',
#   '51B7341B-B9B8-4FA2-874F-00294CAF467A',
#   '2014-09-12 11:15:07.263'),
#  (11211,
#   12549.0,
#   None,
#   6,
#   'AW00011211',
#   'E1285DA5-60D6-441D-AEBF-C11A5EB69BAA',
#   '2014-09-12 11:15:07.263'),
#  (11212,
#   9700.0,
#   None,
#   6,
#   'AW00011212',
#   '870C1E21-882B-4750-B9E5-6D98F9573E04',
#   '2014-09-12 11:15:07.263'),
#  (11213,
#   3074.0,
#   None,
#   1,
#   'AW00011213',
#   '55254B4B-3984-4F50-9A1F-93B1622608AA',
#   '2014-09-12 11:15:07.263'),
#  (11214,
#   4847.0,
#   None,
#   1,
#   'AW00011214',
#   '28F11530-4957-4AAC-BFC2-0FF781F73E24',
#   '2014-09-12 11:15:07.263'),
#  (11215,
#   7440.0,
#   None,
#   6,
#   'AW00011215',
#   '02D1F9CC-F015-4306-AED6-9579102026EF',
#   '2014-09-12 11:15:07.263'),
#  (11216,
#   19820.0,
#   None,
#   1,
#   'AW00011216',
#   '4C8314BF-0D5E-4845-99BB-3E12F3AB220B',
#   '2014-09-12 11:15:07.263'),
#  (11217,
#   10262.0,
#   None,
#   1,
#   'AW00011217',
#   '6AD25F91-0313-4811-A423-A34439701D6E',
#   '2014-09-12 11:15:07.263'),
#  (11218,
#   11750.0,
#   None,
#   1,
#   'AW00011218',
#   '3CC359E7-C4E7-4C59-850F-477886EEB024',
#   '2014-09-12 11:15:07.263'),
#  (11219,
#   15531.0,
#   None,
#   1,
#   'AW00011219',
#   '403BF5B5-9757-4660-9E8A-67531A36CBF9',
#   '2014-09-12 11:15:07.263'),
#  (11220,
#   2477.0,
#   None,
#   4,
#   'AW00011220',
#   '841EAF8D-00AC-408F-99ED-1E66EFBE66BD',
#   '2014-09-12 11:15:07.263'),
#  (11221,
#   5941.0,
#   None,
#   4,
#   'AW00011221',
#   'B149C583-B3E0-4D90-B905-B26E4C0F3C96',
#   '2014-09-12 11:15:07.263'),
#  (11222,
#   2773.0,
#   None,
#   4,
#   'AW00011222',
#   '741654E8-ED9A-4B7E-8410-F8F141F73EE4',
#   '2014-09-12 11:15:07.263'),
#  (11223,
#   3197.0,
#   None,
#   6,
#   'AW00011223',
#   '72BFA246-56C5-4307-914A-04DD9C0F2A34',
#   '2014-09-12 11:15:07.263'),
#  (11224,
#   2656.0,
#   None,
#   1,
#   'AW00011224',
#   '158BC30A-04B4-4E0C-9FBF-302208462273',
#   '2014-09-12 11:15:07.263'),
#  (11225,
#   12350.0,
#   None,
#   1,
#   'AW00011225',
#   'CC9A216F-E02E-45D9-BFE9-906759F3C73F',
#   '2014-09-12 11:15:07.263'),
#  (11226,
#   2873.0,
#   None,
#   1,
#   'AW00011226',
#   'DBF20B18-4F6D-4853-89DC-728F068B30FB',
#   '2014-09-12 11:15:07.263'),
#  (11227,
#   11590.0,
#   None,
#   4,
#   'AW00011227',
#   '98D0F097-B4F1-43CF-847B-1ACD674CA700',
#   '2014-09-12 11:15:07.263'),
#  (11228,
#   12412.0,
#   None,
#   4,
#   'AW00011228',
#   '106BB248-E43C-4489-88ED-F9687D86A0AF',
#   '2014-09-12 11:15:07.263'),
#  (11229,
#   15841.0,
#   None,
#   4,
#   'AW00011229',
#   'BE528BFF-FD36-4027-913D-CF532F972B1B',
#   '2014-09-12 11:15:07.263'),
#  (11230,
#   9612.0,
#   None,
#   4,
#   'AW00011230',
#   'F04C2F9E-557B-4854-ABDA-6F418912F14A',
#   '2014-09-12 11:15:07.263'),
#  (11231,
#   17885.0,
#   None,
#   1,
#   'AW00011231',
#   '9FA72F06-CA29-4F0E-8578-2E15386FB1F7',
#   '2014-09-12 11:15:07.263'),
#  (11232,
#   3210.0,
#   None,
#   1,
#   'AW00011232',
#   '28CABC22-C13A-4507-A8AC-E135F7BA3411',
#   '2014-09-12 11:15:07.263'),
#  (11233,
#   18194.0,
#   None,
#   4,
#   'AW00011233',
#   'B2F3DC1A-67C4-43A9-AC5B-7DCDF079499A',
#   '2014-09-12 11:15:07.263'),
#  (11234,
#   3686.0,
#   None,
#   4,
#   'AW00011234',
#   'C4451355-C5E1-4AAF-B61C-F02DFC248154',
#   '2014-09-12 11:15:07.263'),
#  (11235,
#   15802.0,
#   None,
#   1,
#   'AW00011235',
#   'C72F7BF4-3787-4979-AB4A-51E369FD0801',
#   '2014-09-12 11:15:07.263'),
#  (11236,
#   13521.0,
#   None,
#   1,
#   'AW00011236',
#   'F80670A5-AD53-4296-9C63-8D2F3D45B22E',
#   '2014-09-12 11:15:07.263'),
#  (11237,
#   7511.0,
#   None,
#   8,
#   'AW00011237',
#   '7EF7C3C5-9CB6-4F77-94E1-576C19E341C6',
#   '2014-09-12 11:15:07.263'),
#  (11238,
#   3392.0,
#   None,
#   10,
#   'AW00011238',
#   '9DD00331-CD15-46FB-8174-53CE82E7698E',
#   '2014-09-12 11:15:07.263'),
#  (11239,
#   16405.0,
#   None,
#   10,
#   'AW00011239',
#   '9DA8290E-D0E9-43FC-8410-28A5FB6EF65E',
#   '2014-09-12 11:15:07.263'),
#  (11240,
#   14359.0,
#   None,
#   10,
#   'AW00011240',
#   '2253D8FD-3AC6-4A72-A2A1-15F81CCAFCC2',
#   '2014-09-12 11:15:07.263'),
#  (11241,
#   2436.0,
#   None,
#   7,
#   'AW00011241',
#   '349A059A-A808-4944-AFEE-F651FEA92F62',
#   '2014-09-12 11:15:07.263'),
#  (11242,
#   18425.0,
#   None,
#   7,
#   'AW00011242',
#   'E92F25E3-6930-4045-B078-268AAFAE930C',
#   '2014-09-12 11:15:07.263'),
#  (11243,
#   13712.0,
#   None,
#   10,
#   'AW00011243',
#   '61DD71EB-C410-487F-BE19-CE36803D10AE',
#   '2014-09-12 11:15:07.263'),
#  (11244,
#   12751.0,
#   None,
#   10,
#   'AW00011244',
#   '976A7FEE-5734-46A3-BA98-9B6693942DCF',
#   '2014-09-12 11:15:07.263'),
#  (11245,
#   15603.0,
#   None,
#   8,
#   'AW00011245',
#   'A44D5FCD-481B-4AD6-A4A8-A2D573059048',
#   '2014-09-12 11:15:07.263'),
#  (11246,
#   6162.0,
#   None,
#   8,
#   'AW00011246',
#   '7D65E3A0-B584-44FB-A799-9686030DEA1D',
#   '2014-09-12 11:15:07.263'),
#  (11247,
#   5863.0,
#   None,
#   10,
#   'AW00011247',
#   'EA369D9E-FBD4-4456-B181-7E96B46CBA05',
#   '2014-09-12 11:15:07.263'),
#  (11248,
#   12887.0,
#   None,
#   7,
#   'AW00011248',
#   '69BA261E-37B4-478E-A899-22DC6E76B7BF',
#   '2014-09-12 11:15:07.263'),
#  (11249,
#   7289.0,
#   None,
#   8,
#   'AW00011249',
#   '81C88D3A-EF29-4C6E-BF5A-D867DA20BB63',
#   '2014-09-12 11:15:07.263'),
#  (11250,
#   2526.0,
#   None,
#   10,
#   'AW00011250',
#   '679CEC99-B317-41B4-A477-E94DD066C54F',
#   '2014-09-12 11:15:07.263'),
#  (11251,
#   13411.0,
#   None,
#   6,
#   'AW00011251',
#   '31993A75-DFCB-4CB6-B939-90C468DA10F4',
#   '2014-09-12 11:15:07.263'),
#  (11252,
#   19006.0,
#   None,
#   4,
#   'AW00011252',
#   '0EBE6AB2-95C1-4587-9023-3D7C52B8B5B3',
#   '2014-09-12 11:15:07.263'),
#  (11253,
#   17012.0,
#   None,
#   6,
#   'AW00011253',
#   '86885E04-D00B-4FE2-9FEA-61032F921CB0',
#   '2014-09-12 11:15:07.263'),
#  (11254,
#   15887.0,
#   None,
#   1,
#   'AW00011254',
#   'C3C3351B-E8B1-400F-9AB6-63CC18477045',
#   '2014-09-12 11:15:07.263'),
#  (11255,
#   13436.0,
#   None,
#   1,
#   'AW00011255',
#   '6BA322C4-F18D-4FAB-B5EE-D6772D602209',
#   '2014-09-12 11:15:07.263'),
#  (11256,
#   10472.0,
#   None,
#   1,
#   'AW00011256',
#   'ECF7BDAB-67F9-47A6-B509-B1B4576927C2',
#   '2014-09-12 11:15:07.263'),
#  (11257,
#   7742.0,
#   None,
#   4,
#   'AW00011257',
#   'E68004A3-A6FD-4E29-92C4-8C502A8A49C0',
#   '2014-09-12 11:15:07.263'),
#  (11258,
#   4422.0,
#   None,
#   4,
#   'AW00011258',
#   'C0AB086B-0B6E-4131-9AD4-69C356E8168D',
#   '2014-09-12 11:15:07.263'),
#  (11259,
#   19376.0,
#   None,
#   1,
#   'AW00011259',
#   'D8E0667E-6737-4465-A2E5-9BE23D2A075F',
#   '2014-09-12 11:15:07.263'),
#  (11260,
#   7966.0,
#   None,
#   4,
#   'AW00011260',
#   'BF779C56-568C-4493-AA9C-8F8630A7BC95',
#   '2014-09-12 11:15:07.263'),
#  (11261,
#   9398.0,
#   None,
#   4,
#   'AW00011261',
#   '3E0B689E-D35C-4737-A3E4-26799F1A9A40',
#   '2014-09-12 11:15:07.263'),
#  (11262,
#   20532.0,
#   None,
#   6,
#   'AW00011262',
#   '8097738A-04BA-4082-97A0-6A8589EA299E',
#   '2014-09-12 11:15:07.263'),
#  (11263,
#   8473.0,
#   None,
#   1,
#   'AW00011263',
#   '13022941-BBB3-413E-A6AA-23C0E7C7F422',
#   '2014-09-12 11:15:07.263'),
#  (11264,
#   5022.0,
#   None,
#   1,
#   'AW00011264',
#   'CE2DE3B3-AF16-4BBC-9954-4278F85F37A8',
#   '2014-09-12 11:15:07.263'),
#  (11265,
#   11905.0,
#   None,
#   1,
#   'AW00011265',
#   '7716CBA3-2B05-4F89-BC3B-E6191485B610',
#   '2014-09-12 11:15:07.263'),
#  (11266,
#   3560.0,
#   None,
#   1,
#   'AW00011266',
#   '7BC1BF27-7CBF-44B3-81D0-576B9D6BC1A6',
#   '2014-09-12 11:15:07.263'),
#  (11267,
#   6679.0,
#   None,
#   4,
#   'AW00011267',
#   '2DE2E69B-9D13-4C76-A975-268348D29ED6',
#   '2014-09-12 11:15:07.263'),
#  (11268,
#   9972.0,
#   None,
#   4,
#   'AW00011268',
#   'D2F6930A-31B4-42F2-936E-B9FEA5C4453F',
#   '2014-09-12 11:15:07.263'),
#  (11269,
#   6565.0,
#   None,
#   4,
#   'AW00011269',
#   'F6E5E82B-CCFD-4A36-83AA-360B83548198',
#   '2014-09-12 11:15:07.263'),
#  (11270,
#   17332.0,
#   None,
#   4,
#   'AW00011270',
#   '3D74B544-016F-4118-820E-5EDDF09B4481',
#   '2014-09-12 11:15:07.263'),
#  (11271,
#   9120.0,
#   None,
#   4,
#   'AW00011271',
#   '86A9D2F8-40E7-4527-B745-26E8148FFDC0',
#   '2014-09-12 11:15:07.263'),
#  (11272,
#   11652.0,
#   None,
#   4,
#   'AW00011272',
#   '6B8B4CB6-0CBE-499E-BB32-67340B8CABB0',
#   '2014-09-12 11:15:07.263'),
#  (11273,
#   5982.0,
#   None,
#   4,
#   'AW00011273',
#   '08C55E52-D52F-431C-94FE-6E7D304FDBF2',
#   '2014-09-12 11:15:07.263'),
#  (11274,
#   5755.0,
#   None,
#   1,
#   'AW00011274',
#   'CD5AD158-6A65-4332-88ED-CCAA4B05C421',
#   '2014-09-12 11:15:07.263'),
#  (11275,
#   11516.0,
#   None,
#   4,
#   'AW00011275',
#   '20D36C82-5D22-436D-8D51-B89D4CB5FDD0',
#   '2014-09-12 11:15:07.263'),
#  (11276,
#   15449.0,
#   None,
#   6,
#   'AW00011276',
#   '519A2928-57AE-41B7-9D4C-43425654A7E7',
#   '2014-09-12 11:15:07.263'),
#  (11277,
#   4855.0,
#   None,
#   6,
#   'AW00011277',
#   '936BE340-0161-4E2E-A12D-3DB7BFDC0162',
#   '2014-09-12 11:15:07.263'),
#  (11278,
#   16067.0,
#   None,
#   1,
#   'AW00011278',
#   '64DFF02C-CAEA-4008-8F4D-ED2F7A712863',
#   '2014-09-12 11:15:07.263'),
#  (11279,
#   2996.0,
#   None,
#   1,
#   'AW00011279',
#   '724BCFAD-E4E9-443B-8DC4-BAA0D9C7B645',
#   '2014-09-12 11:15:07.263'),
#  (11280,
#   15746.0,
#   None,
#   1,
#   'AW00011280',
#   '67ECDCD1-8AD4-4193-AD4B-6EC4734E79C4',
#   '2014-09-12 11:15:07.263'),
#  (11281,
#   19134.0,
#   None,
#   4,
#   'AW00011281',
#   '6FFE0A23-D1B0-48B4-BB2F-ACD5FA7D5132',
#   '2014-09-12 11:15:07.263'),
#  (11282,
#   18134.0,
#   None,
#   1,
#   'AW00011282',
#   'F2693F9C-63FB-49BC-983C-3EC459FB56E3',
#   '2014-09-12 11:15:07.263'),
#  (11283,
#   10416.0,
#   None,
#   4,
#   'AW00011283',
#   '23867B28-F013-4350-944C-38D711A31B1C',
#   '2014-09-12 11:15:07.263'),
#  (11284,
#   13914.0,
#   None,
#   4,
#   'AW00011284',
#   '464A810F-4BB0-4200-88DB-5608F7540EBA',
#   '2014-09-12 11:15:07.263'),
#  (11285,
#   3992.0,
#   None,
#   4,
#   'AW00011285',
#   'DD403C97-79C0-43FA-9F59-0A5696B01B5A',
#   '2014-09-12 11:15:07.263'),
#  (11286,
#   6067.0,
#   None,
#   4,
#   'AW00011286',
#   'C670AA5A-BCD6-44C0-9CA6-A1BE14811F04',
#   '2014-09-12 11:15:07.263'),
#  (11287,
#   15978.0,
#   None,
#   6,
#   'AW00011287',
#   'CBF89ED8-0D78-46CB-94AB-5AEE93523383',
#   '2014-09-12 11:15:07.263'),
#  (11288,
#   7340.0,
#   None,
#   4,
#   'AW00011288',
#   '22A6D325-97F8-45AA-B7A3-5D88D4CF1FC0',
#   '2014-09-12 11:15:07.263'),
#  (11289,
#   9943.0,
#   None,
#   4,
#   'AW00011289',
#   '9C37A5A9-7AAF-4D9B-818A-E6D372129E50',
#   '2014-09-12 11:15:07.263'),
#  (11290,
#   9500.0,
#   None,
#   4,
#   'AW00011290',
#   'D94D5215-90E0-4EA1-8F23-B0BC1C9E4BB0',
#   '2014-09-12 11:15:07.263'),
#  (11291,
#   10573.0,
#   None,
#   4,
#   'AW00011291',
#   'F67837BB-DA30-4339-BE40-A656789F944E',
#   '2014-09-12 11:15:07.263'),
#  (11292,
#   4363.0,
#   None,
#   4,
#   'AW00011292',
#   '29C13213-E6E4-4F3C-8951-DCDA9BA5782E',
#   '2014-09-12 11:15:07.263'),
#  (11293,
#   5643.0,
#   None,
#   1,
#   'AW00011293',
#   'C3E6F2D8-E54A-406A-95A8-A89DE0B32629',
#   '2014-09-12 11:15:07.263'),
#  (11294,
#   4480.0,
#   None,
#   1,
#   'AW00011294',
#   '236CE15F-4EBB-49EF-9661-CB285A1ED2B6',
#   '2014-09-12 11:15:07.263'),
#  (11295,
#   12166.0,
#   None,
#   4,
#   'AW00011295',
#   '6D95FBA6-9F9D-479A-B393-33879DA918F6',
#   '2014-09-12 11:15:07.263'),
#  (11296,
#   3390.0,
#   None,
#   1,
#   'AW00011296',
#   '2E32F82F-F299-4157-8FCD-25B96EA1A58E',
#   '2014-09-12 11:15:07.263'),
#  (11297,
#   6090.0,
#   None,
#   4,
#   'AW00011297',
#   '5EDE13C8-DF26-4CAE-AAC2-BC42D827406F',
#   '2014-09-12 11:15:07.263'),
#  (11298,
#   13588.0,
#   None,
#   4,
#   'AW00011298',
#   'B90DA729-FCA7-4A07-8BC9-69614F73CE14',
#   '2014-09-12 11:15:07.263'),
#  ...]

# %% [markdown]
# ### Sales.SalesOrderDetail

# %%
#Escolhendo o arquivo dentro do bucket

bucket.blob('Sales.SalesOrderDetail.csv')
# Out:
# <Blob: desafio-rox-leandro, Sales.SalesOrderDetail.csv, None>

# %%
# Criando o df em pandas para enviar para o mysql
# Alterar , pra . em (UnitPrice UnitPriceDiscount)
df_SalesOrderDetail = pd.read_csv(path_SalesOrderDetail,sep=';')

# Alteração das "," por "." nas colunas abaixo
df_SalesOrderDetail["UnitPrice"] = df_SalesOrderDetail["UnitPrice"].replace(",", ".", regex=True)
df_SalesOrderDetail["UnitPriceDiscount"] = df_SalesOrderDetail["UnitPriceDiscount"].replace(",", ".", regex=True)

# Garantindo para OrderQty o tipo INT
df_SalesOrderDetail["OrderQty"] = df_SalesOrderDetail["OrderQty"].apply(int)

# %%
# Codigo repetido em todos os passos, colab dando erro, foi preciso sempre redefinir o conector.
# Conector host:ip_banco, user:usuario, passwd: senha, db:banco criado

con = mysql.connector.connect(host='34.95.218.222',user='desafio-username',passwd='1234',db='bicicletas')
cur = con.cursor()
engine = create_engine('mysql+pymysql://desafio-username:1234@34.95.218.222/bicicletas')

# %%
# Enviando a tabela SalesSalesOrderDetail para o MySql 

dfsql_SalesOrderDetail = df_SalesOrderDetail.to_sql('SalesSalesOrderDetail',con=engine,if_exists='replace',index=False)

# %%
# Verificando o conteúdo enviado

cur.execute('select * from SalesSalesOrderDetail')
cur.fetchall()
# Out:
# [(43659,
#   1,
#   '4911-403C-98',
#   1,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   'B207C96D-D9E6-402B-8470-2CC176C42283',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   2,
#   '4911-403C-98',
#   3,
#   777,
#   1,
#   '2024.994',
#   '0.00',
#   6074.982,
#   '7ABB600D-1E77-41BE-9FE5-B9142CFC08FA',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   3,
#   '4911-403C-98',
#   1,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   '475CF8C6-49F6-486E-B0AD-AFC6A50CDD2F',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   4,
#   '4911-403C-98',
#   1,
#   771,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   '04C4DE91-5815-45D6-8670-F462719FBCE3',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   5,
#   '4911-403C-98',
#   1,
#   772,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   '5A74C7D2-E641-438E-A7AC-37BF23280301',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   6,
#   '4911-403C-98',
#   2,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   4079.988,
#   'CE472532-A4C0-45BA-816E-EEFD3FD848B3',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   7,
#   '4911-403C-98',
#   1,
#   774,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   '80667840-F962-4EE3-96E0-AECA108E0D4F',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   8,
#   '4911-403C-98',
#   3,
#   714,
#   1,
#   '28.8404',
#   '0.00',
#   86.5212,
#   'E9D54907-E7B7-4969-80D9-76BA69F8A836',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   9,
#   '4911-403C-98',
#   1,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   'AA542630-BDCD-4CE5-89A0-C1BF82747725',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   10,
#   '4911-403C-98',
#   6,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   34.2,
#   'AC769034-3C2F-495C-A5A7-3B71CDB25D4E',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   11,
#   '4911-403C-98',
#   2,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   10.373,
#   '06A66921-6B9F-4199-A912-DDAFD383472B',
#   '2011-05-31 00:00:00.000'),
#  (43659,
#   12,
#   '4911-403C-98',
#   4,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   80.746,
#   '0E371EE3-253E-4BB0-B813-83CF4224F972',
#   '2011-05-31 00:00:00.000'),
#  (43660,
#   13,
#   '6431-4D57-83',
#   1,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '419A1302-AC7A-4044-97B2-66D9D14CD02E',
#   '2011-05-31 00:00:00.000'),
#  (43660,
#   14,
#   '6431-4D57-83',
#   1,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '5D0B2B03-1D4C-4C34-9696-C14C58E7301C',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   15,
#   '4E0A-4F89-AE',
#   1,
#   745,
#   1,
#   '809.76',
#   '0.00',
#   809.76,
#   'EDE1759E-6733-4C7B-A43F-DC6F48002D8A',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   16,
#   '4E0A-4F89-AE',
#   1,
#   743,
#   1,
#   '714.7043',
#   '0.00',
#   714.7043,
#   'FE10BF09-D477-485B-9541-27AE8053A6D4',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   17,
#   '4E0A-4F89-AE',
#   2,
#   747,
#   1,
#   '714.7043',
#   '0.00',
#   1429.4086,
#   'B136852E-24C9-4006-8048-B14AEFE6C337',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   18,
#   '4E0A-4F89-AE',
#   4,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   20.746,
#   'F0F410B6-BC93-4D77-B70D-E4E2465D98EE',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   19,
#   '4E0A-4F89-AE',
#   4,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   115.3616,
#   'AE4CDA7D-9B6E-4ABB-A391-E9E9DDB10125',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   20,
#   '4E0A-4F89-AE',
#   2,
#   742,
#   1,
#   '722.5949',
#   '0.00',
#   1445.1898,
#   '054A9D3B-A178-4656-B2B0-9B9BDDF1C345',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   21,
#   '4E0A-4F89-AE',
#   3,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   6074.982,
#   '8C342A15-8576-4581-AAC9-7BA3BBD8FD8B',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   22,
#   '4E0A-4F89-AE',
#   2,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   'B2760B75-3F1A-4DC4-A377-1051C03C8EB8',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   23,
#   '4E0A-4F89-AE',
#   2,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   '935A70B5-33AD-473D-921C-8D2C36F0D93E',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   24,
#   '4E0A-4F89-AE',
#   2,
#   741,
#   1,
#   '818.70',
#   '0.00',
#   1637.4,
#   '2F911593-E3B8-4ADF-B757-7242004FFB8E',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   25,
#   '4E0A-4F89-AE',
#   4,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   8099.976,
#   'E8E15B60-3A73-4507-9368-A4FB27B6EE0B',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   26,
#   '4E0A-4F89-AE',
#   2,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   4079.988,
#   '4373070F-4EBF-4C50-9DB0-96BFBE937383',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   27,
#   '4E0A-4F89-AE',
#   2,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   'D87D5EDB-B899-4E31-B974-06617DBFFE08',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   28,
#   '4E0A-4F89-AE',
#   2,
#   777,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   'C5762004-DE9E-4339-95E5-89CC8FFF873E',
#   '2011-05-31 00:00:00.000'),
#  (43661,
#   29,
#   '4E0A-4F89-AE',
#   5,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   100.9325,
#   '6C0D0601-76FF-441D-86D5-8343EB0063E7',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   30,
#   '2E53-4802-85',
#   3,
#   764,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   '2DFD4D76-E020-4B80-A0A5-6463D0C2DF73',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   31,
#   '2E53-4802-85',
#   5,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   2097.2945,
#   '1F1AA6DC-04A2-48E2-AF9F-E46D8F59AA55',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   32,
#   '2E53-4802-85',
#   2,
#   730,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '5ACE6CB5-7341-4D88-9425-56AB7AE512E7',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   33,
#   '2E53-4802-85',
#   4,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   3499.176,
#   'DFF2A7F2-37F2-4016-BEDF-4DBB8C88B631',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   34,
#   '2E53-4802-85',
#   3,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   551.8146,
#   '92897EE9-72A6-49E6-A421-C243B531AFF2',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   35,
#   '2E53-4802-85',
#   5,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   2097.2945,
#   '1CE18FAA-047D-41B1-8CF6-5191C092AB3C',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   36,
#   '2E53-4802-85',
#   3,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   'F833CB4A-D6E3-40AC-B383-1C4E7220AFEF',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   37,
#   '2E53-4802-85',
#   2,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'D8E84DBD-A1ED-41E4-A9A1-0AD95FB9B323',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   38,
#   '2E53-4802-85',
#   1,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   2146.962,
#   '491C561F-6B1E-47D0-95D5-6519654A5F47',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   39,
#   '2E53-4802-85',
#   1,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '2BA4CC58-B832-47C0-AEF4-D15D029CC083',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   40,
#   '2E53-4802-85',
#   3,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   'D5C51A6A-6D12-4CEB-AED4-842E78BAF142',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   41,
#   '2E53-4802-85',
#   1,
#   732,
#   1,
#   '356.898',
#   '0.00',
#   356.898,
#   '48420C59-4FBD-4817-A1DF-613DCE40B18B',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   42,
#   '2E53-4802-85',
#   6,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   5248.764,
#   '2C4F704D-C794-4613-9C8B-258619FA20FA',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   43,
#   '2E53-4802-85',
#   1,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   'E53F432B-3E71-4F41-9EE8-DB05A18D98F9',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   44,
#   '2E53-4802-85',
#   3,
#   722,
#   1,
#   '178.5808',
#   '0.00',
#   535.7424,
#   '7C495EF0-4E65-4306-A47F-05F004CE5D4C',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   45,
#   '2E53-4802-85',
#   1,
#   749,
#   1,
#   '2146.962',
#   '0.00',
#   2146.962,
#   '0F38E442-512C-4EB4-85C6-27ABFB61E2E2',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   46,
#   '2E53-4802-85',
#   3,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   '260A3FDA-9B77-4C6C-B67B-EFE84ED56489',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   47,
#   '2E53-4802-85',
#   1,
#   726,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   '2F0EA518-F085-4B63-A103-342408F6C8A7',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   48,
#   '2E53-4802-85',
#   1,
#   733,
#   1,
#   '356.898',
#   '0.00',
#   356.898,
#   '7BA3862C-3C4F-4E87-8C47-25B411FA21E6',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   49,
#   '2E53-4802-85',
#   1,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   178.5808,
#   '13404868-367F-4863-8327-6A45036D53F5',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   50,
#   '2E53-4802-85',
#   3,
#   766,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   'C88AEBDE-9041-4A13-A065-A5E95F0AD165',
#   '2011-05-31 00:00:00.000'),
#  (43662,
#   51,
#   '2E53-4802-85',
#   1,
#   755,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '7AC1F435-63EE-4D53-A532-42D7A3A610E5',
#   '2011-05-31 00:00:00.000'),
#  (43663,
#   52,
#   '1E90-4FBF-B6',
#   1,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   'BA432515-892B-445D-B9A7-97F593A24687',
#   '2011-05-31 00:00:00.000'),
#  (43664,
#   53,
#   '2F44-4BA1-BB',
#   1,
#   772,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   '22DB5FA8-8C63-4A68-A038-435EFD6D7EA2',
#   '2011-05-31 00:00:00.000'),
#  (43664,
#   54,
#   '2F44-4BA1-BB',
#   4,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   8099.976,
#   '7CE8E484-A956-42E3-8A8D-F677765D1DAD',
#   '2011-05-31 00:00:00.000'),
#  (43664,
#   55,
#   '2F44-4BA1-BB',
#   1,
#   714,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   '076636AF-A24F-40D7-AEDC-E1564BB16F0E',
#   '2011-05-31 00:00:00.000'),
#  (43664,
#   56,
#   '2F44-4BA1-BB',
#   1,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   'C77B6559-1F2B-4F5F-883B-0D66CF71876D',
#   '2011-05-31 00:00:00.000'),
#  (43664,
#   57,
#   '2F44-4BA1-BB',
#   2,
#   777,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '525334A5-1293-4379-8C59-F3B421FAADBB',
#   '2011-05-31 00:00:00.000'),
#  (43664,
#   58,
#   '2F44-4BA1-BB',
#   3,
#   771,
#   1,
#   '2039.994',
#   '0.00',
#   6119.982,
#   'CD7E2E99-9BD7-4964-8511-303C9228CD77',
#   '2011-05-31 00:00:00.000'),
#  (43664,
#   59,
#   '2F44-4BA1-BB',
#   1,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   '58BFD62D-5822-4C0E-AE02-B35AD7159D6E',
#   '2011-05-31 00:00:00.000'),
#  (43664,
#   60,
#   '2F44-4BA1-BB',
#   1,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   '0A8BDF35-3273-4CE0-9A62-F07118147B9E',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   61,
#   '19F0-4638-8E',
#   2,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   'D74427B2-27E3-4749-B6E0-422FF21D3996',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   62,
#   '19F0-4638-8E',
#   1,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   '10755C28-85C8-4DB1-B733-E2BD718210AE',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   63,
#   '19F0-4638-8E',
#   1,
#   707,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   'E4A00FC2-6EDA-40D7-AFB4-B6B4C5B3EDEE',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   64,
#   '19F0-4638-8E',
#   2,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   '3CFB91F3-98AB-46D1-8024-DE47B3C4DAE2',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   65,
#   '19F0-4638-8E',
#   2,
#   777,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '268C5514-A052-4D7B-A62A-DFB9F3F8DB5E',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   66,
#   '19F0-4638-8E',
#   2,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   10.373,
#   '9342C497-F31C-4E3E-B390-189A7E7F5B0D',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   67,
#   '19F0-4638-8E',
#   2,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '92F2E542-BE52-42E9-94A8-F248BDAA0693',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   68,
#   '19F0-4638-8E',
#   1,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   '7440E859-39E1-4343-9096-C91782D496DC',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   69,
#   '19F0-4638-8E',
#   6,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   34.2,
#   '4A399178-C0A0-447E-9973-6AB903B4AECD',
#   '2011-05-31 00:00:00.000'),
#  (43665,
#   70,
#   '19F0-4638-8E',
#   1,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   '0D2A679C-6C8E-4CC2-8A55-B8DB83937AC2',
#   '2011-05-31 00:00:00.000'),
#  (43666,
#   71,
#   'D46A-40CA-8D',
#   1,
#   764,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '0A256C7D-F7E7-408A-85B5-4E78B5B0B3B9',
#   '2011-05-31 00:00:00.000'),
#  (43666,
#   72,
#   'D46A-40CA-8D',
#   1,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   2146.962,
#   '64220638-532F-41E5-8B4E-B95640F9627E',
#   '2011-05-31 00:00:00.000'),
#  (43666,
#   73,
#   'D46A-40CA-8D',
#   1,
#   732,
#   1,
#   '356.898',
#   '0.00',
#   356.898,
#   'E992A08A-A9FD-4947-8EF2-51AAE82AA60E',
#   '2011-05-31 00:00:00.000'),
#  (43666,
#   74,
#   'D46A-40CA-8D',
#   1,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '2A447589-1D30-4377-9856-1A28D0D6915E',
#   '2011-05-31 00:00:00.000'),
#  (43666,
#   75,
#   'D46A-40CA-8D',
#   2,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'F919E665-34BA-4075-AA2E-E699D697454C',
#   '2011-05-31 00:00:00.000'),
#  (43666,
#   76,
#   'D46A-40CA-8D',
#   1,
#   766,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '92A93F80-9F8A-4448-8038-CA1F50B6E8DD',
#   '2011-05-31 00:00:00.000'),
#  (43667,
#   77,
#   '4DFB-4B10-A6',
#   3,
#   710,
#   1,
#   '5.70',
#   '0.00',
#   17.1,
#   'A3F2749D-522E-41B3-8C1F-FBDE9592D4E0',
#   '2011-05-31 00:00:00.000'),
#  (43667,
#   78,
#   '4DFB-4B10-A6',
#   1,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   '359B0751-12C8-4875-82AA-C8250A1CF9A9',
#   '2011-05-31 00:00:00.000'),
#  (43667,
#   79,
#   '4DFB-4B10-A6',
#   1,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   '14A291B7-6E23-4AFD-AEC3-4F29C007A766',
#   '2011-05-31 00:00:00.000'),
#  (43667,
#   80,
#   '4DFB-4B10-A6',
#   1,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   '151DDEE1-4345-427B-B285-7B0040621DD8',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   81,
#   '365D-4C9A-BE',
#   3,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   2624.382,
#   '10A9A123-E763-4933-917B-0E48D3EC48E5',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   82,
#   '365D-4C9A-BE',
#   2,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   4293.924,
#   'E5037FAC-FB6F-4408-9EDB-8A58875656D2',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   83,
#   '365D-4C9A-BE',
#   7,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   2936.2123,
#   '9597C1CD-E8EE-4605-8080-32D4DBDA3F2C',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   84,
#   '365D-4C9A-BE',
#   6,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   2516.7534,
#   'CC2E1B7E-A197-45B1-8B44-59BF44C42F5E',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   85,
#   '365D-4C9A-BE',
#   6,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   173.0424,
#   'EC1A080E-1ECB-4009-A121-2F276F1140FF',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   86,
#   '365D-4C9A-BE',
#   6,
#   730,
#   1,
#   '183.9382',
#   '0.00',
#   1103.6292,
#   'CC0D5135-F25E-4E2C-9214-E8920C3A546C',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   87,
#   '365D-4C9A-BE',
#   2,
#   707,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   'C0517F7A-8994-470A-BF62-D7D653972F2A',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   88,
#   '365D-4C9A-BE',
#   2,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   'E58D966C-6D4B-4561-BC5B-E33E0EA0A163',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   89,
#   '365D-4C9A-BE',
#   2,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '9BAD45EB-AFEB-43F9-A177-34244054541C',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   90,
#   '365D-4C9A-BE',
#   4,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   20.746,
#   'B5A65D6E-F32D-4CD2-BE44-D3556C6A2414',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   91,
#   '365D-4C9A-BE',
#   2,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '45306430-002A-4DE2-BAD0-2C6C6CBEC132',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   92,
#   '365D-4C9A-BE',
#   3,
#   755,
#   1,
#   '874.794',
#   '0.00',
#   2624.382,
#   '2DAA6E00-061F-4140-8670-9D69814AB376',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   93,
#   '365D-4C9A-BE',
#   3,
#   761,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   'BA19A0FB-B083-4E8F-81B7-2659AE3D78C3',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   94,
#   '365D-4C9A-BE',
#   2,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'A28B50EF-E8FB-47CF-9760-A6294EE742D2',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   95,
#   '365D-4C9A-BE',
#   3,
#   726,
#   1,
#   '183.9382',
#   '0.00',
#   551.8146,
#   '02F2D90D-7996-4720-9236-61281487C037',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   96,
#   '365D-4C9A-BE',
#   2,
#   764,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'FFFB02E3-1B08-44A7-8DC4-1EE6B24253D4',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   97,
#   '365D-4C9A-BE',
#   2,
#   766,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'B21F0EC7-4B3B-43EF-A6F9-DC2F4CA1B71A',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   98,
#   '365D-4C9A-BE',
#   2,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '0AAAD124-8C88-4B30-9533-65399B6390E2',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   99,
#   '365D-4C9A-BE',
#   1,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   '7C20E15E-66C1-45FA-A10F-C495DDB52BF4',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   100,
#   '365D-4C9A-BE',
#   2,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '4F461FAF-5B23-41D9-893C-29217619D968',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   101,
#   '365D-4C9A-BE',
#   4,
#   732,
#   1,
#   '356.898',
#   '0.00',
#   1427.592,
#   '2B30FA74-CD55-431B-85DC-5466E4462075',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   102,
#   '365D-4C9A-BE',
#   6,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   5248.764,
#   '1A0C02EC-9944-4D42-9F4A-E72D5EB74FDF',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   103,
#   '365D-4C9A-BE',
#   4,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   1677.8356,
#   'EE1766A8-7F9C-4ECC-83A9-685A428BD0A4',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   104,
#   '365D-4C9A-BE',
#   3,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   535.7424,
#   '0235B672-1323-482A-B435-D300C37FD7B8',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   105,
#   '365D-4C9A-BE',
#   4,
#   714,
#   1,
#   '28.8404',
#   '0.00',
#   115.3616,
#   'F5F6F45D-091A-43C8-9513-F600354527A1',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   106,
#   '365D-4C9A-BE',
#   3,
#   722,
#   1,
#   '178.5808',
#   '0.00',
#   535.7424,
#   'CA82FE43-5C94-4C25-8587-8E7FF1708FA5',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   107,
#   '365D-4C9A-BE',
#   1,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   'BF5B072F-C7BD-4620-90C8-012A6EF5C55A',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   108,
#   '365D-4C9A-BE',
#   3,
#   733,
#   1,
#   '356.898',
#   '0.00',
#   1070.694,
#   'FC48A9B5-C89F-4A53-A19A-5E74CC439C6A',
#   '2011-05-31 00:00:00.000'),
#  (43668,
#   109,
#   '365D-4C9A-BE',
#   3,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   'B5F560E3-0046-4C92-8432-463C146B81DB',
#   '2011-05-31 00:00:00.000'),
#  (43669,
#   110,
#   'B65C-4867-86',
#   1,
#   747,
#   1,
#   '714.7043',
#   '0.00',
#   714.7043,
#   '3C261D27-41F1-4FF6-B6BC-07E6E32B4988',
#   '2011-05-31 00:00:00.000'),
#  (43670,
#   111,
#   'F101-4649-85',
#   1,
#   710,
#   1,
#   '5.70',
#   '0.00',
#   5.7,
#   '9C7FC079-CBDC-4CE9-B1DD-2411FB25005E',
#   '2011-05-31 00:00:00.000'),
#  (43670,
#   112,
#   'F101-4649-85',
#   2,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   11.4,
#   '174A4AFD-391E-4C67-B99B-20BCFF9FA93D',
#   '2011-05-31 00:00:00.000'),
#  (43670,
#   113,
#   'F101-4649-85',
#   2,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   4079.988,
#   '3907992F-1BB0-4BEF-A8D0-EB6E33A46528',
#   '2011-05-31 00:00:00.000'),
#  (43670,
#   114,
#   'F101-4649-85',
#   1,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   '7E07B269-8004-418E-A426-A38B3526E467',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   115,
#   'DFD9-41B7-94',
#   1,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   2146.962,
#   'A5364026-D1FB-4887-BED0-E233E2316510',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   116,
#   'DFD9-41B7-94',
#   2,
#   714,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   'B2D524C2-0C33-4C04-9836-93D23662D67B',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   117,
#   'DFD9-41B7-94',
#   1,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '676D1168-FA50-4002-B270-C004798CE5D1',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   118,
#   'DFD9-41B7-94',
#   2,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'A3451590-E39E-4295-B4E3-67AEC866B094',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   119,
#   'DFD9-41B7-94',
#   2,
#   732,
#   1,
#   '356.898',
#   '0.00',
#   713.796,
#   'F7B65BE8-FA28-4ED0-A6A0-01B06564CFD6',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   120,
#   'DFD9-41B7-94',
#   2,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '179FEF04-B571-4367-AB1C-3ED7494F3F14',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   121,
#   'DFD9-41B7-94',
#   2,
#   755,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   'FFD63000-E820-4E44-A0CD-1EA625968AFD',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   122,
#   'DFD9-41B7-94',
#   2,
#   764,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '86542670-8958-4CB1-8030-C0C215F2229D',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   123,
#   'DFD9-41B7-94',
#   1,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   '0F4FA390-33F3-4DA0-8843-EF161817EE08',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   124,
#   'DFD9-41B7-94',
#   1,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   '5CC761A2-8346-40C9-8A4E-498696A55D8F',
#   '2011-05-31 00:00:00.000'),
#  (43671,
#   125,
#   'DFD9-41B7-94',
#   1,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   'AE8EDE9E-CA24-40B3-8EBC-CF1AFD8625BD',
#   '2011-05-31 00:00:00.000'),
#  (43672,
#   126,
#   'F4B5-48D0-BA',
#   6,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   34.2,
#   'A05A6B28-3361-4F44-8E68-28A1CDBB002C',
#   '2011-05-31 00:00:00.000'),
#  (43672,
#   127,
#   'F4B5-48D0-BA',
#   2,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '4FCF9FC7-3B29-41D0-8BAC-E022BD06BA93',
#   '2011-05-31 00:00:00.000'),
#  (43672,
#   128,
#   'F4B5-48D0-BA',
#   1,
#   774,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   'CC644E9E-CF75-444A-9FFB-DDBF8C51FBE9',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   129,
#   '260F-4DCF-A1',
#   1,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '01BF67D4-7C0A-46CE-ABBA-BF7B5A1A2839',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   130,
#   '260F-4DCF-A1',
#   3,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   86.5212,
#   '44FDF641-6A4C-48E2-87AE-07ED0A23E8BA',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   131,
#   '260F-4DCF-A1',
#   1,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   '4BDA1E7F-6EDC-486A-8D4D-804BF7BF1A94',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   132,
#   '260F-4DCF-A1',
#   2,
#   761,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '02F37962-1AD2-4C91-9D8D-77804492B1AB',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   133,
#   '260F-4DCF-A1',
#   1,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '01A7CF79-D5ED-4BEB-B64A-415732985A02',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   134,
#   '260F-4DCF-A1',
#   2,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   357.1616,
#   'B8457B55-6D5B-4EBB-BC76-97B0DD1BB06E',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   135,
#   '260F-4DCF-A1',
#   2,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'A0C653CD-2225-48F7-B816-BFAF7E324754',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   136,
#   '260F-4DCF-A1',
#   1,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   5.1865,
#   '9FC18F07-E341-40DF-A970-26752B606309',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   137,
#   '260F-4DCF-A1',
#   2,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   'BE1941FA-F4B9-4791-9FA0-3C48925ECEFD',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   138,
#   '260F-4DCF-A1',
#   1,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   'D7C72328-8839-443F-8508-592598FDD16C',
#   '2011-05-31 00:00:00.000'),
#  (43673,
#   139,
#   '260F-4DCF-A1',
#   4,
#   707,
#   1,
#   '20.1865',
#   '0.00',
#   80.746,
#   'AC5123F3-3719-4802-9A72-D9A90C721E60',
#   '2011-05-31 00:00:00.000'),
#  (43674,
#   140,
#   '4C12-4FF9-80',
#   3,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   2624.382,
#   '6C8CE125-F119-4EC1-BEB4-9691793F2601',
#   '2011-05-31 00:00:00.000'),
#  (43675,
#   141,
#   '5069-4470-BE',
#   4,
#   761,
#   1,
#   '419.4589',
#   '0.00',
#   1677.8356,
#   '850E56A8-EF75-4486-AA0F-94585ECC6BEB',
#   '2011-05-31 00:00:00.000'),
#  (43675,
#   142,
#   '5069-4470-BE',
#   5,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   100.9325,
#   '3F9005F6-3445-4886-8F71-59314FFBA07C',
#   '2011-05-31 00:00:00.000'),
#  (43675,
#   143,
#   '5069-4470-BE',
#   2,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   357.1616,
#   '7BE016FC-8CF7-4C1E-B6FB-EC394CE3C7BD',
#   '2011-05-31 00:00:00.000'),
#  (43675,
#   144,
#   '5069-4470-BE',
#   1,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   'CB747BFE-926F-4B38-8C41-513D06697B76',
#   '2011-05-31 00:00:00.000'),
#  (43675,
#   145,
#   '5069-4470-BE',
#   2,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'A57CED82-D45A-4111-8AB6-6E7E8434F422',
#   '2011-05-31 00:00:00.000'),
#  (43675,
#   146,
#   '5069-4470-BE',
#   2,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   'F7F26129-64F3-44D8-838B-C05CD2072625',
#   '2011-05-31 00:00:00.000'),
#  (43675,
#   147,
#   '5069-4470-BE',
#   2,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   10.373,
#   '848D1513-DA43-403E-A44E-689243AE72E0',
#   '2011-05-31 00:00:00.000'),
#  (43675,
#   148,
#   '5069-4470-BE',
#   1,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   'A674F133-2554-43A8-925D-551A1A077DA9',
#   '2011-05-31 00:00:00.000'),
#  (43675,
#   149,
#   '5069-4470-BE',
#   3,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   86.5212,
#   '08ED740B-4F35-4666-BDF5-40F55A10F75B',
#   '2011-05-31 00:00:00.000'),
#  (43676,
#   150,
#   '11BA-4D19-B7',
#   2,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '95F26303-015E-4965-BA70-08755928F169',
#   '2011-05-31 00:00:00.000'),
#  (43676,
#   151,
#   '11BA-4D19-B7',
#   2,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   'FC88B691-B298-4E79-8DB7-9237C3740899',
#   '2011-05-31 00:00:00.000'),
#  (43676,
#   152,
#   '11BA-4D19-B7',
#   1,
#   710,
#   1,
#   '5.70',
#   '0.00',
#   5.7,
#   'FD6828E3-D826-4A94-AA38-D335F8477C21',
#   '2011-05-31 00:00:00.000'),
#  (43676,
#   153,
#   '11BA-4D19-B7',
#   3,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   6074.982,
#   'C1CA1727-C82A-487C-B045-49A3C86B90AA',
#   '2011-05-31 00:00:00.000'),
#  (43676,
#   154,
#   '11BA-4D19-B7',
#   4,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   22.8,
#   '0B8AF7E6-0A3B-4647-AA80-943059F6323C',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   155,
#   '8E3A-4564-99',
#   3,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   86.5212,
#   '95C0DA8C-02D3-43BC-B1D8-2F4ABA311F4E',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   156,
#   '8E3A-4564-99',
#   1,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   2146.962,
#   '58401596-2F02-49AD-9396-0E3029A85916',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   157,
#   '8E3A-4564-99',
#   1,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   'BA0904A3-12D4-4624-8DB1-175BEF162CDB',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   158,
#   '8E3A-4564-99',
#   1,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   'EDB27438-6A31-4305-B518-025286423736',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   159,
#   '8E3A-4564-99',
#   2,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   'A415FA0D-0ED3-42FB-9748-634D849C225D',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   160,
#   '8E3A-4564-99',
#   4,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   1677.8356,
#   '78E46982-36A1-40E9-9CC9-BDCFC70331CE',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   161,
#   '8E3A-4564-99',
#   2,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '1A09403C-906A-4983-BC06-2F7EA446B979',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   162,
#   '8E3A-4564-99',
#   1,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '8B1F1A3A-F984-4335-BD39-65E4D221109B',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   163,
#   '8E3A-4564-99',
#   5,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   25.9325,
#   'B47395E9-3033-48D6-9915-F7E8831C81A5',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   164,
#   '8E3A-4564-99',
#   1,
#   707,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   'BBD4B811-9A75-4E74-A514-37B5D381A632',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   165,
#   '8E3A-4564-99',
#   1,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '26BA33D4-048C-482A-A88F-22F9416ABF28',
#   '2011-05-31 00:00:00.000'),
#  (43677,
#   166,
#   '8E3A-4564-99',
#   2,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '8A03105C-B8E7-42F6-BB0D-548D63448237',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   167,
#   'FBD8-4CE4-8B',
#   1,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   'DF2C294E-A488-445A-9F6C-E7DAEC39FF2A',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   168,
#   'FBD8-4CE4-8B',
#   2,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   357.1616,
#   '4BD4DAD2-921F-4948-9732-B052B0296AA6',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   169,
#   'FBD8-4CE4-8B',
#   1,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   'FF26342B-D08E-4597-B38A-8BAD5E6FD8F4',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   170,
#   'FBD8-4CE4-8B',
#   2,
#   732,
#   1,
#   '356.898',
#   '0.00',
#   713.796,
#   '3F3663AD-9896-4F7C-A894-66B88A814FB8',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   171,
#   'FBD8-4CE4-8B',
#   3,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   'EB3B01CF-3994-47F6-9CC6-1C1E5A108713',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   172,
#   'FBD8-4CE4-8B',
#   2,
#   761,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '0CF44A8C-4FD3-42E5-8A33-5C0F277E6F3D',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   173,
#   'FBD8-4CE4-8B',
#   3,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   15.5595,
#   '83D229DC-F929-4EDE-A995-18BC2EE28837',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   174,
#   'FBD8-4CE4-8B',
#   4,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   80.746,
#   '82E7AEA7-B1D2-41FE-9D9F-C58317880C0B',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   175,
#   'FBD8-4CE4-8B',
#   2,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '271F7B7F-5CDE-4A2B-A08A-9A9D19FA9B2C',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   176,
#   'FBD8-4CE4-8B',
#   1,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '19E8E894-FCAD-4957-9105-B507986835EB',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   177,
#   'FBD8-4CE4-8B',
#   2,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '177FAA4C-3945-4C64-AD0F-7482F58B1334',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   178,
#   'FBD8-4CE4-8B',
#   1,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   '5C5CBE97-AD6F-49AA-A13C-81E9D8BCED1D',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   179,
#   'FBD8-4CE4-8B',
#   1,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '5DE88B13-970C-4952-A220-430E1F3D698F',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   180,
#   'FBD8-4CE4-8B',
#   2,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   'FCFE9BD3-775E-4BE8-8819-376247A7AA81',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   181,
#   'FBD8-4CE4-8B',
#   2,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   'AE21D8B7-DA24-4CFE-ABD8-0F958F55C21B',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   182,
#   'FBD8-4CE4-8B',
#   1,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '3305D8DB-86D4-4903-8F1A-9FCB0400EDBB',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   183,
#   'FBD8-4CE4-8B',
#   1,
#   755,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   'C317C204-0B62-473E-B22F-F6D4CAE92A5F',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   184,
#   'FBD8-4CE4-8B',
#   3,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   60.5595,
#   '9D04AB4C-D575-433E-93AC-86710B01C1C6',
#   '2011-05-31 00:00:00.000'),
#  (43678,
#   185,
#   'FBD8-4CE4-8B',
#   1,
#   707,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   'BF77C9DC-B87B-4D59-9254-90F253565B94',
#   '2011-05-31 00:00:00.000'),
#  (43679,
#   186,
#   '918F-49F3-AD',
#   1,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '6E15E57E-BDFB-449B-B9C7-1098BA1847D2',
#   '2011-05-31 00:00:00.000'),
#  (43679,
#   187,
#   '918F-49F3-AD',
#   2,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'BA6CF32E-516E-4DD0-AF76-3BEB187E00E0',
#   '2011-05-31 00:00:00.000'),
#  (43679,
#   188,
#   '918F-49F3-AD',
#   2,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   'E8CC5A8B-64EA-4960-89DA-B0311FCCF466',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   189,
#   'FF1F-4DD0-98',
#   3,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   'FF64F75F-6155-481F-90AE-E0A58951730A',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   190,
#   'FF1F-4DD0-98',
#   2,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '588F4BD2-503E-4C5E-A238-A4FBC0EB5721',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   191,
#   'FF1F-4DD0-98',
#   2,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   357.1616,
#   '52C07533-50A5-4990-8C60-DFEA1247E077',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   192,
#   'FF1F-4DD0-98',
#   4,
#   707,
#   1,
#   '20.1865',
#   '0.00',
#   80.746,
#   '96203912-D86B-4C18-A998-AAB68CE5043A',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   193,
#   'FF1F-4DD0-98',
#   1,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   '7D35E4CD-3E70-41C4-9424-2040650FBFA3',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   194,
#   'FF1F-4DD0-98',
#   1,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   '755EF279-905D-4E8B-BB4C-D07DD94375AC',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   195,
#   'FF1F-4DD0-98',
#   2,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   '53A1485E-F5ED-4F00-BDB5-D78DC1BE5979',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   196,
#   'FF1F-4DD0-98',
#   2,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   'CB1EAC62-9AF1-48A2-99C8-793EC80655E7',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   197,
#   'FF1F-4DD0-98',
#   1,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   'FCFEE92F-52FB-44B9-94CD-7521BB9B7602',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   198,
#   'FF1F-4DD0-98',
#   1,
#   761,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   'E02E4BF2-6F80-49A6-98E9-D7EF636BF41D',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   199,
#   'FF1F-4DD0-98',
#   2,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   4293.924,
#   '92C650A7-CA27-4772-8D98-0118E041CDC8',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   200,
#   'FF1F-4DD0-98',
#   2,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   '52FE0899-B483-4785-9E6C-A53C30D44308',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   201,
#   'FF1F-4DD0-98',
#   3,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   'A26F7EDB-1DC8-4C90-9DEC-CC8525B03698',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   202,
#   'FF1F-4DD0-98',
#   3,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   15.5595,
#   '8528BE39-BFF3-434E-881B-785401BC4A2E',
#   '2011-05-31 00:00:00.000'),
#  (43680,
#   203,
#   'FF1F-4DD0-98',
#   1,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '98629492-E799-4B02-9197-A67BB63213D7',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   204,
#   '6D51-449D-B3',
#   6,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   173.0424,
#   'CE38C822-BC86-4B0F-9870-AA084354634E',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   205,
#   '6D51-449D-B3',
#   5,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   2097.2945,
#   'F16DFE80-78E8-4398-9C84-E31915EE382C',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   206,
#   '6D51-449D-B3',
#   1,
#   732,
#   1,
#   '356.898',
#   '0.00',
#   356.898,
#   '73DFB8C4-49D4-45F2-A630-D6C561818D8D',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   207,
#   '6D51-449D-B3',
#   1,
#   707,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   '2FA998EA-1100-4E10-9206-7788E28B3E19',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   208,
#   '6D51-449D-B3',
#   1,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   '4C46A2F0-3039-40BF-8703-C390F0C36730',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   209,
#   '6D51-449D-B3',
#   2,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   '0F5A66B3-82DD-4FB4-BAD1-523C66B5F395',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   210,
#   '6D51-449D-B3',
#   3,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   '0610EBC9-F8A2-455D-91DC-C3D7EA30A15D',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   211,
#   '6D51-449D-B3',
#   2,
#   730,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   'D594026B-43A6-4904-8FB3-642196EC1A1A',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   212,
#   '6D51-449D-B3',
#   3,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   2624.382,
#   'E09BDAA5-B643-4E8D-8C2A-28FD1CB8DF9D',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   213,
#   '6D51-449D-B3',
#   1,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   'DB1CC906-C552-4830-BD2D-04F5736860C9',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   214,
#   '6D51-449D-B3',
#   2,
#   761,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'D7650FF3-61C0-457B-9EE3-E294F0115B67',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   215,
#   '6D51-449D-B3',
#   2,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   357.1616,
#   '947FD975-6080-4114-A1D4-FBA59042770E',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   216,
#   '6D51-449D-B3',
#   1,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   2146.962,
#   '8B3B06AD-03C8-4768-966B-B57409FF8728',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   217,
#   '6D51-449D-B3',
#   2,
#   714,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   'C5C5F68F-27CA-476A-B7EB-3219359119C0',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   218,
#   '6D51-449D-B3',
#   2,
#   764,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '2D9B98B0-7B7A-4A09-86A4-7221B6A26035',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   219,
#   '6D51-449D-B3',
#   2,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '7CB7AAE5-2225-4ABE-B968-E9859A8F7D19',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   220,
#   '6D51-449D-B3',
#   1,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '23807036-8978-4372-95E7-FC58E00B7D42',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   221,
#   '6D51-449D-B3',
#   2,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   'B321C72F-8374-48F2-B640-844D13D181D6',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   222,
#   '6D51-449D-B3',
#   2,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   'DCF47F5B-B191-4CD8-BF03-0241E0100333',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   223,
#   '6D51-449D-B3',
#   1,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   '71CAC584-7515-44F0-84AD-FE088A2DB851',
#   '2011-05-31 00:00:00.000'),
#  (43681,
#   224,
#   '6D51-449D-B3',
#   2,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   10.373,
#   'F4809618-0C2E-40E9-A14D-27710628FF0E',
#   '2011-05-31 00:00:00.000'),
#  (43682,
#   225,
#   'ECD4-43A8-A8',
#   2,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '4526787E-4DF0-49B5-8226-E934DFBF8E3E',
#   '2011-05-31 00:00:00.000'),
#  (43682,
#   226,
#   'ECD4-43A8-A8',
#   1,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '3BA9B6E0-F663-4751-8C0D-8B98775B13BE',
#   '2011-05-31 00:00:00.000'),
#  (43682,
#   227,
#   'ECD4-43A8-A8',
#   2,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'BD2AA9FA-894A-4533-9A6D-19D37DDD9EC1',
#   '2011-05-31 00:00:00.000'),
#  (43682,
#   228,
#   'ECD4-43A8-A8',
#   2,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'EC3F3939-8EF8-4F77-9882-0605D95F5A4A',
#   '2011-05-31 00:00:00.000'),
#  (43682,
#   229,
#   'ECD4-43A8-A8',
#   1,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   'ADD336C0-7322-40EC-B4E2-527F9ABF37CC',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   230,
#   '2299-44F7-95',
#   2,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '02170C53-A0B1-407A-A4E9-B1B56990CBD1',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   231,
#   '2299-44F7-95',
#   2,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   '9B0E81D0-A201-4978-9FDF-B1E0B06A2D74',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   232,
#   '2299-44F7-95',
#   2,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   4079.988,
#   '379224D7-9625-4D4B-9166-F6A432CEF432',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   233,
#   '2299-44F7-95',
#   1,
#   774,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   '21CFE6F5-C590-4D50-9A48-EEC6DD8726FD',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   234,
#   '2299-44F7-95',
#   1,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   '77959BA9-FE57-42FB-AF0C-B6E75ECEA04C',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   235,
#   '2299-44F7-95',
#   2,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   '890D5E35-90F5-4234-8070-854D56899685',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   236,
#   '2299-44F7-95',
#   3,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   15.5595,
#   '8FE0A019-6E0D-4E48-BD48-B63E7E6B8C13',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   237,
#   '2299-44F7-95',
#   4,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   8099.976,
#   'F95D4E30-97D7-450A-8750-24FB78FFBACB',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   238,
#   '2299-44F7-95',
#   6,
#   777,
#   1,
#   '2024.994',
#   '0.00',
#   12149.964,
#   '3632DE7C-C76A-402B-9AD2-4CA9685842BF',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   239,
#   '2299-44F7-95',
#   1,
#   772,
#   1,
#   '2039.994',
#   '0.00',
#   2039.994,
#   'B16340FD-66FF-42C6-900C-FB4C9DEFAA39',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   240,
#   '2299-44F7-95',
#   3,
#   707,
#   1,
#   '20.1865',
#   '0.00',
#   60.5595,
#   'B2F1A4E4-B716-4DAE-AD20-9AF4CCB5DBFC',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   241,
#   '2299-44F7-95',
#   5,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   10124.97,
#   'E1F53539-9024-4F7C-93D0-C51158C9FAF4',
#   '2011-05-31 00:00:00.000'),
#  (43683,
#   242,
#   '2299-44F7-95',
#   6,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   34.2,
#   '3DCFFF8A-E551-40BF-8340-61781B7B5056',
#   '2011-05-31 00:00:00.000'),
#  (43684,
#   243,
#   '8C01-4CC0-A9',
#   2,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '153452D3-A12C-42A1-ACEA-BDC505E72834',
#   '2011-05-31 00:00:00.000'),
#  (43684,
#   244,
#   '8C01-4CC0-A9',
#   2,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'A197324F-82E2-45DA-8B93-1921298EEDD3',
#   '2011-05-31 00:00:00.000'),
#  (43684,
#   245,
#   '8C01-4CC0-A9',
#   1,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   'CD816453-14C6-4454-B1A1-038187607C61',
#   '2011-05-31 00:00:00.000'),
#  (43684,
#   246,
#   '8C01-4CC0-A9',
#   2,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '945B49C3-32BF-43E0-8496-67114F2C249B',
#   '2011-05-31 00:00:00.000'),
#  (43684,
#   247,
#   '8C01-4CC0-A9',
#   1,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   'F3873B0B-89A5-42AA-BD30-DA8B37FEF9BF',
#   '2011-05-31 00:00:00.000'),
#  (43684,
#   248,
#   '8C01-4CC0-A9',
#   1,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '80C2A11C-E805-4FB7-BEDA-F98C38C345FB',
#   '2011-05-31 00:00:00.000'),
#  (43685,
#   249,
#   'C519-4AB3-88',
#   3,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   '2946C9A9-89F3-4F55-A670-61B13D87B697',
#   '2011-05-31 00:00:00.000'),
#  (43685,
#   250,
#   'C519-4AB3-88',
#   1,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   'F61D4584-4333-4AE4-A9C7-6E93137172D8',
#   '2011-05-31 00:00:00.000'),
#  (43685,
#   251,
#   'C519-4AB3-88',
#   1,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '837D6ECF-6AB8-4434-B60B-A65883163CE2',
#   '2011-05-31 00:00:00.000'),
#  (43685,
#   252,
#   'C519-4AB3-88',
#   1,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   'DCC24246-D5F9-488E-8FFE-AC972370FDB0',
#   '2011-05-31 00:00:00.000'),
#  (43686,
#   253,
#   'FBD0-4F71-80',
#   3,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   2624.382,
#   '0D79BB65-7081-4471-8BEA-AD0DD9ED3925',
#   '2011-05-31 00:00:00.000'),
#  (43686,
#   254,
#   'FBD0-4F71-80',
#   1,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '0CFF97F0-04D0-48B0-90DC-2DF5246634E7',
#   '2011-05-31 00:00:00.000'),
#  (43686,
#   255,
#   'FBD0-4F71-80',
#   1,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '9DF36F69-AB08-44BD-90FC-B67932AC5CD4',
#   '2011-05-31 00:00:00.000'),
#  (43687,
#   256,
#   '61FA-475A-AC',
#   1,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '9BFB4B65-3927-4084-BA66-2678173A69D0',
#   '2011-05-31 00:00:00.000'),
#  (43687,
#   257,
#   '61FA-475A-AC',
#   2,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '76A9DBCD-EA04-4FFE-8C76-063DAE743030',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   258,
#   '16F4-456B-9A',
#   1,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   '5A53AD2C-ECAF-459C-A0A4-1E6A634F59D1',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   259,
#   '16F4-456B-9A',
#   2,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'B4DC295C-356B-480B-8D3D-64E3975453FB',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   260,
#   '16F4-456B-9A',
#   3,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   '9640A93B-CFCB-4863-998A-7CB1B4295A6E',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   261,
#   '16F4-456B-9A',
#   1,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   178.5808,
#   'BBE02A8C-8A1B-4572-8C31-AC170A4010BD',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   262,
#   '16F4-456B-9A',
#   1,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '002349C7-A7C2-409B-826B-025F1188FC46',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   263,
#   '16F4-456B-9A',
#   2,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '8AD575A8-569B-4970-948E-951A576DC6FA',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   264,
#   '16F4-456B-9A',
#   2,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '16CA43FD-45D5-471F-847E-8963119365A6',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   265,
#   '16F4-456B-9A',
#   2,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '19AEB036-E1AE-4476-B744-63B6BD6722B3',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   266,
#   '16F4-456B-9A',
#   3,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   'FB21C6AF-13BE-4E14-9875-9D133D93CC6E',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   267,
#   '16F4-456B-9A',
#   1,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '2BBFAF0F-3909-402A-9705-1A3A681C8B31',
#   '2011-05-31 00:00:00.000'),
#  (43688,
#   268,
#   '16F4-456B-9A',
#   2,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   4293.924,
#   'E8446110-DC59-4187-A035-61E2EA8FC8B7',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   269,
#   'DCD9-4C9A-AB',
#   3,
#   764,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   '4B1E8BCD-9641-47E4-98BE-A1B9A266634E',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   270,
#   'DCD9-4C9A-AB',
#   2,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   357.1616,
#   '68BAF0D6-613B-4B3F-B6BF-A06E81E073B6',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   271,
#   'DCD9-4C9A-AB',
#   2,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '7D867B31-8D89-4BD7-93DC-45A4EC2CEDD6',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   272,
#   'DCD9-4C9A-AB',
#   1,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   2146.962,
#   '90322BB0-B079-4EC3-8750-59B738ACA61C',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   273,
#   'DCD9-4C9A-AB',
#   2,
#   755,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '361C2494-2279-4EBB-A4C4-B2CF896B6FBB',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   274,
#   'DCD9-4C9A-AB',
#   4,
#   766,
#   1,
#   '419.4589',
#   '0.00',
#   1677.8356,
#   '08311371-C59B-4134-82B4-6BCF06596338',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   275,
#   'DCD9-4C9A-AB',
#   2,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '451BD27E-A78F-4C86-B9DC-E64486149112',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   276,
#   'DCD9-4C9A-AB',
#   7,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   2936.2123,
#   '6C1C717D-3403-4E6D-9837-6BE9DC297A2B',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   277,
#   'DCD9-4C9A-AB',
#   3,
#   726,
#   1,
#   '183.9382',
#   '0.00',
#   551.8146,
#   '90D5F355-0A74-4604-93FA-47C8B423EF8D',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   278,
#   'DCD9-4C9A-AB',
#   1,
#   722,
#   1,
#   '178.5808',
#   '0.00',
#   178.5808,
#   '077D4739-C39C-4A1E-B63B-4945C0EC6F09',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   279,
#   'DCD9-4C9A-AB',
#   6,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   2516.7534,
#   '6B5A7A73-1F63-4472-A337-123D6BDAB01F',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   280,
#   'DCD9-4C9A-AB',
#   2,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '45CD69D3-D62B-4626-9310-BB4D6FF2FD7B',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   281,
#   'DCD9-4C9A-AB',
#   2,
#   730,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   'CED8561D-AA4A-43A3-95A9-BB2A55CFD90B',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   282,
#   'DCD9-4C9A-AB',
#   2,
#   732,
#   1,
#   '356.898',
#   '0.00',
#   713.796,
#   '6FA9CEAF-93DD-44A9-95EA-E68289F47DE4',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   283,
#   'DCD9-4C9A-AB',
#   5,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   2097.2945,
#   '5FC81194-BB39-4C96-804B-F75E4BE473C1',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   284,
#   'DCD9-4C9A-AB',
#   2,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '3E8DCC96-71BE-46F9-AAE3-912A42D0B63B',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   285,
#   'DCD9-4C9A-AB',
#   2,
#   761,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '936B0F07-6837-4B6C-BFD5-2AD9F91C3434',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   286,
#   'DCD9-4C9A-AB',
#   3,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   2624.382,
#   '6461DBEF-2B8C-4FB8-B0CA-EDC53170316C',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   287,
#   'DCD9-4C9A-AB',
#   2,
#   749,
#   1,
#   '2146.962',
#   '0.00',
#   4293.924,
#   '9E4B5E64-7639-43A5-A19C-13FA05FD3055',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   288,
#   'DCD9-4C9A-AB',
#   9,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   3775.1301,
#   'C89D62CD-C0E7-456F-80A8-558DB3AFCDBF',
#   '2011-05-31 00:00:00.000'),
#  (43689,
#   289,
#   'DCD9-4C9A-AB',
#   4,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   3499.176,
#   '43BB07F0-EDAB-4898-A540-529F997E87C7',
#   '2011-05-31 00:00:00.000'),
#  (43690,
#   290,
#   '7A3C-492F-A6',
#   1,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   '273489BD-C0CC-4251-BBB8-D876C42BEC4A',
#   '2011-05-31 00:00:00.000'),
#  (43690,
#   291,
#   '7A3C-492F-A6',
#   1,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '142067AE-8763-4522-98A9-37C4E13292C1',
#   '2011-05-31 00:00:00.000'),
#  (43690,
#   292,
#   '7A3C-492F-A6',
#   2,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   10.373,
#   'C6489D7D-8519-4010-B434-2EC4310448C8',
#   '2011-05-31 00:00:00.000'),
#  (43690,
#   293,
#   '7A3C-492F-A6',
#   2,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '320043E9-26BF-4982-AB6B-DFD40105B0DD',
#   '2011-05-31 00:00:00.000'),
#  (43691,
#   294,
#   '272B-4319-9E',
#   1,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   '4B7B432F-5D7B-4285-B618-DBF52B10ED73',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   295,
#   'BFA9-470E-B4',
#   5,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   2097.2945,
#   '1BFF841D-7D9E-498B-9E35-50E52AB801A6',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   296,
#   'BFA9-470E-B4',
#   1,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   'B346513E-5B71-41B5-A1CF-2DE2C9351F69',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   297,
#   'BFA9-470E-B4',
#   8,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   6998.352,
#   '85DCB501-7194-49C8-B10B-4BA09456463A',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   298,
#   'BFA9-470E-B4',
#   2,
#   730,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '045AFCD8-39FC-48A9-8290-510AD5C84924',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   299,
#   'BFA9-470E-B4',
#   10,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   288.404,
#   '3FF25D6C-58B0-4FED-A0A3-CB41C5C4DE2E',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   300,
#   'BFA9-470E-B4',
#   1,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '1754AA5D-66F9-4F62-828E-154652D92DF8',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   301,
#   'BFA9-470E-B4',
#   4,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   3499.176,
#   'EEE637E9-9957-4842-BCED-B05081212F01',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   302,
#   'BFA9-470E-B4',
#   2,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   357.1616,
#   'D3E60969-4860-4F84-B207-F922DFFA980E',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   303,
#   'BFA9-470E-B4',
#   8,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   6998.352,
#   'EB7ED641-2CA4-46F7-B82E-8C915EC3E1A2',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   304,
#   'BFA9-470E-B4',
#   3,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   60.5595,
#   'ECB93758-1D9D-471F-B51F-0E73FA6B9CA4',
#   '2011-05-31 00:00:00.000'),
#  (43692,
#   305,
#   'BFA9-470E-B4',
#   6,
#   762,
#   1,
# ...
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   900,
#   '728A-44AB-A8',
#   3,
#   747,
#   1,
#   '714.7043',
#   '0.00',
#   2144.1129,
#   'AD584CE1-1F7D-4C66-B057-B5AA413D7D6D',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   901,
#   '728A-44AB-A8',
#   4,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   80.746,
#   '5C4472E5-49EC-49E9-946F-A84F9BB921F5',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   902,
#   '728A-44AB-A8',
#   3,
#   745,
#   1,
#   '809.76',
#   '0.00',
#   2429.28,
#   '8D7E853F-784C-4D4B-B983-5265CAEBB9EB',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   903,
#   '728A-44AB-A8',
#   10,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   288.404,
#   '131B6DB0-3553-451E-BD82-BB1F4394BE4A',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   904,
#   '728A-44AB-A8',
#   10,
#   777,
#   1,
#   '2024.994',
#   '0.00',
#   20249.94,
#   'D6D6F69E-7122-47FE-BD25-E3E53DA75032',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   905,
#   '728A-44AB-A8',
#   5,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   10124.97,
#   '3BE7EB62-A5AC-4384-9C6A-D70E6674337F',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   906,
#   '728A-44AB-A8',
#   5,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   10199.97,
#   '1CA3EFBE-B555-46DA-A7D2-7A69B8C72417',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   907,
#   '728A-44AB-A8',
#   3,
#   741,
#   1,
#   '818.70',
#   '0.00',
#   2456.1,
#   'B305A21F-192A-4154-BF01-49B4783497E5',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   908,
#   '728A-44AB-A8',
#   5,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   100.9325,
#   '314ABC36-AC9F-488D-B18C-B89BA6462BE1',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   909,
#   '728A-44AB-A8',
#   4,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   8099.976,
#   '4E6DEC25-BF0B-4AAB-B944-4ED95A5F0130',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   910,
#   '728A-44AB-A8',
#   6,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   173.0424,
#   'E57E5B67-FF6C-47B6-BEF5-ADE5B8455A05',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   911,
#   '728A-44AB-A8',
#   1,
#   748,
#   1,
#   '722.5949',
#   '0.00',
#   722.5949,
#   '89291035-CF7E-45CA-B116-946CA3D95F8B',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   912,
#   '728A-44AB-A8',
#   8,
#   771,
#   1,
#   '2039.994',
#   '0.00',
#   16319.952,
#   '57BB9BAD-DCAA-4C34-BD9C-21E87B9CF3B2',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   913,
#   '728A-44AB-A8',
#   8,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   41.492,
#   '93519861-2D70-4A5A-8763-EAD42F7FE2E5',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   914,
#   '728A-44AB-A8',
#   2,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '7A5B8DA7-6E50-4C3E-8802-C591DE4484D9',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   915,
#   '728A-44AB-A8',
#   3,
#   743,
#   1,
#   '714.7043',
#   '0.00',
#   2144.1129,
#   '6FDA678A-C9C2-49FD-AD89-7F1AD66DCBB6',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   916,
#   '728A-44AB-A8',
#   14,
#   772,
#   2,
#   '1971.9942',
#   '0.02',
#   27055.760424,
#   '24FE52FF-E828-4A45-ACC5-8CC77BFB9664',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   917,
#   '728A-44AB-A8',
#   4,
#   707,
#   1,
#   '20.1865',
#   '0.00',
#   80.746,
#   'A5B16E60-3371-426A-B624-5DB19723786F',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   918,
#   '728A-44AB-A8',
#   4,
#   774,
#   1,
#   '2039.994',
#   '0.00',
#   8159.976,
#   '3BE31A38-A3ED-4B01-8024-846F4CEC9E62',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   919,
#   '728A-44AB-A8',
#   4,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   22.8,
#   'AA5028C1-CB78-4BDC-9172-617A30C58DB2',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   920,
#   '728A-44AB-A8',
#   1,
#   742,
#   1,
#   '722.5949',
#   '0.00',
#   722.5949,
#   '4050BF26-9F22-4641-91F6-82A61EE7B881',
#   '2011-07-01 00:00:00.000'),
#  (43884,
#   921,
#   '728A-44AB-A8',
#   1,
#   714,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   'F16243EE-EDBD-429D-A099-03533A166048',
#   '2011-07-01 00:00:00.000'),
#  (43885,
#   922,
#   '190F-4A02-89',
#   4,
#   710,
#   1,
#   '5.70',
#   '0.00',
#   22.8,
#   '36FE9F79-0068-4F69-8400-718DFF268217',
#   '2011-07-01 00:00:00.000'),
#  (43885,
#   923,
#   '190F-4A02-89',
#   8,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   45.6,
#   'E720D898-FB33-486F-B05C-D68E844A76AB',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   924,
#   'CE58-49B5-82',
#   2,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '7F7361C0-722B-4EF3-8568-9F9FAFC411D4',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   925,
#   'CE58-49B5-82',
#   1,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '5EA2FAC1-C5D1-40C7-8B71-970A2103006B',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   926,
#   'CE58-49B5-82',
#   2,
#   726,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   '37B0D5B2-CCD7-4AD7-AD38-430D173CEC7C',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   927,
#   'CE58-49B5-82',
#   1,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '333FCF52-AABF-48A7-81F9-3A8BE4247F95',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   928,
#   'CE58-49B5-82',
#   2,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '014FB247-77A6-4699-BE8E-471001262A9D',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   929,
#   'CE58-49B5-82',
#   3,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   60.5595,
#   '3C9CA4AA-0DD3-45AC-B915-1437E57B29BA',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   930,
#   'CE58-49B5-82',
#   6,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   31.119,
#   '4F5F9CCF-AD17-48E7-9CC4-6B9D1DBA8A9D',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   931,
#   'CE58-49B5-82',
#   1,
#   708,
#   1,
#   '20.1865',
#   '0.00',
#   20.1865,
#   'E9140CAB-977D-4290-9E6D-F0CDE9B8C84D',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   932,
#   'CE58-49B5-82',
#   2,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   '1611AC48-23F3-45AC-BF20-6361EE2AC8F7',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   933,
#   'CE58-49B5-82',
#   2,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '7392704E-65FE-493B-86FA-29F39A0E88A0',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   934,
#   'CE58-49B5-82',
#   5,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   2097.2945,
#   'E9B05B9F-B914-4226-B921-E7E8DFC2A8F3',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   935,
#   'CE58-49B5-82',
#   1,
#   733,
#   1,
#   '356.898',
#   '0.00',
#   356.898,
#   '5DD7666B-2DDE-4CEA-8862-79F3F7A54C34',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   936,
#   'CE58-49B5-82',
#   1,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   28.8404,
#   'FAEB4F6A-BDC3-48C2-9EA8-AD564C343D74',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   937,
#   'CE58-49B5-82',
#   1,
#   730,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   '6537CA48-777B-4B11-B863-06FA9443F967',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   938,
#   'CE58-49B5-82',
#   1,
#   755,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   'E68007A2-BB8B-4575-AADC-72E0F0A382C8',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   939,
#   'CE58-49B5-82',
#   1,
#   722,
#   1,
#   '178.5808',
#   '0.00',
#   178.5808,
#   '4A95CE07-BD63-4C5B-92C1-D1BAC4A5BE75',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   940,
#   'CE58-49B5-82',
#   5,
#   714,
#   1,
#   '28.8404',
#   '0.00',
#   144.202,
#   '81EC3A52-9772-49C5-91FD-3A42E85C0BE7',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   941,
#   'CE58-49B5-82',
#   1,
#   766,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '680FAEAE-7C2D-4780-B82F-ED347EE23A30',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   942,
#   'CE58-49B5-82',
#   3,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   '94AAA150-D2F5-4747-B06F-1A38A6A02944',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   943,
#   'CE58-49B5-82',
#   2,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   4293.924,
#   '24FB9DB7-801A-463F-AF8F-0AC0820389EE',
#   '2011-07-01 00:00:00.000'),
#  (43886,
#   944,
#   'CE58-49B5-82',
#   4,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   115.3616,
#   'F72FCA82-7C84-4EEC-B017-B9DBF033079F',
#   '2011-07-01 00:00:00.000'),
#  (43887,
#   945,
#   '790D-448C-AA',
#   1,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '3ECF5123-D0EE-4896-BE2F-8FC7FE20398B',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   946,
#   '7AED-4154-93',
#   1,
#   764,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '9773770B-3427-4448-B249-E87414BC7B7B',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   947,
#   '7AED-4154-93',
#   1,
#   755,
#   1,
#   '874.794',
#   '0.00',
#   874.794,
#   'AB0CE62C-AB96-48AF-9E43-E11F4A734728',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   948,
#   '7AED-4154-93',
#   2,
#   738,
#   1,
#   '178.5808',
#   '0.00',
#   357.1616,
#   'EFFCAD19-1DD8-4425-BBFF-45C1665D8B9A',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   949,
#   '7AED-4154-93',
#   1,
#   725,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   'F4C379EA-95D6-4A2E-86E3-2ADB57C7ADBF',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   950,
#   '7AED-4154-93',
#   1,
#   768,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '6C63F914-9F1B-44F4-8741-7E3645B7D7CC',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   951,
#   '7AED-4154-93',
#   2,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '6828F9BA-AF1B-45E3-900B-BEEFA7A2E958',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   952,
#   '7AED-4154-93',
#   1,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   2146.962,
#   'CEAFD4AB-9DF2-4F9C-9C68-A203D587116B',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   953,
#   '7AED-4154-93',
#   2,
#   756,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   'BCA7A200-D64B-489C-939D-BE5513ECBC73',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   954,
#   '7AED-4154-93',
#   5,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   4373.97,
#   '61C158CF-964F-4906-B959-C9D4CFBE67F0',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   955,
#   '7AED-4154-93',
#   2,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '9F44B88B-6F81-4577-91EE-0D11B1E86C96',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   956,
#   '7AED-4154-93',
#   2,
#   730,
#   1,
#   '183.9382',
#   '0.00',
#   367.8764,
#   'ADC8A51F-84DD-4EFA-8C61-73EAF87705B3',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   957,
#   '7AED-4154-93',
#   2,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'D5F67E56-D70C-4BDB-843F-FC6037DDEFAE',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   958,
#   '7AED-4154-93',
#   2,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   'E342224A-C8EA-49E6-8736-4D1FA176462B',
#   '2011-07-01 00:00:00.000'),
#  (43888,
#   959,
#   '7AED-4154-93',
#   1,
#   726,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   '68CBC470-E21F-4AAE-AE00-0247046D0168',
#   '2011-07-01 00:00:00.000'),
#  (43889,
#   960,
#   'F108-4D76-8A',
#   1,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   '9468EC8E-072A-4BC6-B36D-374513D0EF90',
#   '2011-07-01 00:00:00.000'),
#  (43889,
#   961,
#   'F108-4D76-8A',
#   2,
#   716,
#   1,
#   '28.8404',
#   '0.00',
#   57.6808,
#   '1AA73E6E-12EA-4BEC-962C-68F51B07A9E1',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   962,
#   '6787-4174-98',
#   5,
#   771,
#   1,
#   '2039.994',
#   '0.00',
#   10199.97,
#   'D799A944-B99A-48B2-9164-848A6D4B0813',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   963,
#   '6787-4174-98',
#   2,
#   777,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   'A9741688-D1B3-4C69-B5BB-FD0F62D37870',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   964,
#   '6787-4174-98',
#   7,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   14279.958,
#   '440483C7-B9B1-4A74-94FE-898BBE095FA9',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   965,
#   '6787-4174-98',
#   2,
#   774,
#   1,
#   '2039.994',
#   '0.00',
#   4079.988,
#   '6D6D1978-D998-407E-BDC2-61D67C23B92E',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   966,
#   '6787-4174-98',
#   3,
#   742,
#   1,
#   '722.5949',
#   '0.00',
#   2167.7847,
#   'CCE67D1C-06D3-44ED-8216-DC51642AE76B',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   967,
#   '6787-4174-98',
#   5,
#   772,
#   1,
#   '2039.994',
#   '0.00',
#   10199.97,
#   '1E28999E-F178-4C78-9A3E-686ED1ABC598',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   968,
#   '6787-4174-98',
#   2,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   'ABD3089E-25F7-4D18-AC69-E43F83A78CB9',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   969,
#   '6787-4174-98',
#   1,
#   748,
#   1,
#   '722.5949',
#   '0.00',
#   722.5949,
#   'C38B41A7-1058-40D1-AF47-54A7D7CD138C',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   970,
#   '6787-4174-98',
#   1,
#   747,
#   1,
#   '714.7043',
#   '0.00',
#   714.7043,
#   '242074B6-E0F1-4E73-95AD-B036BB515648',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   971,
#   '6787-4174-98',
#   8,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   16199.952,
#   '9F7DD004-7A3D-4AA1-AF1E-34CA763DC3E9',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   972,
#   '6787-4174-98',
#   4,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   22.8,
#   '072C14A6-0935-4B90-AD90-085159CE7778',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   973,
#   '6787-4174-98',
#   3,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   6074.982,
#   '16096B8D-9B36-4F70-84E2-4DFE9BAC1A9E',
#   '2011-07-01 00:00:00.000'),
#  (43890,
#   974,
#   '6787-4174-98',
#   3,
#   745,
#   1,
#   '809.76',
#   '0.00',
#   2429.28,
#   'CC7245E1-5355-4D92-AF3E-9EA84742F378',
#   '2011-07-01 00:00:00.000'),
#  (43891,
#   975,
#   '1094-43CB-B1',
#   2,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '44856DA1-F3BD-484F-B199-656C16B0DEE2',
#   '2011-07-01 00:00:00.000'),
#  (43891,
#   976,
#   '1094-43CB-B1',
#   2,
#   710,
#   1,
#   '5.70',
#   '0.00',
#   11.4,
#   '241B0274-B8E5-490C-A46F-9F2880ED45B3',
#   '2011-07-01 00:00:00.000'),
#  (43891,
#   977,
#   '1094-43CB-B1',
#   1,
#   778,
#   1,
#   '2024.994',
#   '0.00',
#   2024.994,
#   'FA5AB345-AD8C-4C15-B2C6-CDFE8248D3B9',
#   '2011-07-01 00:00:00.000'),
#  (43891,
#   978,
#   '1094-43CB-B1',
#   3,
#   773,
#   1,
#   '2039.994',
#   '0.00',
#   6119.982,
#   'FC1A2DB1-E83A-445A-A6F0-9093D30BA206',
#   '2011-07-01 00:00:00.000'),
#  (43891,
#   979,
#   '1094-43CB-B1',
#   3,
#   771,
#   1,
#   '2039.994',
#   '0.00',
#   6119.982,
#   '43E4D872-0353-4540-A9FB-D1DB47FF99D6',
#   '2011-07-01 00:00:00.000'),
#  (43891,
#   980,
#   '1094-43CB-B1',
#   4,
#   709,
#   1,
#   '5.70',
#   '0.00',
#   22.8,
#   'E3792AE9-F971-4F6F-A0F2-D07266F8B9B7',
#   '2011-07-01 00:00:00.000'),
#  (43891,
#   981,
#   '1094-43CB-B1',
#   2,
#   776,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '6841EC15-0B39-4073-8E29-6501CB14AF67',
#   '2011-07-01 00:00:00.000'),
#  (43891,
#   982,
#   '1094-43CB-B1',
#   3,
#   772,
#   1,
#   '2039.994',
#   '0.00',
#   6119.982,
#   'E1107F2C-EC6B-4943-9436-1268D9FFAD48',
#   '2011-07-01 00:00:00.000'),
#  (43891,
#   983,
#   '1094-43CB-B1',
#   2,
#   777,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '7E8A0205-E908-4EDE-BAB8-81C5C67F386D',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   984,
#   '0D3C-4E1F-9C',
#   2,
#   762,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '716D44B1-7166-44E4-8A1F-E9F84DFBDBB9',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   985,
#   '0D3C-4E1F-9C',
#   3,
#   715,
#   1,
#   '28.8404',
#   '0.00',
#   86.5212,
#   '8D92CDDE-C23D-4104-B0AC-64FB65E8B8ED',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   986,
#   '0D3C-4E1F-9C',
#   2,
#   753,
#   1,
#   '2146.962',
#   '0.00',
#   4293.924,
#   '3867D3C3-4AAC-4113-AF53-02D13E48D694',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   987,
#   '0D3C-4E1F-9C',
#   3,
#   712,
#   1,
#   '5.1865',
#   '0.00',
#   15.5595,
#   '40761057-5846-453C-93DA-BA2EDD30DD04',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   988,
#   '0D3C-4E1F-9C',
#   2,
#   763,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '92EA8653-9E18-4A1A-9854-B96E9E0F81C8',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   989,
#   '0D3C-4E1F-9C',
#   5,
#   760,
#   1,
#   '419.4589',
#   '0.00',
#   2097.2945,
#   'CF43A4AE-E869-44DE-9EE0-1C839156C71D',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   990,
#   '0D3C-4E1F-9C',
#   1,
#   729,
#   1,
#   '183.9382',
#   '0.00',
#   183.9382,
#   '56C3F7BF-FB13-4B6E-A131-8814C9A5FC9F',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   991,
#   '0D3C-4E1F-9C',
#   2,
#   711,
#   1,
#   '20.1865',
#   '0.00',
#   40.373,
#   '23EEF851-5A1C-4338-973C-F13DF3EDFD2E',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   992,
#   '0D3C-4E1F-9C',
#   2,
#   754,
#   1,
#   '874.794',
#   '0.00',
#   1749.588,
#   'EC9B6F38-8EEC-4346-93BD-FF51F372ACC5',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   993,
#   '0D3C-4E1F-9C',
#   3,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   1258.3767,
#   '92E316DB-E9FD-45A0-9EE4-0AA435973214',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   994,
#   '0D3C-4E1F-9C',
#   4,
#   761,
#   1,
#   '419.4589',
#   '0.00',
#   1677.8356,
#   '62BEC424-A7D3-419F-B3DB-A5899C4B53B6',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   995,
#   '0D3C-4E1F-9C',
#   3,
#   758,
#   1,
#   '874.794',
#   '0.00',
#   2624.382,
#   '1D2F1713-C8C9-4737-8105-D26C8CF5AE2D',
#   '2011-07-01 00:00:00.000'),
#  (43892,
#   996,
#   '0D3C-4E1F-9C',
#   2,
#   765,
#   1,
#   '419.4589',
#   '0.00',
#   838.9178,
#   '30EDDEA5-2C93-4F08-B66E-BFADB84AFF0E',
#   '2011-07-01 00:00:00.000'),
#  (43893,
#   997,
#   '7C5D-46AA-A7',
#   1,
#   770,
#   1,
#   '419.4589',
#   '0.00',
#   419.4589,
#   '46A1DA27-B11D-4918-8308-4B7715C12FB5',
#   '2011-07-01 00:00:00.000'),
#  (43894,
#   998,
#   '7DF2-4E54-B0',
#   3,
#   710,
#   1,
#   '5.70',
#   '0.00',
#   17.1,
#   '6005BBFE-CD7C-45FD-80F7-DBBADB10BFEC',
#   '2011-07-01 00:00:00.000'),
#  (43894,
#   999,
#   '7DF2-4E54-B0',
#   2,
#   777,
#   1,
#   '2024.994',
#   '0.00',
#   4049.988,
#   '03FF934E-043F-4CE7-8F44-18BFEE7EDBB7',
#   '2011-07-01 00:00:00.000'),
#  (43894,
#   1000,
#   '7DF2-4E54-B0',
#   3,
#   775,
#   1,
#   '2024.994',
#   '0.00',
#   6074.982,
#   '1EBF5ABC-DDFF-4EE0-8C21-F3DE78477319',
#   '2011-07-01 00:00:00.000'),
#  ...]

# %% [markdown]
# ### Sales.SalesOrderHeader

# %%
#Escolhendo o arquivo dentro do bucket

bucket.blob('Sales.SalesOrderHeader.csv')
# Out:
# <Blob: desafio-rox-leandro, Sales.SalesOrderHeader.csv, None>

# %%
# Criando o df em pandas para enviar para o mysql
# Alterar , para . em  (SubTotal TaxAmt Freight TotalDue)

df_SalesOrderHeader = pd.read_csv(path_SalesOrderHeader,sep=';')

# Alteração das "," por "." nas colunas abaixo
df_SalesOrderHeader["SubTotal"] = df_SalesOrderHeader["SubTotal"].replace(",", ".", regex=True)
df_SalesOrderHeader["TaxAmt"] = df_SalesOrderHeader["TaxAmt"].replace(",", ".", regex=True)
df_SalesOrderHeader["Freight"] = df_SalesOrderHeader["Freight"].replace(",", ".", regex=True)

# %%
# Codigo repetido em todos os passos, colab dando erro, foi preciso sempre redefinir o conector.
# Conector host:ip_banco, user:usuario, passwd: senha, db:banco criado

con = mysql.connector.connect(host='34.95.218.222',user='desafio-username',passwd='1234',db='bicicletas')
cur = con.cursor()
engine = create_engine('mysql+pymysql://desafio-username:1234@34.95.218.222/bicicletas')

# %%
# Enviando a tabela SalesSalesOrderHeader para o MySql 

dfsql_SalesOrderHeader = df_SalesOrderHeader.to_sql('SalesSalesOrderHeader',con=engine,if_exists='replace',index=False)

# %%
# Verificando o conteúdo enviado

cur.execute('select * from SalesSalesOrderHeader')
cur.fetchall()
# Out:
# [(43659,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43659',
#   'PO522145787',
#   '10-4020-000676',
#   29825,
#   279.0,
#   5,
#   985,
#   985,
#   5,
#   16281.0,
#   '105041Vi84182',
#   None,
#   '20565.6206',
#   '1971.5149',
#   '616.0984',
#   '23153,2339',
#   None,
#   '79B65321-39CA-4115-9CBA-8FE0903E12E6',
#   '2011-06-07 00:00:00.000'),
#  (43660,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43660',
#   'PO18850127500',
#   '10-4020-000117',
#   29672,
#   279.0,
#   5,
#   921,
#   921,
#   5,
#   5618.0,
#   '115213Vi29411',
#   None,
#   '1294.2529',
#   '124.2483',
#   '38.8276',
#   '1457,3288',
#   None,
#   '738DC42D-D03B-48A1-9822-F95A67EA7389',
#   '2011-06-07 00:00:00.000'),
#  (43661,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43661',
#   'PO18473189620',
#   '10-4020-000442',
#   29734,
#   282.0,
#   6,
#   517,
#   517,
#   5,
#   1346.0,
#   '85274Vi6854',
#   4.0,
#   '32726.4786',
#   '3153.7696',
#   '985.553',
#   '36865,8012',
#   None,
#   'D91B9131-18A4-4A11-BC3A-90B6F53E9D74',
#   '2011-06-07 00:00:00.000'),
#  (43662,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43662',
#   'PO18444174044',
#   '10-4020-000227',
#   29994,
#   282.0,
#   6,
#   482,
#   482,
#   5,
#   10456.0,
#   '125295Vi53935',
#   4.0,
#   '28832.5289',
#   '2775.1646',
#   '867.2389',
#   '32474,9324',
#   None,
#   '4A1ECFC0-CC3A-4740-B028-1C50BB48711C',
#   '2011-06-07 00:00:00.000'),
#  (43663,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43663',
#   'PO18009186470',
#   '10-4020-000510',
#   29565,
#   276.0,
#   4,
#   1073,
#   1073,
#   5,
#   4322.0,
#   '45303Vi22691',
#   None,
#   '419.4589',
#   '40.2681',
#   '12.5838',
#   '472,3108',
#   None,
#   '9B1E7A40-6AE0-4AD3-811C-A64951857C4B',
#   '2011-06-07 00:00:00.000'),
#  (43664,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43664',
#   'PO16617121983',
#   '10-4020-000397',
#   29898,
#   280.0,
#   1,
#   876,
#   876,
#   5,
#   806.0,
#   '95555Vi4081',
#   None,
#   '24432.6088',
#   '2344.9921',
#   '732.81',
#   '27510,4109',
#   None,
#   '22A8A5DA-8C22-42AD-9241-839489B6EF0D',
#   '2011-06-07 00:00:00.000'),
#  (43665,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43665',
#   'PO16588191572',
#   '10-4020-000146',
#   29580,
#   283.0,
#   1,
#   849,
#   849,
#   5,
#   15232.0,
#   '35568Vi78804',
#   None,
#   '14352.7713',
#   '1375.9427',
#   '429.9821',
#   '16158,6961',
#   None,
#   '5602C304-853C-43D7-9E79-76E320D476CF',
#   '2011-06-07 00:00:00.000'),
#  (43666,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43666',
#   'PO16008173883',
#   '10-4020-000511',
#   30052,
#   276.0,
#   4,
#   1074,
#   1074,
#   5,
#   13349.0,
#   '105623Vi69217',
#   None,
#   '5056.4896',
#   '486.3747',
#   '151.9921',
#   '5694,8564',
#   None,
#   'E2A90057-1366-4487-8A7E-8085845FF770',
#   '2011-06-07 00:00:00.000'),
#  (43667,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43667',
#   'PO15428132599',
#   '10-4020-000646',
#   29974,
#   277.0,
#   3,
#   629,
#   629,
#   5,
#   10370.0,
#   '55680Vi53503',
#   None,
#   '6107.082',
#   '586.1203',
#   '183.1626',
#   '6876,3649',
#   None,
#   '86D5237D-432D-4B21-8ABC-671942F5789D',
#   '2011-06-07 00:00:00.000'),
#  (43668,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43668',
#   'PO14732180295',
#   '10-4020-000514',
#   29614,
#   282.0,
#   6,
#   529,
#   529,
#   5,
#   1566.0,
#   '85817Vi8045',
#   4.0,
#   '35944.1562',
#   '3461.7654',
#   '1081.8017',
#   '40487,7233',
#   None,
#   '281CC355-D538-494E-9B44-461B36A826C6',
#   '2011-06-07 00:00:00.000'),
#  (43669,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43669',
#   'PO14123169936',
#   '10-4020-000578',
#   29747,
#   283.0,
#   1,
#   895,
#   895,
#   5,
#   15538.0,
#   '25877Vi80261',
#   None,
#   '714.7043',
#   '70.5175',
#   '22.0367',
#   '807,2585',
#   None,
#   'FABFC5C2-E034-4E0E-A573-6F39E9FA0484',
#   '2011-06-07 00:00:00.000'),
#  (43670,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43670',
#   'PO14384116310',
#   '10-4020-000504',
#   29566,
#   275.0,
#   3,
#   810,
#   810,
#   5,
#   18017.0,
#   '105888Vi93490',
#   None,
#   '6122.082',
#   '587.5603',
#   '183.6126',
#   '6893,2549',
#   None,
#   '573E52A7-573F-40B6-B695-6F3D242E0C6D',
#   '2011-06-07 00:00:00.000'),
#  (43671,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43671',
#   'PO13978119376',
#   '10-4020-000200',
#   29890,
#   283.0,
#   1,
#   855,
#   855,
#   5,
#   13693.0,
#   '25904Vi70960',
#   None,
#   '8128.7876',
#   '780.8136',
#   '244.0042',
#   '9153,6054',
#   None,
#   '005FDA9D-62E1-4001-A4AC-A976A7905F94',
#   '2011-06-07 00:00:00.000'),
#  (43672,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43672',
#   'PO13862153537',
#   '10-4020-000119',
#   30067,
#   282.0,
#   6,
#   464,
#   464,
#   5,
#   3980.0,
#   '95915Vi20982',
#   4.0,
#   '6124.182',
#   '587.6023',
#   '183.6257',
#   '6895,41',
#   None,
#   '194202AA-8E15-4932-A2C4-7A7AC0713639',
#   '2011-06-07 00:00:00.000'),
#  (43673,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43673',
#   'PO13775141242',
#   '10-4020-000618',
#   29844,
#   275.0,
#   2,
#   821,
#   821,
#   5,
#   1417.0,
#   '35931Vi7271',
#   None,
#   '3746.2015',
#   '357.9614',
#   '111.8629',
#   '4216,0258',
#   None,
#   'C5CD3AE9-41F5-4B71-A3F1-D550B928572B',
#   '2011-06-07 00:00:00.000'),
#  (43674,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43674',
#   'PO12760141756',
#   '10-4020-000083',
#   29596,
#   282.0,
#   6,
#   458,
#   458,
#   5,
#   19204.0,
#   '26081Vi99806',
#   4.0,
#   '2624.382',
#   '251.9407',
#   '78.7315',
#   '2955,0542',
#   None,
#   'CE8BCA02-F705-4AAE-A446-5D8B660C3A1B',
#   '2011-06-07 00:00:00.000'),
#  (43675,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43675',
#   'PO12412186464',
#   '10-4020-000670',
#   29827,
#   277.0,
#   3,
#   631,
#   631,
#   5,
#   11886.0,
#   '126121Vi61402',
#   None,
#   '5716.3102',
#   '546.8759',
#   '170.8987',
#   '6434,0848',
#   None,
#   '9F2CF0EE-F2B8-44D4-897D-7641F4FBD649',
#   '2011-06-07 00:00:00.000'),
#  (43676,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43676',
#   'PO11861165059',
#   '10-4020-000017',
#   29811,
#   275.0,
#   5,
#   755,
#   755,
#   5,
#   18153.0,
#   '36168Vi94127',
#   None,
#   '14203.458',
#   '1363.266',
#   '426.0206',
#   '15992,7446',
#   None,
#   '28C73732-D2FD-4F0D-A9A8-0E53595235F6',
#   '2011-06-07 00:00:00.000'),
#  (43677,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43677',
#   'PO11049174786',
#   '10-4020-000679',
#   29824,
#   278.0,
#   6,
#   556,
#   556,
#   5,
#   14030.0,
#   '16302Vi72763',
#   4.0,
#   '7793.1108',
#   '747.1011',
#   '233.4691',
#   '8773,681',
#   None,
#   '95FAAF28-6495-40B0-9789-466B195F2F96',
#   '2011-06-07 00:00:00.000'),
#  (43678,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43678',
#   'PO10817150168',
#   '10-4020-000203',
#   29889,
#   281.0,
#   4,
#   1021,
#   1021,
#   5,
#   5093.0,
#   '66363Vi26658',
#   None,
#   '9799.9243',
#   '942.074',
#   '294.3981',
#   '11036,3964',
#   None,
#   '7F4B7542-638E-41CA-98D0-93018FE4DF77',
#   '2011-06-07 00:00:00.000'),
#  (43679,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43679',
#   'PO10527142759',
#   '10-4020-000480',
#   29761,
#   278.0,
#   6,
#   525,
#   525,
#   5,
#   5439.0,
#   '126365Vi28482',
#   4.0,
#   '1316.0575',
#   '125.8032',
#   '39.3135',
#   '1481,1742',
#   None,
#   '17D42D83-177D-4C7E-9C86-D2DB69326E04',
#   '2011-06-07 00:00:00.000'),
#  (43680,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43680',
#   'PO10730130087',
#   '10-4020-000491',
#   29489,
#   281.0,
#   4,
#   1069,
#   1069,
#   5,
#   6653.0,
#   '126370Vi34642',
#   None,
#   '11397.4992',
#   '1093.6394',
#   '341.7623',
#   '12832,9009',
#   None,
#   '9CBE5E7A-12D2-4DD4-B50C-1FFB4021C6E1',
#   '2011-06-07 00:00:00.000'),
#  (43681,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43681',
#   'PO1189177803',
#   '10-4020-000423',
#   29661,
#   279.0,
#   5,
#   955,
#   955,
#   5,
#   5301.0,
#   '16608Vi27707',
#   None,
#   '13787.5434',
#   '1323.0668',
#   '413.4584',
#   '15524,0686',
#   None,
#   'C82FC32F-7E10-40D2-8A9F-3D932DB42CD4',
#   '2011-06-07 00:00:00.000'),
#  (43682,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43682',
#   'PO1566124200',
#   '10-4020-000486',
#   29759,
#   275.0,
#   2,
#   808,
#   808,
#   5,
#   76.0,
#   '96712Vi373',
#   None,
#   '3875.7229',
#   '371.8002',
#   '116.1876',
#   '4363,7107',
#   None,
#   'CDC225D3-B639-4217-A7A4-3DED506FCEBE',
#   '2011-06-07 00:00:00.000'),
#  (43683,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43683',
#   'PO2552113807',
#   '10-4020-000506',
#   29497,
#   283.0,
#   1,
#   889,
#   889,
#   5,
#   13045.0,
#   '76866Vi67506',
#   None,
#   '42813.4333',
#   '4107.1489',
#   '1283.484',
#   '48204,0662',
#   None,
#   'F6E2ABB3-6FF8-49A6-9506-0B051A4618A0',
#   '2011-06-07 00:00:00.000'),
#  (43684,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43684',
#   'PO3393188842',
#   '10-4020-000549',
#   29912,
#   279.0,
#   5,
#   971,
#   971,
#   5,
#   267.0,
#   '37982Vi1394',
#   None,
#   '5596.4705',
#   '537.2612',
#   '167.8941',
#   '6301,6258',
#   None,
#   '3A2EFBA3-34E6-4CB5-B983-CB755AEA05DA',
#   '2011-06-07 00:00:00.000'),
#  (43685,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43685',
#   'PO4176124783',
#   '10-4020-000458',
#   30084,
#   279.0,
#   5,
#   958,
#   958,
#   5,
#   2519.0,
#   '108058Vi13146',
#   None,
#   '2736.5678',
#   '263.201',
#   '82.2503',
#   '3082,0191',
#   None,
#   'C8098FE4-2910-4BD3-9251-E9AEA7C7D118',
#   '2011-06-07 00:00:00.000'),
#  (43686,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43686',
#   'PO5075125561',
#   '10-4020-000344',
#   29606,
#   283.0,
#   1,
#   871,
#   871,
#   5,
#   14612.0,
#   '48152Vi75759',
#   None,
#   '3463.2998',
#   '332.4768',
#   '103.899',
#   '3899,6756',
#   None,
#   '65EF22D9-1AD7-40F4-A984-B7F074B7A6CF',
#   '2011-06-07 00:00:00.000'),
#  (43687,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43687',
#   'PO4959110829',
#   '10-4020-000269',
#   29610,
#   275.0,
#   2,
#   783,
#   783,
#   5,
#   3235.0,
#   '128163Vi17021',
#   None,
#   '1258.3767',
#   '120.8042',
#   '37.7513',
#   '1416,9322',
#   None,
#   'D04C9A8A-85B4-48F5-8ACE-D864D7EB94C7',
#   '2011-06-07 00:00:00.000'),
#  (43688,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43688',
#   'PO5365136389',
#   '10-4020-000161',
#   29718,
#   275.0,
#   2,
#   771,
#   771,
#   5,
#   12399.0,
#   '88200Vi64099',
#   None,
#   '12718.0844',
#   '1222.8838',
#   '382.1512',
#   '14323,1194',
#   None,
#   '596DEE2A-ABCB-46D0-95B9-E5AFF8C6C1F8',
#   '2011-06-07 00:00:00.000'),
#  (43689,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43689',
#   'PO5626159507',
#   '10-4020-000166',
#   29646,
#   277.0,
#   4,
#   578,
#   578,
#   5,
#   13054.0,
#   '98228Vi67566',
#   None,
#   '33997.3702',
#   '3271.4942',
#   '1022.3419',
#   '38291,2063',
#   None,
#   'D5628C44-BD37-4337-9412-3407C824DF71',
#   '2011-06-07 00:00:00.000'),
#  (43690,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43690',
#   'PO6235146326',
#   '10-4020-000431',
#   29533,
#   275.0,
#   3,
#   801,
#   801,
#   5,
#   2337.0,
#   '28321Vi12181',
#   None,
#   '1297.5901',
#   '124.2027',
#   '38.8133',
#   '1460,6061',
#   None,
#   '68942478-3091-49D6-AA0F-C3A0AA4D49D0',
#   '2011-06-07 00:00:00.000'),
#  (43691,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43691',
#   'PO6409111675',
#   '10-4020-000292',
#   29570,
#   277.0,
#   4,
#   592,
#   592,
#   5,
#   242.0,
#   '28360Vi1235',
#   None,
#   '874.794',
#   '83.9802',
#   '26.2438',
#   '985,018',
#   None,
#   '2EB93130-1226-4E8B-A2FD-1AD8D951D103',
#   '2011-06-07 00:00:00.000'),
#  (43692,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43692',
#   'PO7859187017',
#   '10-4020-000221',
#   29992,
#   281.0,
#   4,
#   1024,
#   1024,
#   5,
#   7176.0,
#   '108529Vi37251',
#   None,
#   '38510.8973',
#   '3696.3979',
#   '1155.1244',
#   '43362,4196',
#   None,
#   'EDB9E3F0-0B76-4DBC-934E-9DABFBA01EE5',
#   '2011-06-07 00:00:00.000'),
#  (43693,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43693',
#   'PO8120182325',
#   '10-4020-000485',
#   29491,
#   275.0,
#   5,
#   807,
#   807,
#   5,
#   8937.0,
#   '128548Vi46064',
#   None,
#   '20541.4072',
#   '1969.5564',
#   '615.4864',
#   '23126,45',
#   None,
#   '49C3D13D-464F-49D0-B21A-A2C07145EC62',
#   '2011-06-07 00:00:00.000'),
#  (43694,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43694',
#   'PO9657130250',
#   '10-4020-000315',
#   29549,
#   279.0,
#   5,
#   943,
#   943,
#   5,
#   7083.0,
#   '118748Vi36747',
#   None,
#   '20645.634',
#   '1978.3257',
#   '618.2268',
#   '23242,1865',
#   None,
#   'CEAAA999-7157-449D-8665-142793421294',
#   '2011-06-07 00:00:00.000'),
#  (43695,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43695',
#   'PO10179176559',
#   '10-4020-000027',
#   29958,
#   279.0,
#   5,
#   911,
#   911,
#   5,
#   10163.0,
#   '128786Vi52413',
#   None,
#   '39373.781',
#   '3787.4632',
#   '1183.5823',
#   '44344,8265',
#   None,
#   'F5FB98A9-A866-42CE-ADD8-6879231ED1A2',
#   '2011-06-07 00:00:00.000'),
#  (43696,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   0,
#   'SO43696',
#   'PO9947131800',
#   '10-4020-000603',
#   29849,
#   279.0,
#   5,
#   977,
#   977,
#   5,
#   1402.0,
#   '98787Vi7192',
#   None,
#   '419.4589',
#   '40.2681',
#   '12.5838',
#   '472,3108',
#   None,
#   '7C3E3B6D-E76E-470B-A75E-B20C25F86760',
#   '2011-06-07 00:00:00.000'),
#  (43697,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   1,
#   'SO43697',
#   None,
#   '10-4030-021768',
#   21768,
#   None,
#   6,
#   23148,
#   23148,
#   1,
#   4319.0,
#   '530200Vi22686',
#   4.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'BC58017D-0735-4E0E-8930-292290C37ABD',
#   '2011-06-07 00:00:00.000'),
#  (43698,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   1,
#   'SO43698',
#   None,
#   '10-4030-028389',
#   28389,
#   None,
#   7,
#   24593,
#   24593,
#   1,
#   16625.0,
#   '1231736Vi86048',
#   8.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '0AE8A848-41D9-4E5E-8FE8-5CD23F14421E',
#   '2011-06-07 00:00:00.000'),
#  (43699,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   1,
#   'SO43699',
#   None,
#   '10-4030-025863',
#   25863,
#   None,
#   1,
#   19613,
#   19613,
#   1,
#   5796.0,
#   '333376Vi30244',
#   None,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '99B348BD-7700-4D3E-A531-4540C875A2BD',
#   '2011-06-07 00:00:00.000'),
#  (43700,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   1,
#   'SO43700',
#   None,
#   '10-4030-014501',
#   14501,
#   None,
#   4,
#   20278,
#   20278,
#   1,
#   12860.0,
#   '733791Vi66509',
#   None,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   '5509A5B0-A6F3-4209-9728-148FB2D15D59',
#   '2011-06-07 00:00:00.000'),
#  (43701,
#   8,
#   '2011-05-31 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   '2011-06-07 00:00:00.000',
#   5,
#   1,
#   'SO43701',
#   None,
#   '10-4030-011003',
#   11003,
#   None,
#   9,
#   20425,
#   20425,
#   1,
#   11150.0,
#   '335093Vi57504',
#   2.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '4B3A130D-02AE-47AA-A91E-726B39440613',
#   '2011-06-07 00:00:00.000'),
#  (43702,
#   8,
#   '2011-06-01 00:00:00.000',
#   '2011-06-13 00:00:00.000',
#   '2011-06-08 00:00:00.000',
#   5,
#   1,
#   'SO43702',
#   None,
#   '10-4030-027645',
#   27645,
#   None,
#   4,
#   22584,
#   22584,
#   1,
#   8087.0,
#   '1230194Vi41919',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '9310C7F0-9A84-4CE9-BE08-F700FB1AADF7',
#   '2011-06-08 00:00:00.000'),
#  (43703,
#   8,
#   '2011-06-01 00:00:00.000',
#   '2011-06-13 00:00:00.000',
#   '2011-06-08 00:00:00.000',
#   5,
#   1,
#   'SO43703',
#   None,
#   '10-4030-016624',
#   16624,
#   None,
#   9,
#   23967,
#   23967,
#   1,
#   9497.0,
#   '1234632Vi48985',
#   15.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'CC630723-57F1-4E59-B1EF-BF77930B3906',
#   '2011-06-08 00:00:00.000'),
#  (43704,
#   8,
#   '2011-06-01 00:00:00.000',
#   '2011-06-13 00:00:00.000',
#   '2011-06-08 00:00:00.000',
#   5,
#   1,
#   'SO43704',
#   None,
#   '10-4030-011005',
#   11005,
#   None,
#   9,
#   16025,
#   16025,
#   1,
#   1988.0,
#   '835095Vi10342',
#   15.0,
#   '3374.99',
#   '269.9992',
#   '84.3748',
#   '3729,364',
#   None,
#   'B09AF2D1-243D-444F-9784-FCFCEB3FBB0A',
#   '2011-06-08 00:00:00.000'),
#  (43705,
#   8,
#   '2011-06-01 00:00:00.000',
#   '2011-06-13 00:00:00.000',
#   '2011-06-08 00:00:00.000',
#   5,
#   1,
#   'SO43705',
#   None,
#   '10-4030-011011',
#   11011,
#   None,
#   9,
#   27345,
#   27345,
#   1,
#   7205.0,
#   '1035101Vi37381',
#   15.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '17A0EDE6-6F1A-419D-BCF9-3638B79166D0',
#   '2011-06-08 00:00:00.000'),
#  (43706,
#   8,
#   '2011-06-02 00:00:00.000',
#   '2011-06-14 00:00:00.000',
#   '2011-06-09 00:00:00.000',
#   5,
#   1,
#   'SO43706',
#   None,
#   '10-4030-027621',
#   27621,
#   None,
#   4,
#   13264,
#   13264,
#   1,
#   10912.0,
#   '230189Vi56258',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'F02C4CB6-A5B5-4CE4-9473-CB084E383196',
#   '2011-06-09 00:00:00.000'),
#  (43707,
#   8,
#   '2011-06-02 00:00:00.000',
#   '2011-06-14 00:00:00.000',
#   '2011-06-09 00:00:00.000',
#   5,
#   1,
#   'SO43707',
#   None,
#   '10-4030-027616',
#   27616,
#   None,
#   4,
#   20923,
#   20923,
#   1,
#   19069.0,
#   '230298Vi99064',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '0DA77D6E-223E-4BC6-A2ED-43B387692C68',
#   '2011-06-09 00:00:00.000'),
#  (43708,
#   8,
#   '2011-06-02 00:00:00.000',
#   '2011-06-14 00:00:00.000',
#   '2011-06-09 00:00:00.000',
#   5,
#   1,
#   'SO43708',
#   None,
#   '10-4030-020042',
#   20042,
#   None,
#   10,
#   18427,
#   18427,
#   1,
#   4369.0,
#   '130402Vi22912',
#   35.0,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   'C9743A57-08A7-4494-A4BF-4B226C0B35EC',
#   '2011-06-09 00:00:00.000'),
#  (43709,
#   8,
#   '2011-06-02 00:00:00.000',
#   '2011-06-14 00:00:00.000',
#   '2011-06-09 00:00:00.000',
#   5,
#   1,
#   'SO43709',
#   None,
#   '10-4030-016351',
#   16351,
#   None,
#   9,
#   13951,
#   13951,
#   1,
#   15524.0,
#   '1034602Vi80214',
#   28.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '5AA25D99-4CA5-4C80-BBB7-3D97664E2A80',
#   '2011-06-09 00:00:00.000'),
#  (43710,
#   8,
#   '2011-06-02 00:00:00.000',
#   '2011-06-14 00:00:00.000',
#   '2011-06-09 00:00:00.000',
#   5,
#   1,
#   'SO43710',
#   None,
#   '10-4030-016517',
#   16517,
#   None,
#   9,
#   25446,
#   25446,
#   1,
#   5764.0,
#   '1134614Vi30135',
#   28.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '22220985-4182-4C6F-AE48-E920F72F6095',
#   '2011-06-09 00:00:00.000'),
#  (43711,
#   8,
#   '2011-06-03 00:00:00.000',
#   '2011-06-15 00:00:00.000',
#   '2011-06-10 00:00:00.000',
#   5,
#   1,
#   'SO43711',
#   None,
#   '10-4030-027606',
#   27606,
#   None,
#   1,
#   18404,
#   18404,
#   1,
#   3043.0,
#   '430293Vi16007',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'C8651CC4-7BF4-4013-94B2-2EA9FEAAC442',
#   '2011-06-10 00:00:00.000'),
#  (43712,
#   8,
#   '2011-06-03 00:00:00.000',
#   '2011-06-15 00:00:00.000',
#   '2011-06-10 00:00:00.000',
#   5,
#   1,
#   'SO43712',
#   None,
#   '10-4030-013513',
#   13513,
#   None,
#   8,
#   21867,
#   21867,
#   1,
#   6213.0,
#   '1231128Vi32292',
#   45.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '725C5DFE-6EAA-43E3-9571-2B99692DF51D',
#   '2011-06-10 00:00:00.000'),
#  (43713,
#   8,
#   '2011-06-04 00:00:00.000',
#   '2011-06-16 00:00:00.000',
#   '2011-06-11 00:00:00.000',
#   5,
#   1,
#   'SO43713',
#   None,
#   '10-4030-027601',
#   27601,
#   None,
#   4,
#   11855,
#   11855,
#   1,
#   16570.0,
#   '830288Vi85808',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '9DE30294-9066-4988-A3AD-09A0713348E5',
#   '2011-06-11 00:00:00.000'),
#  (43714,
#   8,
#   '2011-06-04 00:00:00.000',
#   '2011-06-16 00:00:00.000',
#   '2011-06-11 00:00:00.000',
#   5,
#   1,
#   'SO43714',
#   None,
#   '10-4030-013591',
#   13591,
#   None,
#   10,
#   15169,
#   15169,
#   1,
#   15963.0,
#   '1031124Vi82522',
#   61.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '40659773-9CE3-4214-9886-C9DE75E40274',
#   '2011-06-11 00:00:00.000'),
#  (43715,
#   8,
#   '2011-06-04 00:00:00.000',
#   '2011-06-16 00:00:00.000',
#   '2011-06-11 00:00:00.000',
#   5,
#   1,
#   'SO43715',
#   None,
#   '10-4030-016483',
#   16483,
#   None,
#   9,
#   28213,
#   28213,
#   1,
#   7985.0,
#   '1134605Vi41375',
#   54.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '36C19607-CC19-4CC0-8EA7-C16A6CC747DD',
#   '2011-06-11 00:00:00.000'),
#  (43716,
#   8,
#   '2011-06-04 00:00:00.000',
#   '2011-06-16 00:00:00.000',
#   '2011-06-11 00:00:00.000',
#   5,
#   1,
#   'SO43716',
#   None,
#   '10-4030-016529',
#   16529,
#   None,
#   9,
#   23557,
#   23557,
#   1,
#   5873.0,
#   '534626Vi30635',
#   54.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '92D7B8BF-071B-478E-A330-DEC813C635F9',
#   '2011-06-11 00:00:00.000'),
#  (43717,
#   8,
#   '2011-06-04 00:00:00.000',
#   '2011-06-16 00:00:00.000',
#   '2011-06-11 00:00:00.000',
#   5,
#   1,
#   'SO43717',
#   None,
#   '10-4030-025249',
#   25249,
#   None,
#   9,
#   11809,
#   11809,
#   1,
#   5700.0,
#   '1235425Vi29858',
#   54.0,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   '8CF612EF-31B8-4A57-8E57-5C62D48A0944',
#   '2011-06-11 00:00:00.000'),
#  (43718,
#   8,
#   '2011-06-05 00:00:00.000',
#   '2011-06-17 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   5,
#   1,
#   'SO43718',
#   None,
#   '10-4030-027668',
#   27668,
#   None,
#   1,
#   25346,
#   25346,
#   1,
#   3049.0,
#   '530203Vi16052',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '877141F0-4AE7-4FB3-B9E0-3CA2CC1A20C9',
#   '2011-06-12 00:00:00.000'),
#  (43719,
#   8,
#   '2011-06-05 00:00:00.000',
#   '2011-06-17 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   5,
#   1,
#   'SO43719',
#   None,
#   '10-4030-027612',
#   27612,
#   None,
#   4,
#   13854,
#   13854,
#   1,
#   5998.0,
#   '1130295Vi31203',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'BF5155EB-C5BE-4245-8FC4-F801DB5B052D',
#   '2011-06-12 00:00:00.000'),
#  (43720,
#   8,
#   '2011-06-05 00:00:00.000',
#   '2011-06-17 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   5,
#   1,
#   'SO43720',
#   None,
#   '10-4030-013264',
#   13264,
#   None,
#   8,
#   18584,
#   18584,
#   1,
#   2765.0,
#   '831105Vi14399',
#   71.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '8832376E-105B-4696-8BB4-E6EC1AA20219',
#   '2011-06-12 00:00:00.000'),
#  (43721,
#   8,
#   '2011-06-05 00:00:00.000',
#   '2011-06-17 00:00:00.000',
#   '2011-06-12 00:00:00.000',
#   5,
#   1,
#   'SO43721',
#   None,
#   '10-4030-013590',
#   13590,
#   None,
#   10,
#   22146,
#   22146,
#   1,
#   11950.0,
#   '331111Vi61776',
#   74.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '3A8A408F-C18F-4AE3-B0C4-F3B82F5F3404',
#   '2011-06-12 00:00:00.000'),
#  (43722,
#   8,
#   '2011-06-06 00:00:00.000',
#   '2011-06-18 00:00:00.000',
#   '2011-06-13 00:00:00.000',
#   5,
#   1,
#   'SO43722',
#   None,
#   '10-4030-013581',
#   13581,
#   None,
#   10,
#   23990,
#   23990,
#   1,
#   12191.0,
#   '331099Vi63048',
#   87.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '681FEC9E-C1FB-42C9-A96C-48C911B086DD',
#   '2011-06-13 00:00:00.000'),
#  (43723,
#   8,
#   '2011-06-06 00:00:00.000',
#   '2011-06-18 00:00:00.000',
#   '2011-06-13 00:00:00.000',
#   5,
#   1,
#   'SO43723',
#   None,
#   '10-4030-014520',
#   14520,
#   None,
#   1,
#   12708,
#   12708,
#   1,
#   16949.0,
#   '833793Vi87871',
#   None,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   '4EB5EC63-D247-468F-B88B-C2E5C019D949',
#   '2011-06-13 00:00:00.000'),
#  (43724,
#   8,
#   '2011-06-06 00:00:00.000',
#   '2011-06-18 00:00:00.000',
#   '2011-06-13 00:00:00.000',
#   5,
#   1,
#   'SO43724',
#   None,
#   '10-4030-016520',
#   16520,
#   None,
#   9,
#   25572,
#   25572,
#   1,
#   6336.0,
#   '834617Vi32891',
#   80.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '62FCAB48-3494-4AF8-A1CB-5E2FE0929FF0',
#   '2011-06-13 00:00:00.000'),
#  (43725,
#   8,
#   '2011-06-07 00:00:00.000',
#   '2011-06-19 00:00:00.000',
#   '2011-06-14 00:00:00.000',
#   5,
#   1,
#   'SO43725',
#   None,
#   '10-4030-013258',
#   13258,
#   None,
#   8,
#   23444,
#   23444,
#   1,
#   6640.0,
#   '832136Vi34578',
#   97.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '607A7986-372A-4939-B2C3-694D8293D99D',
#   '2011-06-14 00:00:00.000'),
#  (43726,
#   8,
#   '2011-06-07 00:00:00.000',
#   '2011-06-19 00:00:00.000',
#   '2011-06-14 00:00:00.000',
#   5,
#   1,
#   'SO43726',
#   None,
#   '10-4030-014560',
#   14560,
#   None,
#   4,
#   25989,
#   25989,
#   1,
#   8533.0,
#   '533796Vi44130',
#   None,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   'C857E6B2-50D6-4B20-92F2-0E5D0C79ABA3',
#   '2011-06-14 00:00:00.000'),
#  (43727,
#   8,
#   '2011-06-07 00:00:00.000',
#   '2011-06-19 00:00:00.000',
#   '2011-06-14 00:00:00.000',
#   5,
#   1,
#   'SO43727',
#   None,
#   '10-4030-016607',
#   16607,
#   None,
#   9,
#   15502,
#   15502,
#   1,
#   11407.0,
#   '834627Vi58835',
#   93.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '7DFEEC8E-63C7-4D87-9ECB-35C1A7AC3FEB',
#   '2011-06-14 00:00:00.000'),
#  (43728,
#   8,
#   '2011-06-08 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   '2011-06-15 00:00:00.000',
#   5,
#   1,
#   'SO43728',
#   None,
#   '10-4030-027666',
#   27666,
#   None,
#   4,
#   20616,
#   20616,
#   1,
#   15630.0,
#   '130201Vi80748',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '1A9730F8-53CA-44A9-A692-6A009189157D',
#   '2011-06-15 00:00:00.000'),
#  (43729,
#   8,
#   '2011-06-08 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   '2011-06-15 00:00:00.000',
#   5,
#   1,
#   'SO43729',
#   None,
#   '10-4030-011238',
#   11238,
#   None,
#   10,
#   12420,
#   12420,
#   1,
#   2636.0,
#   '831735Vi13701',
#   113.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   'BE1BD96B-B584-487A-A740-B096779F6C47',
#   '2011-06-15 00:00:00.000'),
#  (43730,
#   8,
#   '2011-06-08 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   '2011-06-15 00:00:00.000',
#   5,
#   1,
#   'SO43730',
#   None,
#   '10-4030-025861',
#   25861,
#   None,
#   4,
#   23733,
#   23733,
#   1,
#   13323.0,
#   '333375Vi69103',
#   None,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   'AF82E535-AF8D-417F-BA33-620F49BEE5DE',
#   '2011-06-15 00:00:00.000'),
#  (43731,
#   8,
#   '2011-06-08 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   '2011-06-15 00:00:00.000',
#   5,
#   1,
#   'SO43731',
#   None,
#   '10-4030-016629',
#   16629,
#   None,
#   9,
#   14019,
#   14019,
#   1,
#   14302.0,
#   '834633Vi74142',
#   106.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'BB0F57EF-E9DC-4F10-BCED-0270C6F4DD5A',
#   '2011-06-15 00:00:00.000'),
#  (43732,
#   8,
#   '2011-06-08 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   '2011-06-15 00:00:00.000',
#   5,
#   1,
#   'SO43732',
#   None,
#   '10-4030-011025',
#   11025,
#   None,
#   9,
#   21635,
#   21635,
#   1,
#   10882.0,
#   '1235104Vi56140',
#   106.0,
#   '3374.99',
#   '269.9992',
#   '84.3748',
#   '3729,364',
#   None,
#   '80ACD4E1-371E-4A58-90CA-EC866A828CF7',
#   '2011-06-15 00:00:00.000'),
#  (43733,
#   8,
#   '2011-06-08 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   '2011-06-15 00:00:00.000',
#   5,
#   1,
#   'SO43733',
#   None,
#   '10-4030-027577',
#   27577,
#   None,
#   1,
#   24572,
#   24572,
#   1,
#   10600.0,
#   '135716Vi54667',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'A97984DF-2A16-4BAA-B2ED-CD17490E9F93',
#   '2011-06-15 00:00:00.000'),
#  (43734,
#   8,
#   '2011-06-09 00:00:00.000',
#   '2011-06-21 00:00:00.000',
#   '2011-06-16 00:00:00.000',
#   5,
#   1,
#   'SO43734',
#   None,
#   '10-4030-027604',
#   27604,
#   None,
#   1,
#   23224,
#   23224,
#   1,
#   15365.0,
#   '330290Vi79368',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'C1813FDF-AF79-4FBA-8936-70CBD2964535',
#   '2011-06-16 00:00:00.000'),
#  (43735,
#   8,
#   '2011-06-09 00:00:00.000',
#   '2011-06-21 00:00:00.000',
#   '2011-06-16 00:00:00.000',
#   5,
#   1,
#   'SO43735',
#   None,
#   '10-4030-016522',
#   16522,
#   None,
#   9,
#   25384,
#   25384,
#   1,
#   6526.0,
#   '1034619Vi33896',
#   119.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '98F80245-C398-4562-BDAF-EA3E9A0DDFAC',
#   '2011-06-16 00:00:00.000'),
#  (43736,
#   8,
#   '2011-06-09 00:00:00.000',
#   '2011-06-21 00:00:00.000',
#   '2011-06-16 00:00:00.000',
#   5,
#   1,
#   'SO43736',
#   None,
#   '10-4030-011002',
#   11002,
#   None,
#   9,
#   20336,
#   20336,
#   1,
#   1416.0,
#   '1135092Vi7270',
#   119.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   'C14E29E7-DB11-44EF-943E-143925A5A9AE',
#   '2011-06-16 00:00:00.000'),
#  (43737,
#   8,
#   '2011-06-10 00:00:00.000',
#   '2011-06-22 00:00:00.000',
#   '2011-06-17 00:00:00.000',
#   5,
#   1,
#   'SO43737',
#   None,
#   '10-4030-013261',
#   13261,
#   None,
#   8,
#   29772,
#   29772,
#   1,
#   None,
#   None,
#   136.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '0B3E274D-E5A8-4E8C-A417-0EAFABCFF162',
#   '2011-06-17 00:00:00.000'),
#  (43738,
#   8,
#   '2011-06-10 00:00:00.000',
#   '2011-06-22 00:00:00.000',
#   '2011-06-17 00:00:00.000',
#   5,
#   1,
#   'SO43738',
#   None,
#   '10-4030-011606',
#   11606,
#   None,
#   7,
#   26167,
#   26167,
#   1,
#   12005.0,
#   '631125Vi62053',
#   138.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '2869C629-EBBD-47BC-87B1-A6871CD8C5CF',
#   '2011-06-17 00:00:00.000'),
#  (43739,
#   8,
#   '2011-06-10 00:00:00.000',
#   '2011-06-22 00:00:00.000',
#   '2011-06-17 00:00:00.000',
#   5,
#   1,
#   'SO43739',
#   None,
#   '10-4030-013563',
#   13563,
#   None,
#   10,
#   29262,
#   29262,
#   1,
#   None,
#   None,
#   139.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '9192752E-18F9-4AFE-B4DA-CFABF0E9F6CE',
#   '2011-06-17 00:00:00.000'),
#  (43740,
#   8,
#   '2011-06-10 00:00:00.000',
#   '2011-06-22 00:00:00.000',
#   '2011-06-17 00:00:00.000',
#   5,
#   1,
#   'SO43740',
#   None,
#   '10-4030-016527',
#   16527,
#   None,
#   9,
#   28420,
#   28420,
#   1,
#   18137.0,
#   '834624Vi94036',
#   132.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '1242EF55-1FE1-4501-B21B-CA74FC31053C',
#   '2011-06-17 00:00:00.000'),
#  (43741,
#   8,
#   '2011-06-11 00:00:00.000',
#   '2011-06-23 00:00:00.000',
#   '2011-06-18 00:00:00.000',
#   5,
#   1,
#   'SO43741',
#   None,
#   '10-4030-027671',
#   27671,
#   None,
#   1,
#   13036,
#   13036,
#   1,
#   4679.0,
#   '530206Vi24524',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'C674C190-0CDA-46F5-AAC1-A65D9F902572',
#   '2011-06-18 00:00:00.000'),
#  (43742,
#   8,
#   '2011-06-11 00:00:00.000',
#   '2011-06-23 00:00:00.000',
#   '2011-06-18 00:00:00.000',
#   5,
#   1,
#   'SO43742',
#   None,
#   '10-4030-013576',
#   13576,
#   None,
#   10,
#   20966,
#   20966,
#   1,
#   17254.0,
#   '932138Vi89574',
#   152.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '7B65FBC1-E19B-44FF-B5B3-4999C9F300B6',
#   '2011-06-18 00:00:00.000'),
#  (43743,
#   8,
#   '2011-06-11 00:00:00.000',
#   '2011-06-23 00:00:00.000',
#   '2011-06-18 00:00:00.000',
#   5,
#   1,
#   'SO43743',
#   None,
#   '10-4030-011007',
#   11007,
#   None,
#   9,
#   12909,
#   12909,
#   1,
#   1546.0,
#   '1235097Vi7903',
#   145.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '49CE5DDA-33B4-4E30-9945-0F54BB36A823',
#   '2011-06-18 00:00:00.000'),
#  (43744,
#   8,
#   '2011-06-11 00:00:00.000',
#   '2011-06-23 00:00:00.000',
#   '2011-06-18 00:00:00.000',
#   5,
#   1,
#   'SO43744',
#   None,
#   '10-4030-016631',
#   16631,
#   None,
#   9,
#   12423,
#   12423,
#   1,
#   12980.0,
#   '635648Vi67147',
#   145.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '6F4346C6-953D-4BB5-8508-18F9CF31A83C',
#   '2011-06-18 00:00:00.000'),
#  (43745,
#   8,
#   '2011-06-12 00:00:00.000',
#   '2011-06-24 00:00:00.000',
#   '2011-06-19 00:00:00.000',
#   5,
#   1,
#   'SO43745',
#   None,
#   '10-4030-016514',
#   16514,
#   None,
#   9,
#   25018,
#   25018,
#   1,
#   9626.0,
#   '634611Vi49589',
#   158.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'F8D467F2-7039-430D-BFAA-3F6D0405FC6F',
#   '2011-06-19 00:00:00.000'),
#  (43746,
#   8,
#   '2011-06-12 00:00:00.000',
#   '2011-06-24 00:00:00.000',
#   '2011-06-19 00:00:00.000',
#   5,
#   1,
#   'SO43746',
#   None,
#   '10-4030-016616',
#   16616,
#   None,
#   9,
#   28214,
#   28214,
#   1,
#   5138.0,
#   '434629Vi26884',
#   158.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'CE002911-F422-449D-AC95-C542A5553F46',
#   '2011-06-19 00:00:00.000'),
#  (43747,
#   8,
#   '2011-06-13 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   5,
#   1,
#   'SO43747',
#   None,
#   '10-4030-027623',
#   27623,
#   None,
#   4,
#   27241,
#   27241,
#   1,
#   16044.0,
#   '1230190Vi82952',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '5DC249A1-592C-472E-93B7-E2F26DDE5DAB',
#   '2011-06-20 00:00:00.000'),
#  (43748,
#   8,
#   '2011-06-13 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   5,
#   1,
#   'SO43748',
#   None,
#   '10-4030-027625',
#   27625,
#   None,
#   1,
#   16663,
#   16663,
#   1,
#   14948.0,
#   '430191Vi77442',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '5D25E2A5-A4C6-45AA-B388-9BD83769A2AF',
#   '2011-06-20 00:00:00.000'),
#  (43749,
#   8,
#   '2011-06-13 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   5,
#   1,
#   'SO43749',
#   None,
#   '10-4030-027636',
#   27636,
#   None,
#   1,
#   17878,
#   17878,
#   1,
#   12504.0,
#   '130192Vi64692',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '6C9F6457-1494-4C6C-8F57-3DA2505D2BF6',
#   '2011-06-20 00:00:00.000'),
#  (43750,
#   8,
#   '2011-06-13 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   5,
#   1,
#   'SO43750',
#   None,
#   '10-4030-011591',
#   11591,
#   None,
#   7,
#   26694,
#   26694,
#   1,
#   15541.0,
#   '1131100Vi80273',
#   177.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '9F5B2B08-C237-4691-B757-A5D15970A6DC',
#   '2011-06-20 00:00:00.000'),
#  (43751,
#   8,
#   '2011-06-13 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   5,
#   1,
#   'SO43751',
#   None,
#   '10-4030-011592',
#   11592,
#   None,
#   7,
#   17421,
#   17421,
#   1,
#   711.0,
#   '331101Vi3645',
#   177.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'BECFDFC1-4E38-4250-9ED8-5F88282865F8',
#   '2011-06-20 00:00:00.000'),
#  (43752,
#   8,
#   '2011-06-13 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   5,
#   1,
#   'SO43752',
#   None,
#   '10-4030-013265',
#   13265,
#   None,
#   8,
#   25970,
#   25970,
#   1,
#   2736.0,
#   '731107Vi14233',
#   175.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '3C3CE19A-5EB4-4A2B-931E-BD2A65334F12',
#   '2011-06-20 00:00:00.000'),
#  (43753,
#   8,
#   '2011-06-13 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   '2011-06-20 00:00:00.000',
#   5,
#   1,
#   'SO43753',
#   None,
#   '10-4030-016482',
#   16482,
#   None,
#   9,
#   19434,
#   19434,
#   1,
#   7588.0,
#   '734604Vi39312',
#   171.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'E133A699-6529-4494-80F0-C700A193585D',
#   '2011-06-20 00:00:00.000'),
#  (43754,
#   8,
#   '2011-06-14 00:00:00.000',
#   '2011-06-26 00:00:00.000',
#   '2011-06-21 00:00:00.000',
#   5,
#   1,
#   'SO43754',
#   None,
#   '10-4030-027617',
#   27617,
#   None,
#   1,
#   18700,
#   18700,
#   1,
#   9734.0,
#   '630188Vi50171',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '86B0C2B9-6ABD-4B69-9C76-2B702B604D77',
#   '2011-06-21 00:00:00.000'),
#  (43755,
#   8,
#   '2011-06-14 00:00:00.000',
#   '2011-06-26 00:00:00.000',
#   '2011-06-21 00:00:00.000',
#   5,
#   1,
#   'SO43755',
#   None,
#   '10-4030-027670',
#   27670,
#   None,
#   4,
#   21785,
#   21785,
#   1,
#   14614.0,
#   '1030205Vi75785',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '98337979-2598-4E10-8666-4823D1EB0564',
#   '2011-06-21 00:00:00.000'),
#  (43756,
#   8,
#   '2011-06-14 00:00:00.000',
#   '2011-06-26 00:00:00.000',
#   '2011-06-21 00:00:00.000',
#   5,
#   1,
#   'SO43756',
#   None,
#   '10-4030-019941',
#   19941,
#   None,
#   10,
#   12565,
#   12565,
#   1,
#   9528.0,
#   '830399Vi49119',
#   191.0,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   '6D3EE374-D017-4007-9BA3-8966F2B3CD00',
#   '2011-06-21 00:00:00.000'),
#  (43757,
#   8,
#   '2011-06-14 00:00:00.000',
#   '2011-06-26 00:00:00.000',
#   '2011-06-21 00:00:00.000',
#   5,
#   1,
#   'SO43757',
#   None,
#   '10-4030-011017',
#   11017,
#   None,
#   9,
#   11541,
#   11541,
#   1,
#   12801.0,
#   '635102Vi66203',
#   184.0,
#   '3374.99',
#   '269.9992',
#   '84.3748',
#   '3729,364',
#   None,
#   '238FD676-5C9C-44A6-8C10-F890887887B6',
#   '2011-06-21 00:00:00.000'),
#  (43758,
#   8,
#   '2011-06-15 00:00:00.000',
#   '2011-06-27 00:00:00.000',
#   '2011-06-22 00:00:00.000',
#   5,
#   1,
#   'SO43758',
#   None,
#   '10-4030-027646',
#   27646,
#   None,
#   4,
#   14400,
#   14400,
#   1,
#   17093.0,
#   '1230195Vi88773',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'C54AB7FA-B136-4954-9E52-ED8283E91460',
#   '2011-06-22 00:00:00.000'),
#  (43759,
#   8,
#   '2011-06-15 00:00:00.000',
#   '2011-06-27 00:00:00.000',
#   '2011-06-22 00:00:00.000',
#   5,
#   1,
#   'SO43759',
#   None,
#   '10-4030-013257',
#   13257,
#   None,
#   8,
#   21516,
#   21516,
#   1,
#   11314.0,
#   '132135Vi58334',
#   201.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '12C67787-B108-41BC-8EAD-7241E2FE1F14',
#   '2011-06-22 00:00:00.000'),
#  (43760,
#   8,
#   '2011-06-15 00:00:00.000',
#   '2011-06-27 00:00:00.000',
#   '2011-06-22 00:00:00.000',
#   5,
#   1,
#   'SO43760',
#   None,
#   '10-4030-016352',
#   16352,
#   None,
#   9,
#   11694,
#   11694,
#   1,
#   7485.0,
#   '234603Vi38778',
#   197.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'FF8ED378-D791-4029-A332-0B0AD2751CB1',
#   '2011-06-22 00:00:00.000'),
#  (43761,
#   8,
#   '2011-06-15 00:00:00.000',
#   '2011-06-27 00:00:00.000',
#   '2011-06-22 00:00:00.000',
#   5,
#   1,
#   'SO43761',
#   None,
#   '10-4030-016493',
#   16493,
#   None,
#   9,
#   24449,
#   24449,
#   1,
#   11678.0,
#   '434607Vi60395',
#   197.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'D8D63FCB-CA38-41D2-BBEE-ADD8BDC7A11A',
#   '2011-06-22 00:00:00.000'),
#  (43762,
#   8,
#   '2011-06-16 00:00:00.000',
#   '2011-06-28 00:00:00.000',
#   '2011-06-23 00:00:00.000',
#   5,
#   1,
#   'SO43762',
#   None,
#   '10-4030-027578',
#   27578,
#   None,
#   4,
#   19011,
#   19011,
#   1,
#   4503.0,
#   '930287Vi23588',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '587A050C-626F-4D69-A5AC-5E4CF662A13B',
#   '2011-06-23 00:00:00.000'),
#  (43763,
#   8,
#   '2011-06-16 00:00:00.000',
#   '2011-06-28 00:00:00.000',
#   '2011-06-23 00:00:00.000',
#   5,
#   1,
#   'SO43763',
#   None,
#   '10-4030-016525',
#   16525,
#   None,
#   9,
#   13961,
#   13961,
#   1,
#   17110.0,
#   '934622Vi88860',
#   210.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '1F38B7D0-0C7A-4E66-ABC4-91D79143F276',
#   '2011-06-23 00:00:00.000'),
#  (43764,
#   8,
#   '2011-06-16 00:00:00.000',
#   '2011-06-28 00:00:00.000',
#   '2011-06-23 00:00:00.000',
#   5,
#   1,
#   'SO43764',
#   None,
#   '10-4030-016612',
#   16612,
#   None,
#   9,
#   18740,
#   18740,
#   1,
#   10644.0,
#   '334628Vi54854',
#   210.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '4B61937A-7E76-4F51-94AD-20784258E473',
#   '2011-06-23 00:00:00.000'),
#  (43765,
#   8,
#   '2011-06-16 00:00:00.000',
#   '2011-06-28 00:00:00.000',
#   '2011-06-23 00:00:00.000',
#   5,
#   1,
#   'SO43765',
#   None,
#   '10-4030-011010',
#   11010,
#   None,
#   9,
#   15412,
#   15412,
#   1,
#   10245.0,
#   '535100Vi52885',
#   210.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '41A0F8E4-D228-441F-97D3-E7E4A6DE042C',
#   '2011-06-23 00:00:00.000'),
#  (43766,
#   8,
#   '2011-06-17 00:00:00.000',
#   '2011-06-29 00:00:00.000',
#   '2011-06-24 00:00:00.000',
#   5,
#   1,
#   'SO43766',
#   None,
#   '10-4030-016518',
#   16518,
#   None,
#   9,
#   26446,
#   26446,
#   1,
#   10469.0,
#   '834615Vi53986',
#   223.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'BCB28F9B-69D0-4FBE-AA8A-6B4CDA8E7BFE',
#   '2011-06-24 00:00:00.000'),
#  (43767,
#   8,
#   '2011-06-17 00:00:00.000',
#   '2011-06-29 00:00:00.000',
#   '2011-06-24 00:00:00.000',
#   5,
#   1,
#   'SO43767',
#   None,
#   '10-4030-011001',
#   11001,
#   None,
#   9,
#   14489,
#   14489,
#   1,
#   8810.0,
#   '235091Vi45462',
#   223.0,
#   '3374.99',
#   '269.9992',
#   '84.3748',
#   '3729,364',
#   None,
#   'BF2E1105-44C2-422F-92E8-59C575BF2652',
#   '2011-06-24 00:00:00.000'),
#  (43768,
#   8,
#   '2011-06-18 00:00:00.000',
#   '2011-06-30 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   5,
#   1,
#   'SO43768',
#   None,
#   '10-4030-027649',
#   27649,
#   None,
#   1,
#   24209,
#   24209,
#   1,
#   18040.0,
#   '830196Vi93642',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '534C4DAF-51FE-47D6-B58A-35358BBAD410',
#   '2011-06-25 00:00:00.000'),
#  (43769,
#   8,
#   '2011-06-18 00:00:00.000',
#   '2011-06-30 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   5,
#   1,
#   'SO43769',
#   None,
#   '10-4030-021659',
#   21659,
#   None,
#   6,
#   12365,
#   12365,
#   1,
#   7388.0,
#   '1030286Vi38309',
#   238.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'EC7C8A6C-120C-4025-B230-52E48B27FDAD',
#   '2011-06-25 00:00:00.000'),
#  (43770,
#   8,
#   '2011-06-18 00:00:00.000',
#   '2011-06-30 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   5,
#   1,
#   'SO43770',
#   None,
#   '10-4030-027614',
#   27614,
#   None,
#   1,
#   21039,
#   21039,
#   1,
#   16136.0,
#   '230296Vi83473',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '7D3CE5FA-5B2A-4D88-A33C-72EFCC5AEC8A',
#   '2011-06-25 00:00:00.000'),
#  (43771,
#   8,
#   '2011-06-18 00:00:00.000',
#   '2011-06-30 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   5,
#   1,
#   'SO43771',
#   None,
#   '10-4030-014559',
#   14559,
#   None,
#   4,
#   21657,
#   21657,
#   1,
#   16934.0,
#   '633795Vi87782',
#   None,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   '45081816-B4D2-42D5-B761-84F1157DFD31',
#   '2011-06-25 00:00:00.000'),
#  (43772,
#   8,
#   '2011-06-18 00:00:00.000',
#   '2011-06-30 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   5,
#   1,
#   'SO43772',
#   None,
#   '10-4030-016524',
#   16524,
#   None,
#   9,
#   15700,
#   15700,
#   1,
#   12834.0,
#   '334621Vi66368',
#   236.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '877A235B-C962-4F16-BA92-48AE4C8E5E5B',
#   '2011-06-25 00:00:00.000'),
#  (43773,
#   8,
#   '2011-06-18 00:00:00.000',
#   '2011-06-30 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   5,
#   1,
#   'SO43773',
#   None,
#   '10-4030-016526',
#   16526,
#   None,
#   9,
#   19998,
#   19998,
#   1,
#   19057.0,
#   '534623Vi99022',
#   236.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'F49BC13F-8993-4042-9B85-8F671B1E15F0',
#   '2011-06-25 00:00:00.000'),
#  (43774,
#   8,
#   '2011-06-18 00:00:00.000',
#   '2011-06-30 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   5,
#   1,
#   'SO43774',
#   None,
#   '10-4030-016348',
#   16348,
#   None,
#   9,
#   20184,
#   20184,
#   1,
#   1311.0,
#   '434719Vi6675',
#   236.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '3C2F2CF6-D381-4233-A5A7-DD2A2E31A503',
#   '2011-06-25 00:00:00.000'),
#  (43775,
#   8,
#   '2011-06-18 00:00:00.000',
#   '2011-06-30 00:00:00.000',
#   '2011-06-25 00:00:00.000',
#   5,
#   1,
#   'SO43775',
#   None,
#   '10-4030-011027',
#   11027,
#   None,
#   9,
#   14561,
#   14561,
#   1,
#   6918.0,
#   '535106Vi36020',
#   236.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '64BEC07C-2D34-4360-97F9-AAB1D4EC53F5',
#   '2011-06-25 00:00:00.000'),
#  (43776,
#   8,
#   '2011-06-19 00:00:00.000',
#   '2011-07-01 00:00:00.000',
#   '2011-06-26 00:00:00.000',
#   5,
#   1,
#   'SO43776',
#   None,
#   '10-4030-013260',
#   13260,
#   None,
#   8,
#   15402,
#   15402,
#   1,
#   10653.0,
#   '1231103Vi54892',
#   253.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '7D468137-4412-4BDE-BC27-EA17D07BB01E',
#   '2011-06-26 00:00:00.000'),
#  (43777,
#   8,
#   '2011-06-19 00:00:00.000',
#   '2011-07-01 00:00:00.000',
#   '2011-06-26 00:00:00.000',
#   5,
#   1,
#   'SO43777',
#   None,
#   '10-4030-016515',
#   16515,
#   None,
#   9,
#   24873,
#   24873,
#   1,
#   1850.0,
#   '734612Vi9613',
#   249.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '764526C9-3393-4B23-850D-F744944C00D3',
#   '2011-06-26 00:00:00.000'),
#  (43778,
#   8,
#   '2011-06-19 00:00:00.000',
#   '2011-07-01 00:00:00.000',
#   '2011-06-26 00:00:00.000',
#   5,
#   1,
#   'SO43778',
#   None,
#   '10-4030-011018',
#   11018,
#   None,
#   9,
#   16433,
#   16433,
#   1,
#   9930.0,
#   '735103Vi51096',
#   249.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '2226D4B2-38A6-4F18-9925-77F36F8902E2',
#   '2011-06-26 00:00:00.000'),
#  (43779,
#   8,
#   '2011-06-19 00:00:00.000',
#   '2011-07-01 00:00:00.000',
#   '2011-06-26 00:00:00.000',
#   5,
#   1,
#   'SO43779',
#   None,
#   '10-4030-025252',
#   25252,
#   None,
#   9,
#   20850,
#   20850,
#   1,
#   6901.0,
#   '235427Vi35948',
#   249.0,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   '6628447B-1958-48BF-B611-60B751FA8DAF',
#   '2011-06-26 00:00:00.000'),
#  (43780,
#   8,
#   '2011-06-20 00:00:00.000',
#   '2011-07-02 00:00:00.000',
#   '2011-06-27 00:00:00.000',
#   5,
#   1,
#   'SO43780',
#   None,
#   '10-4030-011599',
#   11599,
#   None,
#   7,
#   25850,
#   25850,
#   1,
#   17097.0,
#   '131108Vi88806',
#   268.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '8450AF5F-35E8-4085-A27F-7BD68A1393AC',
#   '2011-06-27 00:00:00.000'),
#  (43781,
#   8,
#   '2011-06-20 00:00:00.000',
#   '2011-07-02 00:00:00.000',
#   '2011-06-27 00:00:00.000',
#   5,
#   1,
#   'SO43781',
#   None,
#   '10-4030-016495',
#   16495,
#   None,
#   9,
#   22857,
#   22857,
#   1,
#   5269.0,
#   '634609Vi27549',
#   262.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '4BF0100B-0CC1-4FAF-ACE2-1A0A6748AAD6',
#   '2011-06-27 00:00:00.000'),
#  (43782,
#   8,
#   '2011-06-20 00:00:00.000',
#   '2011-07-02 00:00:00.000',
#   '2011-06-27 00:00:00.000',
#   5,
#   1,
#   'SO43782',
#   None,
#   '10-4030-016516',
#   16516,
#   None,
#   9,
#   13386,
#   13386,
#   1,
#   9916.0,
#   '1034613Vi51017',
#   262.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '82648EC2-CF59-46F6-8F89-434ED5E035FB',
#   '2011-06-27 00:00:00.000'),
#  (43783,
#   8,
#   '2011-06-20 00:00:00.000',
#   '2011-07-02 00:00:00.000',
#   '2011-06-27 00:00:00.000',
#   5,
#   1,
#   'SO43783',
#   None,
#   '10-4030-016620',
#   16620,
#   None,
#   9,
#   26601,
#   26601,
#   1,
#   4651.0,
#   '934630Vi24399',
#   262.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '4B963EE6-0B6E-4AD5-B778-A24757B6C1F2',
#   '2011-06-27 00:00:00.000'),
#  (43784,
#   8,
#   '2011-06-21 00:00:00.000',
#   '2011-07-03 00:00:00.000',
#   '2011-06-28 00:00:00.000',
#   5,
#   1,
#   'SO43784',
#   None,
#   '10-4030-027667',
#   27667,
#   None,
#   4,
#   12491,
#   12491,
#   1,
#   15794.0,
#   '1030202Vi81657',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '8D7E4809-DF6B-4B89-B92F-724FFB2BE7A2',
#   '2011-06-28 00:00:00.000'),
#  (43785,
#   8,
#   '2011-06-21 00:00:00.000',
#   '2011-07-03 00:00:00.000',
#   '2011-06-28 00:00:00.000',
#   5,
#   1,
#   'SO43785',
#   None,
#   '10-4030-011601',
#   11601,
#   None,
#   7,
#   17236,
#   17236,
#   1,
#   3584.0,
#   '931114Vi18886',
#   281.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '3A9346F3-F9B0-4446-B336-82767FDA4371',
#   '2011-06-28 00:00:00.000'),
#  (43786,
#   8,
#   '2011-06-21 00:00:00.000',
#   '2011-07-03 00:00:00.000',
#   '2011-06-28 00:00:00.000',
#   5,
#   1,
#   'SO43786',
#   None,
#   '10-4030-011607',
#   11607,
#   None,
#   7,
#   23683,
#   23683,
#   1,
#   12315.0,
#   '931126Vi63695',
#   281.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '24838E6C-11C1-4547-B8D8-1049DB94D2FB',
#   '2011-06-28 00:00:00.000'),
#  (43787,
#   8,
#   '2011-06-21 00:00:00.000',
#   '2011-07-03 00:00:00.000',
#   '2011-06-28 00:00:00.000',
#   5,
#   1,
#   'SO43787',
#   None,
#   '10-4030-029385',
#   29385,
#   None,
#   8,
#   29348,
#   29348,
#   1,
#   None,
#   None,
#   279.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
# ...
#   None,
#   '59A897EE-3AD2-4939-B7B7-BEB6F820B8A3',
#   '2011-10-15 00:00:00.000'),
#  (44616,
#   8,
#   '2011-10-08 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   '2011-10-15 00:00:00.000',
#   5,
#   1,
#   'SO44616',
#   None,
#   '10-4030-028655',
#   28655,
#   None,
#   1,
#   13945,
#   13945,
#   1,
#   14338.0,
#   '732858Vi74341',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'E432D34A-6021-4276-8961-69D6E7243C06',
#   '2011-10-15 00:00:00.000'),
#  (44617,
#   8,
#   '2011-10-08 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   '2011-10-15 00:00:00.000',
#   5,
#   1,
#   'SO44617',
#   None,
#   '10-4030-028666',
#   28666,
#   None,
#   1,
#   27677,
#   27677,
#   1,
#   9509.0,
#   '1232868Vi49027',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'FA0445DF-E564-4AB1-ABDE-6832592E8077',
#   '2011-10-15 00:00:00.000'),
#  (44618,
#   8,
#   '2011-10-08 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   '2011-10-15 00:00:00.000',
#   5,
#   1,
#   'SO44618',
#   None,
#   '10-4030-018205',
#   18205,
#   None,
#   9,
#   29786,
#   29786,
#   1,
#   None,
#   None,
#   1692.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '5538A8C2-52D5-431F-AD97-C5AE6A2DC35C',
#   '2011-10-15 00:00:00.000'),
#  (44619,
#   8,
#   '2011-10-09 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   '2011-10-16 00:00:00.000',
#   5,
#   1,
#   'SO44619',
#   None,
#   '10-4030-013789',
#   13789,
#   None,
#   8,
#   29057,
#   29057,
#   1,
#   11868.0,
#   '930917Vi61279',
#   1709.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '56AD4AA2-A984-4894-AC7C-4A270731CEE2',
#   '2011-10-16 00:00:00.000'),
#  (44620,
#   8,
#   '2011-10-09 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   '2011-10-16 00:00:00.000',
#   5,
#   1,
#   'SO44620',
#   None,
#   '10-4030-018204',
#   18204,
#   None,
#   9,
#   29796,
#   29796,
#   1,
#   None,
#   None,
#   1705.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '6D3FDD75-6676-4CF3-9497-66F3E38822DD',
#   '2011-10-16 00:00:00.000'),
#  (44621,
#   8,
#   '2011-10-09 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   '2011-10-16 00:00:00.000',
#   5,
#   1,
#   'SO44621',
#   None,
#   '10-4030-018217',
#   18217,
#   None,
#   9,
#   23825,
#   23825,
#   1,
#   12879.0,
#   '335335Vi66610',
#   1705.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '33D83FD8-669C-4D6C-A861-063AB0A4CE67',
#   '2011-10-16 00:00:00.000'),
#  (44622,
#   8,
#   '2011-10-09 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   '2011-10-16 00:00:00.000',
#   5,
#   1,
#   'SO44622',
#   None,
#   '10-4030-013771',
#   13771,
#   None,
#   8,
#   28326,
#   28326,
#   1,
#   15452.0,
#   '535731Vi79804',
#   1709.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '63162505-412E-4E2C-8C4F-CDB61C9DF5EA',
#   '2011-10-16 00:00:00.000'),
#  (44623,
#   8,
#   '2011-10-10 00:00:00.000',
#   '2011-10-22 00:00:00.000',
#   '2011-10-17 00:00:00.000',
#   5,
#   1,
#   'SO44623',
#   None,
#   '10-4030-012301',
#   12301,
#   None,
#   7,
#   25701,
#   25701,
#   1,
#   10091.0,
#   '630921Vi52012',
#   1724.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '9374AACF-7DA1-4CF6-AA14-3C031C0C5FFB',
#   '2011-10-17 00:00:00.000'),
#  (44624,
#   8,
#   '2011-10-10 00:00:00.000',
#   '2011-10-22 00:00:00.000',
#   '2011-10-17 00:00:00.000',
#   5,
#   1,
#   'SO44624',
#   None,
#   '10-4030-019357',
#   19357,
#   None,
#   8,
#   15593,
#   15593,
#   1,
#   17117.0,
#   '732669Vi88874',
#   1722.0,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   '4EF7585D-044D-44A3-BD6E-85529AF81A13',
#   '2011-10-17 00:00:00.000'),
#  (44625,
#   8,
#   '2011-10-10 00:00:00.000',
#   '2011-10-22 00:00:00.000',
#   '2011-10-17 00:00:00.000',
#   5,
#   1,
#   'SO44625',
#   None,
#   '10-4030-028658',
#   28658,
#   None,
#   4,
#   28904,
#   28904,
#   1,
#   18313.0,
#   '1132860Vi95100',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'E858E732-D6E2-45B6-8112-560D10B6EC12',
#   '2011-10-17 00:00:00.000'),
#  (44626,
#   8,
#   '2011-10-10 00:00:00.000',
#   '2011-10-22 00:00:00.000',
#   '2011-10-17 00:00:00.000',
#   5,
#   1,
#   'SO44626',
#   None,
#   '10-4030-018272',
#   18272,
#   None,
#   9,
#   14955,
#   14955,
#   1,
#   5005.0,
#   '534422Vi26224',
#   1718.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '94071C86-C357-4832-99A5-5F004002B3CD',
#   '2011-10-17 00:00:00.000'),
#  (44627,
#   8,
#   '2011-10-10 00:00:00.000',
#   '2011-10-22 00:00:00.000',
#   '2011-10-17 00:00:00.000',
#   5,
#   1,
#   'SO44627',
#   None,
#   '10-4030-011109',
#   11109,
#   None,
#   9,
#   20252,
#   20252,
#   1,
#   10958.0,
#   '134962Vi56506',
#   1718.0,
#   '3374.99',
#   '269.9992',
#   '84.3748',
#   '3729,364',
#   None,
#   '813DB798-D0FB-470B-AD64-A964EC4F85D7',
#   '2011-10-17 00:00:00.000'),
#  (44628,
#   8,
#   '2011-10-10 00:00:00.000',
#   '2011-10-22 00:00:00.000',
#   '2011-10-17 00:00:00.000',
#   5,
#   1,
#   'SO44628',
#   None,
#   '10-4030-011356',
#   11356,
#   None,
#   9,
#   13309,
#   13309,
#   1,
#   5303.0,
#   '334973Vi27713',
#   1718.0,
#   '3374.99',
#   '269.9992',
#   '84.3748',
#   '3729,364',
#   None,
#   'B845E8CA-B3D1-4A2A-BDBC-931909BDD9E5',
#   '2011-10-17 00:00:00.000'),
#  (44629,
#   8,
#   '2011-10-10 00:00:00.000',
#   '2011-10-22 00:00:00.000',
#   '2011-10-17 00:00:00.000',
#   5,
#   1,
#   'SO44629',
#   None,
#   '10-4030-018209',
#   18209,
#   None,
#   9,
#   16268,
#   16268,
#   1,
#   7792.0,
#   '435330Vi40377',
#   1718.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '98F71F58-844A-48B8-9D5F-FEAD6A6C9736',
#   '2011-10-17 00:00:00.000'),
#  (44630,
#   8,
#   '2011-10-11 00:00:00.000',
#   '2011-10-23 00:00:00.000',
#   '2011-10-18 00:00:00.000',
#   5,
#   1,
#   'SO44630',
#   None,
#   '10-4030-028765',
#   28765,
#   None,
#   4,
#   13011,
#   13011,
#   1,
#   13120.0,
#   '532762Vi67949',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '874967CF-CB99-47ED-A6A3-0B078E45D8BE',
#   '2011-10-18 00:00:00.000'),
#  (44631,
#   8,
#   '2011-10-11 00:00:00.000',
#   '2011-10-23 00:00:00.000',
#   '2011-10-18 00:00:00.000',
#   5,
#   1,
#   'SO44631',
#   None,
#   '10-4030-028629',
#   28629,
#   None,
#   4,
#   28834,
#   28834,
#   1,
#   10078.0,
#   '632846Vi51920',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'FAB1E22D-9E12-4A74-93F3-C33C2726B278',
#   '2011-10-18 00:00:00.000'),
#  (44632,
#   8,
#   '2011-10-11 00:00:00.000',
#   '2011-10-23 00:00:00.000',
#   '2011-10-18 00:00:00.000',
#   5,
#   1,
#   'SO44632',
#   None,
#   '10-4030-018196',
#   18196,
#   None,
#   9,
#   17235,
#   17235,
#   1,
#   7406.0,
#   '735320Vi38398',
#   1731.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'EB65772F-51BF-42D2-9329-143D1DCD6E0E',
#   '2011-10-18 00:00:00.000'),
#  (44633,
#   8,
#   '2011-10-11 00:00:00.000',
#   '2011-10-23 00:00:00.000',
#   '2011-10-18 00:00:00.000',
#   5,
#   1,
#   'SO44633',
#   None,
#   '10-4030-018203',
#   18203,
#   None,
#   9,
#   22158,
#   22158,
#   1,
#   17458.0,
#   '335325Vi90716',
#   1731.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '6C75F155-8CCF-479A-ADE9-D8FC10CE6410',
#   '2011-10-18 00:00:00.000'),
#  (44634,
#   8,
#   '2011-10-11 00:00:00.000',
#   '2011-10-23 00:00:00.000',
#   '2011-10-18 00:00:00.000',
#   5,
#   1,
#   'SO44634',
#   None,
#   '10-4030-018213',
#   18213,
#   None,
#   9,
#   17760,
#   17760,
#   1,
#   11837.0,
#   '635333Vi61169',
#   1731.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '0EA3157F-FF63-496C-8990-2F7500B235E9',
#   '2011-10-18 00:00:00.000'),
#  (44635,
#   8,
#   '2011-10-11 00:00:00.000',
#   '2011-10-23 00:00:00.000',
#   '2011-10-18 00:00:00.000',
#   5,
#   1,
#   'SO44635',
#   None,
#   '10-4030-018218',
#   18218,
#   None,
#   9,
#   14727,
#   14727,
#   1,
#   17513.0,
#   '535336Vi90954',
#   1731.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '793CDAAD-E2A9-484E-941D-F69514739371',
#   '2011-10-18 00:00:00.000'),
#  (44636,
#   8,
#   '2011-10-12 00:00:00.000',
#   '2011-10-24 00:00:00.000',
#   '2011-10-19 00:00:00.000',
#   5,
#   1,
#   'SO44636',
#   None,
#   '10-4030-014705',
#   14705,
#   None,
#   10,
#   16399,
#   16399,
#   1,
#   3709.0,
#   '1130910Vi19572',
#   1751.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '6D4B3BD4-4C53-4B98-A125-4FDB2CE3ADCA',
#   '2011-10-19 00:00:00.000'),
#  (44637,
#   8,
#   '2011-10-12 00:00:00.000',
#   '2011-10-24 00:00:00.000',
#   '2011-10-19 00:00:00.000',
#   5,
#   1,
#   'SO44637',
#   None,
#   '10-4030-028644',
#   28644,
#   None,
#   1,
#   13924,
#   13924,
#   1,
#   6835.0,
#   '832850Vi35634',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '90B582F0-26EE-402E-8EC9-298AC0632350',
#   '2011-10-19 00:00:00.000'),
#  (44638,
#   8,
#   '2011-10-12 00:00:00.000',
#   '2011-10-24 00:00:00.000',
#   '2011-10-19 00:00:00.000',
#   5,
#   1,
#   'SO44638',
#   None,
#   '10-4030-028651',
#   28651,
#   None,
#   4,
#   20687,
#   20687,
#   1,
#   6636.0,
#   '132854Vi34547',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '54D16593-F421-4560-8FF2-BD43BA20AD0C',
#   '2011-10-19 00:00:00.000'),
#  (44639,
#   8,
#   '2011-10-12 00:00:00.000',
#   '2011-10-24 00:00:00.000',
#   '2011-10-19 00:00:00.000',
#   5,
#   1,
#   'SO44639',
#   None,
#   '10-4030-014617',
#   14617,
#   None,
#   1,
#   14531,
#   14531,
#   1,
#   3534.0,
#   '533822Vi18604',
#   None,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   'DC41279B-9DA8-4F91-91FD-0B5DE2994510',
#   '2011-10-19 00:00:00.000'),
#  (44640,
#   8,
#   '2011-10-12 00:00:00.000',
#   '2011-10-24 00:00:00.000',
#   '2011-10-19 00:00:00.000',
#   5,
#   1,
#   'SO44640',
#   None,
#   '10-4030-018246',
#   18246,
#   None,
#   9,
#   13308,
#   13308,
#   1,
#   6719.0,
#   '534411Vi34979',
#   1744.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '29BB4CA3-9158-482B-9D0B-88FFF0B9B86C',
#   '2011-10-19 00:00:00.000'),
#  (44641,
#   8,
#   '2011-10-12 00:00:00.000',
#   '2011-10-24 00:00:00.000',
#   '2011-10-19 00:00:00.000',
#   5,
#   1,
#   'SO44641',
#   None,
#   '10-4030-018255',
#   18255,
#   None,
#   9,
#   28889,
#   28889,
#   1,
#   19182.0,
#   '434418Vi99679',
#   1744.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '1FBFC5F2-7364-43E3-8334-912B616F9586',
#   '2011-10-19 00:00:00.000'),
#  (44642,
#   8,
#   '2011-10-12 00:00:00.000',
#   '2011-10-24 00:00:00.000',
#   '2011-10-19 00:00:00.000',
#   5,
#   1,
#   'SO44642',
#   None,
#   '10-4030-025567',
#   25567,
#   None,
#   9,
#   27011,
#   27011,
#   1,
#   223.0,
#   '434564Vi1149',
#   1744.0,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   'E2B21D19-D6B6-4882-8956-BC0DE830440E',
#   '2011-10-19 00:00:00.000'),
#  (44643,
#   8,
#   '2011-10-13 00:00:00.000',
#   '2011-10-25 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   5,
#   1,
#   'SO44643',
#   None,
#   '10-4030-012280',
#   12280,
#   None,
#   7,
#   22960,
#   22960,
#   1,
#   2334.0,
#   '230907Vi12170',
#   1763.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'FF83E557-1801-4F36-B4C3-B292625E966E',
#   '2011-10-20 00:00:00.000'),
#  (44644,
#   8,
#   '2011-10-13 00:00:00.000',
#   '2011-10-25 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   5,
#   1,
#   'SO44644',
#   None,
#   '10-4030-012279',
#   12279,
#   None,
#   7,
#   23617,
#   23617,
#   1,
#   10618.0,
#   '230965Vi54749',
#   1763.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '0CC667BF-8CDD-48AF-9E2D-E5FF4385FBC1',
#   '2011-10-20 00:00:00.000'),
#  (44645,
#   8,
#   '2011-10-13 00:00:00.000',
#   '2011-10-25 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   5,
#   1,
#   'SO44645',
#   None,
#   '10-4030-011344',
#   11344,
#   None,
#   10,
#   14467,
#   14467,
#   1,
#   11312.0,
#   '131760Vi58323',
#   1764.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '69E88B00-14F9-40BF-B8CA-FAFDC00209AE',
#   '2011-10-20 00:00:00.000'),
#  (44646,
#   8,
#   '2011-10-13 00:00:00.000',
#   '2011-10-25 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   5,
#   1,
#   'SO44646',
#   None,
#   '10-4030-029449',
#   29449,
#   None,
#   8,
#   11407,
#   11407,
#   1,
#   759.0,
#   '631763Vi3879',
#   1761.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   'B8A0DF2C-B748-4C40-AC91-BB18AB7FA813',
#   '2011-10-20 00:00:00.000'),
#  (44647,
#   8,
#   '2011-10-13 00:00:00.000',
#   '2011-10-25 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   5,
#   1,
#   'SO44647',
#   None,
#   '10-4030-028770',
#   28770,
#   None,
#   1,
#   23080,
#   23080,
#   1,
#   1759.0,
#   '432764Vi9066',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '12F2EDAB-1B99-41F8-B166-EFEB0C6A4FC4',
#   '2011-10-20 00:00:00.000'),
#  (44648,
#   8,
#   '2011-10-13 00:00:00.000',
#   '2011-10-25 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   5,
#   1,
#   'SO44648',
#   None,
#   '10-4030-025916',
#   25916,
#   None,
#   4,
#   26605,
#   26605,
#   1,
#   5495.0,
#   '733279Vi28821',
#   None,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   '0922E619-87A1-462D-9E0C-810413E72C0B',
#   '2011-10-20 00:00:00.000'),
#  (44649,
#   8,
#   '2011-10-13 00:00:00.000',
#   '2011-10-25 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   5,
#   1,
#   'SO44649',
#   None,
#   '10-4030-025924',
#   25924,
#   None,
#   4,
#   21368,
#   21368,
#   1,
#   18132.0,
#   '1233282Vi94024',
#   None,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   'CC5B5EF6-B141-4F5E-973C-39355AC873B8',
#   '2011-10-20 00:00:00.000'),
#  (44650,
#   8,
#   '2011-10-13 00:00:00.000',
#   '2011-10-25 00:00:00.000',
#   '2011-10-20 00:00:00.000',
#   5,
#   1,
#   'SO44650',
#   None,
#   '10-4030-011147',
#   11147,
#   None,
#   9,
#   15498,
#   15498,
#   1,
#   967.0,
#   '834971Vi4843',
#   1757.0,
#   '3374.99',
#   '269.9992',
#   '84.3748',
#   '3729,364',
#   None,
#   'EE3B8124-B4B1-41F3-88CA-7AC2784E9CD2',
#   '2011-10-20 00:00:00.000'),
#  (44651,
#   8,
#   '2011-10-14 00:00:00.000',
#   '2011-10-26 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   5,
#   1,
#   'SO44651',
#   None,
#   '10-4030-014720',
#   14720,
#   None,
#   10,
#   26535,
#   26535,
#   1,
#   13014.0,
#   '530915Vi67328',
#   1777.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'D2978559-C28F-406E-9E73-746E33D0ADA5',
#   '2011-10-21 00:00:00.000'),
#  (44652,
#   8,
#   '2011-10-14 00:00:00.000',
#   '2011-10-26 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   5,
#   1,
#   'SO44652',
#   None,
#   '10-4030-028407',
#   28407,
#   None,
#   7,
#   20926,
#   20926,
#   1,
#   6625.0,
#   '931757Vi34487',
#   1776.0,
#   '3374.99',
#   '269.9992',
#   '84.3748',
#   '3729,364',
#   None,
#   '68864183-B9CE-4B11-94B7-EC15877DCC56',
#   '2011-10-21 00:00:00.000'),
#  (44653,
#   8,
#   '2011-10-14 00:00:00.000',
#   '2011-10-26 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   5,
#   1,
#   'SO44653',
#   None,
#   '10-4030-020170',
#   20170,
#   None,
#   10,
#   16731,
#   16731,
#   1,
#   13272.0,
#   '1232674Vi68837',
#   1777.0,
#   '699.0982',
#   '55.9279',
#   '17.4775',
#   '772,5036',
#   None,
#   '9F1552DB-91C1-4C55-AD40-186D8D3B391A',
#   '2011-10-21 00:00:00.000'),
#  (44654,
#   8,
#   '2011-10-14 00:00:00.000',
#   '2011-10-26 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   5,
#   1,
#   'SO44654',
#   None,
#   '10-4030-028619',
#   28619,
#   None,
#   4,
#   28292,
#   28292,
#   1,
#   12353.0,
#   '1032841Vi63906',
#   None,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '999EC164-6BC0-4D4D-B0D7-BF8A3377CC7C',
#   '2011-10-21 00:00:00.000'),
#  (44655,
#   8,
#   '2011-10-14 00:00:00.000',
#   '2011-10-26 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   5,
#   1,
#   'SO44655',
#   None,
#   '10-4030-011105',
#   11105,
#   None,
#   9,
#   24502,
#   24502,
#   1,
#   18919.0,
#   '834150Vi98284',
#   1770.0,
#   '3399.99',
#   '271.9992',
#   '84.9998',
#   '3756,989',
#   None,
#   'FAC4363F-6932-47FF-8801-5619ED2BBA56',
#   '2011-10-21 00:00:00.000'),
#  (44656,
#   8,
#   '2011-10-14 00:00:00.000',
#   '2011-10-26 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   5,
#   1,
#   'SO44656',
#   None,
#   '10-4030-018275',
#   18275,
#   None,
#   9,
#   11651,
#   11651,
#   1,
#   12162.0,
#   '1234424Vi62869',
#   1770.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   '51FBF6A5-4AF7-49F1-B9EF-F4100496F000',
#   '2011-10-21 00:00:00.000'),
#  (44657,
#   8,
#   '2011-10-14 00:00:00.000',
#   '2011-10-26 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   5,
#   1,
#   'SO44657',
#   None,
#   '10-4030-011120',
#   11120,
#   None,
#   9,
#   15108,
#   15108,
#   1,
#   5503.0,
#   '934967Vi28849',
#   1770.0,
#   '3374.99',
#   '269.9992',
#   '84.3748',
#   '3729,364',
#   None,
#   'CF059E0D-3392-49F0-8DA9-0865798C4FB3',
#   '2011-10-21 00:00:00.000'),
#  (44658,
#   8,
#   '2011-10-14 00:00:00.000',
#   '2011-10-26 00:00:00.000',
#   '2011-10-21 00:00:00.000',
#   5,
#   1,
#   'SO44658',
#   None,
#   '10-4030-018201',
#   18201,
#   None,
#   9,
#   12512,
#   12512,
#   1,
#   1429.0,
#   '135323Vi7318',
#   1770.0,
#   '3578.27',
#   '286.2616',
#   '89.4568',
#   '3953,9884',
#   None,
#   'D55CC1B2-4443-4DA7-BB75-F5DEFD62B2B8',
#   '2011-10-21 00:00:00.000'),
#  ...]

# %% [markdown]
# ### Sales.SpecialOfferProduct

# %%
#Escolhendo o arquivo dentro do bucket

bucket.blob('Sales.SpecialOfferProduct.csv')
# Out:
# <Blob: desafio-rox-leandro, Sales.SpecialOfferProduct.csv, None>

# %%
# Criando o df em pandas para enviar para o mysql
# SpecialOfferID com valores iguais.

df_SpecialOfferProduct = pd.read_csv(path_SpecialOfferProduct,sep=';')

# Definindo uma nova numeração de ID para SpecialOfferID
for i in range(len(df_SpecialOfferProduct)):
    df_SpecialOfferProduct.at[i, 'SpecialOfferID'] = i+1

# %%
# Codigo repetido em todos os passos, colab dando erro, foi preciso sempre redefinir o conector.
# Conector host:ip_banco, user:usuario, passwd: senha, db:banco criado

con = mysql.connector.connect(host='34.95.218.222',user='desafio-username',passwd='1234',db='bicicletas')
cur = con.cursor()
engine = create_engine('mysql+pymysql://desafio-username:1234@34.95.218.222/bicicletas')

# %%
# Enviando a tabela SalesSpecialOfferProduct para o MySql 

dfsql_SpecialOfferProduct = df_SpecialOfferProduct.to_sql('SalesSpecialOfferProduct',con=engine,if_exists='replace',index=False)

# %%
# Verificando o conteúdo enviado

cur.execute('select * from SalesSpecialOfferProduct')
cur.fetchall()
# Out:
# [(1, 680, 'BB30B868-D86C-4557-8DB2-4B2D0A83A0FB', '2011-04-01 00:00:00.000'),
#  (2, 706, 'B3C9A4B1-2AE6-4CBA-B552-1F206C9F4C1F', '2011-04-01 00:00:00.000'),
#  (3, 707, '27B711FE-0B77-4EA4-AD1A-7C239956BEF4', '2011-04-01 00:00:00.000'),
#  (4, 708, '46CBB78B-246E-4D69-9BD6-E521277C1078', '2011-04-01 00:00:00.000'),
#  (5, 709, 'CF102AA0-055F-4D2B-8B98-04B161758EA8', '2011-04-01 00:00:00.000'),
#  (6, 710, '63718DA1-464B-4325-9514-CDEE46CB124F', '2011-04-01 00:00:00.000'),
#  (7, 711, '457EB971-D1C9-48CA-B947-AE7E1B114377', '2011-04-01 00:00:00.000'),
#  (8, 712, '5B948448-BAE5-4F2A-A1F3-8203E892FD24', '2011-04-01 00:00:00.000'),
#  (9, 713, '07768F40-6E46-430F-AC1A-FF6A3629729C', '2011-04-01 00:00:00.000'),
#  (10, 714, '85004BCE-C74A-4D4E-8D17-3157991A1400', '2011-04-01 00:00:00.000'),
#  (11, 715, 'BE469616-B279-452F-8C41-9EB30B2E935A', '2011-04-01 00:00:00.000'),
#  (12, 716, '96D141FD-1D8E-4312-B4B1-E72C0A0D15FE', '2011-04-01 00:00:00.000'),
#  (13, 717, 'F717C3DC-3DBF-4F4E-B57A-BACB0134BDBC', '2011-04-01 00:00:00.000'),
#  (14, 718, 'B4634789-ACBB-4701-A006-186B18875FCD', '2011-04-01 00:00:00.000'),
#  (15, 719, 'B0F55004-472E-4C6B-B80F-095C135258A7', '2011-04-01 00:00:00.000'),
#  (16, 720, '691B64BD-C417-4787-99B3-FCFF8046AC5F', '2011-04-01 00:00:00.000'),
#  (17, 721, '0FE22357-94A1-4080-B941-2AF7E3513E40', '2011-04-01 00:00:00.000'),
#  (18, 722, '87AF8A2A-02B8-4657-AA55-327B87685C5C', '2011-04-01 00:00:00.000'),
#  (19, 723, '6A155B5E-7E94-4A79-AC70-CA099B86981E', '2011-04-01 00:00:00.000'),
#  (20, 724, 'EBFBD8D4-3067-4D21-8DDB-64A3945D06D6', '2011-04-01 00:00:00.000'),
#  (21, 725, '97476DD3-53E3-4C0A-B90D-177075E7BC26', '2011-04-01 00:00:00.000'),
#  (22, 726, '0EA15696-E203-4627-B2F1-2B8D24B23116', '2011-04-01 00:00:00.000'),
#  (23, 727, '3A1175F0-940F-4FFA-9D5C-695DB429BC76', '2011-04-01 00:00:00.000'),
#  (24, 728, 'DC027483-C1C1-4449-AA5E-457DD1221803', '2011-04-01 00:00:00.000'),
#  (25, 729, 'F7BDDB48-FA74-41E5-8913-ECBA4393254B', '2011-04-01 00:00:00.000'),
#  (26, 730, '4A12BD85-DC0A-4CA4-A30F-D1A68B8C5E0F', '2011-04-01 00:00:00.000'),
#  (27, 731, 'CCDC8B7B-B7EB-4C53-96B5-0215D904D51E', '2011-04-01 00:00:00.000'),
#  (28, 732, '447E29A2-6026-426D-A5CC-586E684EFFFD', '2011-04-01 00:00:00.000'),
#  (29, 733, '5E22434E-8BE1-44B1-85E2-2547F01DC44F', '2011-04-01 00:00:00.000'),
#  (30, 734, 'EBE7B2C5-8963-4D34-BE81-20BEC896E5B8', '2011-04-01 00:00:00.000'),
#  (31, 735, '38629ADF-024C-42A1-98E4-E33DF40BBAAB', '2011-04-01 00:00:00.000'),
#  (32, 736, '8AF19B7E-007E-4531-9808-B1C01505EDFD', '2011-04-01 00:00:00.000'),
#  (33, 737, '1F845481-CAA5-4F9A-BCB5-C79FDED5CFB4', '2011-04-01 00:00:00.000'),
#  (34, 738, 'CADF8706-7C3F-426F-9EA6-A2859D372110', '2011-04-01 00:00:00.000'),
#  (35, 739, '9AC4A238-D3FD-4F8B-A0BA-22874F2EE828', '2011-04-01 00:00:00.000'),
#  (36, 740, '335B8526-2242-4E6F-940F-2C817947A262', '2011-04-01 00:00:00.000'),
#  (37, 741, 'E1138B2A-B3A2-44F0-9E9B-FCD948766830', '2011-04-01 00:00:00.000'),
#  (38, 742, 'AA5F7567-E06B-4D6C-9804-9169564439AF', '2011-04-01 00:00:00.000'),
#  (39, 743, 'EED6435E-E95D-4332-B4A0-C91B22FC198D', '2011-04-01 00:00:00.000'),
#  (40, 744, '4679B501-DE36-4E38-859A-F72D88F96D8D', '2011-04-01 00:00:00.000'),
#  (41, 745, '00365938-3422-494E-B92E-C00AFD691469', '2011-04-01 00:00:00.000'),
#  (42, 746, 'C7CA66B2-5AA8-4F8F-9873-D80167B34DE6', '2011-04-01 00:00:00.000'),
#  (43, 747, '042C1933-0B2F-4FD8-B756-EA1ED88A42EE', '2011-04-01 00:00:00.000'),
#  (44, 748, 'C730BD7C-1E95-4EC1-B1F1-CB2F778C8CB7', '2011-04-01 00:00:00.000'),
#  (45, 749, 'E4568488-03A5-467A-9836-32E47379E158', '2011-04-01 00:00:00.000'),
#  (46, 750, '8DEFDAE3-8D7F-4996-BBAE-34350A8C5406', '2011-04-01 00:00:00.000'),
#  (47, 751, '019CA613-172C-43AB-AD67-47DD78291C5F', '2011-04-01 00:00:00.000'),
#  (48, 752, 'C95D0A99-88AF-4904-8D0C-EC790BF6AC38', '2011-04-01 00:00:00.000'),
#  (49, 753, '3130BBB6-E0DA-457D-BD10-8E90C975AA56', '2011-04-01 00:00:00.000'),
#  (50, 754, '7C6AF643-5CE8-4929-BD5E-7821AEAAEFCB', '2011-04-01 00:00:00.000'),
#  (51, 755, '0DBD2112-54C5-4FBA-9535-FB6AC85FBC1A', '2011-04-01 00:00:00.000'),
#  (52, 756, '0E45ECA1-D17F-44E4-9768-80B82F980376', '2011-04-01 00:00:00.000'),
#  (53, 757, '40A9E94E-3CEE-4F4C-A97C-0776D38ABFD5', '2011-04-01 00:00:00.000'),
#  (54, 758, '1D082E24-2F19-49D6-A4E1-4D7328806633', '2011-04-01 00:00:00.000'),
#  (55, 759, 'AEE3C9F4-C219-438D-84EE-6C5E3BF074B7', '2011-04-01 00:00:00.000'),
#  (56, 760, 'F19F943B-7BF6-4617-87D9-316CC4C9BAB2', '2011-04-01 00:00:00.000'),
#  (57, 761, '5AE00BCA-B5B9-4F0B-8B2A-9560BD2EE07F', '2011-04-01 00:00:00.000'),
#  (58, 762, '7899DC72-5E42-4C5C-838B-CB551537329B', '2011-04-01 00:00:00.000'),
#  (59, 763, '23970497-E475-48DC-9A38-96DC956F4608', '2011-04-01 00:00:00.000'),
#  (60, 764, '8B5D68B0-EB43-45D5-A062-368C9ED00DFD', '2011-04-01 00:00:00.000'),
#  (61, 765, '6B1EBF89-40CA-471C-A243-EA6E178AEF1B', '2011-04-01 00:00:00.000'),
#  (62, 766, '6D4ED8CD-579D-4B7C-B44A-6CFF4AABEC20', '2011-04-01 00:00:00.000'),
#  (63, 767, '1BCBB834-57A1-424B-B8B1-42EA18F381CB', '2011-04-01 00:00:00.000'),
#  (64, 768, '93ABBCF6-DA36-4BCC-AF79-3BAC86331972', '2011-04-01 00:00:00.000'),
#  (65, 769, '21A2F964-6D44-40D7-ABE2-EF974C4D19FF', '2011-04-01 00:00:00.000'),
#  (66, 770, 'F3414C43-CF20-4AEB-AD8E-0B7E6E682D1C', '2011-04-01 00:00:00.000'),
#  (67, 771, 'F9A22C63-1CA7-48E4-870B-CEDF4BA0F00B', '2011-04-01 00:00:00.000'),
#  (68, 772, '8E5C4CC8-669F-4A72-9E99-5DB8CCBEF765', '2011-04-01 00:00:00.000'),
#  (69, 773, 'BB0F1748-3BFF-4307-ABF2-04B26FAF3499', '2011-04-01 00:00:00.000'),
#  (70, 774, '870FA4A2-B3D5-4057-A2B1-A2CAF6A31DB0', '2011-04-01 00:00:00.000'),
#  (71, 775, 'F49C722C-6CD0-49D3-85EF-B6AFB67B6E73', '2011-04-01 00:00:00.000'),
#  (72, 776, 'D70CF5A5-07F0-4D60-B292-5E07F5EC614D', '2011-04-01 00:00:00.000'),
#  (73, 777, '97A7183A-A0BE-42FD-BE18-209881576558', '2011-04-01 00:00:00.000'),
#  (74, 778, '61AE5D03-B7EE-4A61-A233-CC23D526A8A9', '2011-04-01 00:00:00.000'),
#  (75, 779, '4193FD04-F96B-4146-895C-292C969B468A', '2011-04-01 00:00:00.000'),
#  (76, 780, '59D8170E-02D0-455A-9E43-E9590E732D34', '2011-04-01 00:00:00.000'),
#  (77, 781, '4A71D4B6-62EE-4BCC-ABA8-5870917316BB', '2011-04-01 00:00:00.000'),
#  (78, 782, '35E1419D-AC65-4305-ADFD-50B4CB1AD7BF', '2011-04-01 00:00:00.000'),
#  (79, 783, '4CE5BF73-511A-4308-817D-EB0FEE2F07FD', '2011-04-01 00:00:00.000'),
#  (80, 784, '018C6DD3-A040-4818-9D0F-4C08D0017633', '2011-04-01 00:00:00.000'),
#  (81, 785, '646E2EA2-E817-414E-BB53-08F6206E238B', '2011-04-01 00:00:00.000'),
#  (82, 786, 'D91637E6-25E8-472A-929F-B3843FC005B4', '2011-04-01 00:00:00.000'),
#  (83, 787, '72C859BE-0038-41B3-8F3A-5E60D31E8691', '2011-04-01 00:00:00.000'),
#  (84, 788, 'ACF3185D-F485-4AF6-9C8D-4C757F68A435', '2011-04-01 00:00:00.000'),
#  (85, 789, '0EA6B126-864C-4647-B997-5224DFE460AA', '2011-04-01 00:00:00.000'),
#  (86, 790, 'A1D516CA-D93E-428D-8A43-E47F62B67078', '2011-04-01 00:00:00.000'),
#  (87, 791, '218533E8-AE68-457D-8BB8-7884B354BAD7', '2011-04-01 00:00:00.000'),
#  (88, 792, '24A371BB-6730-4FA4-B2B9-16ADEC67395B', '2011-04-01 00:00:00.000'),
#  (89, 793, '35AD391F-A302-4C9A-A1A2-5945FE409A62', '2011-04-01 00:00:00.000'),
#  (90, 794, '37B81B4E-A906-4CC7-B748-DE511FBC0EAD', '2011-04-01 00:00:00.000'),
#  (91, 795, '115F558F-D46B-4968-B22D-D697A4E00182', '2011-04-01 00:00:00.000'),
#  (92, 796, '5770E071-2BF3-4E2A-A7AD-4A1320F629DB', '2011-04-01 00:00:00.000'),
#  (93, 797, 'F453D8B5-D7CE-484D-A3D1-2767FF9276C5', '2011-04-01 00:00:00.000'),
#  (94, 798, '5D990BEC-06A0-4677-BDE1-D2B3F5897345', '2011-04-01 00:00:00.000'),
#  (95, 799, 'CB74499A-2819-4D7C-B8E3-BBBA7A625F9B', '2011-04-01 00:00:00.000'),
#  (96, 800, '0804B4A3-A704-4921-BC38-52A5ECD7F140', '2011-04-01 00:00:00.000'),
#  (97, 801, 'CD3FB612-33DA-40BE-9367-D613F8A36EF3', '2011-04-01 00:00:00.000'),
#  (98, 802, '78AACB54-2B48-4059-A191-D9B804EA0466', '2011-04-01 00:00:00.000'),
#  (99, 803, '641EE9D1-456B-425A-BB05-7CF2F4319FE1', '2011-04-01 00:00:00.000'),
#  (100, 804, '67204815-5122-4935-9E39-5E2CBE1CFE47', '2011-04-01 00:00:00.000'),
#  (101, 805, 'D065F8A0-BBEC-4192-8D5C-68C169A0F2B1', '2011-04-01 00:00:00.000'),
#  (102, 806, 'FCDF211F-8A2A-4F6D-8581-BB3051BD9891', '2011-04-01 00:00:00.000'),
#  (103, 807, '6D0078F8-2151-4438-A863-E55CD01BA3DF', '2011-04-01 00:00:00.000'),
#  (104, 808, '4DC70FFB-A6A9-4757-9E46-30193CC962C3', '2011-04-01 00:00:00.000'),
#  (105, 809, '60FC6A5D-81A2-483B-BE4A-BB2A70F8BF1B', '2011-04-01 00:00:00.000'),
#  (106, 810, '68B1C1A8-511C-45A7-8EDA-FE41F7E650E2', '2011-04-01 00:00:00.000'),
#  (107, 811, '9DB66331-11A5-4BE7-90D3-8043C2A3B210', '2011-04-01 00:00:00.000'),
#  (108, 812, '9F67A271-D700-4D25-A846-1EAAF1F11F73', '2011-04-01 00:00:00.000'),
#  (109, 813, '46960BB3-D5C9-4670-8449-74F9E99827A9', '2011-04-01 00:00:00.000'),
#  (110, 814, 'D16AAF96-C0A6-494A-B916-DE391F5389DF', '2011-04-01 00:00:00.000'),
#  (111, 815, '747089A2-E9BE-4E4E-816C-50EE674D938D', '2011-04-01 00:00:00.000'),
#  (112, 816, '6027777C-A61A-4AC9-BC6E-E691FB0B1B8F', '2011-04-01 00:00:00.000'),
#  (113, 817, '832B8E07-09DE-499F-B5E3-1F10541734A7', '2011-04-01 00:00:00.000'),
#  (114, 818, 'CD7CE0C4-1745-4F1E-A0F1-C62116BDBC20', '2011-04-01 00:00:00.000'),
#  (115, 819, 'B8C23CDF-B28A-45EE-96EC-6BB1FE665765', '2011-04-01 00:00:00.000'),
#  (116, 820, 'F125C363-21A0-4BBE-A5FE-D2FC974098E1', '2011-04-01 00:00:00.000'),
#  (117, 821, '27505F65-C5AB-4007-BA7A-042156A98967', '2011-04-01 00:00:00.000'),
#  (118, 822, '825D9493-BEE3-450A-9B56-766745B21931', '2011-04-01 00:00:00.000'),
#  (119, 823, '5B8CE0C5-54C9-4B87-90A0-F3E2AD92846F', '2011-04-01 00:00:00.000'),
#  (120, 824, 'DECE8415-513C-48D0-979A-08223BEAAF59', '2011-04-01 00:00:00.000'),
#  (121, 825, '06C4205A-E342-4216-AE2E-A231B2012B08', '2011-04-01 00:00:00.000'),
#  (122, 826, '8DA559A4-3BE0-429B-97CB-46BA98B6B1A2', '2011-04-01 00:00:00.000'),
#  (123, 827, '99223613-CB70-46E2-9881-D574B69736DE', '2011-04-01 00:00:00.000'),
#  (124, 828, 'C8A7B3FF-1322-4031-AA96-1BC38F09A7CA', '2011-04-01 00:00:00.000'),
#  (125, 829, '29673D72-2C56-4445-A10C-8B51627923FA', '2011-04-01 00:00:00.000'),
#  (126, 830, 'A96236FC-E731-4599-9EA5-67C00BD25EC0', '2011-04-01 00:00:00.000'),
#  (127, 831, '12B4F2A1-131F-47D6-BF07-8B4AFDBF36B3', '2011-04-01 00:00:00.000'),
#  (128, 832, 'DEB80CA9-7F9F-45CE-9ABA-411C2A8887CA', '2011-04-01 00:00:00.000'),
#  (129, 833, '64A665EE-361E-45E6-AB06-365A5FE85395', '2011-04-01 00:00:00.000'),
#  (130, 834, 'BBA0194A-605B-4C97-943B-E9BF4E51FA9E', '2011-04-01 00:00:00.000'),
#  (131, 835, 'D397760D-EACD-4F26-A03E-3AD2A84C7E56', '2011-04-01 00:00:00.000'),
#  (132, 836, '6B12FF4A-5467-47F6-8584-0B40AB14D8C2', '2011-04-01 00:00:00.000'),
#  (133, 837, 'BDFBCA49-92C3-4155-8D36-5159B1776770', '2011-04-01 00:00:00.000'),
#  (134, 838, '6A97249A-58DD-44D8-B405-EBA0B56FC1AF', '2011-04-01 00:00:00.000'),
#  (135, 839, 'EA3DEC45-3AFB-42B5-A3BB-C6369D9E3C1D', '2011-04-01 00:00:00.000'),
#  (136, 840, 'BE57F03C-3CDA-4FE8-9522-FB050782B3D0', '2011-04-01 00:00:00.000'),
#  (137, 841, '64478404-D1E3-4E45-AB75-A2189C725B6B', '2011-04-01 00:00:00.000'),
#  (138, 842, 'C6E0259D-03C0-4DDE-A667-0ACC230C6CB5', '2011-04-01 00:00:00.000'),
#  (139, 843, '7084ED14-EBC6-421A-BB27-0A87C36BFC3A', '2011-04-01 00:00:00.000'),
#  (140, 844, '3D26662B-8965-4931-A80E-AA04645F9CF9', '2011-04-01 00:00:00.000'),
#  (141, 845, 'CA877AB0-1673-4105-BA28-BA02AD6A1961', '2011-04-01 00:00:00.000'),
#  (142, 846, '58DBA248-DCC0-49A4-9A14-98D2872FFC4F', '2011-04-01 00:00:00.000'),
#  (143, 847, '24CF450A-D013-4C23-8FFE-38FA37B6B507', '2011-04-01 00:00:00.000'),
#  (144, 848, 'F111BB9D-A39B-4177-8703-042A98C58798', '2011-04-01 00:00:00.000'),
#  (145, 849, 'FB5D3790-15C5-4433-B112-F98F20993DAA', '2011-04-01 00:00:00.000'),
#  (146, 850, '5872AD5C-6627-4F50-A867-30D15EF82379', '2011-04-01 00:00:00.000'),
#  (147, 851, 'DA8D3484-FE54-4EFC-871C-41BBCD9836D9', '2011-04-01 00:00:00.000'),
#  (148, 852, '55120297-5C4E-4B4F-AE5A-BE6E4FCB3C62', '2011-04-01 00:00:00.000'),
#  (149, 853, '27921017-5D3A-4483-BFCE-CFE2829A672A', '2011-04-01 00:00:00.000'),
#  (150, 854, '371E3188-0814-4C39-9873-324036FA8BEB', '2011-04-01 00:00:00.000'),
#  (151, 855, 'C02443BE-B75F-4303-8B66-42BD772D93CE', '2011-04-01 00:00:00.000'),
#  (152, 856, '50C1A2C4-BF53-4B2A-BE25-6CE64C39F208', '2011-04-01 00:00:00.000'),
#  (153, 857, '6D732238-B6E3-4141-AC3A-0D0375C64E12', '2011-04-01 00:00:00.000'),
#  (154, 858, 'F921A9CF-4317-4551-BF86-A2F43F1A16CD', '2011-04-01 00:00:00.000'),
#  (155, 859, 'DD7D4183-2D5B-4F4D-8BDD-B2329A58D766', '2011-04-01 00:00:00.000'),
#  (156, 860, 'C1B69EAC-9620-40E4-A6ED-78AA8B039E21', '2011-04-01 00:00:00.000'),
#  (157, 861, 'BC481B9C-1CCB-4CBC-8152-89DA596C93D0', '2011-04-01 00:00:00.000'),
#  (158, 862, 'F8019958-409F-4E8F-AE4B-00136B6D75B5', '2011-04-01 00:00:00.000'),
#  (159, 863, '02EF598A-FB96-471D-9A52-1B8126FD6C35', '2011-04-01 00:00:00.000'),
#  (160, 864, 'CD77BDC6-2F5E-42B7-B08D-C54E42B85489', '2011-04-01 00:00:00.000'),
#  (161, 865, 'AA28EF5D-B6A2-42A5-B85C-28E2F3B04643', '2011-04-01 00:00:00.000'),
#  (162, 866, '3D0B6A28-4F8E-47F3-AC80-993F6FEF8305', '2011-04-01 00:00:00.000'),
#  (163, 867, '440548A8-810A-495B-89B0-F20469F8A987', '2011-04-01 00:00:00.000'),
#  (164, 868, 'C73285EF-8AEF-4668-9E7B-008301EF4795', '2011-04-01 00:00:00.000'),
#  (165, 869, 'A985EFAB-8697-4830-8D1F-FE80B74EB251', '2011-04-01 00:00:00.000'),
#  (166, 870, '5750B20F-CD8C-4E80-82AF-34FC59E87111', '2011-04-01 00:00:00.000'),
#  (167, 871, '7E56D319-9819-492E-A952-63ECA1C7C329', '2011-04-01 00:00:00.000'),
#  (168, 872, '4F5625F4-BF82-4BC8-91C0-7407F7E2384B', '2011-04-01 00:00:00.000'),
#  (169, 873, '78DC23C8-77F1-401F-97CD-44ED97B603A7', '2011-04-01 00:00:00.000'),
#  (170, 874, 'F44F5982-6C49-48E1-818E-BE0516BDF202', '2011-04-01 00:00:00.000'),
#  (171, 875, '21704CBF-711F-4A52-91CD-2694DBCFC8DD', '2011-04-01 00:00:00.000'),
#  (172, 876, '9FECC643-163F-4221-82F4-7DB0C267B5CE', '2011-04-01 00:00:00.000'),
#  (173, 877, '0020931C-087C-42F8-B441-EBE3D3B5F51E', '2011-04-01 00:00:00.000'),
#  (174, 878, '3C1D19AD-BB0C-46AB-9EFA-AFADD58BCB8F', '2011-04-01 00:00:00.000'),
#  (175, 879, 'C83CD1BA-DC3A-44C6-B3EE-FFCD33C64428', '2011-04-01 00:00:00.000'),
#  (176, 880, '8D98FD8C-410D-4B08-A705-F8F10BBE5BD8', '2011-04-01 00:00:00.000'),
#  (177, 881, 'D83C5DBF-9A9E-49D1-8599-B9135BDF1EA5', '2011-04-01 00:00:00.000'),
#  (178, 882, '7EE698AD-218B-40C2-B4F4-3ECDDE2D45C0', '2011-04-01 00:00:00.000'),
#  (179, 883, 'ECE69FF8-228D-4DFB-AA11-77A7A854398C', '2011-04-01 00:00:00.000'),
#  (180, 884, 'BA2F7F0D-24A2-4F73-A197-A57B40DC31D6', '2011-04-01 00:00:00.000'),
#  (181, 885, '36A68BDB-64F2-46F6-9DAC-C8621A2547D8', '2011-04-01 00:00:00.000'),
#  (182, 886, '843AE863-48A1-4E98-8F4B-8F20790372F6', '2011-04-01 00:00:00.000'),
#  (183, 887, 'EF822D3D-CA91-4ABA-B4CC-CCF9DD8692DD', '2011-04-01 00:00:00.000'),
#  (184, 888, '50D4F67F-B29F-49E4-A3E3-FC8A2B5C75E9', '2011-04-01 00:00:00.000'),
#  (185, 889, '2E75EDD3-4159-4167-AECD-593054BD5633', '2011-04-01 00:00:00.000'),
#  (186, 890, '3FFCBAE3-7C62-425B-A4B4-FA62E5418B53', '2011-04-01 00:00:00.000'),
#  (187, 891, '67FA261D-A132-4CB2-8F2E-75A22EBEA936', '2011-04-01 00:00:00.000'),
#  (188, 892, 'E5609DD6-ED8E-476A-860F-B7A199930EE2', '2011-04-01 00:00:00.000'),
#  (189, 893, '0321450F-E12A-4AAF-8557-F620AA007A0D', '2011-04-01 00:00:00.000'),
#  (190, 894, 'C2289842-1B49-4B64-B078-E9CC9620BE14', '2011-04-01 00:00:00.000'),
#  (191, 895, '4DDC5976-FFDD-44C6-A4A8-910C807D58EF', '2011-04-01 00:00:00.000'),
#  (192, 896, '9674B93E-902C-420D-9A59-C92C75EC26F2', '2011-04-01 00:00:00.000'),
#  (193, 897, 'C32171E5-C9AB-41B7-9F33-30D246341A00', '2011-04-01 00:00:00.000'),
#  (194, 898, 'A45298CD-763D-459F-8430-ED4BDE09DD94', '2011-04-01 00:00:00.000'),
#  (195, 899, '4342A7B3-891F-46CB-9FCA-5131EAD4CF73', '2011-04-01 00:00:00.000'),
#  (196, 900, 'AD58E169-56FA-4B9D-9969-812374E0D708', '2011-04-01 00:00:00.000'),
#  (197, 901, 'B404B9FB-84F0-43DE-AEE2-AD37909C2670', '2011-04-01 00:00:00.000'),
#  (198, 902, '88E8ED10-2088-4EA2-A595-14916242D9F4', '2011-04-01 00:00:00.000'),
#  (199, 903, '512DECE6-0FDF-405E-85F6-357A3AFBE17E', '2011-04-01 00:00:00.000'),
#  (200, 904, '5A5C4491-7C6E-4D7F-A4ED-DF77D376AE31', '2011-04-01 00:00:00.000'),
#  (201, 905, '05363824-5EB0-4C28-B7B0-18262CD6490F', '2011-04-01 00:00:00.000'),
#  (202, 906, 'C911E0EF-467B-4888-9A67-BF6F81645A62', '2011-04-01 00:00:00.000'),
#  (203, 907, 'A21F9C48-0C03-41B7-A943-DB14238BAD8E', '2011-04-01 00:00:00.000'),
#  (204, 908, '0AB9AECC-61E5-4A5A-BA33-B7E678F6D1E0', '2011-04-01 00:00:00.000'),
#  (205, 909, 'D119C9AD-6066-46D6-8B96-E44BDAAA6553', '2011-04-01 00:00:00.000'),
#  (206, 910, 'EC8E33E4-0ABA-4208-8FDF-0CB89B98DD8A', '2011-04-01 00:00:00.000'),
#  (207, 911, '796240C6-64B1-48F6-91E5-BF584FADB20D', '2011-04-01 00:00:00.000'),
#  (208, 912, '8AE0266B-004B-45BE-9D9D-33D12D81F4E4', '2011-04-01 00:00:00.000'),
#  (209, 913, '13DFEDE7-BB40-42EF-96FB-6CB3A5A7476D', '2011-04-01 00:00:00.000'),
#  (210, 914, '139E916E-E908-4442-8163-9ECFA42EEDDB', '2011-04-01 00:00:00.000'),
#  (211, 915, 'FCE4A2F8-643F-49C4-BD5F-31AA4B542F8D', '2011-04-01 00:00:00.000'),
#  (212, 916, 'B24A30EE-6EF0-4ADE-AC68-05BD2B0077B6', '2011-04-01 00:00:00.000'),
#  (213, 917, '216D8315-5527-4E73-A1C3-0D4F48641550', '2011-04-01 00:00:00.000'),
#  (214, 918, 'F4D2000D-5FE6-4AC9-A847-A31D033071E8', '2011-04-01 00:00:00.000'),
#  (215, 919, '277EC836-AD28-4BF2-A54D-0F1C05D75892', '2011-04-01 00:00:00.000'),
#  (216, 920, 'BF197561-1536-42B8-A9ED-A19836BAC351', '2011-04-01 00:00:00.000'),
#  (217, 921, 'FFE24AE4-9E46-4336-843F-D3C0EFBD09F8', '2011-04-01 00:00:00.000'),
#  (218, 922, '8E83B24E-FA2F-4DFF-8DB3-5D29A7F11598', '2011-04-01 00:00:00.000'),
#  (219, 923, 'E8F6EF53-26B0-4E3D-B276-C2FDA7949FFC', '2011-04-01 00:00:00.000'),
#  (220, 924, '5805AD46-3714-4904-AA76-5227A274CAEE', '2011-04-01 00:00:00.000'),
#  (221, 925, '1AD68C9C-48A0-4826-9686-094890E282DA', '2011-04-01 00:00:00.000'),
#  (222, 926, '7D5A2F59-E318-48F2-8B2C-526FD091614A', '2011-04-01 00:00:00.000'),
#  (223, 927, 'DC3EB2FB-985E-4D51-8ED6-B5B34F3CB6CD', '2011-04-01 00:00:00.000'),
#  (224, 928, '9124ECD0-B64E-4879-8E59-68B6823F0CE9', '2011-04-01 00:00:00.000'),
#  (225, 929, '4735F282-8A3E-4489-9356-CD28DF2A0173', '2011-04-01 00:00:00.000'),
#  (226, 930, 'E7AEC04B-D966-4235-B6B8-968966AD9763', '2011-04-01 00:00:00.000'),
#  (227, 931, '58E1ABBD-9926-4E12-8C0C-F96446A42D3F', '2011-04-01 00:00:00.000'),
#  (228, 932, '49EFF4C6-9560-4860-BA68-DAB5CFAA2200', '2011-04-01 00:00:00.000'),
#  (229, 933, '86F24C2A-108A-46AE-8C67-F26289571153', '2011-04-01 00:00:00.000'),
#  (230, 934, 'A316F6BF-5529-494D-BFDB-7E24DAAC823A', '2011-04-01 00:00:00.000'),
#  (231, 935, 'F34B9F39-0F7F-486D-97AA-2E76C21EAD48', '2011-04-01 00:00:00.000'),
#  (232, 936, '9FB71A15-3549-409A-8297-78E038B58545', '2011-04-01 00:00:00.000'),
#  (233, 937, '4CFC5A24-0305-454C-8C4F-A02E13BCB75C', '2011-04-01 00:00:00.000'),
#  (234, 938, 'BCDD293D-64A9-453F-BCCC-87A4B884F311', '2011-04-01 00:00:00.000'),
#  (235, 939, '38684803-60E5-471A-A5DC-F479C66523DD', '2011-04-01 00:00:00.000'),
#  (236, 940, '61811747-044C-4379-AD4F-876BE3FAC2F9', '2011-04-01 00:00:00.000'),
#  (237, 941, '01096D18-0E95-4940-95C2-E036FBCA2E0E', '2011-04-01 00:00:00.000'),
#  (238, 942, '6E5678FC-18BC-4CA4-82CF-A92E86570F6D', '2011-04-01 00:00:00.000'),
#  (239, 943, '88E86C7E-711A-49B4-A9DC-662D585A1FB7', '2011-04-01 00:00:00.000'),
#  (240, 944, 'D25125F3-5A80-4AEA-B6B0-40A0E0C1B86A', '2011-04-01 00:00:00.000'),
#  (241, 945, 'E01898AB-30B3-4D3D-9355-F8549584C9D7', '2011-04-01 00:00:00.000'),
#  (242, 946, '421B74C3-E6D6-465A-8A6B-60C3A5E45218', '2011-04-01 00:00:00.000'),
#  (243, 947, '92F44AEE-9667-4C65-A4E4-A78BE52FD033', '2011-04-01 00:00:00.000'),
#  (244, 948, 'B660A8D6-FE43-4EA2-9815-22D7475EF79C', '2011-04-01 00:00:00.000'),
#  (245, 949, '871A209A-7CBE-4C48-B5D9-49CD828C70F3', '2011-04-01 00:00:00.000'),
#  (246, 950, '6D4C232D-0753-48A9-B41E-889F3EC897C3', '2011-04-01 00:00:00.000'),
#  (247, 951, '00C21E7C-FD29-44D5-96C4-7DC75D83C0A3', '2011-04-01 00:00:00.000'),
#  (248, 952, '8166FB14-6B3D-4446-9390-1B46ED281310', '2011-04-01 00:00:00.000'),
#  (249, 953, 'F517D2F4-35BB-458E-8F9B-B8F2766DBE08', '2011-04-01 00:00:00.000'),
#  (250, 954, '2139D2AD-BA56-47D1-9273-8181E055ED1D', '2011-04-01 00:00:00.000'),
#  (251, 955, 'D8B9563C-C4AC-4280-891D-65F52F846249', '2011-04-01 00:00:00.000'),
#  (252, 956, '12892F65-077A-4163-8C10-9440C299E93E', '2011-04-01 00:00:00.000'),
#  (253, 957, 'C34A20A9-C0FC-497E-B9ED-F8533A27DF99', '2011-04-01 00:00:00.000'),
#  (254, 958, 'C2D8594E-599B-45D2-8876-FAD32A2B1BB4', '2011-04-01 00:00:00.000'),
#  (255, 959, 'E91C2832-06F7-47A1-BE1B-0181EE8C3B7E', '2011-04-01 00:00:00.000'),
#  (256, 960, '5FDAA339-AAFD-4BC4-AA78-94926ADAFC13', '2011-04-01 00:00:00.000'),
#  (257, 961, '35289DA6-3DAD-463C-B3E0-07E8146C1859', '2011-04-01 00:00:00.000'),
#  (258, 962, '5C034AA2-6F1A-43F4-9BEB-486D5770A7A5', '2011-04-01 00:00:00.000'),
#  (259, 963, 'E9E6AB9E-C425-4EBC-A7F2-740C43D57D59', '2011-04-01 00:00:00.000'),
#  (260, 964, 'A848379A-3438-465A-95EB-77D9AFD583F3', '2011-04-01 00:00:00.000'),
#  (261, 965, 'AC5D171F-11BB-4130-82BF-8E16F14D948B', '2011-04-01 00:00:00.000'),
#  (262, 966, 'DEDED0B9-5BF7-416E-9B9D-E316316274FD', '2011-04-01 00:00:00.000'),
#  (263, 967, 'F65A54E8-1399-422D-8912-5B3C77795B5F', '2011-04-01 00:00:00.000'),
#  (264, 968, 'CDCAC396-94F0-40AF-83C2-B8E393DB095C', '2011-04-01 00:00:00.000'),
#  (265, 969, '886476C5-D3F6-4340-BCE7-8911A896C899', '2011-04-01 00:00:00.000'),
#  (266, 970, 'F74EF6B1-7FB9-4F19-8881-3C3F0712187A', '2011-04-01 00:00:00.000'),
#  (267, 971, '8EC6AFAC-C0A3-4825-9978-BC3FAF6225E4', '2011-04-01 00:00:00.000'),
#  (268, 972, 'D652D9AD-6D41-4526-8E3B-2E19EC9E2550', '2011-04-01 00:00:00.000'),
#  (269, 973, '11089557-0C5B-4D65-96C6-DFBD32E50AD1', '2011-04-01 00:00:00.000'),
#  (270, 974, '416C7D99-588F-431A-8D22-1791E1130094', '2011-04-01 00:00:00.000'),
#  (271, 975, 'B33DB957-B4DF-4DEE-862A-BF63C1329884', '2011-04-01 00:00:00.000'),
#  (272, 976, 'D7D19687-493E-4919-9AE6-ADAA75F64AB0', '2011-04-01 00:00:00.000'),
#  (273, 977, 'ADA1F2D1-9375-427F-93A8-F333C9781199', '2011-04-01 00:00:00.000'),
#  (274, 978, 'D83AB13E-6C83-4D10-88E3-24A3A6BFAC89', '2011-04-01 00:00:00.000'),
#  (275, 979, '46C9E8F0-725E-4E97-8766-B39E90C3E8A4', '2011-04-01 00:00:00.000'),
#  (276, 980, '2B6664F4-64B8-4CF7-A549-0DB9772B1CF0', '2011-04-01 00:00:00.000'),
#  (277, 981, '32AA7C9C-7B5B-4777-9E6F-25AEC4830D63', '2011-04-01 00:00:00.000'),
#  (278, 982, 'C76260E4-72DE-4DFD-A969-921302134AE7', '2011-04-01 00:00:00.000'),
#  (279, 983, '3FBBC5C7-8506-4FA6-8BD1-C5E3CFDE5A72', '2011-04-01 00:00:00.000'),
#  (280, 984, '69A8565A-7991-4874-86D0-327C4F320755', '2011-04-01 00:00:00.000'),
#  (281, 985, '90A7F526-C1EA-41E4-9F96-130C94B08604', '2011-04-01 00:00:00.000'),
#  (282, 986, 'E8682657-7C58-4926-8606-4C358B7DB09D', '2011-04-01 00:00:00.000'),
#  (283, 987, 'EAEEB46D-01C2-4307-98C2-5E96DE25C684', '2011-04-01 00:00:00.000'),
#  (284, 988, '73CBC91E-5633-46ED-8635-4E06FE1560C8', '2011-04-01 00:00:00.000'),
#  (285, 989, '5CF6D1B5-DA76-491D-B514-ED5B5FEA572C', '2011-04-01 00:00:00.000'),
#  (286, 990, '5FA38631-F1D4-4B66-B93A-01E3141DDACE', '2011-04-01 00:00:00.000'),
#  (287, 991, '36AE12E0-4D4C-457D-AE97-18BA0475EC33', '2011-04-01 00:00:00.000'),
#  (288, 992, '3D56F896-E3D6-4A21-B617-31C51490E94D', '2011-04-01 00:00:00.000'),
#  (289, 993, '694F5070-923E-4232-8A80-F034E6B0CBB2', '2011-04-01 00:00:00.000'),
#  (290, 994, '0F2BE73D-8BB3-4461-8A5D-6A0C29F83241', '2011-04-01 00:00:00.000'),
#  (291, 995, '6AB429F1-8778-4C0E-B346-8E32346D4963', '2011-04-01 00:00:00.000'),
#  (292, 996, '7645F0DD-C620-48AB-A727-E8AD39AFDD56', '2011-04-01 00:00:00.000'),
#  (293, 997, '95F47129-3AB3-4E1C-ABD6-706113E285F7', '2011-04-01 00:00:00.000'),
#  (294, 998, '14AE71DA-6003-4B55-93E0-DCAA68A4F334', '2011-04-01 00:00:00.000'),
#  (295, 999, 'B2084244-90A4-4908-BC45-0F4FE01E7E22', '2011-04-01 00:00:00.000'),
#  (296, 707, 'CCA6DBA4-0483-4292-A44E-E1AA3B49F63C', '2011-05-01 00:00:00.000'),
#  (297, 708, '859A66B9-D4FA-44EF-8F5F-D5F2CEF35A50', '2011-05-01 00:00:00.000'),
#  (298, 709, 'BD95CAC4-C96B-411F-9BDB-83226AA5BEA4', '2011-05-01 00:00:00.000'),
#  (299, 711, '11166A91-5087-4C1E-B32A-D6FE4EAD9144', '2011-05-01 00:00:00.000'),
#  (300, 712, '94F10037-9F1A-47E1-A490-332DB0D30918', '2011-05-01 00:00:00.000'),
#  (301, 714, '7609C967-E0D0-485D-8E84-39CFE90106A8', '2011-05-01 00:00:00.000'),
#  (302, 715, '921A19C7-F31F-40E1-A8C4-F08EB77F67AD', '2011-05-01 00:00:00.000'),
#  (303, 716, '3796F39E-E0F7-4F48-88A6-4F971C10B351', '2011-05-01 00:00:00.000'),
#  (304, 725, '2A37D3F0-DE8A-491B-B8ED-E97617D19946', '2011-05-01 00:00:00.000'),
#  (305, 730, '50DEC893-F96A-428B-91CD-161D677ABD65', '2011-05-01 00:00:00.000'),
#  (306, 738, 'C670B74C-D37C-4BC5-B368-95BB3B9C5B11', '2011-05-01 00:00:00.000'),
#  (307, 748, '4E87F2C0-3E1E-430F-90EB-32E790C1C739', '2011-05-01 00:00:00.000'),
#  (308, 754, 'EFF3B406-75E6-49A2-B4EA-2255DB731514', '2011-05-01 00:00:00.000'),
#  (309, 760, '8077C273-D074-4A0E-82A4-052330BDE1A2', '2011-05-01 00:00:00.000'),
#  (310, 761, '2397F96E-2A43-44CD-B992-1B367D3B25AD', '2011-05-01 00:00:00.000'),
#  (311, 762, 'D2C85483-4FFC-4AF6-ABCA-4B92C56FF5C1', '2011-05-01 00:00:00.000'),
#  (312, 763, 'EE7562B5-BE42-408E-ABDA-628D27CCCA04', '2011-05-01 00:00:00.000'),
#  (313, 765, 'B886F443-3956-4C32-91CE-4CA998BF2B98', '2011-05-01 00:00:00.000'),
#  (314, 766, '420DD72D-5186-4EC1-8D95-25C02A6978B1', '2011-05-01 00:00:00.000'),
#  (315, 768, '759570EF-0D80-43FA-9B83-786CCBB4D5A8', '2011-05-01 00:00:00.000'),
#  (316, 770, '04020C5C-ABC7-48C8-8495-99362004551E', '2011-05-01 00:00:00.000'),
#  (317, 772, '1F491435-6E07-44C0-A7EB-57A8B23EAC11', '2011-05-01 00:00:00.000'),
#  (318, 773, 'E036A50F-07C2-4798-9E33-044FFC8E9107', '2011-05-01 00:00:00.000'),
#  (319, 775, '0AFDE120-913B-4FAD-8D98-63CBA5CEFE05', '2011-05-01 00:00:00.000'),
#  (320, 776, '2BE15DD8-B110-418A-B0EE-AC5F1A35B10B', '2011-05-01 00:00:00.000'),
#  (321, 777, '3D539D6C-DFBE-4839-ADCB-09B1D4D9235A', '2011-05-01 00:00:00.000'),
#  (322, 779, 'F743E371-0E9B-462F-A214-E0E541AF6E0D', '2011-05-01 00:00:00.000'),
#  (323, 780, '7D3E5CB5-0943-4C0F-8FC2-BE2CB8F69D56', '2011-05-01 00:00:00.000'),
#  (324, 781, 'A1896489-4925-4ABC-96C4-F66BA6F171C9', '2011-05-01 00:00:00.000'),
#  (325, 782, '1494A6E1-A73C-45DA-A6B8-CF1BD0B7A3D3', '2011-05-01 00:00:00.000'),
#  (326, 783, '65817836-B76A-44CF-9BD7-050E832C8D08', '2011-05-01 00:00:00.000'),
#  (327, 784, '5FB39C4B-2B7D-4B01-92AA-7730C25B3178', '2011-05-01 00:00:00.000'),
#  (328, 785, 'AFC7AC0D-8EC3-4143-BBC1-D0AB2FD21AC5', '2011-05-01 00:00:00.000'),
#  (329, 786, '386882AB-F552-4324-B2A1-5E82A6999769', '2011-05-01 00:00:00.000'),
#  (330, 788, '443988C4-6852-4510-877F-1E12F4846CA4', '2011-05-01 00:00:00.000'),
#  (331, 789, '7BF2ED5C-B2C4-4C2E-9732-7E1495A9D59C', '2011-05-01 00:00:00.000'),
#  (332, 790, '607A569B-8A5B-4A37-88D5-CB52F902DE47', '2011-05-01 00:00:00.000'),
#  (333, 793, '76A77EDA-AF12-4D5F-A83F-1BA721AFB513', '2011-05-01 00:00:00.000'),
#  (334, 794, '1F95169B-FB08-43A1-940B-852FA4E97FE6', '2011-05-01 00:00:00.000'),
#  (335, 797, 'F7E02A4E-AFF6-4655-944E-25EFD2880B37', '2011-05-01 00:00:00.000'),
#  (336, 798, '7903B768-D573-49C2-8007-82A466D112B2', '2011-05-01 00:00:00.000'),
#  (337, 801, 'A0F4DDEA-045C-4E59-9135-737D2D66F1C2', '2011-05-01 00:00:00.000'),
#  (338, 804, '9B7D807D-DB0E-4CE7-BD6E-1584BACBA995', '2011-05-01 00:00:00.000'),
#  (339, 806, '66742649-45AD-4719-B97E-ABD944D0001B', '2011-05-01 00:00:00.000'),
#  (340, 808, '26551B66-C6F4-4B79-ADFC-0EFD10BBEE13', '2011-05-01 00:00:00.000'),
#  (341, 809, '305320EA-4DDC-4F81-9E9E-ACDEED9D2861', '2011-05-01 00:00:00.000'),
#  (342, 815, '511AF135-4785-40D1-9544-64F9C37E78BC', '2011-05-01 00:00:00.000'),
#  (343, 824, 'F89A424B-7CF5-44C6-8DF8-4F86420AE061', '2011-05-01 00:00:00.000'),
#  (344, 825, '005D8818-0E25-4770-9A86-2B05371A5A1B', '2011-05-01 00:00:00.000'),
#  (345, 832, '71048253-685C-4738-B6FC-6DD88059D0A9', '2011-05-01 00:00:00.000'),
#  (346, 835, 'C23E000B-6E49-4C4B-9B77-F1CCE7841BBE', '2011-05-01 00:00:00.000'),
#  (347, 841, '125BCD14-FFF4-425F-990E-7227E6D33EBA', '2011-05-01 00:00:00.000'),
#  (348, 843, '34CFEC0C-AFE9-4370-B504-1375D5698086', '2011-05-01 00:00:00.000'),
#  (349, 844, 'A6FD3C8C-6FEE-41D9-9BA7-0AE9492E45A1', '2011-05-01 00:00:00.000'),
#  (350, 849, 'CA2EE297-2A8F-4108-BC3D-C7B7D3E42003', '2011-05-01 00:00:00.000'),
#  (351, 852, 'BCA372B9-0901-4C1D-8516-A526725C9B87', '2011-05-01 00:00:00.000'),
#  (352, 854, '076D7AE6-6AB7-4928-8987-18337709AF60', '2011-05-01 00:00:00.000'),
#  (353, 855, 'DE5F28FC-37B5-431E-A7BD-D14A11AB0043', '2011-05-01 00:00:00.000'),
#  (354, 856, '23E2646F-4852-49AB-B709-3AC663217D2C', '2011-05-01 00:00:00.000'),
#  (355, 858, '4837F43B-931B-4CD1-8DB9-43976C6BB66C', '2011-05-01 00:00:00.000'),
#  (356, 859, '143F9FAF-85CE-4470-B76A-5F55E3FCC3A2', '2011-05-01 00:00:00.000'),
#  (357, 860, 'A7801785-91B9-466C-91E4-7A41F447C36A', '2011-05-01 00:00:00.000'),
#  (358, 862, '7B838B44-9B4B-4268-B4C8-836A9022CAED', '2011-05-01 00:00:00.000'),
#  (359, 863, '1B0A1609-8E2E-4117-8066-CDF887A017DB', '2011-05-01 00:00:00.000'),
#  (360, 864, '2658A9D5-1554-49B3-9B01-5822067C9BAF', '2011-05-01 00:00:00.000'),
#  (361, 865, '434F2317-9479-41C8-B406-4AEEF32F73F8', '2011-05-01 00:00:00.000'),
#  (362, 867, '1941CFD2-1ACE-44D1-AD81-8DEF1DE5B99A', '2011-05-01 00:00:00.000'),
#  (363, 869, '8314CFC1-0EA8-4BC8-8D75-57DD6A36A4C4', '2011-05-01 00:00:00.000'),
#  (364, 870, '4B548FE0-1451-4A88-8A08-C460630E4C10', '2011-05-01 00:00:00.000'),
#  (365, 873, 'F26C5A40-AE7C-4DFC-8DBE-EA655743CDD6', '2011-05-01 00:00:00.000'),
#  (366, 874, '7EAEF32A-336F-41B8-8B55-CF8BE3BFDD80', '2011-05-01 00:00:00.000'),
#  (367, 875, 'FE624A90-9B5F-4287-8B14-9EEA867892AF', '2011-05-01 00:00:00.000'),
#  (368, 876, '3666A980-435C-4BEC-BB65-EB6C709A319D', '2011-05-01 00:00:00.000'),
#  (369, 877, '472196E8-98F3-4435-9A1A-046C9FB610D8', '2011-05-01 00:00:00.000'),
#  (370, 880, 'ECA76182-2851-46A6-AB9E-76FEDF5CD8A7', '2011-05-01 00:00:00.000'),
#  (371, 881, '6F0CBE39-F9D8-4C21-9DCC-F80CF5930C38', '2011-05-01 00:00:00.000'),
#  (372, 883, 'B3EC4738-468B-4426-A222-E01DD3B97680', '2011-05-01 00:00:00.000'),
#  (373, 884, '5D6308A2-E7FF-4C40-830D-A83CAD38F691', '2011-05-01 00:00:00.000'),
#  (374, 885, 'A5DA0FCC-4B07-4E82-AA52-5243DFB36777', '2011-05-01 00:00:00.000'),
#  (375, 889, '6B360A64-38D4-4481-802D-17499C267587', '2011-05-01 00:00:00.000'),
#  (376, 892, '7C2E3DFD-89DB-4E32-8301-B8F382E7826C', '2011-05-01 00:00:00.000'),
#  (377, 893, 'E05EA91B-82A8-4570-A572-2DB2BEFFDEE4', '2011-05-01 00:00:00.000'),
#  (378, 899, 'FFC1F8D0-F9C4-452B-A827-8DFBA61FE1A4', '2011-05-01 00:00:00.000'),
#  (379, 904, '40752BC7-0EFC-48AC-B6AD-80CB52A0AA32', '2011-05-01 00:00:00.000'),
#  (380, 908, 'F7809C83-F62E-4F38-8BC7-1D0C76AA35F8', '2011-05-01 00:00:00.000'),
#  (381, 909, 'AA76A900-D7FD-4EE7-9C4C-1750CEEDACEF', '2011-05-01 00:00:00.000'),
#  (382, 917, '6C8803F6-B56D-4033-B24B-55A2F2317F15', '2011-05-01 00:00:00.000'),
#  (383, 925, '2E115D4A-988D-462A-B034-33FA9FEA2367', '2011-05-01 00:00:00.000'),
#  (384, 937, '3AD2917F-2E0E-435F-98D7-F1E03CB88407', '2011-05-01 00:00:00.000'),
#  (385, 944, 'ACAA9E83-B670-4B6D-A826-30A76C4924E4', '2011-05-01 00:00:00.000'),
#  (386, 945, '311E3BD2-CF50-45BC-9385-D3CA59B404F0', '2011-05-01 00:00:00.000'),
#  (387, 948, '3978D7BC-5B59-4FDC-A77E-0D53FA7E2AE6', '2011-05-01 00:00:00.000'),
#  (388, 951, '2696B5B4-02C1-41AC-B976-BC4EA174EA60', '2011-05-01 00:00:00.000'),
#  (389, 952, '0D28AC46-7164-4507-9B33-1B8F75906734', '2011-05-01 00:00:00.000'),
#  (390, 953, '6AB947F6-5E2A-44C1-9984-B927800D6650', '2011-05-01 00:00:00.000'),
#  (391, 954, '077B559A-7A1D-41BD-A550-1DDCF82C6BFF', '2011-05-01 00:00:00.000'),
#  (392, 957, '33252F3C-CC82-41E7-8A5B-2D4F9595A7F1', '2011-05-01 00:00:00.000'),
#  (393, 961, '45233C6A-ACE4-4DB5-BDAD-B37FB35A3ACA', '2011-05-01 00:00:00.000'),
#  (394, 965, 'B517299A-0212-4E00-8C65-F6BB3185F148', '2011-05-01 00:00:00.000'),
#  (395, 966, 'A29DA87F-326C-4450-B1C6-87CB477A732F', '2011-05-01 00:00:00.000'),
#  (396, 969, 'E53D8624-A7A4-44EE-8C19-7936B5452581', '2011-05-01 00:00:00.000'),
#  (397, 970, '33F98549-2225-4557-865B-722A37134173', '2011-05-01 00:00:00.000'),
#  (398, 972, '592DAB8A-1C90-4609-9E0F-DC2DFE6F0C56', '2011-05-01 00:00:00.000'),
#  (399, 973, '500E425C-5F9F-40F4-8730-8383003936D8', '2011-05-01 00:00:00.000'),
#  (400, 974, 'F445BE01-2386-4FC2-A3CA-5C1052E48E76', '2011-05-01 00:00:00.000'),
#  (401, 976, '12460F83-1677-431A-B7CF-28A3A980B99F', '2011-05-01 00:00:00.000'),
#  (402, 979, '3BC8F1FE-4500-4545-8B25-922BE55DCFF9', '2011-05-01 00:00:00.000'),
#  (403, 981, '041CE039-CCB5-469B-B581-6F20D6011431', '2011-05-01 00:00:00.000'),
#  (404, 983, '9344F964-044A-48CE-A5F5-7130CC3B8EEE', '2011-05-01 00:00:00.000'),
#  (405, 998, 'AED3F29F-A5F1-4411-A37D-6D604C9D4F45', '2011-05-01 00:00:00.000'),
#  (406, 999, '4FF26A13-4806-4B51-94D3-D545DAEC7825', '2011-05-01 00:00:00.000'),
#  (407, 707, '5F32C413-EFD3-460C-9FDD-88F8504230F4', '2011-05-01 00:00:00.000'),
#  (408, 708, '50C8F56C-ACEE-4639-9E13-10D5FBD29C5C', '2011-05-01 00:00:00.000'),
#  (409, 709, '29B54CF5-A065-4C82-A321-6C328200DC93', '2011-05-01 00:00:00.000'),
#  (410, 711, 'DD280317-257F-47C8-BE06-29DF75B505CC', '2011-05-01 00:00:00.000'),
#  (411, 712, 'A35D29E0-58D0-416B-A724-285EC66304F7', '2011-05-01 00:00:00.000'),
#  (412, 714, 'B6BB40EE-1A7B-4DD9-967F-D80140FE5253', '2011-05-01 00:00:00.000'),
#  (413, 715, '0B7BA964-E788-4252-80EF-20A0684BDF79', '2011-05-01 00:00:00.000'),
#  (414, 760, 'CF66AC74-71CC-4E2C-A1B9-9254C492BC32', '2011-05-01 00:00:00.000'),
#  (415, 761, '920EED8B-BF82-401D-A0E5-CFD894582EE5', '2011-05-01 00:00:00.000'),
#  (416, 762, 'C7721B66-9CCB-4CE2-989F-6B3B8F80C19E', '2011-05-01 00:00:00.000'),
#  (417, 763, '8C9D89C6-5B82-4DC9-9A56-3730B344FE6A', '2011-05-01 00:00:00.000'),
#  (418, 765, 'AE7D5732-AD18-42D8-85EB-2A9F3653BDCA', '2011-05-01 00:00:00.000'),
#  (419, 770, 'AF086096-3F8B-4272-9041-4F2A3D459BBB', '2011-05-01 00:00:00.000'),
#  (420, 780, '0EC4E533-8225-4FE6-A9A3-BD7A0AF1D4A4', '2011-05-01 00:00:00.000'),
#  (421, 782, '1B1F3866-8078-440E-AA15-AD857553CCF7', '2011-05-01 00:00:00.000'),
#  (422, 783, 'F9D280F0-0081-4884-896D-95FF7EC520AB', '2011-05-01 00:00:00.000'),
#  (423, 789, '6165C1D9-BC2D-4CDB-A400-57265FB0D281', '2011-05-01 00:00:00.000'),
#  (424, 801, '18FC9478-B0E6-41CB-B0A7-CBE4CB9BACB8', '2011-05-01 00:00:00.000'),
#  (425, 806, 'A8E94C3D-54D7-4DBD-90B9-6C97D0D1865F', '2011-05-01 00:00:00.000'),
#  (426, 808, '17B7F5F3-3D75-4E42-A02A-1254E056AD22', '2011-05-01 00:00:00.000'),
#  (427, 824, '945CCFB9-D152-4A1B-A388-C8FFC03F3DF7', '2011-05-01 00:00:00.000'),
#  (428, 825, 'FE144D0A-26D0-4E26-A3C8-98681DA0A7E2', '2011-05-01 00:00:00.000'),
#  (429, 835, 'C33C4BEB-25E2-4C05-AF57-1FE1FD3B713B', '2011-05-01 00:00:00.000'),
#  (430, 849, '28CBD30C-9782-453A-BF80-DB5B06CD0684', '2011-05-01 00:00:00.000'),
#  (431, 852, '80E1FABB-7B30-433C-A78A-2164407C9585', '2011-05-01 00:00:00.000'),
#  (432, 854, '849F66E7-7AA7-45C8-8E61-FAABB1ADAC70', '2011-05-01 00:00:00.000'),
#  (433, 856, 'CE547656-EFD9-4649-B7A6-5CFC92E7D583', '2011-05-01 00:00:00.000'),
#  (434, 858, '6A1A5E22-1174-4751-9BF2-7ED80949F1AE', '2011-05-01 00:00:00.000'),
#  (435, 859, '9C3E1F5A-A4BB-4B8D-9AA1-40976B106CE3', '2011-05-01 00:00:00.000'),
#  (436, 862, '6BF85B37-C468-41C9-8F8B-E6D088856B2B', '2011-05-01 00:00:00.000'),
#  (437, 863, 'EBD91F48-7809-4949-B88D-DE3405FFA143', '2011-05-01 00:00:00.000'),
#  (438, 864, '2B1101FD-C6AE-4D7B-87AC-524685C79A87', '2011-05-01 00:00:00.000'),
#  (439, 865, '90130F12-EFEE-4C3B-B6CC-379234A3E51A', '2011-05-01 00:00:00.000'),
#  (440, 867, '086FBC66-DF6D-46CF-97D4-61A33573C505', '2011-05-01 00:00:00.000'),
#  (441, 869, '9EF691CE-15B7-469E-B772-619B53258E59', '2011-05-01 00:00:00.000'),
#  (442, 870, '4B657970-415A-4107-A78D-BF6FB4316981', '2011-05-01 00:00:00.000'),
#  (443, 875, 'A878FD99-4543-45B4-AFB3-CBDB2232CFE6', '2011-05-01 00:00:00.000'),
#  (444, 876, '2D0A5933-FD1A-4877-A8ED-D78349F13477', '2011-05-01 00:00:00.000'),
#  (445, 877, 'DF648321-DB4A-41F3-AC66-CFFAA561C24E', '2011-05-01 00:00:00.000'),
#  (446, 880, '0DF2DE48-6EFB-4AEE-8B1F-F7684625E0DC', '2011-05-01 00:00:00.000'),
#  (447, 881, 'DC11D5DA-2D55-478C-82F3-C612A5BF033F', '2011-05-01 00:00:00.000'),
#  (448, 883, 'F37D5E09-CDA8-47BD-A334-7829E557F058', '2011-05-01 00:00:00.000'),
#  (449, 884, 'A338943D-7C5D-47C7-97A1-A5B931F73123', '2011-05-01 00:00:00.000'),
#  (450, 886, 'EAC3AC1C-3D1A-4EF2-B2E0-83D86B7F4260', '2011-05-01 00:00:00.000'),
#  (451, 892, 'F30ACD94-2563-4817-8DAC-16452B145160', '2011-05-01 00:00:00.000'),
#  (452, 893, 'CFE810CE-610A-4131-9B65-ABE4AFFE6D9F', '2011-05-01 00:00:00.000'),
#  (453, 957, '4772E647-75B9-457A-8816-615096474376', '2011-05-01 00:00:00.000'),
#  (454, 966, '90C39E08-4171-425A-80A1-EFF5A5BA5C63', '2011-05-01 00:00:00.000'),
#  (455, 969, 'B6D475B4-D76D-4899-A9B4-3A7D4FA7230E', '2011-05-01 00:00:00.000'),
#  (456, 972, 'D8F8484F-D53B-470F-ABE6-6FD933109755', '2011-05-01 00:00:00.000'),
#  (457, 973, '02F8656C-0612-4AA2-BE91-1AB39847F276', '2011-05-01 00:00:00.000'),
#  (458, 974, '229D2375-2D78-4C6A-806B-0B359716A9F8', '2011-05-01 00:00:00.000'),
#  (459, 976, '0EEEA76A-5F20-4305-BD42-9277612E6C9E', '2011-05-01 00:00:00.000'),
#  (460, 979, 'C4C198E9-685A-4984-B8AD-9D45DD163B7E', '2011-05-01 00:00:00.000'),
#  (461, 998, 'FE9976C4-2B12-4F73-995A-2F407810BC3D', '2011-05-01 00:00:00.000'),
#  (462, 709, 'D0AB45EB-5451-4E87-A2B4-1F331788DC39', '2011-05-01 00:00:00.000'),
#  (463, 712, 'D633C207-8BA5-414D-87B5-8BA1FFBF9482', '2011-05-01 00:00:00.000'),
#  (464, 715, 'AA7929FF-9888-4D12-B9CB-A5326E2E8501', '2011-05-01 00:00:00.000'),
#  (465, 794, 'CE63A0FD-D375-4A30-8F2F-035DCA1D1AE5', '2011-05-01 00:00:00.000'),
#  (466, 852, '0471A4C0-C19D-4EF0-BE64-1E27BD6E7E69', '2011-05-01 00:00:00.000'),
#  (467, 862, 'D0A99995-AF29-47FF-984E-F694EB93A3CC', '2011-05-01 00:00:00.000'),
#  (468, 863, '0DEFBC2F-F6B5-4BC0-AEC0-971CA3D4FCE1', '2011-05-01 00:00:00.000'),
#  (469, 864, 'C0309837-0E2A-40BE-826C-627063DBA185', '2011-05-01 00:00:00.000'),
#  (470, 867, '386CA7AE-45C6-42F1-A654-CDDB10BC5C8E', '2011-05-01 00:00:00.000'),
#  (471, 869, 'ECE5A78F-804B-4610-89D7-4DA879CB9082', '2011-05-01 00:00:00.000'),
#  (472, 870, '7B95B3D9-69F9-462A-B610-E89E3E66C4D3', '2011-05-01 00:00:00.000'),
#  (473, 875, 'FE70F9BC-B3F6-44B0-896F-1BDAD5674B2A', '2011-05-01 00:00:00.000'),
#  (474, 876, '1AC1972E-B7E5-49FC-88AB-AC938590F955', '2011-05-01 00:00:00.000'),
#  (475, 877, '6138D258-1801-4E2B-B5EA-9BA1F3F4E8BB', '2011-05-01 00:00:00.000'),
#  (476, 884, '3930F7A8-3053-40C3-8088-9F082ABA327B', '2011-05-01 00:00:00.000'),
#  (477, 954, '5DE01F87-A8C7-4978-AD9B-5C63824D702A', '2011-05-01 00:00:00.000'),
#  (478, 976, 'E7366117-782D-4290-BF30-11C42BFE3E42', '2011-05-01 00:00:00.000'),
#  (479, 863, '64A60AE5-7214-4D31-A6F0-34C72F16E018', '2011-05-01 00:00:00.000'),
#  (480, 869, '58FE602F-F754-4EFC-BDFA-63D7571C1C24', '2011-05-01 00:00:00.000'),
#  (481, 771, 'EE509F88-CF3E-4CD7-ACAE-E68C4B924E66', '2012-03-14 00:00:00.000'),
#  (482, 772, 'FB4D2557-6B0C-4739-994B-7E4DC0DA5005', '2012-03-14 00:00:00.000'),
#  (483, 773, '25DCFFD9-DAC8-4AFF-918F-A96011A03607', '2012-03-14 00:00:00.000'),
#  (484, 774, 'B5C1F1B7-AE3A-433C-B1AC-B14A2676CF28', '2012-03-14 00:00:00.000'),
#  (485, 775, '59D27EEC-FA9F-46AE-A877-1FA28487FD69', '2012-03-14 00:00:00.000'),
#  (486, 776, '8A0B46A3-7336-4F9A-AA82-A90380E33572', '2012-03-14 00:00:00.000'),
#  (487, 777, 'F5171C6E-995D-49D8-86BD-A30878E0E05D', '2012-03-14 00:00:00.000'),
#  (488, 778, '0C1AFE3D-0CB5-47C4-9DDA-475570F278D6', '2012-03-14 00:00:00.000'),
#  (489, 707, '13302081-DE14-494E-8C18-BC6849760168', '2012-04-30 00:00:00.000'),
#  (490, 708, '4C95EB32-7858-4DB8-B9BF-D39CF3C8E269', '2012-04-30 00:00:00.000'),
#  (491, 711, 'F7676DEC-B06B-48AF-917E-7C39341E7F74', '2012-04-30 00:00:00.000'),
#  (492, 762, '0EE62DEA-0281-4512-89FF-C745A207C91B', '2012-04-30 00:00:00.000'),
#  (493, 928, 'DC836DA3-B45C-4CC8-9C17-45B84E9333DE', '2013-04-14 00:00:00.000'),
#  (494, 929, '400EE299-745C-4003-B59A-4142FC8CE0B1', '2013-04-14 00:00:00.000'),
#  (495, 930, '33713B2B-4275-4004-82E0-BAA66E63B095', '2013-04-14 00:00:00.000'),
#  (496, 707, 'AF988F8E-4FEC-4C77-9D51-C869C7CE2628', '2013-04-30 00:00:00.000'),
#  (497, 708, '3754699E-F05F-451B-BFAE-9CA15EBFC377', '2013-04-30 00:00:00.000'),
#  (498, 711, '9BF2C427-FF7E-4765-8BCB-7592F243F6E8', '2013-04-30 00:00:00.000'),
#  (499, 722, 'C5614BC8-BE1B-429E-A088-C460DA833113', '2013-04-30 00:00:00.000'),
#  (500, 723, 'DD5BE8A7-2EE6-4D2B-A2E3-D31630426106', '2013-04-30 00:00:00.000'),
#  (501, 724, 'D7D21F00-02FA-41BB-A300-7CA79E26D6EF', '2013-04-30 00:00:00.000'),
#  (502, 725, '2AF51035-AE0E-4B00-B513-A9F8DE6F0851', '2013-04-30 00:00:00.000'),
#  (503, 726, 'FBAEC2A3-59BA-495D-AAB5-87BC02F4D6E9', '2013-04-30 00:00:00.000'),
#  (504, 727, 'DFA49312-8AF0-40AD-B3C0-BBF77736D85E', '2013-04-30 00:00:00.000'),
#  (505, 728, '2AE19599-7A40-4FB6-9B5D-F85CCA827BED', '2013-04-30 00:00:00.000'),
#  (506, 729, 'B1AD17FD-24D8-4FB0-A821-6665B6BE9626', '2013-04-30 00:00:00.000'),
#  (507, 730, 'ADF3AEB6-ADF8-4D45-8B80-8A301489E74C', '2013-04-30 00:00:00.000'),
#  (508, 736, '49DCD015-844E-4B96-B819-84B0E46BD47A', '2013-04-30 00:00:00.000'),
#  (509, 737, '2D79385D-555C-4033-8083-3517D802F1A4', '2013-04-30 00:00:00.000'),
#  (510, 738, 'D58832BE-37F7-406E-9149-CDA313155EC2', '2013-04-30 00:00:00.000'),
#  (511, 958, '0D90D096-7D39-41AA-A5D7-AD4716605175', '2013-04-30 00:00:00.000'),
#  (512, 959, 'E592063B-BA98-4A38-83E0-1C55A1D4D26D', '2013-04-30 00:00:00.000'),
#  (513, 960, '4B0FBEE7-BF5E-4D32-9F70-F2AB236A3049', '2013-04-30 00:00:00.000'),
#  (514, 961, '436204C6-2266-4F99-9A32-97A0016AB189', '2013-04-30 00:00:00.000'),
#  (515, 962, 'DD1308B7-9972-479C-9E65-9143E5279CC0', '2013-04-30 00:00:00.000'),
#  (516, 963, '9B4278BD-6C79-454D-9BA1-9342F445106B', '2013-04-30 00:00:00.000'),
#  (517, 964, '69BE3FAF-96F4-4555-8015-167295621BFE', '2013-04-30 00:00:00.000'),
#  (518, 965, '2893EE65-7188-4613-A9C6-F6EF22AB063D', '2013-04-30 00:00:00.000'),
#  (519, 978, 'F324603B-4482-48A7-95A5-137D28F4C572', '2013-04-30 00:00:00.000'),
#  (520, 979, '680038C5-5C0B-4AC2-8D71-BD63F5DD04E3', '2013-04-30 00:00:00.000'),
#  (521, 954, '6C388B60-BA16-4162-A2A3-7571BC7940C8', '2013-04-30 00:00:00.000'),
#  (522, 955, '37C1C12C-AEAE-42CF-9F42-2B5D4BB7AF7D', '2013-04-30 00:00:00.000'),
#  (523, 956, '0A6D6E36-1708-44EC-9528-67BB8472FFC7', '2013-04-30 00:00:00.000'),
#  (524, 957, 'E9E679DB-0A94-429D-896B-353D08CACE47', '2013-04-30 00:00:00.000'),
#  (525, 935, 'E51B726D-274A-4A27-85BC-2148D4219E92', '2013-06-14 00:00:00.000'),
#  (526, 936, '09659C40-EE49-4D99-8A4E-EC09C366F383', '2013-06-14 00:00:00.000'),
#  (527, 937, '08A8EB19-1142-4E8E-BB80-38811E485200', '2013-06-14 00:00:00.000'),
#  (528, 938, 'FF93AC1F-49DC-4A67-9C96-9592CCE6D2B1', '2013-06-14 00:00:00.000'),
#  (529, 939, 'E91B2C2D-A400-4945-9CE0-A1D59063C3C6', '2013-06-14 00:00:00.000'),
#  (530, 940, 'A497D0BD-5CF4-46CB-A596-FAA6B28932F7', '2013-06-14 00:00:00.000'),
#  (531, 941, '339358CA-F265-460E-8510-CBC10388DF38', '2013-06-14 00:00:00.000'),
#  (532, 782, 'C643F9AE-F5C5-45B1-8D0B-E2BF4D78A315', '2014-03-01 00:00:00.000'),
#  (533, 784, 'EEF40E39-872F-45A1-81B0-50857E089A11', '2014-03-01 00:00:00.000'),
#  (534, 984, '52DD0F65-0EA9-4848-9884-7594BA953274', '2014-03-01 00:00:00.000'),
#  (535, 985, 'C8127A82-05C3-42FD-A5C6-215D58A236BD', '2014-03-01 00:00:00.000'),
#  (536, 986, 'C60FB28D-2431-481C-985E-3FEA8119D705', '2014-03-01 00:00:00.000'),
#  (537, 987, 'BEBD6F20-D6C2-4511-8C97-1F53B2099D1F', '2014-03-01 00:00:00.000'),
#  (538, 988, '2981C98B-A18F-4153-A6A2-EC453CB130CE', '2014-03-01 00:00:00.000')]

# %% [markdown]
# ## Ligacoes PK FK

# %%
# Primary Key para ProductID em ProductionProduct

query = 'ALTER TABLE ProductionProduct ADD PRIMARY KEY (ProductID)'

executar_sql(con,query)
# Out:
# Query executada com sucesso!

# %%
# Primary Key para BusinessEntityID em PersonPerson

query = 'ALTER TABLE PersonPerson ADD PRIMARY KEY (BusinessEntityID)'

executar_sql(con,query)
# Out:
# Query executada com sucesso!

# %%
# Primary Key para CustomerID em SalesCustomer

query = 'ALTER TABLE SalesCustomer ADD PRIMARY KEY (CustomerID)'

executar_sql(con,query)
# Out:
# Query executada com sucesso!

# %%
# Foreign Key na SalesSpecialOfferProduct vindo de ProductID em ProductionProduct 

query ='ALTER TABLE SalesSpecialOfferProduct \
        ADD CONSTRAINT fk_ProductionProduct FOREIGN KEY(ProductID) \
        REFERENCES ProductionProduct(ProductID)'

executar_sql(con,query)
# Out:
# Query executada com sucesso!

# %%
# Primary Key para SpecialOfferID em SalesSpecialOfferProduct
# Erro ao executar a Query! 1062 (23000): Duplicate entry '1' for key 'SalesSpecialOfferProduct.PRIMARY' (Resolvido) 

query = 'ALTER TABLE SalesSpecialOfferProduct ADD PRIMARY KEY (SpecialOfferID)'

executar_sql(con,query)
# Out:
# Query executada com sucesso!

# %%
# Primary Key para SalesOrderID em SalesSalesOrderHeader

query ='ALTER TABLE SalesSalesOrderHeader ADD PRIMARY KEY (SalesOrderID)'

executar_sql(con,query)
# Out:
# Query executada com sucesso!

# %%
# Primary Key para SalesOrderDetailID em SalesSalesOrderDetail

query ='ALTER TABLE SalesSalesOrderDetail ADD PRIMARY KEY (SalesOrderDetailID)'

executar_sql(con,query)
# Out:
# Query executada com sucesso!

# %%
# Foreign Key na SalesSalesOrderDetail vindo de SalesOrderID em SalesSalesOrderHeader 

query ='ALTER TABLE SalesSalesOrderDetail \
        ADD CONSTRAINT fk_SalesOrder FOREIGN KEY(SalesOrderID) \
        REFERENCES SalesSalesOrderHeader(SalesOrderID)'

executar_sql(con,query)
# Out:
# Query executada com sucesso!

# %% [markdown]
# ## Análise de dados - Querys

# %%
#1 Escreva uma query que retorna a quantidade de linhas na tabela Sales.SalesOrderDetail 
#  pelo campo SalesOrderID, desde que tenham pelo menos três linhas de detalhes. 

query = "SELECT SalesOrderID, COUNT(*) \
         FROM SalesSalesOrderDetail \
         GROUP BY SalesOrderID \
         HAVING COUNT(SalesOrderID) >= 3"

query1 = retorno_sql(con,query)
print(query1)
# Out:
# [(43659, 12), (43661, 15), (43662, 22), (43664, 8), (43665, 10), (43666, 6), (43667, 4), (43668, 29), (43670, 4), (43671, 11), (43672, 3), (43673, 11), (43675, 9), (43676, 5), (43677, 12), (43678, 19), (43679, 3), (43680, 15), (43681, 21), (43682, 5), (43683, 13), (43684, 6), (43685, 4), (43686, 3), (43688, 11), (43689, 21), (43690, 4), (43692, 28), (43693, 10), (43694, 11), (43695, 8), (43843, 10), (43844, 4), (43845, 10), (43846, 4), (43847, 3), (43848, 5), (43849, 11), (43850, 11), (43851, 12), (43853, 6), (43855, 13), (43857, 14), (43858, 13), (43859, 4), (43860, 12), (43861, 27), (43862, 9), (43863, 4), (43864, 9), (43865, 14), (43866, 3), (43867, 18), (43869, 10), (43870, 5), (43871, 14), (43872, 16), (43873, 28), (43875, 21), (43876, 8), (43877, 10), (43879, 26), (43880, 13), (43881, 8), (43883, 17), (43884, 22), (43886, 21), (43888, 14), (43890, 13), (43891, 9), (43892, 13), (43894, 7), (43895, 15), (43896, 5), (43897, 14), (43898, 28), (43899, 13), (43900, 9), (43901, 10), (43902, 20), (43904, 12), (43905, 11), (43906, 14), (43907, 22), (43908, 3), (43909, 9), (43910, 16), (43911, 15), (43912, 16), (43913, 12), (43914, 5), (43916, 14), (43917, 14), (44074, 3), (44075, 9), (44077, 8), (44078, 8), (44079, 27), (44081, 16), (44083, 4), (44085, 21), (44086, 21), (44089, 3), (44090, 13), (44091, 7), (44092, 8), (44093, 19), (44095, 9), (44097, 12), (44098, 6), (44099, 6), (44100, 21), (44101, 4), (44102, 5), (44103, 5), (44105, 4), (44107, 21), (44109, 15), (44110, 22), (44111, 19), (44112, 5), (44113, 15), (44114, 22), (44115, 19), (44116, 6), (44117, 16), (44118, 3), (44119, 11), (44120, 15), (44121, 14), (44124, 21), (44125, 3), (44126, 7), (44127, 22), (44128, 11), (44129, 30), (44130, 9), (44131, 10), (44133, 17), (44282, 15), (44283, 27), (44284, 16), (44285, 13), (44286, 6), (44287, 5), (44288, 34), (44289, 3), (44290, 4), (44292, 4), (44293, 25), (44294, 11), (44295, 9), (44296, 26), (44297, 8), (44298, 27), (44299, 27), (44300, 10), (44301, 27), (44304, 9), (44305, 15), (44306, 20), (44307, 9), (44308, 9), (44309, 18), (44311, 7), (44312, 4), (44313, 22), (44314, 23), (44315, 5), (44316, 6), (44317, 28), (44318, 6), (44319, 14), (44481, 7), (44483, 4), (44484, 5), (44487, 8), (44488, 27), (44489, 5), (44490, 7), (44491, 4), (44492, 19), (44493, 9), (44494, 26), (44495, 3), (44496, 19), (44498, 15), (44499, 4), (44500, 6), (44501, 20), (44502, 14), (44503, 4), (44504, 27), (44505, 8), (44506, 30), (44507, 13), (44508, 4), (44509, 32), (44511, 5), (44513, 16), (44514, 11), (44515, 7), (44517, 27), (44518, 20), (44520, 34), (44521, 26), (44522, 22), (44523, 17), (44524, 3), (44525, 27), (44526, 13), (44527, 5), (44528, 12), (44530, 22), (44531, 20), (44533, 20), (44534, 13), (44535, 14), (44538, 35), (44540, 16), (44541, 10), (44542, 7), (44544, 14), (44545, 8), (44547, 29), (44549, 12), (44550, 21), (44551, 15), (44552, 19), (44555, 22), (44556, 16), (44557, 21), (44559, 20), (44561, 10), (44562, 18), (44563, 28), (44564, 24), (44565, 4), (44566, 15), (44567, 12), (44568, 3), (44569, 15), (44570, 32), (44740, 9), (44742, 27), (44743, 8), (44744, 25), (44745, 15), (44746, 7), (44747, 9), (44749, 33), (44750, 24), (44751, 3), (44752, 9), (44753, 3), (44754, 14), (44755, 25), (44756, 17), (44757, 9), (44758, 27), (44759, 5), (44760, 4), (44761, 12), (44762, 21), (44763, 7), (44764, 3), (44765, 11), (44766, 4), (44767, 11), (44768, 26), (44770, 8), (44771, 32), (44772, 35), (44773, 23), (44774, 9), (44775, 4), (44776, 16), (44777, 20), (44778, 21), (44779, 9), (44780, 19), (44782, 21), (44783, 16), (44784, 4), (44787, 17), (44788, 14), (44791, 19), (44792, 11), (44793, 3), (44795, 20), (44796, 8), (44797, 32), (44798, 13), (44799, 10), (44800, 6), (44801, 26), (44802, 6), (45038, 15), (45039, 19), (45042, 7), (45043, 8), (45044, 6), (45045, 6), (45047, 26), (45048, 4), (45049, 5), (45050, 3), (45051, 3), (45052, 5), (45053, 17), (45054, 8), (45055, 17), (45056, 9), (45057, 17), (45058, 7), (45059, 17), (45060, 19), (450 ...

# %%
#2 Escreva uma query que ligue as tabelas Sales.SalesOrderDetail, Sales.SpecialOfferProduct e Production.Product e 
#  retorne os 3 produtos (Name) mais vendidos (pela soma de OrderQty), agrupados pelo número de dias para manufatura (DaysToManufacture).
 

query = 'SELECT ProductionProduct.Name, SUM(SalesSalesOrderDetail.OrderQty) AS TotalQty, ProductionProduct.DaysToManufacture \
          FROM SalesSpecialOfferProduct\
          JOIN SalesSalesOrderDetail \
            ON SalesSpecialOfferProduct.SpecialOfferID = SalesSalesOrderDetail.SpecialOfferID\
          JOIN ProductionProduct \
            ON ProductionProduct.ProductID = SalesSpecialOfferProduct.ProductID\
         GROUP BY ProductionProduct.Name, ProductionProduct.DaysToManufacture\
         ORDER BY TotalQty DESC LIMIT 3'

query2 = retorno_sql(con,query)
print(query2)
# Out:
# [('HL Road Frame - Black, 58', Decimal('238944'), 1), ('HL Road Frame - Red, 58', Decimal('18181'), 1), ('Sport-100 Helmet, Red', Decimal('10713'), 0)]

# %%
#3 Escreva uma query ligando as tabelas Person.Person, Sales.Customer e Sales.SalesOrderHeader 
#  de forma a obter uma lista de nomes de clientes e uma contagem de pedidos efetuados. 

query = 'SELECT PersonPerson.FirstName, PersonPerson.LastName, COUNT(SalesSalesOrderHeader.SalesOrderID) AS Qtd_Pedidos \
        FROM SalesCustomer\
        JOIN PersonPerson ON SalesCustomer.PersonID = PersonPerson.BusinessEntityID\
        JOIN SalesSalesOrderHeader ON SalesCustomer.CustomerID = SalesSalesOrderHeader.CustomerID\
        GROUP BY PersonPerson.FirstName, PersonPerson.LastName\
        ORDER BY Qtd_Pedidos DESC'

query3 = retorno_sql(con,query)
print(query3)
# Out:
# [('Dalton', 'Perez', 28), ('Mason', 'Roberts', 28), ('Nancy', 'Chapman', 27), ('Henry', 'Garcia', 27), ('Hailey', 'Patterson', 27), ('Fernando', 'Barnes', 27), ('Charles', 'Jackson', 27), ('Daniel', 'Davis', 27), ('Jason', 'Griffin', 27), ('Samantha', 'Jenkins', 27), ('Ryan', 'Thompson', 27), ('Ashley', 'Henderson', 27), ('Jennifer', 'Simmons', 27), ('April', 'Shan', 25), ('Chloe', 'Campbell', 17), ('Samantha', 'Russell', 17), ('Luke', 'Lal', 17), ('Eduardo', 'Patterson', 17), ('Ana', 'Perry', 17), ('Gina', 'Martin', 17), ('Luis', 'Diaz', 17), ('Andrew', 'Martinez', 16), ('Jared', 'Peterson', 16), ('Alexandra', 'Jenkins', 16), ('Sarah', 'Simmons', 16), ('Antonio', 'Bennett', 16), ('Sierra', 'Young', 16), ('Isabella', 'Russell', 16), ('Jasmine', 'Powell', 16), ('Jada', 'Morgan', 16), ('Arturo', 'Sun', 16), ('José', 'Hernandez', 16), ('Nicholas', 'Brown', 16), ('Jerome', 'Navarro', 16), ('Brandy', 'Chandra', 16), ('Roger', 'Harui', 13), ('Sunil', 'Uppal', 13), ('James', 'Hendergart', 12), ('Jauna', 'Elson', 12), ('Robin', 'McGuigan', 12), ('Richard', 'Bready', 12), ('Ryan', 'Calafato', 12), ('Phyllis', 'Thomas', 12), ('Nancy', 'Hirota', 12), ('Valerie', 'Hendricks', 12), ('Mark', 'Hanson', 12), ('Susan', 'French', 12), ('Frances', 'Adams', 12), ('François', 'Ferrier', 12), ('Stacey', 'Cereghino', 12), ('Douglas', 'Baldwin', 12), ('Michael', 'Blythe', 12), ('Sandra', 'Maynard', 12), ('David', 'Liu', 12), ('Joan', 'Campbell', 12), ('Brannon', 'Jones', 12), ('Josh', 'Barnhill', 12), ('Michael', 'Allen', 12), ('Lucio', 'Iallo', 12), ('Robert', 'Vessa', 12), ('Gabriel', 'Bockenkamp', 12), ('Margaret', 'Vanderkamp', 12), ('Aaron', 'Con', 12), ('Diane', 'Tibbott', 12), ('Brian', 'Goldstein', 12), ('Bernard', 'Duerr', 12), ('Garth', 'Fort', 12), ('Jacob', 'Dean', 12), ('Blaine', 'Dockter', 12), ('Thomas', 'Armstrong', 12), ('Della', 'Demott Jr', 12), ('Samuel', 'Johnson', 12), ('John', 'Kelly', 12), ('Douglas', 'Hite', 12), ('John', 'Arthur', 12), ('Carla', 'Eldridge', 12), ('Spencer', 'Low', 12), ('Lindsey', 'Camacho', 12), ('Tom', 'Johnston', 12), ('Kevin', 'Browne', 12), ('Rudolph', 'Dillon', 12), ('Yale', 'Li', 12), ('Hattie', 'Haemon', 12), ('Joseph', 'Castellucio', 12), ('Reuben', "D'sa", 12), ('Lee', 'Chapla', 12), ('Kay', 'Krane', 12), ('Conor', 'Cunningham', 12), ('Gary', 'Drury', 12), ('Lester', 'Bowman', 12), ('Kim', 'Abercrombie', 12), ('Frank', 'Campbell', 12), ('Pamela', 'Cox', 12), ('Cheryl', 'Herring', 12), ('Aidan', 'Delaney', 12), ('Donna', 'Carreras', 12), ('Jean', 'Handley', 12), ('Richard', 'Lum', 12), ('Andrew', 'Dixon', 12), ('Dylan', 'Miller', 12), ('Gloria', 'Lesko', 11), ('Ruby Sue', 'Styles', 11), ('Helen', 'Lutes', 11), ('Oscar', 'Alpuerto', 11), ('Humberto', 'Acevedo', 11), ('Eric', 'Meyer', 11), ('Melissa', 'Marple', 11), ('Jeanette', 'Cole', 11), ('Cory', 'Booth', 11), ('Karren', 'Burkhardt', 10), ('John', 'Long', 10), ('Linda', 'Burnett', 10), ('Kari', 'Hensien', 10), ('Henry', 'Campen', 10), ('Mike', 'Hines', 10), ('Willie', 'Brooks', 10), ('Marvin', 'Allen', 10), ('Matthew', 'Miller', 10), ('Carolyn', 'Farino', 9), ('Brenda', 'Heaney', 9), ('Run', 'Liu', 9), ('Sandra', 'Kitt', 9), ('John', 'Berger', 9), ('David', 'Johnson', 9), ('Samuel', 'Agcaoili', 9), ('Sara', 'Breer', 9), ('Elizabeth', 'Catalano', 9), ('Mary', 'Vaca', 9), ('Andrew', 'Kobylinski', 9), ('Jordan', 'Turner', 9), ('Jimmy', 'Bischoff', 8), ('Peggy', 'Justice', 8), ('Jean', 'Jordan', 8), ('Abe', 'Tramel', 8), ('John', 'Donovan', 8), ('Shane', 'Belli', 8), ('Steve', 'Masters', 8), ('Linda', 'Leste', 8), ('Dorothy', 'Contreras', 8), ('Yuping', 'Tian', 8), ('John', 'Ford', 8), ('Stefan', 'Delmarco', 8), ('Lynn', 'Tsoflias', 8), ('Maxwell', 'Amland', 8), ('Phyllis', 'Allen', 8), ('Juanita', 'Holman', 8), ('Michael', 'Vanderhyde', 8), ('Martha', 'Espinoza', 8), ('Pat', 'Chambers', 8), ('Fadi', 'Fakhouri', 8), ('Kim', 'Akers', 8), ('Steven', 'Brown', 8), ('Scott', 'Cooper', 8), ('Mike', 'Taylor', 8), ('Payton', 'Benson', 8), ('Robert', 'Stotka', ...

# %%
#4 Escreva uma query usando as tabelas Sales.SalesOrderHeader, Sales.SalesOrderDetail e Production.Product, 
#  de forma a obter a soma total de produtos (OrderQty) por ProductID e OrderDate.

query = 'SELECT SalesSalesOrderDetail.ProductID, \
                SUM(SalesSalesOrderDetail.OrderQty) AS OrderQty, \
                SalesSalesOrderHeader.OrderDate \
          FROM SalesSalesOrderHeader\
          JOIN SalesSalesOrderDetail \
            ON SalesSalesOrderHeader.SalesOrderID = SalesSalesOrderDetail.SalesOrderID\
          JOIN ProductionProduct \
            ON ProductionProduct.ProductID = SalesSalesOrderDetail.ProductID\
        GROUP BY SalesSalesOrderDetail.ProductID, SalesSalesOrderHeader.OrderDate\
        ORDER BY OrderQty DESC'

query4 = retorno_sql(con,query)
print(query4)
# Out:
# [(864, Decimal('498'), '2013-06-30 00:00:00.000'), (864, Decimal('465'), '2013-07-31 00:00:00.000'), (884, Decimal('444'), '2013-06-30 00:00:00.000'), (867, Decimal('427'), '2013-06-30 00:00:00.000'), (864, Decimal('424'), '2014-03-31 00:00:00.000'), (884, Decimal('420'), '2013-07-31 00:00:00.000'), (712, Decimal('415'), '2013-06-30 00:00:00.000'), (863, Decimal('409'), '2012-06-30 00:00:00.000'), (715, Decimal('406'), '2013-06-30 00:00:00.000'), (876, Decimal('397'), '2013-07-31 00:00:00.000'), (864, Decimal('383'), '2014-05-01 00:00:00.000'), (864, Decimal('383'), '2013-09-30 00:00:00.000'), (864, Decimal('380'), '2013-10-30 00:00:00.000'), (869, Decimal('374'), '2013-07-31 00:00:00.000'), (712, Decimal('363'), '2013-07-31 00:00:00.000'), (876, Decimal('363'), '2013-06-30 00:00:00.000'), (863, Decimal('358'), '2013-03-30 00:00:00.000'), (863, Decimal('357'), '2012-05-30 00:00:00.000'), (867, Decimal('356'), '2013-07-31 00:00:00.000'), (715, Decimal('354'), '2013-07-31 00:00:00.000'), (870, Decimal('350'), '2013-06-30 00:00:00.000'), (863, Decimal('347'), '2012-07-31 00:00:00.000'), (712, Decimal('345'), '2012-06-30 00:00:00.000'), (877, Decimal('339'), '2013-06-30 00:00:00.000'), (869, Decimal('338'), '2013-06-30 00:00:00.000'), (715, Decimal('334'), '2012-06-30 00:00:00.000'), (864, Decimal('333'), '2013-05-30 00:00:00.000'), (863, Decimal('331'), '2012-09-30 00:00:00.000'), (884, Decimal('329'), '2013-09-30 00:00:00.000'), (875, Decimal('322'), '2013-06-30 00:00:00.000'), (880, Decimal('319'), '2013-06-30 00:00:00.000'), (884, Decimal('317'), '2013-05-30 00:00:00.000'), (883, Decimal('316'), '2013-06-30 00:00:00.000'), (715, Decimal('313'), '2013-09-30 00:00:00.000'), (870, Decimal('304'), '2013-07-31 00:00:00.000'), (883, Decimal('304'), '2013-07-31 00:00:00.000'), (884, Decimal('303'), '2014-03-31 00:00:00.000'), (711, Decimal('302'), '2013-06-30 00:00:00.000'), (884, Decimal('300'), '2013-10-30 00:00:00.000'), (865, Decimal('298'), '2013-06-30 00:00:00.000'), (884, Decimal('298'), '2014-05-01 00:00:00.000'), (712, Decimal('296'), '2013-09-30 00:00:00.000'), (867, Decimal('295'), '2013-09-30 00:00:00.000'), (876, Decimal('294'), '2013-09-30 00:00:00.000'), (707, Decimal('292'), '2013-07-31 00:00:00.000'), (864, Decimal('291'), '2013-08-30 00:00:00.000'), (876, Decimal('291'), '2014-03-31 00:00:00.000'), (852, Decimal('287'), '2012-06-30 00:00:00.000'), (867, Decimal('284'), '2014-03-31 00:00:00.000'), (859, Decimal('283'), '2013-07-31 00:00:00.000'), (708, Decimal('281'), '2013-07-31 00:00:00.000'), (708, Decimal('281'), '2013-06-30 00:00:00.000'), (859, Decimal('280'), '2013-06-30 00:00:00.000'), (877, Decimal('279'), '2013-07-31 00:00:00.000'), (870, Decimal('279'), '2014-03-31 00:00:00.000'), (863, Decimal('275'), '2012-10-30 00:00:00.000'), (862, Decimal('274'), '2012-06-30 00:00:00.000'), (854, Decimal('273'), '2012-06-30 00:00:00.000'), (715, Decimal('273'), '2012-07-31 00:00:00.000'), (880, Decimal('269'), '2013-07-31 00:00:00.000'), (865, Decimal('268'), '2013-07-31 00:00:00.000'), (711, Decimal('266'), '2013-07-31 00:00:00.000'), (869, Decimal('264'), '2014-03-31 00:00:00.000'), (867, Decimal('264'), '2014-05-01 00:00:00.000'), (712, Decimal('263'), '2014-03-31 00:00:00.000'), (869, Decimal('263'), '2013-09-30 00:00:00.000'), (863, Decimal('262'), '2012-12-31 00:00:00.000'), (876, Decimal('260'), '2013-10-30 00:00:00.000'), (712, Decimal('259'), '2013-05-30 00:00:00.000'), (867, Decimal('258'), '2013-10-30 00:00:00.000'), (883, Decimal('257'), '2014-05-01 00:00:00.000'), (870, Decimal('256'), '2013-10-30 00:00:00.000'), (715, Decimal('256'), '2013-05-30 00:00:00.000'), (864, Decimal('256'), '2014-01-29 00:00:00.000'), (862, Decimal('254'), '2012-07-31 00:00:00.000'), (876, Decimal('253'), '2014-05-01 00:00:00.000'), (870, Decimal('251'), '2013-09-30 00:00:00.000'), (712, Decimal('251'), '2013-10-30 00:00:00.000'), (869, Decimal('246'), '2014-05-01 00:00:00.000'), (864, Decimal('246'), '2014-03-01 00:00:00.000'), ...

# %%
#5 Escreva uma query mostrando os campos SalesOrderID, OrderDate e TotalDue da tabela Sales.SalesOrderHeader. 
#  Obtenha apenas as linhas onde a ordem tenha sido feita durante o mês de setembro/2011 e o total devido esteja acima de 1.000. 
#  Ordene pelo total devido decrescente.

query = "SELECT SalesOrderID, OrderDate, ROUND(TotalDue , 2) AS Total_devido \
        FROM SalesSalesOrderHeader \
          WHERE OrderDate \
          BETWEEN '2011-09-01' AND '2011-09-30' AND TotalDue > 1000 \
        ORDER BY TotalDue DESC"

query5 = retorno_sql(con,query)
print(query5)
# Out:
# [(44324, '2011-09-01 00:00:00.000', 3953.0), (44478, '2011-09-29 00:00:00.000', 3953.0), (44326, '2011-09-01 00:00:00.000', 3953.0), (44327, '2011-09-02 00:00:00.000', 3953.0), (44328, '2011-09-02 00:00:00.000', 3953.0), (44329, '2011-09-02 00:00:00.000', 3953.0), (44330, '2011-09-02 00:00:00.000', 3953.0), (44331, '2011-09-03 00:00:00.000', 3953.0), (44332, '2011-09-03 00:00:00.000', 3953.0), (44477, '2011-09-29 00:00:00.000', 3953.0), (44334, '2011-09-04 00:00:00.000', 3953.0), (44476, '2011-09-29 00:00:00.000', 3953.0), (44473, '2011-09-29 00:00:00.000', 3953.0), (44338, '2011-09-04 00:00:00.000', 3953.0), (44339, '2011-09-04 00:00:00.000', 3953.0), (44340, '2011-09-04 00:00:00.000', 3953.0), (44472, '2011-09-29 00:00:00.000', 3953.0), (44343, '2011-09-05 00:00:00.000', 3953.0), (44344, '2011-09-06 00:00:00.000', 3953.0), (44345, '2011-09-06 00:00:00.000', 3953.0), (44347, '2011-09-06 00:00:00.000', 3953.0), (44348, '2011-09-07 00:00:00.000', 3953.0), (44349, '2011-09-07 00:00:00.000', 3953.0), (44350, '2011-09-07 00:00:00.000', 3953.0), (44351, '2011-09-07 00:00:00.000', 3953.0), (44352, '2011-09-07 00:00:00.000', 3953.0), (44470, '2011-09-28 00:00:00.000', 3953.0), (44469, '2011-09-28 00:00:00.000', 3953.0), (44357, '2011-09-07 00:00:00.000', 3953.0), (44358, '2011-09-07 00:00:00.000', 3953.0), (44359, '2011-09-08 00:00:00.000', 3953.0), (44360, '2011-09-08 00:00:00.000', 3953.0), (44361, '2011-09-08 00:00:00.000', 3953.0), (44362, '2011-09-08 00:00:00.000', 3953.0), (44363, '2011-09-08 00:00:00.000', 3953.0), (44464, '2011-09-28 00:00:00.000', 3953.0), (44365, '2011-09-08 00:00:00.000', 3953.0), (44366, '2011-09-08 00:00:00.000', 3953.0), (44368, '2011-09-09 00:00:00.000', 3953.0), (44369, '2011-09-09 00:00:00.000', 3953.0), (44370, '2011-09-09 00:00:00.000', 3953.0), (44371, '2011-09-09 00:00:00.000', 3953.0), (44372, '2011-09-09 00:00:00.000', 3953.0), (44373, '2011-09-10 00:00:00.000', 3953.0), (44374, '2011-09-10 00:00:00.000', 3953.0), (44375, '2011-09-10 00:00:00.000', 3953.0), (44462, '2011-09-28 00:00:00.000', 3953.0), (44377, '2011-09-10 00:00:00.000', 3953.0), (44461, '2011-09-27 00:00:00.000', 3953.0), (44459, '2011-09-27 00:00:00.000', 3953.0), (44380, '2011-09-10 00:00:00.000', 3953.0), (44381, '2011-09-11 00:00:00.000', 3953.0), (44458, '2011-09-27 00:00:00.000', 3953.0), (44383, '2011-09-11 00:00:00.000', 3953.0), (44384, '2011-09-11 00:00:00.000', 3953.0), (44385, '2011-09-11 00:00:00.000', 3953.0), (44386, '2011-09-11 00:00:00.000', 3953.0), (44457, '2011-09-27 00:00:00.000', 3953.0), (44388, '2011-09-11 00:00:00.000', 3953.0), (44389, '2011-09-11 00:00:00.000', 3953.0), (44390, '2011-09-11 00:00:00.000', 3953.0), (44391, '2011-09-11 00:00:00.000', 3953.0), (44392, '2011-09-11 00:00:00.000', 3953.0), (44455, '2011-09-26 00:00:00.000', 3953.0), (44394, '2011-09-12 00:00:00.000', 3953.0), (44395, '2011-09-12 00:00:00.000', 3953.0), (44454, '2011-09-26 00:00:00.000', 3953.0), (44398, '2011-09-12 00:00:00.000', 3953.0), (44399, '2011-09-13 00:00:00.000', 3953.0), (44400, '2011-09-13 00:00:00.000', 3953.0), (44401, '2011-09-13 00:00:00.000', 3953.0), (44402, '2011-09-14 00:00:00.000', 3953.0), (44453, '2011-09-26 00:00:00.000', 3953.0), (44404, '2011-09-15 00:00:00.000', 3953.0), (44405, '2011-09-15 00:00:00.000', 3953.0), (44406, '2011-09-15 00:00:00.000', 3953.0), (44451, '2011-09-26 00:00:00.000', 3953.0), (44450, '2011-09-26 00:00:00.000', 3953.0), (44410, '2011-09-16 00:00:00.000', 3953.0), (44411, '2011-09-16 00:00:00.000', 3953.0), (44449, '2011-09-26 00:00:00.000', 3953.0), (44413, '2011-09-17 00:00:00.000', 3953.0), (44414, '2011-09-17 00:00:00.000', 3953.0), (44415, '2011-09-17 00:00:00.000', 3953.0), (44448, '2011-09-26 00:00:00.000', 3953.0), (44417, '2011-09-17 00:00:00.000', 3953.0), (44418, '2011-09-17 00:00:00.000', 3953.0), (44419, '2011-09-17 00:00:00.000', 3953.0), (44420, '2011-09-17 00:00:00.000', 3953.0), (44421, '2011-09-18 00:00:00.000', 3953.0), (44423, '2011-09-18 00:00:00.000', 3953 ...

# %% [markdown]
# ## Salvando os dados na pasta TRUSTED

# %%
dfssave = [
          df_Person,
          df_Product,
          df_Customer,
          df_SalesOrderDetail,
          df_SalesOrderHeader,
          df_SpecialOfferProduct]

name_save = [
          'Person.Person',
          'Production.Product',
          'Sales.Customer',
          'Sales.SalesOrderDetail',
          'Sales.SalesOrderHeader',
          'Sales.SpecialOfferProduct'

]

for i in range(len(dfssave)):
  dfssave[i].to_csv(f'gs://desafio-rox-leandro/TRUSTED/{name_save[i]}.trusted.csv', index=False)
